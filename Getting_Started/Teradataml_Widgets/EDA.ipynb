# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Exploring Data Analysis using Teradataml Widgets
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;'><b>Introduction</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;margin-bottom:0'> The Exploratory Data Analysis (EDA) UI allows the user to take a deeper look into their dataset. The tabs include Data, Analyze, Visualize, Describe, and Persist.
# This provides  visual components for scaled, in-Database Analytics with data that you keep in the Teradata Vantage Analytics Database within a notebook.</p>
#
# <ul style = 'font-size:16px;font-family:Arial;'>
#     <li> <strong>Data:</strong> DataFrame</li>
#     <ul style = 'font-size:16px;font-family:Arial;'>
#         <li>A select subset of the DataFrame.</li>
#     </ul>
# </ul>
# <ul style = 'font-size:16px;font-family:Arial;'>
#     <li><strong>Visualize:</strong> Utilizing TD_PLOT function for visualizations</li>
#     <ul style = 'font-size:16px;font-family:Arial;'>
#         <li>Plot and visualize the DataFrames.</li>
#     </ul>
# </ul>
# <ul style = 'font-size:16px;font-family:Arial;'>
#     <li><strong>Analyze:</strong> Access and execute analytic functions that reside in the Teradata Vantage Analytics Database </li>
#     <ul style = 'font-size:16px;font-family:Arial;'>
#         <li>A select subset of the Analytics Database analytic functions.</li>
#         <li>The entire Vantage Analytics Library (VAL) functions set.</li>
#         <li>The Unbounded Array Framework (UAF) time series functions.</li>
#         <li>AutoML.</li>
#     </ul>
# </ul>
# <ul style = 'font-size:16px;font-family:Arial;'>
#     <li><strong>Describe:</strong> DataFrame description and information</li>
#     <ul style = 'font-size:16px;font-family:Arial;'>
#         <li>Shape and Size, Column Statistics, Column Types, Column Summary, Categorical Summary, Futile Columns and Source Query.</li>
#     </ul>
# </ul>
# <ul style = 'font-size:16px;font-family:Arial;'>
#     <li><strong>Persist:</strong> Writes records stored in a teradataml DataFrame to Teradata Vantage</li>
#     <ul style = 'font-size:16px;font-family:Arial;'>
#         <li>Output, Column Type, Primary Time Index tabs</li>
#     </ul>
# </ul>

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style = 'font-size:20px;font-family:Arial;'><b>Import the required Libraries</b></p>

# %%
from teradataml import *
import getpass

# %% [markdown]
# <hr style='height:2px;border:none;'>
#
# <p style='font-size:18px;font-family:Arial;'><b>Connect to Vantage</b></p>
# <p style = 'font-size:16px;font-family:Arial'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
# %run -i /home/jovyan/JupyterLabRoot/UseCases/startup.ipynb
eng = create_context(host = 'host.docker.internal', username = 'demo_user', password = password)
print(eng)

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style = 'font-size:20px;font-family:Arial;margin-bottom:0'><b>Load the Example Data and Analyze</b></p>
# <p style = 'font-size:16px;font-family:Arial;'>Use <code>load_example_data()</code> to import example datasets into our database using <b>teradataml</b>.

# %%
# Load the example data.
load_example_data("movavg", "ibm_stock")

# %%
# %run -i /home/jovyan/JupyterLabRoot/UseCases/run_procedure.py "call get_data('DEMO_Financial_cloud');"

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;'><b>Create a DataFrame</b></p>
# <p style = 'font-size:16px;font-family:Arial;'>By setting the DataFrame and calling it, the EDA UI will appear with 5 different tabs:<br> (Data, Describe, Visualize, Analyze, and Persist).</p>

# %%
df = DataFrame("ibm_stock")
df

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;'>As mentioned in the introduction, data tab displays the data in the dataframe.<br> The describe tab displays the statistics of the data, which can be called as below also./p>

# %%
from teradatamlwidgets import describe
ui = describe.Ui(df = df)

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;'><b>Analyze and View the Pipeline</b></p>
# <p style = 'font-size:16px;font-family:Arial;'>Pipelining is possible within the <b>Analyze</b> tab.
# <ol style = 'font-size:16px;font-family:Arial;bottom-margin:0'>
#     <li>Click on the <b>Analyze</b> tab</li>
#     <li>In the <b>Function</b> section, click in the <i>Select a function</i> and choose "<b>Linear Regression"</b> from the drop-down list</li>
#     <li>This will open another section. In the <b>Required</b> tab, click in the selector for <i>Inputcolumns</i> and select "age", "years_with_bank", and "nbr_children". For *Response Column* choose "income"</li>
# <li>Click <b>Execute</b> button</li>
# <li>Click <b>Add to Pipeline</b> button</li>
# <li>Type in and choose "<b>Linear Regression Predict</b>"</li>
#     <li>Under Optional tab for <i>Index Columns</i> select "age", "years_with_bank". For *Response Column* choose "income". For *Acumulate* choose "nbr_children"</li>
# <li>Click <b>Execute</b> button</li>

# %%
df = DataFrame(in_schema("DEMO_Financial", "Customer"))
df

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;'><b>Analyze Tab - Access Output DataFrame</b></p>
# <p style = 'font-size:16px;font-family:Arial;margin-bottom:0'>After executing in the Analyze, it is possible to access the last output dataframe by calling the method below.</p>

# %%
df.get_output()

# %% [markdown]
# ### Also possible with query input

# %%
df = DataFrame(in_schema("DEMO_Financial", "Customer"))
if True:
    for i in range(10):
        df = df.assign(**{"column_long_xyz_{}".format(i): i})
df

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;'><b>Approach 2</b></p>
# <p style = 'font-size:16px;font-family:Arial;'>
# The EDA UI is also callable within teradatamlwidgets, using <br><code>from teradatamlwidgets import eda</code></p>
#
# <p style = 'font-size:16px;font-family:Arial;'> <b>Code Explanation</b> <br>
# Below is the basic set up of the notebook to call the EDA UI :
# <ol style = 'font-size:16px;font-family:Arial;'>
# <li> Create a connection using teradataml create_context or log in using<br><code>from teradatamlwidgets import login<br>ui = login.Ui(val_location="VAL")</code></li>
#     <li>Import the notebook using the code : <br><code>from teradatamlwidgets import eda</code></li>
#     <li>Set up the input DataFrame and call code using :<br><code>ui = eda.Ui(df = df)</code></li>
#     </ol>

# %%
from teradatamlwidgets import eda

df = DataFrame("ibm_stock")

ui = eda.Ui(df = df)

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;'><b> Each tab from the EDA UI is also callable separately within teradatamlwidgets.</b>
# <ul style = 'font-size:16px;font-family:Arial;'>
#     <li>
# <strong>Analyze:</strong> `from teradatamlwidgets import analytic_functions` </li>
#
# <strong>Visualize:</strong> `from teradatamlwidgets import plot` </li>
#
# <strong>Describe:</strong> `from teradatamlwidgets import describe` </li>
#
# <strong>Persist:</strong> `from teradatamlwidgets import persist` </li>
#
# </ul>
# <p style = 'font-size:16px;font-family:Arial;'>The explanation for <b>Analyze</b> (analytic_functions) is available in separate notebook "Analytic_Functions_Tutorial.ipynb".<br>The explanation for <b>Visualize</b> (plot) is available in separate notebook "Plot_Notebook.ipynb".

# %% [markdown]
# <hr style='height:1px;border:none;'>
# <p style = 'font-size:18px;font-family:Arial'><b>Clean up</b>

# %%
# %run -i /home/jovyan/JupyterLabRoot/UseCases/run_procedure.py "call remove_data('DEMO_Financial');" 
#Takes 5 seconds

# %%
tables = [ "ibm_stock"]

# Loop through the list of tables and execute the drop table command for each table
for table in tables:
    try:
        db_drop_table(table_name=table)
    except:
        pass

# %%
remove_context()

# %% [markdown]
# <footer style="padding-bottom:35px; border-bottom:3px solid #91A0Ab">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2026. All Rights Reserved
#         </div>
#     </div>
# </footer>
