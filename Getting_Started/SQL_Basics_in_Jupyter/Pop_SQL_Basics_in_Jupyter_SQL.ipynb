# %% [markdown]
# <header style="padding:1px;background:#f9f9f9;border-top:3px solid #00b2b1"><img id="Teradata-logo" src="https://www.teradata.com/Teradata/Images/Rebrand/Teradata_logo-two_color.png" alt="Teradata" width="220" align="right" />
#
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>Vantage SQL Plugin Basics</b>
# </header>
#
# <p style = 'font-size:16px;font-family:Arial'>Welcome to this introductory guide. This guide will walk you through your first SQL queries.  A more extensive notebook with more commands can be found online in the Teradata Vantage Modules for Jupyter <a href = 'https://teradata.github.io/jupyterextensions/#/'>Here.</a></p>

# %% [markdown]
# <hr>
# <p style = 'font-size:16px;font-family:Arial'>For help on available "magic" commands in the Teradata SQL plugin, run the following cell:</p>

# %%
%help
# Out:
# %help **command** - Display detailed help for one magic command (without %).</br>
# %help **all** - Display detailed help for all magic commands.</br>
# %help **snippets** - Display the list of SQL command Snippets.</br>
# %help **rowcount** - Display the current rowcount value.</br>
# %help **currentdb** - Display the current database for the user.</br>
# %help **hidewarnings** - Display the current hide warnings value.</br>
# #### Notation conventions: Items in [] are optional, all others are required.  Parameter names are not case sensitive.</br>
# #### Magic Commands:</br>
# **%addconnect** - Add a Teradata Vantage database connection specification.</br>**%connect** - Connect to a Vantage system and/or make the connection active.</br>**%disconnect** - Disconnect from a Vantage system.</br>**%rmconnect** - Remove a connection specification.</br>**%chconnect** - Change a connection specification.</br>**%lsconnect** - List the known connections.</br>**%chart** - Display a Vega-Lite visualization of a query result set or an existing Vega or VegaLite chart.</br>**%table** - Display a previous result set as a table.</br>**%meta** - Display metadata of a previous result set.</br>**%dataload** - Load a CSV file into a database table.</br>**%history** - Display a table or the details of previously executed commands.
# 		If a single history item is specified, the details for that item will be displayed.</br>**%rmhistory** - Remove one or more history items and associated result set(s).</br>**%var** - Define one or more variables for use in SQL statements and magic commands.</br>**%lsvar** - List one or more variables. If no names are provided, list all defined variables.</br>**%rmvar** - Remove one or more defined variables.</br>**%pyinfo** - Display information about the version of Python installed on the Vantage system.</br>**%rinfo** - Display information about the version of R installed on the Vantage system.</br>**%runsto** - Run a Script Table Operator.</br>**%installfile** - Install a file onto the Vantage system.</br>**%rmfile** - Remove a file that has been installed on the Vantage system.</br>**%showfile** - Display the contents of a file that has been installed on the Vantage system.</br>**%loglevel** - Set the logging level for the Teradata SQL kernel.</br>**%lsmagic** - List the supported magic commands.</br>**%quickref** - Display help for magic commands.</br>**%help** - Display help for magic commands.</br>**%savecolumn** - Save a BLOB column data to a file.</br>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Object Browser</b>
#
# <p style = 'font-size:16px;font-family:Arial'>Included with the plugin is a browser that alows you to view the databases and tables on your ClearScape Analytics Experience platform.  Note that if you haven't run any demos or haven't used the data dictionary, you will only see system tables.</p>
#
# <ol style = 'font-size:16px;font-family:Arial'>
#     <li>Select <b>File/New Launcher</b> or if there is a launcher t to a launcher (new or existing)</li>
# <li>Click Navigator</li>
# <li>Select database profile</li>
# </ol>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Introduction to SQL</b>
#
# <p style = 'font-size:16px;font-family:Arial'>This page is a Jupyter Notebook. Looking at the top-right corner, you can see that it is running a *Teradata SQL* kernel. Other kernel include R and Python. This means that any command on this notebook will have to be a SQL statement.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>The first step with any SQL editor or Jupyter Notebook is to connect to a Teradata system.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>If this notebook is being run from the Vantage LIVE image, three connections should already be set up; representing connections to Transcend Production, Transcend AWS, and Vantage LIVE (Azure).  The below command will list configured connections</p>

# %%
%lsconnect
# Out:
# Disconnected: NAME=local, USER=demo_user, HOST=host.docker.internal, DATABASE=demo_user

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>You are connected if the last command returned `Success:... connection established`</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The most simple SQL you can run is to calculate a formula, for example 2+2. Click on the cell below and press Shift-Return to execute its content. The result is saved in the Teradata directory mentioned above with the exact path below which can be accessed/downloaded from the file browser on the left.</p>

# %%
SELECT 2+5
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory956813"><style>
#       table.tdhistory956813 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory956813 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory956813:last-child { text-align: left !important; }
#       tbody.tdhistory956813 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory956813 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory956813 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory956813"></th><th class="tdhistory956813">(2+5)</th></tr></thead><tbody class="tdhistory956813 resultset-body"><tr><th class="tdhistory956813" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory956813">7</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Now, let's run your first real SQL query. Click in the cell below and press Shift+Return to execute it. It will retrieve ten rows from a table named DBC.TablesV</p>

# %%
SELECT TOP 5 * FROM DBC.TablesV;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory613364"><style>
#       table.tdhistory613364 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory613364 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory613364:last-child { text-align: left !important; }
#       tbody.tdhistory613364 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory613364 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory613364 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#  UNIQUE PRIMARY INDEX ( cust_id );</td><td class="tdhistory613364"></td><td class="tdhistory613364">0</td><td class="tdhistory613364">0</td><td class="tdhistory613364">0</td><td class="tdhistory613364">N </td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">2023-05-18 01:51:22</td><td class="tdhistory613364">val</td><td class="tdhistory613364">2023-05-18 01:51:22</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">1</td><td class="tdhistory613364">N </td><td class="tdhistory613364">N </td><td class="tdhistory613364">Y </td><td class="tdhistory613364">N </td><td class="tdhistory613364">N </td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">N </td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">1</td><td class="tdhistory613364">0</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">DEFAULT</td><td class="tdhistory613364">DEFAULT</td><td class="tdhistory613364">DEFAULT</td><td class="tdhistory613364">0 </td><td class="tdhistory613364">0</td><td class="tdhistory613364">TD_Map1</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td></tr><tr><th class="tdhistory613364" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory613364">SYSUDTLIB</td><td class="tdhistory613364">JSON_COMBINE_UJL_RESULT</td><td class="tdhistory613364">1</td><td class="tdhistory613364">H </td><td class="tdhistory613364">F </td><td class="tdhistory613364">N   </td><td class="tdhistory613364">DBC</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">0</td><td class="tdhistory613364">0</td><td class="tdhistory613364">0</td><td class="tdhistory613364">N </td><td class="tdhistory613364">0</td><td class="tdhistory613364"></td><td class="tdhistory613364">2023-05-18 01:21:48</td><td class="tdhistory613364">DBC</td><td class="tdhistory613364">2023-05-18 01:21:48</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">N </td><td class="tdhistory613364">N </td><td class="tdhistory613364">Y </td><td class="tdhistory613364">N </td><td class="tdhistory613364">N </td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">N </td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">0</td><td class="tdhistory613364">0</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364">0</td><td class="tdhistory613364">TD_DataDictionaryMap</td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td><td class="tdhistory613364"></td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
#     This is the simplest high-level SQL query. <b>SELECT</b> is a SQL keyword that starts the first section on defining the columns we wan to extract. <b>FROM</b> is a SQL keyword that starts the source data section. <b>DBC.TablesV</b> is the table we want to extract all the columns.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>
#     Instead of "shift+Enter", one can also click on the <b>Execute</b> button (triangular Play button in the top toolbar) will run the SQL query on our Vantage environment</p>
#
# <p style = 'font-size:16px;font-family:Arial'>After a few seconds you will find the results in the result window. You can select any cell, type Ctrl-C to copy the data, and then Ctrl-P in Excel to paste the data for further analysis (filtering, pivoting, etc.).</p>
#
# <p style = 'font-size:16px;font-family:Arial'>The results include the following columns:</p>
#
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>DatabaseName, name of the database a table is in</li>
# <li>TableName, name of the table</li>
# <li>Version</li>
# <li>TableKind</li>
# <li>ProtectionType</li>
# <li>JournalFlag</li>
# <li>CreatorName</li>
# <li>RequestText</li>
# <li>CommentString</li>
# <li>ParentCount</li>
# <li>ChildCount</li>
# <li>...</li>
# </ul>
#
# <p style = 'font-size:16px;font-family:Arial'>To select specific columns, we define them in the <b>SELECT</b> statement delimitated by a comma. For readability, we will enter each one on a new line and use a nice tabular form:</p>

# %%
SELECT TOP 5 TableName, DatabaseName FROM DBC.TablesV;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory474332"><style>
#       table.tdhistory474332 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory474332 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory474332:last-child { text-align: left !important; }
#       tbody.tdhistory474332 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory474332 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory474332 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory474332"></th><th class="tdhistory474332">TableName</th><th class="tdhistory474332">DataBaseName</th></tr></thead><tbody class="tdhistory474332 resultset-body"><tr><th class="tdhistory474332" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory474332">ESCINSERT</td><td class="tdhistory474332">SYSJDBC</td></tr><tr><th class="tdhistory474332" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory474332">XSLT_SHRED</td><td class="tdhistory474332">TD_SYSXML</td></tr><tr><th class="tdhistory474332" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory474332">AS_SHRED_BATCH</td><td class="tdhistory474332">TD_SYSXML</td></tr><tr><th class="tdhistory474332" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory474332">AllGlobalSpaceV</td><td class="tdhistory474332">DBC</td></tr><tr><th class="tdhistory474332" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory474332">JAR_JAR_USAGE</td><td class="tdhistory474332">DBC</td></tr></tbody></table></div>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Ordering</b>
#
# <p style = 'font-size:16px;font-family:Arial'>We can order the data by Name:</p>

# %%
SELECT TOP 5 TableName, DatabaseName FROM DBC.TablesV ORDER BY TableName;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory172829"><style>
#       table.tdhistory172829 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory172829 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory172829:last-child { text-align: left !important; }
#       tbody.tdhistory172829 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory172829 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory172829 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory172829"></th><th class="tdhistory172829">TableName</th><th class="tdhistory172829">DataBaseName</th></tr></thead><tbody class="tdhistory172829 resultset-body"><tr><th class="tdhistory172829" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory172829">AbortCollect</td><td class="tdhistory172829">TDStats</td></tr><tr><th class="tdhistory172829" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory172829">AbortListSessions</td><td class="tdhistory172829">SYSLIB</td></tr><tr><th class="tdhistory172829" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory172829">AbortSessions</td><td class="tdhistory172829">SYSLIB</td></tr><tr><th class="tdhistory172829" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory172829">AccessLog</td><td class="tdhistory172829">DBC</td></tr><tr><th class="tdhistory172829" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory172829">AccessLogV</td><td class="tdhistory172829">DBC</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>We added here the SQL keyword <b>ORDER BY</b> followed by the column on which we want to order the data.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>To order in descendign order, we add the SQL keyword <b>DESC</b> next to the column name:</p>

# %%
SELECT TOP 5 TableName, DatabaseName FROM DBC.TablesV ORDER BY TableName DESC;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory790865"><style>
#       table.tdhistory790865 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory790865 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory790865:last-child { text-align: left !important; }
#       tbody.tdhistory790865 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory790865 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory790865 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory790865"></th><th class="tdhistory790865">TableName</th><th class="tdhistory790865">DataBaseName</th></tr></thead><tbody class="tdhistory790865 resultset-body"><tr><th class="tdhistory790865" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory790865">ZTEST_CONTRACT</td><td class="tdhistory790865">TD_SYSFNLIB</td></tr><tr><th class="tdhistory790865" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory790865">Zones_TD15</td><td class="tdhistory790865">DBC</td></tr><tr><th class="tdhistory790865" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory790865">ZonesV_SZ</td><td class="tdhistory790865">DBC</td></tr><tr><th class="tdhistory790865" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory790865">ZonesVX</td><td class="tdhistory790865">DBC</td></tr><tr><th class="tdhistory790865" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory790865">ZonesV</td><td class="tdhistory790865">DBC</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>We can order using multiple columns, for example:</p>

# %%
SELECT
    TOP 5 *
FROM
    DBC.TablesV
ORDER BY DatabaseName DESC, TableName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory734819"><style>
#       table.tdhistory734819 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory734819 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory734819:last-child { text-align: left !important; }
#       tbody.tdhistory734819 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory734819 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory734819 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#  UNIQUE PRIMARY INDEX ( cust_id,tran_id );</td><td class="tdhistory734819"></td><td class="tdhistory734819">0</td><td class="tdhistory734819">0</td><td class="tdhistory734819">0</td><td class="tdhistory734819">N </td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819">2023-05-18 01:51:22</td><td class="tdhistory734819">val</td><td class="tdhistory734819">2023-05-18 01:51:22</td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819">1</td><td class="tdhistory734819">N </td><td class="tdhistory734819">N </td><td class="tdhistory734819">Y </td><td class="tdhistory734819">N </td><td class="tdhistory734819">N </td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819">N </td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819">2</td><td class="tdhistory734819">0</td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819">DEFAULT</td><td class="tdhistory734819">DEFAULT</td><td class="tdhistory734819">DEFAULT</td><td class="tdhistory734819">0 </td><td class="tdhistory734819">0</td><td class="tdhistory734819">TD_Map1</td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td><td class="tdhistory734819"></td></tr></tbody></table></div>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Filtering</b>
#
# <p style = 'font-size:16px;font-family:Arial'>We can filter for specific value with the SQL keyword <b>WHERE</b>. For example:</p>

# %%
SELECT TOP 5 * FROM DBC.TablesV
WHERE TableKind = 'T'
ORDER BY DatabaseName DESC, TableName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory789945"><style>
#       table.tdhistory789945 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory789945 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory789945:last-child { text-align: left !important; }
#       tbody.tdhistory789945 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory789945 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory789945 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#  UNIQUE PRIMARY INDEX ( cust_id,tran_id );</td><td class="tdhistory789945"></td><td class="tdhistory789945">0</td><td class="tdhistory789945">0</td><td class="tdhistory789945">0</td><td class="tdhistory789945">N </td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945">2023-05-18 01:51:22</td><td class="tdhistory789945">val</td><td class="tdhistory789945">2023-05-18 01:51:22</td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945">1</td><td class="tdhistory789945">N </td><td class="tdhistory789945">N </td><td class="tdhistory789945">Y </td><td class="tdhistory789945">N </td><td class="tdhistory789945">N </td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945">N </td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945">2</td><td class="tdhistory789945">0</td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945">DEFAULT</td><td class="tdhistory789945">DEFAULT</td><td class="tdhistory789945">DEFAULT</td><td class="tdhistory789945">0 </td><td class="tdhistory789945">0</td><td class="tdhistory789945">TD_Map1</td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td><td class="tdhistory789945"></td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>We use the SQL keyword **AND** and **OR** with parenthesis to define any logic. For example, to select only the CreatorName of DBC OR SYSADM:</p>

# %%
SELECT TOP 5 * FROM DBC.TablesV
WHERE (TableKind = 'T' AND CreatorName = 'DBC')
  OR (TableKind = 'T' AND CreatorName = 'SYSADM')
ORDER BY DatabaseName DESC, TableName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory475244"><style>
#       table.tdhistory475244 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory475244 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory475244:last-child { text-align: left !important; }
#       tbody.tdhistory475244 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory475244 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory475244 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
# )UNIQUE PRIMARY INDEX(ObjectName);</td><td class="tdhistory475244">Table to store metadata object which will be use by analytic functions.</td><td class="tdhistory475244">0</td><td class="tdhistory475244">0</td><td class="tdhistory475244">0</td><td class="tdhistory475244">Y </td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">2023-05-18 01:22:18</td><td class="tdhistory475244">DBC</td><td class="tdhistory475244">2023-05-18 01:22:18</td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">1</td><td class="tdhistory475244">N </td><td class="tdhistory475244">N </td><td class="tdhistory475244">Y </td><td class="tdhistory475244">N </td><td class="tdhistory475244">N </td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">N </td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">1</td><td class="tdhistory475244">0</td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">DEFAULT</td><td class="tdhistory475244">DEFAULT</td><td class="tdhistory475244">DEFAULT</td><td class="tdhistory475244">0 </td><td class="tdhistory475244">1</td><td class="tdhistory475244">TD_Map1</td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td></tr><tr><th class="tdhistory475244" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory475244">tdwm</td><td class="tdhistory475244">Actions</td><td class="tdhistory475244">1</td><td class="tdhistory475244">T </td><td class="tdhistory475244">F </td><td class="tdhistory475244">NN  </td><td class="tdhistory475244">DBC</td><td class="tdhistory475244">CREATE TABLE Actions (  ActionId    INTEGER NOT NULL, CreateDate  INTEGER NOT NULL, CreateTime  INTEGER FORMAT '99:99:99' NOT NULL, RemoveDate  INTEGER NOT NULL, RemoveTime  INTEGER FORMAT '99:99:99' NOT NULL, Description VARCHAR(80) CHARACTER SET UNICODE, ConfigId    INTEGER NOT NULL, ParentId    INTEGER NOT NULL, VersionNo   INTEGER NOT NULL, ActionName  VARCHAR(30) CHARACTER SET UNICODE NOT NULL, ActionType  VARCHAR(10) CHARACTER SET UNICODE NOT NULL, SysConId    INTEGER, OpEnvId     INTEGER, ActionValue INTEGER, ActionInfo  VARCHAR(120) CHARACTER SET UNICODE) PRIMARY INDEX (ActionId);</td><td class="tdhistory475244"></td><td class="tdhistory475244">0</td><td class="tdhistory475244">0</td><td class="tdhistory475244">0</td><td class="tdhistory475244">N </td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">2023-05-18 01:32:48</td><td class="tdhistory475244">DBC</td><td class="tdhistory475244">2023-05-18 01:32:48</td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">1</td><td class="tdhistory475244">N </td><td class="tdhistory475244">N </td><td class="tdhistory475244">Y </td><td class="tdhistory475244">N </td><td class="tdhistory475244">N </td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">N </td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244">1</td><td class="tdhistory475244">0</td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244"></td><td class="tdhistory475244 ...

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Aggregation</b>
#
# <p style = 'font-size:16px;font-family:Arial'>We can aggregate multiple rows together in a similar way as pivot tables work in Excel. For example, to count how many object (tables, views, macros, stored procedures, functions, etc) we have with the same name in Vantage, we would do:</p>

# %%
SELECT TOP 5 DatabaseName, count(*) as ObjectCount FROM DBC.TablesV
GROUP BY DatabaseName  
ORDER BY DatabaseName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory611178"><style>
#       table.tdhistory611178 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory611178 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory611178:last-child { text-align: left !important; }
#       tbody.tdhistory611178 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory611178 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory611178 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory611178"></th><th class="tdhistory611178">DataBaseName</th><th class="tdhistory611178">ObjectCount</th></tr></thead><tbody class="tdhistory611178 resultset-body"><tr><th class="tdhistory611178" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory611178">DBC</td><td class="tdhistory611178">872</td></tr><tr><th class="tdhistory611178" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory611178">dbcmngr</td><td class="tdhistory611178">2</td></tr><tr><th class="tdhistory611178" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory611178">DemoNow_Monitor</td><td class="tdhistory611178">1</td></tr><tr><th class="tdhistory611178" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory611178">demo_user</td><td class="tdhistory611178">19</td></tr><tr><th class="tdhistory611178" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory611178">GLOBAL_FUNCTIONS</td><td class="tdhistory611178">1</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>In the <b>SELECT</b> example below, we use a sub query to aggregate object size within a database, then we use functions to get the minimum and maximum object size and count for each database.  (The counts are different from above because views and macros take no space).</p>
#
# <p style = 'font-size:16px;font-family:Arial'>There are multiple aggregation functions:</p>
#
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>SUM(X) to sum all the X values</li>
# <li>AVG(X) for the average of X</li>
# <li>MIN(X) for the smallest X value</li>
# <li>MAX(X) for the largest X value</li>
# </ul>
#
# <p style = 'font-size:16px;font-family:Arial'>For example:</p>

# %%
SELECT
    TOP 5 databasename,
    MIN(TableBytes)  AS MinSize,
    MAX(TableBytes)  AS MaxSize,
    COUNT(*) AS #Objects_Using_Space
FROM (
    SELECT
        DatabaseName,
        TableName,
        Sum(CurrentPerm) AS TableBytes   
        FROM DBC.TablesizeV
        GROUP By DatabaseName, Tablename
    ) AS Subtotals 
GROUP BY DatabaseName order by DatabaseName;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory556195"><style>
#       table.tdhistory556195 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory556195 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory556195:last-child { text-align: left !important; }
#       tbody.tdhistory556195 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory556195 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory556195 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory556195"></th><th class="tdhistory556195">DataBaseName</th><th class="tdhistory556195">MinSize</th><th class="tdhistory556195">MaxSize</th><th class="tdhistory556195">#Objects_Using_Space</th></tr></thead><tbody class="tdhistory556195 resultset-body"><tr><th class="tdhistory556195" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory556195">DBC</td><td class="tdhistory556195">36864</td><td class="tdhistory556195">142737408</td><td class="tdhistory556195">189</td></tr><tr><th class="tdhistory556195" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory556195">dbcmngr</td><td class="tdhistory556195">65536</td><td class="tdhistory556195">65536</td><td class="tdhistory556195">2</td></tr><tr><th class="tdhistory556195" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory556195">DemoNow_Monitor</td><td class="tdhistory556195">98304</td><td class="tdhistory556195">98304</td><td class="tdhistory556195">1</td></tr><tr><th class="tdhistory556195" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory556195">demo_user</td><td class="tdhistory556195">65536</td><td class="tdhistory556195">770048</td><td class="tdhistory556195">9</td></tr><tr><th class="tdhistory556195" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory556195">GLOBAL_FUNCTIONS</td><td class="tdhistory556195">131072</td><td class="tdhistory556195">131072</td><td class="tdhistory556195">1</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>For courageous readers, you can also try the following aggregation functions:</p>
#
# <ul style = 'font-size:16px;font-family:Arial'>
# <li>STDDEV_POP(X) and STDDEV_SAMP(X) to measure the standard deviation of the X distribution (for the full population, and for a sampled population)
# <li>VAR_POP(X) and VAR_SAMP(X) to measure the variance of the X distribution (for the full population, and for a sampled population)
# <li>COVAR_POP(X,Y) and COVAR_SAMP(X,Y) to measure the covariance between X and Y (for the full population, and for a sampled population)
# <li>CORR(X,Y) to measure the correlation between the columns X and Y
# <li>KURTOSIS(X) to measure the kurtosis of the X distribution **minus** 3 (the tailedness of the distribution, it should be around 0 for a Normal/Gaussian distribution)
# <li>SKEW(X) to measure the skewness of the X distribution (the asymetry of the distribution, it should be around 0 for a Normal/Gaussian distribution)
# </ul>

# %% [markdown]
# <footer style="padding:10px;background:#f9f9f9;border-bottom:3px solid #394851">©2023 Teradata. All Rights Reserved</footer>
