# %% [markdown]
# <header style="padding:1px;background:#f9f9f9;border-top:3px solid #00b2b1"><img id="Teradata-logo" src="https://www.teradata.com/Teradata/Images/Rebrand/Teradata_logo-two_color.png" alt="Teradata" width="220" align="right" />
#
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>Vantage SQL Plugin Basics</b>
# </header>
#
# <p style = 'font-size:16px;font-family:Arial'>Welcome to this introductory guide. This guide will walk you through your first SQL queries.  A more extensive notebook with more commands can be found online in the Teradata Vantage Modules for Jupyter <a href = 'https://teradata.github.io/jupyterextensions/#/'>Here.</a></p>
#
# <hr>
# <p style = 'font-size:16px;font-family:Arial'>For help on available "magic" commands in the Teradata SQL plugin, run the following cell:</p>

# %%
%help
# Out:
# %help **command** - Display detailed help for one magic command (without %).</br>
# %help **all** - Display detailed help for all magic commands.</br>
# %help **snippets** - Display the list of SQL command Snippets.</br>
# %help **rowcount** - Display the current rowcount value.</br>
# %help **currentdb** - Display the current database for the user.</br>
# %help **hidewarnings** - Display the current hide warnings value.</br>
# #### Notation conventions: Items in [] are optional, all others are required.  Parameter names are not case sensitive.</br>
# #### Magic Commands:</br>
# **%addconnect** - Add a Teradata Vantage database connection specification.</br>**%connect** - Connect to a Vantage system and/or make the connection active.</br>**%disconnect** - Disconnect from a Vantage system.</br>**%rmconnect** - Remove a connection specification.</br>**%chconnect** - Change a connection specification.</br>**%lsconnect** - List the known connections.</br>**%chart** - Display a Vega-Lite visualization of a query result set or an existing Vega or VegaLite chart.</br>**%table** - Display a previous result set as a table.</br>**%meta** - Display metadata of a previous result set.</br>**%dataload** - Load a CSV file into a database table.</br>**%history** - Display a table or the details of previously executed commands.
# 		If a single history item is specified, the details for that item will be displayed.</br>**%rmhistory** - Remove one or more history items and associated result set(s).</br>**%var** - Define one or more variables for use in SQL statements and magic commands.</br>**%lsvar** - List one or more variables. If no names are provided, list all defined variables.</br>**%rmvar** - Remove one or more defined variables.</br>**%pyinfo** - Display information about the version of Python installed on the Vantage system.</br>**%rinfo** - Display information about the version of R installed on the Vantage system.</br>**%runsto** - Run a Script Table Operator.</br>**%installfile** - Install a file onto the Vantage system.</br>**%rmfile** - Remove a file that has been installed on the Vantage system.</br>**%showfile** - Display the contents of a file that has been installed on the Vantage system.</br>**%loglevel** - Set the logging level for the Teradata SQL kernel.</br>**%lsmagic** - List the supported magic commands.</br>**%quickref** - Display help for magic commands.</br>**%help** - Display help for magic commands.</br>**%savecolumn** - Save a BLOB column data to a file.</br>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Object Browser</b>
#
# Included with the plugin is a browser that alows you to view the databases and tables on your ClearScape Analytics Experience platform.  Note that if you haven't run any demos or haven't used the data dictionary, you will only see system tables.
#
# <ol style = 'font-size:16px;font-family:Arial'>
#     <li>Select <b>File/New Launcher</b> or if there is a launcher t to a launcher (new or existing)</li>
# <li>Click Navigator</li>
# <li>Select database profile</li>
# </ol>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Introduction to SQL</b>
#
# <p style = 'font-size:16px;font-family:Arial'>This page is a Jupyter Notebook. Looking at the top-right corner, you can see that it is running a *Teradata SQL* kernel. Other kernel include R and Python. This means that any command on this notebook will have to be a SQL statement.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>The first step with any SQL editor or Jupyter Notebook is to connect to a Teradata system.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>If this notebook is being run from the Vantage LIVE image, three connections should already be set up; representing connections to Transcend Production, Transcend AWS, and Vantage LIVE (Azure).  The below command will list configured connections</p>

# %%
%lsconnect
# Out:
# Disconnected: NAME=local, USER=demo_user, HOST=host.docker.internal, DATABASE=demo_user

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>You are connected if the last command returned `Success:... connection established`</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The most simple SQL you can run is to calculate a formula, for example 2+2. Click on the cell below and press Shift-Return to execute its content. The result is saved in the Teradata directory mentioned above with the exact path below which can be accessed/downloaded from the file browser on the left.</p>

# %%
SELECT 2+5
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory910550"><style>
#       table.tdhistory910550 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory910550 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory910550:last-child { text-align: left !important; }
#       tbody.tdhistory910550 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory910550 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory910550 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory910550"></th><th class="tdhistory910550">(2+5)</th></tr></thead><tbody class="tdhistory910550 resultset-body"><tr><th class="tdhistory910550" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory910550">7</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Now, let's run your first real SQL query. Click in the cell below and press Shift+Return to execute it. It will retrieve ten rows from a table named DBC.TablesV</p>

# %%
SELECT top 10 * FROM DBC.TablesV;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory522831"><style>
#       table.tdhistory522831 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory522831 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory522831:last-child { text-align: left !important; }
#       tbody.tdhistory522831 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory522831 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory522831 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     EXTERNAL NAME 'SL!udflib';</td><td class="tdhistory522831"></td><td class="tdhistory522831">0</td><td class="tdhistory522831">0</td><td class="tdhistory522831">0</td><td class="tdhistory522831">N </td><td class="tdhistory522831">0</td><td class="tdhistory522831"></td><td class="tdhistory522831">2023-05-17 10:56:41</td><td class="tdhistory522831">DBC</td><td class="tdhistory522831">2023-05-17 11:01:01</td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831">N </td><td class="tdhistory522831">N </td><td class="tdhistory522831">Y </td><td class="tdhistory522831">N </td><td class="tdhistory522831">N </td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831">N </td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831">0</td><td class="tdhistory522831">0</td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831">1</td><td class="tdhistory522831">TD_DataDictionaryMap</td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td><td class="tdhistory522831"></td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
#     This is the simplest high-level SQL query. <b>SELECT</b> is a SQL keyword that starts the first section on defining the columns we wan to extract. <b>FROM</b> is a SQL keyword that starts the source data section. <b>DBC.TablesV</b> is the table we want to extract all the columns.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>
#     Instead of "shift+Enter", one can also click on the <b>Execute</b> button (triangular Play button in the top toolbar) will run the SQL query on our Vantage environment</p>
#
# <p style = 'font-size:16px;font-family:Arial'>After a few seconds you will find the results in the result window. You can select any cell, type Ctrl-C to copy the data, and then Ctrl-P in Excel to paste the data for further analysis (filtering, pivoting, etc.).</p>
#
# <p style = 'font-size:16px;font-family:Arial'>The results include the following columns:</p>
#
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>DatabaseName, name of the database a table is in</li>
# <li>TableName, name of the table</li>
# <li>Version</li>
# <li>TableKind</li>
# <li>ProtectionType</li>
# <li>JournalFlag</li>
# <li>CreatorName</li>
# <li>RequestText</li>
# <li>CommentString</li>
# <li>ParentCount</li>
# <li>ChildCount</li>
# <li>...</li>
# </ul>
#
# <p style = 'font-size:16px;font-family:Arial'>To select specific columns, we define them in the <b>SELECT</b> statement delimitated by a comma. For readability, we will enter each one on a new line and use a nice tabular form:</p>

# %%
SELECT top 5 TableName, DatabaseName FROM DBC.TablesV;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory945344"><style>
#       table.tdhistory945344 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory945344 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory945344:last-child { text-align: left !important; }
#       tbody.tdhistory945344 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory945344 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory945344 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory945344"></th><th class="tdhistory945344">TableName</th><th class="tdhistory945344">DataBaseName</th></tr></thead><tbody class="tdhistory945344 resultset-body"><tr><th class="tdhistory945344" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory945344">ESCINSERT</td><td class="tdhistory945344">SYSJDBC</td></tr><tr><th class="tdhistory945344" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory945344">byte2int</td><td class="tdhistory945344">GLOBAL_FUNCTIONS</td></tr><tr><th class="tdhistory945344" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory945344">ESCREPEAT</td><td class="tdhistory945344">SYSJDBC</td></tr><tr><th class="tdhistory945344" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory945344">DatasetSchemaDependenciesV</td><td class="tdhistory945344">DBC</td></tr><tr><th class="tdhistory945344" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory945344">ResCPUByPE</td><td class="tdhistory945344">DBC</td></tr></tbody></table></div>

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Ordering</b>
#
# <p style = 'font-size:16px;font-family:Arial'>We can order the data by Name:</p>

# %%
SELECT top 5 TableName, DatabaseName FROM DBC.TablesV ORDER BY TableName;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory589402"><style>
#       table.tdhistory589402 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory589402 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory589402:last-child { text-align: left !important; }
#       tbody.tdhistory589402 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory589402 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory589402 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory589402"></th><th class="tdhistory589402">TableName</th><th class="tdhistory589402">DataBaseName</th></tr></thead><tbody class="tdhistory589402 resultset-body"><tr><th class="tdhistory589402" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory589402">AbortCollect</td><td class="tdhistory589402">TDStats</td></tr><tr><th class="tdhistory589402" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory589402">AbortListSessions</td><td class="tdhistory589402">SYSLIB</td></tr><tr><th class="tdhistory589402" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory589402">AbortSessions</td><td class="tdhistory589402">SYSLIB</td></tr><tr><th class="tdhistory589402" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory589402">AccessLog</td><td class="tdhistory589402">DBC</td></tr><tr><th class="tdhistory589402" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory589402">AccessLogV</td><td class="tdhistory589402">DBC</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>We added here the SQL keyword <b>ORDER BY</b> followed by the column on which we want to order the data.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>To order in descendign order, we add the SQL keyword <b>DESC</b> next to the column name:</p>

# %%
SELECT top 5 TableName, DatabaseName FROM DBC.TablesV ORDER BY TableName DESC;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory980621"><style>
#       table.tdhistory980621 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory980621 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory980621:last-child { text-align: left !important; }
#       tbody.tdhistory980621 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory980621 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory980621 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory980621"></th><th class="tdhistory980621">TableName</th><th class="tdhistory980621">DataBaseName</th></tr></thead><tbody class="tdhistory980621 resultset-body"><tr><th class="tdhistory980621" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory980621">_val_ks_out1</td><td class="tdhistory980621">demo_user</td></tr><tr><th class="tdhistory980621" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory980621">_val_chisquare_out</td><td class="tdhistory980621">demo_user</td></tr><tr><th class="tdhistory980621" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory980621">_val_binomial_example4</td><td class="tdhistory980621">demo_user</td></tr><tr><th class="tdhistory980621" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory980621">_val_binomial_example2</td><td class="tdhistory980621">demo_user</td></tr><tr><th class="tdhistory980621" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory980621">_TWM_1_TO_1_AFFINITY</td><td class="tdhistory980621">demo_user</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>We can order using multiple columns, for example:</p>

# %%
SELECT
    top 50 *
FROM
    DBC.TablesV
ORDER BY DatabaseName DESC, TableName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory278173"><style>
#       table.tdhistory278173 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory278173 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory278173:last-child { text-align: left !important; }
#       tbody.tdhistory278173 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory278173 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory278173 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#  UNIQUE PRIMARY INDEX ( cust_id,tran_id );</td><td class="tdhistory278173"></td><td class="tdhistory278173">0</td><td class="tdhistory278173">0</td><td class="tdhistory278173">0</td><td class="tdhistory278173">N </td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173">2023-05-17 11:26:09</td><td class="tdhistory278173">val</td><td class="tdhistory278173">2023-05-17 11:26:09</td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173">1</td><td class="tdhistory278173">N </td><td class="tdhistory278173">N </td><td class="tdhistory278173">Y </td><td class="tdhistory278173">N </td><td class="tdhistory278173">N </td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173">N </td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173">2</td><td class="tdhistory278173">0</td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173">DEFAULT</td><td class="tdhistory278173">DEFAULT</td><td class="tdhistory278173">DEFAULT</td><td class="tdhistory278173">0 </td><td class="tdhistory278173">0</td><td class="tdhistory278173">TD_Map1</td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td></tr><tr><th class="tdhistory278173" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory278173">val</td><td class="tdhistory278173">TdAnalyzeJarId_2.1.0.0</td><td class="tdhistory278173">1</td><td class="tdhistory278173">D </td><td class="tdhistory278173">F </td><td class="tdhistory278173">N   </td><td class="tdhistory278173">val</td><td class="tdhistory278173">CALL SQLJ.INSTALL_JAR('SJ!/opt/teradata/val/2.1.0.0/lib64/TdAnalyzeJarFile.jar','TdAnalyzeJarId_2.1.0.0', 0);</td><td class="tdhistory278173"></td><td class="tdhistory278173">0</td><td class="tdhistory278173">0</td><td class="tdhistory278173">0</td><td class="tdhistory278173">N </td><td class="tdhistory278173">0</td><td class="tdhistory278173"></td><td class="tdhistory278173">2023-05-17 11:25:29</td><td class="tdhistory278173">val</td><td class="tdhistory278173">2023-05-17 11:25:29</td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhistory278173"></td><td class="tdhis

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Filtering</b>
#
# <p style = 'font-size:16px;font-family:Arial'>We can filter for specific value with the SQL keyword <b>WHERE</b>. For example:</p>

# %%
SELECT top 50 * FROM DBC.TablesV
WHERE TableKind = 'T'
ORDER BY DatabaseName DESC, TableName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory856561"><style>
#       table.tdhistory856561 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory856561 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory856561:last-child { text-align: left !important; }
#       tbody.tdhistory856561 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory856561 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory856561 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#  UNIQUE PRIMARY INDEX ( tran_id,acct_nbr );</td><td class="tdhistory856561"></td><td class="tdhistory856561">0</td><td class="tdhistory856561">0</td><td class="tdhistory856561">0

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>We use the SQL keyword **AND** and **OR** with parenthesis to define any logic. For example, to select only the CreatorName of DBC OR SYSADM:</p>

# %%
SELECT top 50 * FROM DBC.TablesV
WHERE (TableKind = 'T' AND CreatorName = 'DBC')
  OR (TableKind = 'T' AND CreatorName = 'SYSADM')
ORDER BY DatabaseName DESC, TableName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory838680"><style>
#       table.tdhistory838680 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory838680 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory838680:last-child { text-align: left !important; }
#       tbody.tdhistory838680 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory838680 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory838680 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
# )UNIQUE PRIMARY INDEX(ObjectName);</td><td class="tdhistory838680">Table to store metadata object which will be use by analytic functions.</td><td class="tdhistory838680">0</td><td class="tdhistory838680">0</td><td class="tdhistory838680">0</td><td class="tdhistory838680">Y </td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">2023-05-17 10:58:05</td><td class="tdhistory838680">DBC</td><td class="tdhistory838680">2023-05-17 10:58:05</td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">1</td><td class="tdhistory838680">N </td><td class="tdhistory838680">N </td><td class="tdhistory838680">Y </td><td class="tdhistory838680">N </td><td class="tdhistory838680">N </td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">N </td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">1</td><td class="tdhistory838680">0</td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">DEFAULT</td><td class="tdhistory838680">DEFAULT</td><td class="tdhistory838680">DEFAULT</td><td class="tdhistory838680">0 </td><td class="tdhistory838680">1</td><td class="tdhistory838680">TD_Map1</td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td></tr><tr><th class="tdhistory838680" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory838680">tdwm</td><td class="tdhistory838680">Actions</td><td class="tdhistory838680">1</td><td class="tdhistory838680">T </td><td class="tdhistory838680">F </td><td class="tdhistory838680">NN  </td><td class="tdhistory838680">DBC</td><td class="tdhistory838680">CREATE TABLE Actions (  ActionId    INTEGER NOT NULL, CreateDate  INTEGER NOT NULL, CreateTime  INTEGER FORMAT '99:99:99' NOT NULL, RemoveDate  INTEGER NOT NULL, RemoveTime  INTEGER FORMAT '99:99:99' NOT NULL, Description VARCHAR(80) CHARACTER SET UNICODE, ConfigId    INTEGER NOT NULL, ParentId    INTEGER NOT NULL, VersionNo   INTEGER NOT NULL, ActionName  VARCHAR(30) CHARACTER SET UNICODE NOT NULL, ActionType  VARCHAR(10) CHARACTER SET UNICODE NOT NULL, SysConId    INTEGER, OpEnvId     INTEGER, ActionValue INTEGER, ActionInfo  VARCHAR(120) CHARACTER SET UNICODE) PRIMARY INDEX (ActionId);</td><td class="tdhistory838680"></td><td class="tdhistory838680">0</td><td class="tdhistory838680">0</td><td class="tdhistory838680">0</td><td class="tdhistory838680">N </td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">2023-05-17 11:06:44</td><td class="tdhistory838680">DBC</td><td class="tdhistory838680">2023-05-17 11:06:44</td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">1</td><td class="tdhistory838680">N </td><td class="tdhistory838680">N </td><td class="tdhistory838680">Y </td><td class="tdhistory838680">N </td><td class="tdhistory838680">N </td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">N </td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680">1</td><td class="tdhistory838680">0</td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680"></td><td class="tdhistory838680 ...

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Aggregation</b>
#
# <p style = 'font-size:16px;font-family:Arial'>We can aggregate multiple rows together in a similar way as pivot tables work in Excel. For example, to count how many object (tables, views, macros, stored procedures, functions, etc) we have with the same name in Vantage, we would do:</p>

# %%
SELECT top 20 DatabaseName, count(*) as ObjectCount FROM DBC.TablesV
GROUP BY DatabaseName  
ORDER BY DatabaseName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory754174"><style>
#       table.tdhistory754174 { display: block !important; min-height: 504px !important; overflow: auto !important; height: 504px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory754174 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory754174:last-child { text-align: left !important; }
#       tbody.tdhistory754174 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory754174 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory754174 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory754174"></th><th class="tdhistory754174">DataBaseName</th><th class="tdhistory754174">ObjectCount</th></tr></thead><tbody class="tdhistory754174 resultset-body"><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory754174">DBC</td><td class="tdhistory754174">872</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory754174">dbcmngr</td><td class="tdhistory754174">2</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory754174">DemoNow_Monitor</td><td class="tdhistory754174">1</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory754174">DEMO_RemaingUsefulLife</td><td class="tdhistory754174">1</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory754174">demo_user</td><td class="tdhistory754174">86</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory754174">GLOBAL_FUNCTIONS</td><td class="tdhistory754174">1</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory754174">gs_tables_db</td><td class="tdhistory754174">4</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory754174">LockLogShredder</td><td class="tdhistory754174">5</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory754174">mldb</td><td class="tdhistory754174">10</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory754174">SQLJ</td><td class="tdhistory754174">11</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory754174">SysAdmin</td><td class="tdhistory754174">6</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory754174">SYSBAR</td><td class="tdhistory754174">6</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory754174">SYSJDBC</td><td class="tdhistory754174">3</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory754174">SYSLIB</td><td class="tdhistory754174">133</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory754174">SYSSPATIAL</td><td class="tdhistory754174">25</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory754174">SystemFe</td><td class="tdhistory754174">64</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory754174">SYSUDTLIB</td><td class="tdhistory754174">395</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory754174">SYSUIF</td><td class="tdhistory754174">6</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory754174">Sys_Calendar</td><td class="tdhistory754174">15</td></tr><tr><th class="tdhistory754174" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory754174">tapidb</td><td class="tdhistory754174">2</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>In the <b>SELECT</b> example below, we use a sub query to aggregate object size within a database, then we use functions to get the minimum and maximum object size and count for each database.  (The counts are different from above because views and macros take no space).</p>
#
# <p style = 'font-size:16px;font-family:Arial'>There are multiple aggregation functions:</p>
#
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>SUM(X) to sum all the X values</li>
# <li>AVG(X) for the average of X</li>
# <li>MIN(X) for the smallest X value</li>
# <li>MAX(X) for the largest X value</li>
# </ul>
#
# <p style = 'font-size:16px;font-family:Arial'>For example:</p>

# %%
SELECT
    TOP 20 databasename,
    MIN(TableBytes)  AS MinSize,
    MAX(TableBytes)  AS MaxSize,
    COUNT(*) AS #Objects_Using_Space
FROM (
    SELECT
        DatabaseName,
        TableName,
        Sum(CurrentPerm) as TableBytes   
        From DBC.TablesizeV
        Group By DatabaseName, Tablename
    ) as Subtotals 
GROUP BY DatabaseName order by DatabaseName;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory992133"><style>
#       table.tdhistory992133 { display: block !important; min-height: 504px !important; overflow: auto !important; height: 504px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory992133 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory992133:last-child { text-align: left !important; }
#       tbody.tdhistory992133 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory992133 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory992133 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory992133"></th><th class="tdhistory992133">DataBaseName</th><th class="tdhistory992133">MinSize</th><th class="tdhistory992133">MaxSize</th><th class="tdhistory992133">#Objects_Using_Space</th></tr></thead><tbody class="tdhistory992133 resultset-body"><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory992133">DBC</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">142737408</td><td class="tdhistory992133">189</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory992133">dbcmngr</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">2</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory992133">DemoNow_Monitor</td><td class="tdhistory992133">98304</td><td class="tdhistory992133">98304</td><td class="tdhistory992133">1</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory992133">demo_user</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">7593984</td><td class="tdhistory992133">77</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory992133">GLOBAL_FUNCTIONS</td><td class="tdhistory992133">131072</td><td class="tdhistory992133">131072</td><td class="tdhistory992133">1</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory992133">gs_tables_db</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">2</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory992133">LockLogShredder</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">229376</td><td class="tdhistory992133">5</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory992133">mldb</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">35610624</td><td class="tdhistory992133">10</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory992133">SQLJ</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">196608</td><td class="tdhistory992133">8</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory992133">SysAdmin</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">786432</td><td class="tdhistory992133">2</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory992133">SYSBAR</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">3</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory992133">SYSLIB</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">2031616</td><td class="tdhistory992133">92</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory992133">SYSSPATIAL</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">729088</td><td class="tdhistory992133">25</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory992133">SystemFe</td><td class="tdhistory992133">65536</td><td class="tdhistory992133">524288</td><td class="tdhistory992133">26</td></tr><tr><th class="tdhistory992133" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory992133">SYSUDTLIB</td><td class="tdhistory992133">98304</td><td class="tdhistory992133">491520</td><td class="tdhistory992133">21</td></tr> ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>For courageous readers, you can also try the following aggregation functions:</p>
#
# <ul style = 'font-size:16px;font-family:Arial'>
# <li>STDDEV_POP(X) and STDDEV_SAMP(X) to measure the standard deviation of the X distribution (for the full population, and for a sampled population)
# <li>VAR_POP(X) and VAR_SAMP(X) to measure the variance of the X distribution (for the full population, and for a sampled population)
# <li>COVAR_POP(X,Y) and COVAR_SAMP(X,Y) to measure the covariance between X and Y (for the full population, and for a sampled population)
# <li>CORR(X,Y) to measure the correlation between the columns X and Y
# <li>KURTOSIS(X) to measure the kurtosis of the X distribution **minus** 3 (the tailedness of the distribution, it should be around 0 for a Normal/Gaussian distribution)
# <li>SKEW(X) to measure the skewness of the X distribution (the asymetry of the distribution, it should be around 0 for a Normal/Gaussian distribution)
# </ul>

# %% [markdown]
# <footer style="padding:10px;background:#f9f9f9;border-bottom:3px solid #394851">©2022 Teradata. All Rights Reserved</footer>
