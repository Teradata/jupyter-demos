# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        ClearScape Analytics Environment<br>
#        Release Notes
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# This ClearScape Analytics Experience is running on a VM in the Google Cloud Platform (GCP) with:
# * vCPUS: 2
# * AMPs: 4
# * RAM: 22 GB
# * <b>Updated: Total Disk Storage: 120 GB</b>
# * Recommended Maximum DBMS table space: 28 GB.
#
# Even though it is running on GCP, data can be exchanged with all cloud platforms. We've provided demos in the catalog that integrate with data stored on AWS. This experience is focused on ClearScape Analytics and is agnostic to the surrounding cloud service.
#
# The standard "Free" usage is 40 hours over a 30 day period, based on 4 hours a day for half of the working days.  There is a Monitor application that will check your environment every 5 minutes and if there has been no usage for 2 hours, it will suspend your environment. You can return to the ClearScape Experience web console to resume your environment. That usually takes between 10 and 15 seconds. You can also suspend your environment manually from the  Console.
#
# You will receive a warning message if your environment has not been used in the past 14 days that in 14 more days, the environment will be deleted. However, you will still have an account and you can provision a new environment which has the advantage of getting the latest notebooks. If you use a notebook or run queries in Vantage, your environment will not be deleted.
#
# Each environment has a maximum life of 60 days.  You will receive a warning message at the end of 48 days about the pending end-of-life for your environment.  At 60 days it will be "Terminated" which will prevent you from starting it but allows you to request a short extension to recover any work.  Seven days after environments are terminated, they are deleted.
#
# We are working to improve our portfolio of notebooks and we encourage you to
# [submit your notebooks for publication.](./Getting_Started/How_to_Submit_Your_Demos/How_to_Share_Demos.ipynb)

# %% [markdown]
# <hr>
# <b style = 'font-size:18px;font-family:Arial;color:#E37C4D'>Changes:</b>

# %% [markdown]
# - #### 2025-12-19
#
# #### New Notebooks
# - Chatbot using Teradata's Enterprise Vector Store: Build a chat interface to ask questions using conversational AI after loading a selection of PDF files.
# - Vectore Store - Getting Started: Explore the key concepts, vector embedding mechanisms and efficient search techniques using Vector Store in VantageCloud Lake.
# - Getting Started with Teradata MCP Server on Teradata Vantage Enterprise - Installation: Download and install the required infrastructure to run the Teradata MCP Server connected to the local Vantage database.
# - Teradata MCP - Local Vantage Demo: Explore some of the features of the Teradata MCP Server. Run a chat bot to ask questions about the local Vantage Enterprise database.
# - Combining Structured and Unstructured Data for Predictive Modeling: Turn structured and unstructured data into meaningful features using embeddings and clustering and then send them to a model.
# - Supervised Text Classification using ONNX Embeddings and BYOM: Explore a practical approach to text classification using ONNXEmbeddings a a medical dataset.
# - Entity Resolution with In-Database Embeddings and Analytics: Model Creation: Install and run a local H2O instance to build a Binary Classification model using Open Source H2O AutoML.
# - Entity Resolution with In-Database Embeddings and Analytics: Enhance conventional text matching by incorporating semantic embeddngs derived from pre-trained language models.
# - Anomaly Detection in Credit Card Accounts: Use K-Means clustering to group similar transactions and identify anomalies based on Euclidean distances.
# - Teradata_AgentBuilder Getting Started: This notebook provides step by step instructions on how to create an agent, connect to the Teradata Enterprise MCP Server, access a Large Language Model, and then create a chat session with our database.
# - Improve Customer Satisfaction Through Travel Insights: Analyze how the distance a customer travels to a bank branch affects customer satisfaction.
# - Use Parallel CPU Inferencing of HuggingFace Models in Vantage to build a model: Select a HuggingFace Model, Load it into the database, then use Parallel Inferencing in-Db to create model files and embeddings tables for use in other demos.
# - Discover Customer Lifetime Value using Teradata AgentBuilder: Explore the capabilities of Teradata AgentBuilder to explore an AgenticAI workflow to ask questions and generate charts about Customer Lifetime Value.
#
# #### Updated Notebooks
# - ModelOps/05_ModelOps_BYOM_PIMA_H2O.ipynb- Getting_Started/Data_Loading/Data_Loading_SQL.ipynb
# - UseCases/Anomaly_Detection/Anomaly_Detection_PY_SQL.ipynb
# - UseCases/Health_Insurance/Health_Insurance_Costs_Python.ipynb
# - UseCases/Telco_Customer_Churn/Telco_Customer_Churn_GLM_Python.ipynb
# - UseCases/Telco_Customer_Churn/Telco_Customer_Churn_Python.ipynb
# - UseCases/Telco_Network_Coverage/Telco_Network_Coverage_Python.ipynb
# - UseCases/Train_Delay/Train_Delay_Python.ipynb
# - UseCases/Hyper_Personalization/Hyper_Personalization_PY_SQL.ipynb
# - UseCases/Credit_Risk_Assessment/Credit_Risk_Assessment_Python.ipynb
# - UseCases/Green_Manufacturing/Green_Manufacturing_Python.ipynb
# - UseCases/Heart_Failure_Prediction/Heart_Failure_Prediction_Python.ipynb
# - UseCases/Diabetes_Prediction/Diabetes_Prediction_via_DF_and_GLM_Python.ipynb/
# - UseCases/Telco_Complaints_Analysis_InVantage/Initialization_and_Model_Load.ipynb
# - UseCases/Telco_Complaints_Analysis_Onnx/Telco_Complaints_Analysis_Onnx.ipynb
# - UseCases/Anomaly_Detection/Anomaly_Detection_Python_TrustedAI.ipynb
# - UseCases/Supply_Chain_Visibility/Supply_Chain_Visibility_Python.ipynb
# - UseCases/Financial_Fraud_Detection_InDB/Financial_Fraud_Detection_InDB_R.ipynb
# - UseCases/Sales_Forecasting_AutoArima/Sales_Forecasting_AutoArima_Python.ipynb
# - UseCases/Vehicle_Routing_Delivery/Vehicle_Routing_Delivery_STO_PY_SQL.ipynb
# - UseCases/Shipping_Time_Prediction/Shipping_Time_Prediction_PY_SQL.ipynb
# - UseCases/Remaining_Useful_Life_Forecasting/Remaining_Useful_Life_Forecasting_PY_SQL.ipynb
# - UseCases/Vantage_Analytics_Library/VAL_Analytics_and_ML_SQL.ipynb
# - UseCases/Vantage_Analytics_Library/VAL_Descriptive_Statistics_SQL.ipynb
# - UseCases/Vantage_Analytics_Library/VAL_Hypothesis_Tests_SQL.ipynb
# - UseCases/Vantage_Analytics_Library/VAL_Overview_SQL.ipynb
# - UseCases/Vantage_Analytics_Library/VAL_teradataml_Demo_Python.ipynb
# - UseCases/Generative_Question_Answering_GenAI/Generative_Question_Answering_Python.ipynb
# - UseCases/Language_Models_InVantage/Initialization_and_Model_Load.ipynb
# - UseCases/Language_Models_InVantage/RAG_and_Bedrock_QueryPDF.ipynb
# - UseCases/Language_Models_InVantage/RAG_and_Bedrock_Querycatalogue.ipynb
# - UseCases/Language_Models_InVantage/Semantic_Clustering_Python.ipynb
# - UseCases/Language_Models_InVantage/Semantic_Similarity_Python.ipynb
# - UseCases/Broken_Digital_Journey/Broken_Digital_Journey_Python.ipynb
# - UseCases/Customer_Behavior_Analysis/Customer_Behavior_Analysis_Python.ipynb
# - UseCases/Financial_Customer_Journey/Financial_Customer_Journey_PY_SQL.ipynb
# - UseCases/ServiceNow_Multipath_PatternAnalysis/ServiceNow_Multipath_PatternAnalysis_Python.ipynb
# - UseCases/Teradata_End_to_End_Demos/Telco_Customer_Churn/Telco_Customer_Churn_Traditional_Approach.ipynb
# - UseCases/Teradata_End_to_End_Demos/Telco_Customer_Churn/Telco_Customer_Churn_AutoML_Approach.ipynb
# - UseCases/Car_Complaints/Car_Complaints_PY_SQL.ipynb
# - UseCases/Credit_Card_Data_Preparation/Credit_Card_Data_Preparation_Python.ipynb
# - UseCases/Customer_Behavior_Analysis/Customer_Behavior_Analysis_Python.ipynb
# - UseCases/Competitor_Proximity_Geospatial_Analysis/Competitor_Proximity_Geospatial_Analysis_Python.ipynb
# - UseCases/Teradata_End_to_End_Demos/Financial_Fraud_Detection/Financial_Fraud_Detection_AutoML_Approach.ipynb
# - UseCases/Teradata_End_to_End_Demos/Financial_Fraud_Detection/Financial_Fraud_Detection_Traditional_Approach.ipynb
# - UseCases/Teradata_End_to_End_Demos/Financial_Fraud_Detection/FinFraud_EndtoEnd_ModelOps_GIT_Python_indb_XGB.ipynb
# - VantageCloud_Lake/UseCases/Chatbot_Teradata_Vector_Store/requirements.txt
#
#
# #### New Filtering Options
# - <b>Teradata AgentBuilder</b>
#     - Enterprise MCP Server
#     - Flowise
#     - Vector Store
#     - VantageCloud
#
# <hr>

# %% [markdown]
# - #### 2025-10-07
#
# #### New Getting Started Notebooks
# - Enterprise Feature Store - DataDomain: Build and manage a feature store across multiple business domains.
# - Enterprise Feature Store - DatasetCatalog: Execute an end-to-end workflow that will build a feature store and dataset catalog.
# - Enterprise Feature Store - FeatureProcess: Build and manage a feature store for sales analytics. Execute an end-to-end process of feature engineering, transformation, and governance for sales transaction data.
# - Enterprise Feature Store - Feature Store: Build, manage, and utilize an enterprise feature store. Execute an  end-to-end workflow for feature engineering, ingestion, cataloging, and governance with features derived from business data such as sales, marketing, and transactions.
#
# <hr>

# %% [markdown]
# - #### 2025-10-03
#
# #### New Notebooks
# - Chat with VantageCloud Lake Using the Google ADK and the Teradata MCP Server: Use the Google ADK to connect to the Teradata MCP Server and ask questions about the databases in our VantageCloud Lake database.
# - ServiceNow Multipath Pattern Analysis: Use Vantage's nPath® functionality to unlock critical insights from a case history.
# - An Introduction to Parallel CPU Inferencing of HuggingFace Models in Vantage: Select a HuggingFace model, export the model into the database in ONNX format and then use Parallel inferencing in the database.
# - From Complaints to Clarity: Uncovering Hidden Trends in Telco Customer Feedback: See how a fully data-driven approach can help analyze large volumes of text data, automatically identifying topics and tracking their trends over time.
# - Telco Customer Churn Using Enterprise Feature Store (EFS): Use the massive parallel architecture of Teradata Vantage to prepare data, train, evaluate, and deploy models at unprecedented scale.
# - Telco Customer Churn using the GLM Function: Use Teradata’s machine learning and predictive analytics to build a model to predict customers which are likely to churn in the future.
#
# #### Updated Notebooks
# - ModelOps/05_ModelOps_BYOM_PIMA_H2O.ipynb
# - ModelOps/06_ModelOps_GIT_Project_Setup.ipynb
# - ModelOps/08_ModelOps_GIT_PIMA_Python_H2OAutoML.ipynb
# - UseCases/Generative_Question_Answering_GenAI/Generative_Question_Answering_Python.ipynb
# - Telco_Customer_Churn_Python.ipynb: Re-Titled to Telco Customer Churn using XGBoost
#
# #### New Filtering Options
# - <b>VantageCloud Lake</b>
#     - Open Analytics Framework
#     - Vectore Store
#     - VantageCloud Lake
#     - MCP Server
# - <b>Possible 2025</b>
#     - Workshop
# - <b>Other</b>
#     - Google ADK<b>
# <hr>

# %% [markdown]
# #### 2025-08-14
#
# #### New Notebooks
# - Banking Customer Churn Analysis using AutoML with a JSON Parameter File: Use Automated Machine Learning to automate the entire process of developing a predictive model by saving parameters into a JSON file and then execute the model to create a Prediction and a ROC curve.
# - Teradata Use Case Solution Offerings: Find out how Teradata can help you deliver better customer experience, build customer loyalty, and accelerate value leveraging the most powerful, open, and connected AI/ML capabilities on the market through our use case solution offerings
# - Analysis of NBA BasketBall Data: Use Language Modeling to return answers to common NBA Statistics questions for a single game or questions about players over several years.
# - End-to-End Demo for Customer Churn in Telco: Introduction to the traditional and automated approaches of building models to identify and predict customer churn.
# - Telco_Customer_Churn_Traditional_Approach.ipynb: Step through a traditional approach of building models to identify and predict customer churn.
# - Telco_EndtoEnd_ModelOps_GIT_Python_indb_DF.ipynb: Step through a traditional approach of building models to identify and predict customer churn and storing them in the database.
# - Telco_Customer_Churn_AutoML_Approach.ipynb: Step through an automated approach of building models to identify and predict customer churn.
# - End-to-End Demo for Financial Fraud Detection using Vantage: Introduction to the traditional and automated approaches of building models to detect fraud.
# - Financial Fraud Detection using AutoML: Step through an automated approach of building models to identify fraud.
# - Financial Fraud Detection using a Traditional Approach: Step through a traditional approach of building models to identify and identify fraud.
# - In-Database XGBoost using ModelOps and Git for Financial Fraud Detection: Step through a traditional approach of building models to identify and predict customer churn and storing them in the database.
# - Hospital Readmission using Teradata AutoML Functionality: Identify patients with a history of high hospital utilization, prescribed, or adjusted diabetes medications to derive predictions.
#
# #### Updated Notebooks
# - Plotting with teradataml Widgets
# - UseCases/Language_Models_InVantage: Initialization_and_Model_Load.ipynb
# - UseCases/Banking_Customer_Churn_AutoML: Banking_AutoML.ipynb
# - Diabetes Prediction via BYOM H2O: This uses BYOM to import a trained H2O model to identify potential diabetes patients. BYOM allows the data scientist to create models in languages they prefer and run at scale inside Vantage without moving data.
# - UseCases/Banking_Customer_Churn_IVSM: IVSM_Banking_Customer_Churn.ipynb
# - UseCases/Parkinsons_Disease_Prediction: Parkinsons_Disease_Prediction_Python.ipynb
# - Search all notebooks with a ChatBot and Database Connectivity: Use this notebook to create a chatbot that will answer questions about any of the notebooks in this Environment.
#
# #### New Filtering Options
# - <b>VantageCloud Lake</b>
#     - <b>Open Analytics Framework</b>
# - Solution Accelerator
#     - <b>End-to-End</b>
# - Getting Started
#     - <b>Demo Introduction</b>
#
# <hr>

# %% [markdown]
# #### 2025-04-11
#
# #### New Notebooks
# - Augmented Call Center: Revolutionizing Customer Support with Advanced AI Technologies
# - Customer Retail Journeys
# - Customer Segmentation with K-means Clustering and Data Preparation Pipelines
#
# #### New Recipes
# - BinarySeriesOp Function in Vantage
# - BinaryMatrixOP Function in Vantage
# - NPath Function in Vantage
# - PowerTransform Function in Vantage
# - Sessionize Function in Vantage
# - PowerSpec Function in Vantage
# - OneHotEncodingFit and OneHotEncodingTransform in Vantage
# - OrdinalEncodingFit and OrdinalEncodingTransform in Vantage
# - DataRobotPredict Function in Vantage
# - DFFT and IDFFT Functions in Vantage
# - DFFT2 and IDFFT2 Functions in Vantage
# - Kmeans and KMeansPredict Functions in Vantage
# - ScaleFit and ScaleTransform Functions in Vantage
# - RowNormalizeFit and RowNormalizeTransform Functions in Vantage
# - PolynomialFeaturesFit and PolynomialFeaturesTransform Functions in Vantage
# - SVM and SVMPredict Functions in Vantage.
# - Convolve Function in Vantage
# - Convolve2 Function in Vantage
# - DFFTConv Function in Vantage
# - DFFT2Conv Function in Vantage
# - Pack and Unpack Functions in Vantage
# - GenseriesSinusoids Function in Vantage
# - SentimentExtractor Function in Vantage
# - ACF and PACF Functions in Vantage
# - StringSimilarity Function in Vantage
# - TargetEncodingFit and TargetEncodingTransform Functions in Vantage
# - RandomProjectionMinComponents, RandomProjectionFit and RandomProjectionTransform Functions in Vantage
# - TextParser Function in Vantage
# - TrainTestSplit Function in Vantage
# - XGBoost and XGBoostPredict Functions in Vantage
# - NGramSplitter Function in Vantage
# - ConvertTo Function in Vantage
# - MovingAverage Function in Vantage
# - Arima Functions in Vantage
# - WhitesGeneral Function in Vantage
# - LineSpec Function in Vantage
# - NaiveBayesTextClassifierTrainer and NaiveBayesTextClassifierPredict Functions in Vantage
# - FillrowId Function in Vantage
# - DTW Function in Vantage
# - NumApply Function in Vantage
# - RoundColumns Function in Vantage
# - HoldWintersForecaster Function in Vantage
# - MAMean Function in Vantage
# - StrApply Function in Vantage
# - DickeyFuller Function in Vantage
# - ZTest Function in Vantage
# - DurbinWatson Function in Vantage
# - BreuschGodfrey Function in Vantage
# - BreuschPaganGodfrey Function in Vantage
# - RegressionEvaluator Function in Vantage
# - Silhouette Function in Vantage
# - CumulPeriodogram Function in Vantage
# - FitMetrics Function in Vantage
# - GLM and TDGLMPredict Functions in Vantage
# - SignifResidmean Function in Vantage
# - DecisionForest and TDDecisionForestPredict Functions in Vantage
# - SignifPeriodicities Function in Vantage
# - SelectionCriteria Function in Vantage
# - GLMPerSegment and GLMPredictPerSegment Functions in Vantage
# - Portman Function in Vantage
# - SimpleExp Function in Vantage
# - Extract Results Function in Vantage
# - InputValidator Function in Vantage
# - Minfo Function in Vantage
# - SInfo Function in Vantage
# - TrackingOp Function in Vantage
# - VectorDistance Function in Vantage
# - WordEmbeddings Function in Vantage
# - ROC Function in Vantage
# - ClassificationEvaluator Function in Vantage
# - ColumnTransformer Function in Vantage
# - Solve Imbalance Class Problems with ClearScape Analytics
# - Hashing Your Data
# - Video Analyzer with Google Gemini
# - Image2Matrix and Matrix2Image Functions in Vantage
# - Variational AutoEncoders (VAE) in Generative AI
#
# #### Updated Notebooks
# - Search all notebooks with a ChatBot using Vantage
# - Search all notebooks with a ChatBot using Pre-built Indexes
# - RAG solution with Embeding/Chunking in Vantge and AWS Bedrock integration
# - RAG solution with Vantage catalogue and AWS Bedrock integration
# - Complaints Analysis Integration with Customer360
#
# #### Updated ModelOps Notebooks
# - ModelOps00_ModelOps_Introduction.ipynb
# - ModelOps15_ModelOps_Feature_Engineering.ipynb
#
# #### New Filter Option
# - LangChain
#
# #### New Jupyter Feature
# - We're making an effort to update all the notebooks to use Jupyter's Dark Mode.
# <hr>
#
# #### 2025-02-25
#
# #### New Notebooks
# - Data Analyst AI Agent with LangChain and Google Gemini
# - <b>Recipes</b>
#     - OneClassSVM and OneClassSVMPredict functions in Vantage
#     - Fit and Transform functions in Vantage
#     - MatricMultiply Function in Vantage
#     - Attribution Function in Vantage
#     - NonLinearCombineFit and NonLinearCombineTransform Function in Vantage
#     - GenseriesFormula Function in Vantage
#
# #### Updated Notebooks
# - Chatbot using GenAI with insurance PDF document
#
# - <b>ModelOps</b>
#     - ModelOps Introduction & List of Notebooks
#     - ModelOps Add XGBoost to Project
#     - ModelOps demo: In-Database XGBoost using Git
#
# #### New Filter Options
# - LangSmith has been added under 3rd Party Tools
# <hr>
#
# #### 2025-02-07
#
# #### New Notebooks
# - Search all notebooks with a ChatBot
# - Search all notebooks with a ChatBot using Vantage
# - Advertising Sales Prediction using teradataml OpenSourceML in Vantage
# - Solve complex inventory issues with Vantage In-DB functions.
# - Telco Churn using Feature Store in Vantage
# - <b>Recipes</b>
#     - Automatic Data Pre-Processing with tdprepview
#     - TD GeoDataFrame to ESRI Conversion
#     - Hugging Face Model using Script Table Operator
#     - Using Pearson's chi-squared test function in Vantage
#     - Using the Analysis of Variance (Anova) function in Vantage
#     - Create a Workshop version of a Notebook
#     - Ftest function in Vantage
#     - CategoricalSummary function in Vantage
#     - ColumnSummary function in Vantage
#     - GetRowsWithMissingValues function in Vantage
#     - QQNorm function in Vantage
#     - Histogram function in Vantage
#     - Feature Store and Feature Engineering using tdfs4ds
#     - UnivariateStatistics function in Vantage
#     - WhichMax function in Vantage
#     - WhichMin function in Vantage
#     - SimpleImputeFit and SimpleImputeTransform functions in Vantage
#     - GetRowsWithoutMissingValues function in Vantage
#     - GetFutileColumns function in Vantage
#     - Resample function in Vantage
#     - Smoothma function in Vantage
#     - OutlierFilterFit and OutlierFilterTransform
#     - SeasonalNormalize and Unnormalize functions in Vantage
#     - DIFF and UNDIFF functions in Vantage
#     - LinearRegr function in Vantage
#     - MultivarRegr function in Vantage
#     - Deploy a Hyper-Segmented Model Scikit Learn Pipeline
#     - Interactive Npath Widget
#     - Antiselect function in Vantage
#     - BincodeFit and BincodeTransform functions in Vantage
# - <b>ModelOps</b>
#     - PIMA Predictions with teradataml OpenSourceML LightFBM using GIT
#     - ModelOps Notebook Scheduling using BYOM
#     - ModelOps BYOM with Dataiku
#     - ModelOps BYOM with Datarobot
#     - ModelOps Feature Engineering
#
# #### Updated Notebooks
# - ModelOps Introduction & List of Notebooks
# - 01 ModelOps Getting Started
# - Customer Complaints Analysis with Customer360 with Google Gemini
# - Complaints Summarization with Google Gemini
# - Complaints Classification with Google Gemini
# - Complaints Clustering with Google Gemini
# - Sentiment Analysis with Google Gemini
# - Semantic Clustering using OpenSource Language Models
# - Initiate Parallel CPU Inferencing of Hugging Face Models in Vantage
#
# #### New Filter Options
# - A new category of notebooks have been added: <b>Recipes</b>  These are currently being segregated by these topics:
#     - ClearScape Analytics Functions
#     - Model Pipelines
#     - Teradata Packages
#     - Vantage Database Functions
# - <b>Getting Started</b> has a new category: ExperienceBot
# - <b>Other</b> has a new category: <b>EFS</b>
# - <b>3rd Party Tools</b> has a new category: <b>DataRobot</b>
# <hr>
#
# #### 2024-08-01
# - Environments are now being created with 22GB of Memory.
#
# #### New Notebooks
# - Teradata Package for R (tdplyr) Basics
# - Customer Complaint Analyzer with GenAI
# - Introduction to the various Plot types using Teradataml Widgets.
# - Tutorial on using Teradataml Widgets
# - Banking Churn Prediction with AutoML
# - tdplyr R Basics
# - Customer Segmentation with K-means
# - Financial Fraud Detection InDB
# - Data Loading (R)
# - Generate Teradata SQL with GenAI and Bedrock
# - Predicting Medical Expenses in Healthcare
#
# #### Updated Notebooks
# - Multi-Touch Attribution for Business Analyst
# - Multi-Touch Attribution for Data Scientist
# - Generative AI Question Answering
# - Vehicle Routing for Delivery
# - Product Recommendation via AWS Bedrock
# - Chatbot using GenAI with insurance PDF document
# - Chatbot using GenAI with insurance PDF document
# - Natural Language Processing
# - Data Loading (Python)
# - Remaining Useful Life Forecasting
# - Data Loading (SQL)
#
# #### New Filter Options
# - The Beta process is now being deprecated.  It is being replaced with a a new filtering option: <b>New</b>.
#
# <hr>
#
# #### 2024-06-25
# - Environments are now being created with 22GB of Memory.
#
# #### New Notebooks
# - Mortgage Calculator Chatbot using Trusted AI(RAG) *Beta*
# - Fine-Tune OpenAI GPT-3.5 Turbo Model *Beta*
# - Credit Risk Assessment using Teradataml OpenSource Functions *Beta*
# - Convert PySpark to teradatamlspk
# - Mortgage Calculator chatbot using Gen AI: Fine-tune LLM *Beta*
# - Mortgage Calculator chatbot using Gen AI: RAG *Beta*
# - Customer Reviews Analysis using GenAI *Beta*
# - Anomaly Detection in Spot Welding Process - Trusted AI *Beta*
# - Parkinson's Disease Prediction using Signal Processing *Beta*
# - Mental Health Chat with Fine-tuned OpenAI Model *Beta*
#
# #### Updated Notebooks
# - 00_ModelOps_Introduction
# - 12_ModelOps_Model_Factory_REST_Python
# - Battery Defect Analysis
# - Energy Consumption Forecasting Dataiku
# - Sales Forecasting with Vantage vs SAS
# - Anomaly Detection of Outstanding Amounts
# - Telco 5G Quality of Experience
# - Store Sales Forecast via Prophet
# - Credit Card Data Preparation
#
# #### New Filter Options
# - The Analytic Function filter selection now contains two new options:
#     - Open Source
#     - Signal Processing
#
# <hr>
#
# #### 2024-04-29
# - New notebooks are now being deployed into the environment as <b>Beta</b> notebooks.  This means that you are invited to submit your reviews and recommendations to a new email address that is solely being used for listening to you.  The details are in the introductions of each Beta Notebook.
#
# ##### New Notebooks
# - Product Recommendation via AWS Bedrock *Beta*
# - Cancer Prediction using the TDAPIClient and VertexAI *Beta*
#
# ##### Updated Notebooks
# - Mortgage Calculator using GenAI
# - Generative AI Question Answering
# - Banking Customer Churn
# - Anomaly Detection
# <hr>
#
# #### 2024-04-18
# - New notebooks are now being deployed into the environment as <b>Beta</b> notebooks.  This means that you are invited to submit your reviews and recommendations to a new email address that is solely being used for listening to you.  The details are in the introductions of each Beta Notebook.
#
# ##### New Notebooks
# - Natural Language Processing *Beta*
# - Anomaly Detection of Outstanding Amounts *Beta*
# - Product Recommentations via TDApiClient *Beta*
# - Shipping Time Prediction *Beta*
# - Charting and Visualizations using teradataml *Beta*
#
# ##### Updated Notebooks
# - 4D Analytics on bike sharing
# - Mortgage Calculator using GenAI
# - Energy Consumption Forecasting
# - Financial Fraud Detection VIA BYOM
# - Financial Fraud Detection InDB
# - Heart Failure Prediction
# - Product Recommendations via OpenAI
# - Product Recommendations via Open Source
# - Green Manufacturing
# - Graph Analysis of CDR Records
# - Predictive Maintenance
# - Knee Replacement
#
# ##### Other Changes
# - Added new topics:
#     - Text Analysis
# - Added new Filter Section (not all sections have notebooks):
#     - Solution Accelerator
#         - Anomaly Detection
#         - Enterprise Feature Store
#         - Customer Complaint Analysis
#         - Model Factory
#
# <hr>
#
# #### 2024-03-28
# - New notebooks are now being deployed into the environment as <b>Beta</b> notebooks.  This means that you are invited to submit your reviews and recommendations to a new email address that is solely being used for listening to you.  The details are in the introductions of each Beta Notebook.
#
# ##### Updated Notebooks
# -  Customer Behavior Analysis
# -  Retail Demand Forecasting
# -  Anomaly Detection
# -  Train Delay Path Analysis
# -  Multi-Touch Attribution for Business Analyst
# -  Multi-Touch Attribution for Data Scientist
# -  Financial Fraud Detection inDB
# -  Financial Fraud Detection VIA BYOM
# -  Telco Customer Churn
# -  Broken Digital Journey
# -  Store Sales Forecasting via ARIMA
# -  Heart Failure Prediction
# -  Telco Network Coverage
# -  Financial Customer Journey
# -  Energy Consumption Forecasting
# -  Generative AI Question Answering
# -  Energy Consumption Forecasting using AzureML
# -  ModelOPs Introduction & List of Notebooks
# -  Diabetes Prediction via BYOM H2O
# -  Diabetes Prediction via DF and GLM
#
# ##### New Notebooks
# -  Hyperparameter tuning *Beta*
# -  Grocery Recommendations using GenAI *Beta*
# -  Using ClearScape Analytics with OpenAI *Beta*
# -  Getting Started With Azure *Beta*
# -  Signal Processing and Classification *Beta*
# -  Cancer Prediction using Teradata and the SageMaker API *Beta*
#
# ##### Other Changes
# - Added a new Industry: Defense
# - Added new topics:
#     - Prediction Analysis
#     - Vertex AI
#     - Beta Review
#     - Azure Cloud
# - Added a new Filter Section: <b>Other</b> (This includes includes a filter for the new Beta notebooks.)
# <hr>
#
# #### 2024-01-23
# - Added the notebook, "ModelOps demo: In-Database XGBoost using Git".
# - Added an option to skip to the Table of Contents in the "ClearScape Analytics™ ModelOps Demonstrations" Introduction notebook.
#
#
# #### 2023-12-27
# - Added a new filter for SQL or Python.
#
# ##### Added new notebooks:
# - Chatbot using GenAI with insurance PDF document
# - Credit Card Data Preparation
# - Mortage Calculator using GenAI
# - Sales Forecasting with Vantage vs SAS
# - Supply Chain Visibility
# - Telco 5G Quality of Experience
# - Vehicle Routing for Delivery
#
#
# #### 2023-11-16
# - Added 25 new Read Only versions of the notebooks
#
# #### 2023-08-30
# - Flood Proximity to Climate Risk Analysis
# - Product recommendations via Open Source - suggests additional products consumer might purchase
#
# #### 2023-08-06
# - Energy Consumption Forecasting using AzureML plus ClearScape Analytics
# - Customer 360 - integrating data about customers from multiple sources
#
# #### 2023-08-02
# - Generative AI Question Answering = translates english language questions to SQL
# - Competitor Proximity Geospatial Analysis - Support proximity based marketing
# - Recommendation product search - suggests additional products consumer might purchase
#
# #### 2023-07-16
# - Added Cash Demand Forecasting
# - Added Query Service REST API demonstration
# - Updated Table of contents to simplify selections when multiple languages are available
#
# #### 2023-07-04
# - Added ModelOps application and 11 demonstration notebookes
# - Added Hyper Personalization to recommend best offer
# - Added Graph analysis of Telco CDR records to identify key influencers
# - Added Marketing Campaign Effectiveness
# - Added Multi-Touch Attribution with versions for Data Scientists and business users
# - Added Retail item demand forecast to build models for multiple SKUs
# - Added Store Sales Volume forecasting using Prophet and STO
# - Added Store Sales Volume forecasting using ARIMA
#
# #### 2023-06-07
# - Added Retail Demand Forecasting
# - Added Energy Consumption Forecasting using Dataiku
# - Added MultiTouch Attribution
# - Added Remaining Useful Life Forecasting
# - Added Customer Behavior Analysis for Python and PY_SQL
#
# #### 2023-05-21
# - Added Getting started notebook for data loading using SQL
# - Added Getting started notebook for data loading using Python
# - Added new python version of the Austin Bike Share demo with interactive maps
# - Added Anomaly Detection in manufacturing welding
# - Added Car Complaints
# - Added Train Delay analysis
# - Revised Air Passenger Forecasting for accuracy
# - Revised Financial Fraud Detection in DB using Python for accuracy
#
# #### 2023-05-14
# - Added Python version of Financial Fraud Detection via BYOM
# - Added Python version of Financial Fraud Detection InDB
# - Added Python version of Data Prep and Transformation
#
# #### 2023-05-07
# - Added Green Manufacturing
# - Added Heart Failure Prediction
# - Added Diabetes Prediction via Decision Forest (DF) and Generalized Linear Model (GLM)
# - Added Predictive Maintenance
# - Improved graphics in Energy Consumption Forecasting
#
# #### 2023-05-01
# - Added Financial Customer Journey, both SQL and PY_SQL versions
# - Added Financial Fraud Detection via BYOM
# - added Predictive Maintenance
#
# #### 2023-04-25
# - Updated README.md with improved index
#
# #### 2023-04-18
# - Availability to the public
#
# #### 2023-01-16
# - Initial release at Sales Kickoff in Vancouver
