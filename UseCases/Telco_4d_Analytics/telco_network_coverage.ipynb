# %% [markdown]
# <header style="padding:1px;background:#f9f9f9;border-top:3px solid #00b2b1"><img id="Teradata-logo" src="https://www.teradata.com/Teradata/Images/Rebrand/Teradata_logo-two_color.png" alt="Teradata" width="220" align="right" />
#
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>Telco Network Coverage</b>
# </header>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'><b>Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>Teradata® Geospatial Utilities User Guide: <a href = 'https://docs.teradata.com/r/Teradata-Geospatial-Utilities-User-Guide/June-2022/Teradata-Geospatial-Utilities-Overview/Welcome-to-Teradata-Tools-and-Utilities-Teradata-Geospatial-Utilities-User-Guide'>https://docs.teradata.com/r/Teradata-Geospatial-Utilities-User-Guide/June-2022/Teradata-Geospatial-Utilities-Overview/Welcome-to-Teradata-Tools-and-Utilities-Teradata-Geospatial-Utilities-User-Guide</a></li>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
# Driving Spatial Insights for Network Optimization to optimize network layouts to minimize construction costs and plan least-cost network, reducing CapEx
# </p>
# <p style = 'font-size:16px;font-family:Arial'>
# Mobile communication is one of the technology that is very asociated in the present era, with the rapid development of technology. Telecommunications tower that is a supporting factor of mobile telecommunications services are constantly constructed as a form of community needs in communication.
# </p>
# <p style = 'font-size:16px;font-family:Arial'>
# To achieve these objectives, the calculation of the number of mobile subscribers and traffic capacity into a method of planning is needed in determining the number of base stations and telecommunications towers
#
#
# </p>
#
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Analyzing New Potential Coverage Area using GIS</b></p>
#
# <p style = 'font-size:16px;font-family:Arial'>With geographic information in the form of geographic Information systems (GIS) can provide information about the reach and area of signal strength in each telecommunication tower, information about prospective customers who are in an area that has not been reached by the existing tower so that it can be a reference for the addition of towers, this information system can facilitate the service provider to determine the service users who will be subscribe.
# </p>

# %% [markdown]
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>Initial Data Sets</b>
#
# <p style = 'font-size:16px;font-family:Arial'>Coverage Map : Polygon based Shape (Geospatial data) file of  a geographical area. </p>
# <p style = 'font-size:16px;font-family:Arial'>Cell Sites/Towers : Geographical location (Longitude and Latitude) of Cell Towers with additional details of the Cell Towers. </p>
# <p style = 'font-size:16px;font-family:Arial'>Aggregated Customer Experience : Geographical points (Longitude and Latitude) of customer experience using RSCP/signal dBm values </p>
# <p style = 'font-size:16px;font-family:Arial'>Customer Journey : Contains the Customer Journey steps for all 364 Journeys. It’s the super set. Contains details like Incremental Journey Sequence,Incremental Timestamp for each step based on the mode of Transport,Values of signal_dBm,Geographical co-ordinates of each journey,Mobile App,Throughput
#  </p>

# %%
%connect Vantage-LIVE
# Out:
# Success: 'Vantage-LIVE' connection established and activated for user 'nl186010'

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Coveage Map Table</b></p>

# %%
/*Coverage Map data is loaded in table using GeoImport utility */
select * from TRNG_TELCONETWORK.NEXTGEN_MOBILE_NW_COVERAGE_MAP sample 10;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory393441"><style>
#       table.tdhistory393441 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory393441 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory393441:last-child { text-align: left !important; }
#       tbody.tdhistory393441 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# This map data is stored in the format of polygon and multipolygon in ST_Geometry Datatype.
# To read more about Teradata Vantage™ - Geospatial Data Types, please refer https://docs.teradata.com/r/Teradata-VantageTM-Geospatial-Data-Types/June-2022/Introduction-to-Geospatial-Data-Types

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Cell Tower Table</b></p>

# %%
select * from TRNG_TELCONETWORK.NEXTGEN_MOBILE_NW_CELL_TOWERS sample 10;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory323720"><style>
#       table.tdhistory323720 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory323720 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory323720:last-child { text-align: left !important; }
#       tbody.tdhistory323720 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Aggregated Customer Experience Table</b></p>

# %%
select * from TRNG_TelcoNetwork.NEXTGEN_MOBILE_NW_GPSLOC_CUM_EXPERIENCE sample 10;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory72632"><style>
#       table.tdhistory72632 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory72632 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory72632:last-child { text-align: left !important; }
#       tbody.tdhistory72632 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory72632 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
# ...

# %% [markdown]
# BTS antenna Coverage Area is a distribution of signals from the antenna on the earth surface. The aspects affecting the coverage area are the type of antenna, the type of environment, the propagation model, the cell radius and the power budget.
#
# The Signal strength is measured in RSCP(received signal code power) which denoted the power measured by a receiver on a particular physical communication channel. It is used as an indication of signal strength, as a handover criterion.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Visualization</b></p>
#
# <p>*Visualisation for this usecase is done in open source tools Geoserver & QGIS which needs separate installations and are beyond scope. </p>
# <p>Data from Teradata can be exported in the form of shape files or Geojson which can be used in any visualization tool for geometry data.</p>

# %% [markdown]
# ![image.png](attachment:18cea7bf-4fa8-4173-9180-0638bd26c22c.png)

# %% [markdown]
# In the visualization above we can see the cell towers and the associated signal strengths for the same.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Customer Journey Table</b></p>

# %%
Select * from TRNG_TELCONETWORK.NEXTGEN_MOBILE_NW_CUST_JOURNEY_SCALED sample 10;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory140570"><style>
#       table.tdhistory140570 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory140570 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory140570:last-child { text-align: left !important; }
#       tbody.tdhistory140570 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# The original source table looks like above. From the data above we created 1 row for each customer journey in the new table with all journey steps in the same row. For example, if a journey has 35 steps then all the 35 steps will be created in one row.

# %%
select * from TRNG_TELCONETWORK.NEXTGEN_MOBILE_NW_CUST_NAVIGATION sample 10;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory817968"><style>
#       table.tdhistory817968 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory817968 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory817968:last-child { text-align: left !important; }
#       tbody.tdhistory817968 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# The above data was inserted in the table using the query below.

# %%
SELECT top 5
CUSTOMER_ID,
JOURNEY_ID,
'LINESTRING('||TRIM(TRAILING ',' FROM (XMLAGG(JOURNEY_GEOM || ','  ORDER BY JOURNEY_SEQ ASC ) (VARCHAR(10000))))||'))' AS JOURNEY_NAV
FROM
(
SEL
CUSTOMER_ID AS CUSTOMER_ID,
JOURNEY_ID AS JOURNEY_ID , 
JOURNEY_SEQ,
TRIM(OREPLACE(OREPLACE(CAST(JOURNEY_GEOM AS VARCHAR(100)),'POINT (',''),')','')) AS JOURNEY_GEOM
FROM  TRNG_TELCONETWORK.NEXTGEN_MOBILE_NW_CUST_JOURNEY_SCALED
)A
GROUP BY CUSTOMER_ID,JOURNEY_ID;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory99745"><style>
#       table.tdhistory99745 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99745 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99745:last-child { text-align: left !important; }
#       tbody.tdhistory99745 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory99745 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
# ...

# %% [markdown]
# We have used 5 journeys for visulatization.
# Based on the source data above, we have calculated the mobility and navigation diection of the customer journey.
#
# •	Speed - In the midpoint of the journey display the mode of transport. To do this, calculate the speed and based on the below range classify with the mode of transport.
#
# <style>
# table, th, td {
#   border: 1px solid black;
#   border-collapse: collapse;
# }
# </style>
# <body>
# <table style="width:100%">
#   <tr>
#     <th>Speed Value Range Low</th>
#     <th>Speed Value Range High</th>
#     <th>Resulting Value</th>
#   </tr>
#   <tr>
#     <td>0.4</td>
#     <td>0.6</td>
#     <td>A(UTOMOBILE)</td>
#   </tr>
#   <tr>
#     <td>0.08</td>
#     <td>0.2</td>
#     <td>C(YCLING)</td>
#   </tr>
#     <tr>
#     <td>0.04</td>
#     <td>0.07</td>
#     <td>W(ALKING)</td>
#   </tr>
# </table>
#
# </body>
#
# •	Navigation Direction – Using the start and end points of each journey, find the direction of the overall journey.
#
# <style>
# table, th, td {
#   border: 1px solid black;
#   border-collapse: collapse;
# }
# </style>
# <body>
# <table style="width:100%">
#   <tr>
#     <th>HeadingN  Value Range Low</th>
#     <th>HeadingN  Value Range High</th>
#     <th>Direction</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>22.49</td>
#     <td>N</td>
#   </tr>
#   <tr>
#     <td>22.5</td>
#     <td>67.49</td>
#     <td>NE</td>
#   </tr>
#     <tr>
#     <td>67.5</td>
#     <td>112.49</td>
#     <td>E</td>
#   </tr>
#    <tr>
#     <td>112.5</td>
#     <td>157.49</td>
#     <td>SE</td>
#   </tr>
#    <tr>
#     <td>157.5</td>
#     <td>202.49</td>
#     <td>S</td>
#   </tr>
#        <tr>
#     <td>202.5</td>
#     <td>247.49</td>
#     <td>SW</td>
#   </tr>
#         <tr>
#     <td>247.5</td>
#     <td>292.49</td>
#     <td>W</td>
#            </tr>
#         <tr>
#     <td>292.5</td>
#     <td>337.49</td>
#     <td>NW</td>
#   </tr>
#         <tr>
#     <td>337.5</td>
#     <td>360</td>
#     <td>N</td>
#   </tr>
# </table>
#
# </body>

# %%
select * from TRNG_TELCONETWORK.NEXTGEN_MOBILE_NW_CUST_JOURNEY_MOBILITY;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory667757"><style>
#       table.tdhistory667757 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory667757 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory667757:last-child { text-align: left !important; }
#       tbody.tdhistory667757 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
# ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Visualization</b></p>

# %% [markdown]
# ![image.png](attachment:92546fd4-30c1-4d00-9d48-4ef411a6e39a.png)

# %% [markdown]
# In this visualization we can see the route customer took when he was in the coverage area along with the signal strength he was getting at the point of observation. We have also added information about the vehicle he might be using based on calculated speed.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Conclusion</b></p>
# Tower map distribution in digital form can be used as one tool that can facilitate the operational field for monitoring, organizing BTS assets owned by the company in one map view.
#
# With the existence of a map of the potential analysis of service areas, this can be used as reference for stakeholders to help determine decisions in terms of telecommunications development based on spatial data that has been analyzed.
