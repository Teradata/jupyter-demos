# %% [markdown]
# <header style="padding:1px;background:#f9f9f9;border-top:3px solid #00b2b1"><img id="Teradata-logo" src="https://www.teradata.com/Teradata/Images/Rebrand/Teradata_logo-two_color.png" alt="Teradata" width="220" align="right" />
#
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>Time Series Analysis - Analyzing Consumer Complaints Over Time</b>
# </header>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
# In this example we will be analyzing the number of complaints over time received by the Consumer Financial Protection Bureau (CFPB).
# <p style = 'font-size:16px;font-family:Arial'>
# How can we use Vantage to extract insights and tell a story behind a dataset? In this use case, you will see how powerful and simple it is to extract answers from a public dataset available through <a href="http://data.gov">Data.gov</a>. We use SQL and a visualization tool to analyze the number of complaints over time to answer the following questions:
# <br><p style = 'font-size:16px;font-family:Arial'>
#  <i>What are the trends of complaints over time? How can we interpret the outliers in the dataset?</i>
# <br>
# <p style = 'font-size:16px;font-family:Arial'>
# By answering questions like the ones above, we gain a deeper understanding of the dataset, and we can explain in plain language how the number of complaints evolve over time. In the Explore section, we focus on analyzing the number of complaints over time and identifying trends and outliers in the time series to answer the questions above.
# </p>

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>1. Connect to Vantage</b></p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'> <b>Let's start by connecting to the Teradata system </b></p>
# <p style = 'font-size:16px;font-family:Arial'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
Set query_band='DEMO=Consumer_Complaints_SQL.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'> <b>Getting Data for This Demo</b></p>
# <p style = 'font-size:16px;font-family:Arial'>We have provided data for this demo on cloud storage. In this demo since we are using Temporal table we will be creating databases and tables in local storage and use them in the notebook. Please execute the procedure in the next cell.</p>

# %%
call get_data('DEMO_Financial_cloud');    -- takes about 50 seconds, estimated space: 0 MB
--call get_data('DEMO_Financial_local');     -- takes about 4 minutes, estimated space: 300 MB
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory50470"><style>
#       table.tdhistory50470 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory50470 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory50470:last-child { text-align: left !important; }
#       tbody.tdhistory50470 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory50470 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory50470 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory50470"></th><th class="tdhistory50470">Message</th></tr></thead><tbody class="tdhistory50470 resultset-body"><tr><th class="tdhistory50470" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory50470">That ran for   0:00:38.73 with 17 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();  -- optional, takes about 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory787458"><style>
#       table.tdhistory787458 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory787458 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory787458:last-child { text-align: left !important; }
#       tbody.tdhistory787458 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory787458 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory787458 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory787458"></th><th class="tdhistory787458">Space_Report</th></tr></thead><tbody class="tdhistory787458 resultset-body"><tr><th class="tdhistory787458" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory787458">You have:  #databases=1 #tables=7 #views=14  You have used 1.7 MB of 27,914.4 MB available - 0.0%  ... Space Usage OK</td></tr><tr><th class="tdhistory787458" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory787458"> </td></tr><tr><th class="tdhistory787458" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory787458">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory787458" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory787458">   demo_user                            7       7  27,914.4 MB       1.7 MB </td></tr><tr><th class="tdhistory787458" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory787458">   DEMO_Financial                       0       7       0.0 MB       0.0 MB </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>2.  Querying the Data</b></p>
# <p style = 'font-size:16px;font-family:Arial'>We have made our connection to the Vantage system, now let's start exploring the data. We'll start by counting the number of rows in the table.

# %%
select count(*) from DEMO_Financial.Consumer_complaints;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory871596"><style>
#       table.tdhistory871596 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory871596 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory871596:last-child { text-align: left !important; }
#       tbody.tdhistory871596 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory871596 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory871596 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory871596"></th><th class="tdhistory871596">Count(*)</th></tr></thead><tbody class="tdhistory871596 resultset-body"><tr><th class="tdhistory871596" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory871596">1273782</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
# There are just under 1.3 million rows. Not a problem to analyze large datasets using Vantage, lets take a look at a sample of the data.

# %%
select TOP 100 * from DEMO_Financial.Consumer_Complaints;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory324918"><style>
#       table.tdhistory324918 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory324918 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory324918:last-child { text-align: left !important; }
#       tbody.tdhistory324918 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory324918 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory324918 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory324918"></th><th class="tdhistory324918">date_received</th><th class="tdhistory324918">product</th><th class="tdhistory324918">sub_product</th><th class="tdhistory324918">issue</th><th class="tdhistory324918">sub_issue</th><th class="tdhistory324918">consumer_complaint_narrative</th><th class="tdhistory324918">company_public_response</th><th class="tdhistory324918">company</th><th class="tdhistory324918">state</th><th class="tdhistory324918">zip_code</th><th class="tdhistory324918">tags</th><th class="tdhistory324918">consumer_consent_provided</th><th class="tdhistory324918">submitted_via</th><th class="tdhistory324918">date_sent_to_company</th><th class="tdhistory324918">company_response_to_consumer</th><th class="tdhistory324918">timely_response</th><th class="tdhistory324918">consumer_disputed</th><th class="tdhistory324918">complaint_id</th></tr></thead><tbody class="tdhistory324918 resultset-body"><tr><th class="tdhistory324918" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory324918">2017-05-05</td><td class="tdhistory324918">Debt collection</td><td class="tdhistory324918">Medical debt</td><td class="tdhistory324918">Attempts to collect debt not owed</td><td class="tdhistory324918">Debt is not yours</td><td class="tdhistory324918"></td><td class="tdhistory324918"></td><td class="tdhistory324918">OPTIMUM OUTCOMES, INC.</td><td class="tdhistory324918">GA</td><td class="tdhistory324918">30083</td><td class="tdhistory324918"></td><td class="tdhistory324918"></td><td class="tdhistory324918">Postal mail</td><td class="tdhistory324918">2017-05-15</td><td class="tdhistory324918">Closed with explanation</td><td class="tdhistory324918">Yes</td><td class="tdhistory324918"></td><td class="tdhistory324918">2476894</td></tr><tr><th class="tdhistory324918" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory324918">2017-05-05</td><td class="tdhistory324918">Debt collection</td><td class="tdhistory324918">Credit card debt</td><td class="tdhistory324918">Took or threatened to take negative or legal action</td><td class="tdhistory324918">Threatened or suggested your credit would be damaged</td><td class="tdhistory324918">F</td><td class="tdhistory324918"></td><td class="tdhistory324918">ENCORE CAPITAL GROUP INC.</td><td class="tdhistory324918">NY</td><td class="tdhistory324918">104XX</td><td class="tdhistory324918"></td><td class="tdhistory324918">Consent provided</td><td class="tdhistory324918">Web</td><td class="tdhistory324918">2017-05-12</td><td class="tdhistory324918">Closed with explanation</td><td class="tdhistory324918">Yes</td><td class="tdhistory324918"></td><td class="tdhistory324918">2476519</td></tr><tr><th class="tdhistory324918" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory324918">2017-05-05</td><td class="tdhistory324918">Credit card or prepaid card</td><td class="tdhistory324918">Store credit card</td><td class="tdhistory324918">Advertising and marketing, including promotional offers</td><td class="tdhistory324918">Confusing or misleading advertising about the credit card</td><td class="tdhistory324918">I</td><td class="tdhistory324918">Company has responded to the consumer and the CFPB and chooses not to provide a public response</td><td class="tdhistory324918">CITIBANK, N.A.</td><td class="tdhistory324918">MD</td><td class="tdhistory324918"></td><td class="tdhistory324918">Servicemember</td><td class="tdhistory324918">Consent provided</td><td class="tdhistory324918">Web</td><td class="tdhistory324918">2017-05-05</td><td class="tdhistory324918">Closed with explanation</td><td class="tdhistory324918">Yes</td><td class="tdhistory324918"></td><td class="tdhistory324918">2476865</td></tr><tr><th class="tdhistory324918" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory324918">2017-05-05</td><td class="tdhistory324918">Credit reporting, credit ...

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>3.  Visualizing the Data</b></p>
# <p style = 'font-size:16px;font-family:Arial'>
# From the query above, we notice that this dataset has a lot of information. To derive some insights, we need to start grouping the data.
# <p style = 'font-size:16px;font-family:Arial'>
# The first column is <b>date_received</b>. This is the date the complaints were received, and it means that we can look at a time series plot of the data. Let's start by grouping the counts of <b>complaint_id</b> over time, using <b>date_received</b> as our time axis.

# %%
select date_received, count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
group by date_received;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory210078"><style>
#       table.tdhistory210078 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory210078 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory210078:last-child { text-align: left !important; }
#       tbody.tdhistory210078 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory210078 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory210078 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory210078"></th><th class="tdhistory210078">date_received</th><th class="tdhistory210078">counts</th></tr></thead><tbody class="tdhistory210078 resultset-body"><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory210078">2017-06-15</td><td class="tdhistory210078">728</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory210078">2014-01-04</td><td class="tdhistory210078">178</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory210078">2018-07-23</td><td class="tdhistory210078">754</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory210078">2014-08-15</td><td class="tdhistory210078">475</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory210078">2019-01-20</td><td class="tdhistory210078">233</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory210078">2016-10-07</td><td class="tdhistory210078">624</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory210078">2011-12-26</td><td class="tdhistory210078">21</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory210078">2016-03-20</td><td class="tdhistory210078">200</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory210078">2012-06-23</td><td class="tdhistory210078">66</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory210078">2018-05-12</td><td class="tdhistory210078">418</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory210078">2013-07-31</td><td class="tdhistory210078">473</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory210078">2015-09-23</td><td class="tdhistory210078">751</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory210078">2013-07-07</td><td class="tdhistory210078">57</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory210078">2012-05-08</td><td class="tdhistory210078">275</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory210078">2017-09-04</td><td class="tdhistory210078">298</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory210078">2013-08-03</td><td class="tdhistory210078">148</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory210078">2015-02-12</td><td class="tdhistory210078">593</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory210078">2018-03-01</td><td class="tdhistory210078">919</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory210078">2016-02-05</td><td class="tdhistory210078">576</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory210078">2017-04-28</td><td class="tdhistory210078">727</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistory210078">2017-04-04</td><td class="tdhistory210078">914</td></tr><tr><th class="tdhistory210078" style= "background: rgba(243, 243, 243, 0.75)">22</th><td class="tdhistory210078">2017-09-28</td><td class="tdhistory210078">886</td></tr><tr><th class="tdhistory2 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
# This is great; we now have the number of complaints (<b>counts</b>) by time (<b>date_received</b>), but how do we make sense of this data? Let's plot this time series on a graph.

# %%
%chart date_received, counts, title='Number of Complaints over Time', width=900, height=400

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
# By visualizing the data above, we can see that the number of complaints varies a lot over time and there also seem to be more complaints as time progresses. There are also some unusual spikes in 2017. Let's understand more about our data. We start by looking at the general trend.
# <br>
# Let's group the data by month and replot the graph above.

# %%
select extract(year from date_received) || extract(month from date_received) as month_date, count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
group by month_date
order by month_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory191438"><style>
#       table.tdhistory191438 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory191438 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory191438:last-child { text-align: left !important; }
#       tbody.tdhistory191438 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory191438 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory191438 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory191438"></th><th class="tdhistory191438">month_date</th><th class="tdhistory191438">counts</th></tr></thead><tbody class="tdhistory191438 resultset-body"><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory191438">       2011         12</td><td class="tdhistory191438">2536</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory191438">       2012          1</td><td class="tdhistory191438">3230</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory191438">       2012          2</td><td class="tdhistory191438">3509</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory191438">       2012          3</td><td class="tdhistory191438">6230</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory191438">       2012          4</td><td class="tdhistory191438">5703</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory191438">       2012          5</td><td class="tdhistory191438">7617</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory191438">       2012          6</td><td class="tdhistory191438">7841</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory191438">       2012          7</td><td class="tdhistory191438">6755</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory191438">       2012          8</td><td class="tdhistory191438">6877</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory191438">       2012          9</td><td class="tdhistory191438">5493</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory191438">       2012         10</td><td class="tdhistory191438">6741</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory191438">       2012         11</td><td class="tdhistory191438">6139</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory191438">       2012         12</td><td class="tdhistory191438">6238</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory191438">       2013          1</td><td class="tdhistory191438">9741</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory191438">       2013          2</td><td class="tdhistory191438">8349</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory191438">       2013          3</td><td class="tdhistory191438">8784</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory191438">       2013          4</td><td class="tdhistory191438">8633</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory191438">       2013          5</td><td class="tdhistory191438">8170</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory191438">       2013          6</td><td class="tdhistory191438">8035</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory191438">       2013          7</td><td class="tdhistory191438">9271</td></tr><tr><th class="tdhistory191438" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistor ...

# %%
%chart month_date, counts, title='Number of Complaints by Month and Year', width=900, height=400, mark=line

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Looking at complaints over month and year, we see there is clearly an upward trend. One hypothesis is that as time progresses, people get more conscious and spread the word. The media can also advertise the complaint channels over time. Through this chart we can see clearly the spikes that we saw above were in January 2017 and September 2017. Let's dive deeper into these dates and draw some insights on the next step.

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>4.  Extracting Insights from the Data</b></p>
# <p style = 'font-size:16px;font-family:Arial'>
# Let's narrow down the two spikes above and see exactly where they are happening. We can do this by ploting another time series plot, this time only in 2017.

# %%
select date_received, count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
where year(date_received) = 2017
group by date_received
order by date_received;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory82908"><style>
#       table.tdhistory82908 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory82908 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory82908:last-child { text-align: left !important; }
#       tbody.tdhistory82908 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory82908 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory82908 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory82908"></th><th class="tdhistory82908">date_received</th><th class="tdhistory82908">counts</th></tr></thead><tbody class="tdhistory82908 resultset-body"><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory82908">2017-01-01</td><td class="tdhistory82908">105</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory82908">2017-01-02</td><td class="tdhistory82908">299</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory82908">2017-01-03</td><td class="tdhistory82908">604</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory82908">2017-01-04</td><td class="tdhistory82908">789</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory82908">2017-01-05</td><td class="tdhistory82908">718</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory82908">2017-01-06</td><td class="tdhistory82908">656</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory82908">2017-01-07</td><td class="tdhistory82908">257</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory82908">2017-01-08</td><td class="tdhistory82908">232</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory82908">2017-01-09</td><td class="tdhistory82908">585</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory82908">2017-01-10</td><td class="tdhistory82908">744</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory82908">2017-01-11</td><td class="tdhistory82908">744</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory82908">2017-01-12</td><td class="tdhistory82908">603</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory82908">2017-01-13</td><td class="tdhistory82908">691</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory82908">2017-01-14</td><td class="tdhistory82908">297</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory82908">2017-01-15</td><td class="tdhistory82908">219</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory82908">2017-01-16</td><td class="tdhistory82908">332</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory82908">2017-01-17</td><td class="tdhistory82908">625</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory82908">2017-01-18</td><td class="tdhistory82908">900</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory82908">2017-01-19</td><td class="tdhistory82908">2070</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory82908">2017-01-20</td><td class="tdhistory82908">1633</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistory82908">2017-01-21</td><td class="tdhistory82908">559</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">22</th><td class="tdhistory82908">2017-01-22</td><td class="tdhistory82908">360</td></tr><tr><th class="tdhistory82908" style= "background: rgba(243, 243, 243, 0.75)">23</th><td c ...

# %%
%chart date_received, counts, title='Complaints over time - 2017', width=900, height=400, mark=line

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>As we look at the peaks, we find that they occurred from January 15th to 21st and during the first week of September. To find the actual dates of the peaks, we can limit the query to pick up at least 1,500 complaints a day.

# %%
select date_received,
    month(date_received) as month_date,
    count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
where year(date_received) = 2017 and month_date in (1, 9)
group by date_received
having counts >= 1500
order by month_date, counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory404445"><style>
#       table.tdhistory404445 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory404445 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory404445:last-child { text-align: left !important; }
#       tbody.tdhistory404445 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory404445 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory404445 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory404445"></th><th class="tdhistory404445">date_received</th><th class="tdhistory404445">month_date</th><th class="tdhistory404445">counts</th></tr></thead><tbody class="tdhistory404445 resultset-body"><tr><th class="tdhistory404445" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory404445">2017-01-19</td><td class="tdhistory404445">1</td><td class="tdhistory404445">2070</td></tr><tr><th class="tdhistory404445" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory404445">2017-01-20</td><td class="tdhistory404445">1</td><td class="tdhistory404445">1633</td></tr><tr><th class="tdhistory404445" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory404445">2017-09-08</td><td class="tdhistory404445">9</td><td class="tdhistory404445">3553</td></tr><tr><th class="tdhistory404445" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory404445">2017-09-09</td><td class="tdhistory404445">9</td><td class="tdhistory404445">2709</td></tr><tr><th class="tdhistory404445" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory404445">2017-09-13</td><td class="tdhistory404445">9</td><td class="tdhistory404445">1600</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Let's look at some of the issues that were reported during these dates.

# %%
select date_received, company, count(company) as counts
from DEMO_Financial.Consumer_Complaints
where date_received in (
    date '2017-01-19',
    date '2017-01-20',
    date '2017-09-08',
    date '2017-09-09',
    date '2017-09-13'
)
group by date_received, company
having counts > 500
order by date_received, counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory754770"><style>
#       table.tdhistory754770 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory754770 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory754770:last-child { text-align: left !important; }
#       tbody.tdhistory754770 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory754770 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory754770 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory754770"></th><th class="tdhistory754770">date_received</th><th class="tdhistory754770">company</th><th class="tdhistory754770">counts</th></tr></thead><tbody class="tdhistory754770 resultset-body"><tr><th class="tdhistory754770" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory754770">2017-01-19</td><td class="tdhistory754770">Navient Solutions, LLC.</td><td class="tdhistory754770">1195</td></tr><tr><th class="tdhistory754770" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory754770">2017-01-20</td><td class="tdhistory754770">Navient Solutions, LLC.</td><td class="tdhistory754770">895</td></tr><tr><th class="tdhistory754770" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory754770">2017-09-08</td><td class="tdhistory754770">EQUIFAX, INC.</td><td class="tdhistory754770">2731</td></tr><tr><th class="tdhistory754770" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory754770">2017-09-09</td><td class="tdhistory754770">EQUIFAX, INC.</td><td class="tdhistory754770">2318</td></tr><tr><th class="tdhistory754770" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory754770">2017-09-13</td><td class="tdhistory754770">EQUIFAX, INC.</td><td class="tdhistory754770">547</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Interestingly, we can see that the great majority of the the complaints were directed at two companies: Navient Solutions and EQUIFAX. These seem to be highly correlated with the Navient Lawsuit and the Equifax breach events that happened around those dates, respectively. Let's recap what happened:
#
# <p>
# <blockquote><i>Navient Lawsuit: On January 2017, the U.S. Consumer Financial Protection Bureau (CFPB) and the Illinois and Washington attorneys general sued Navient Solutions. Navient is a major servicer of private and federal student loans. According to the CFPB at least since January 2010 "Navient has misallocated payments, steered struggling borrowers toward multiple forbearances instead of income-driven repayment plans, and provided unclear information about how to re-enrol in income-driven repayment plans and how to qualify for a co-signer release"
#
# Equifax Breach: On September 7th, 2017 Equifax announced a cybersecurity breach, one of the largest in history, had happened from mid-May through July 2017. Some of the personal information that was accessed included names, social security numbers, birth dates, addresses and driver's license numbers.</i></blockquote>
# </p>
# <p style = 'font-size:16px;font-family:Arial'>
# Let's now look at the top issues for Navient Solutions and Equifax during those periods to confirm our hypothesis.

# %%
-- analyze top issues reported against Navient Solutions on 2017-01-19 and 2017-01-20
select company, product, issue, count(issue) as counts
from DEMO_Financial.Consumer_Complaints
where date_received in (
    date '2017-01-19',
    date '2017-01-20') and
    company like 'Navient Solutions%'
group by company, product, issue
order by counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory296197"><style>
#       table.tdhistory296197 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory296197 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory296197:last-child { text-align: left !important; }
#       tbody.tdhistory296197 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory296197 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory296197 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory296197"></th><th class="tdhistory296197">company</th><th class="tdhistory296197">product</th><th class="tdhistory296197">issue</th><th class="tdhistory296197">counts</th></tr></thead><tbody class="tdhistory296197 resultset-body"><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Student loan</td><td class="tdhistory296197">Dealing with my lender or servicer</td><td class="tdhistory296197">1107</td></tr><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Student loan</td><td class="tdhistory296197">Can't repay my loan</td><td class="tdhistory296197">968</td></tr><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Student loan</td><td class="tdhistory296197">Getting a loan</td><td class="tdhistory296197">9</td></tr><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Debt collection</td><td class="tdhistory296197">Cont'd attempts collect debt not owed</td><td class="tdhistory296197">2</td></tr><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Debt collection</td><td class="tdhistory296197">False statements or representation</td><td class="tdhistory296197">2</td></tr><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Consumer Loan</td><td class="tdhistory296197">Managing the loan or lease</td><td class="tdhistory296197">1</td></tr><tr><th class="tdhistory296197" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory296197">Navient Solutions, LLC.</td><td class="tdhistory296197">Debt collection</td><td class="tdhistory296197">Communication tactics</td><td class="tdhistory296197">1</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>
# We can see the top two issues represent the majority of complaint counts against Navient Solutions. Furthermore, by looking at the product and issue columns we can infer that they are indeed related to the lawsuit regarding student loans. Now let's do the same analysis for the Equifax issues.

# %%
-- analyze top issues reported against EQUIFAX on 2017-01-19 and 2017-01-20
select
    company,
    product,
    issue,
    count(issue) as counts
from DEMO_Financial.Consumer_Complaints
where date_received in (
    date '2017-09-08',
    date '2017-09-09',
    date '2017-09-13') and
        company like 'EQUIFAX%'
group by company, product, issue
order by counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory9516"><style>
#       table.tdhistory9516 { display: block !important; min-height: 483px !important; overflow: auto !important; height: 483px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory9516 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory9516:last-child { text-align: left !important; }
#       tbody.tdhistory9516 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory9516 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory9516 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory9516"></th><th class="tdhistory9516">company</th><th class="tdhistory9516">product</th><th class="tdhistory9516">issue</th><th class="tdhistory9516">counts</th></tr></thead><tbody class="tdhistory9516 resultset-body"><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Improper use of your report</td><td class="tdhistory9516">4500</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Problem with fraud alerts or security freezes</td><td class="tdhistory9516">322</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Credit monitoring or identity theft protection services</td><td class="tdhistory9516">264</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Problem with a credit reporting company's investigation into an existing problem</td><td class="tdhistory9516">234</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Incorrect information on your report</td><td class="tdhistory9516">177</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Unable to get your credit report or credit score</td><td class="tdhistory9516">35</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Identity theft protection or other monitoring services</td><td class="tdhistory9516">22</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Problem with a company's investigation into an existing issue</td><td class="tdhistory9516">10</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Debt collection</td><td class="tdhistory9516">Attempts to collect debt not owed</td><td class="tdhistory9516">7</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory9516">Problem with customer service</td><td class="tdhistory9516">6</td></tr><tr><th class="tdhistory9516" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory9516">EQUIFAX, INC.</td><td class="tdhistory9516">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhis ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Here we can also confirm our hypothesis. The top issues talk about improper use of the credit report, fraud alerts, identity theft etc. This really does seem related to the Equifax breach that happened around the same time frame.

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>5.  Clean up </b>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'> <b>Database and Tables </b>
# <p style = 'font-size:16px;font-family:Arial'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_Financial');
-- takes about 10 seconds, optional if you want to use the data later
--the same data is used in UseCases/VantageAnalyticLibrary and UseCases/FSCustomerJourney
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory205461"><style>
#       table.tdhistory205461 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory205461 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory205461:last-child { text-align: left !important; }
#       tbody.tdhistory205461 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory205461 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory205461 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory205461"></th><th class="tdhistory205461">Message</th></tr></thead><tbody class="tdhistory205461 resultset-body"><tr><th class="tdhistory205461" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory205461">Removed objects related to DEMO_Financial. That ran for 0:00:06.22</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>6. Dataset</b>
# <p style = 'font-size:16px;font-family:Arial'>
# The Consumer Complaints Database has complaints data that was received by the Consumer Financial Protection Bureau (CFPB) on financial products and services, which include but are not limited to bank accounts, credit cards, credit reporting, debt collection, money transfers, mortgages, student loans and other types of consumer credit. The dataset is refreshed daily and contains information on the provider, the complaint, date, ZIP code and more. More information about the dataset can be found in the Consumer section of the <a href="data.gov">Data.gov</a> website.
# <p style = 'font-size:16px;font-family:Arial'>
# The <b>TRNG_FinancialProtection.consumer_complaints</b> dataset has 1,273,782 rows, each representing a unique consumer complaint, and 18 columns, representing the following features:
#
# - `date_received`: date that CFPB received the complaint
# - `product`: type of product the consumer identified in the complaint
# - `sub_product`: type of sub-product the consumer identified in the complaint
# - `issue`: issue the consumer identified in the complaint
# - `sub_issue`: sub-issue the consumer identified in the complaint
# - `consumer_complaint_narrative`: consumer-submitted description of "what happened" from the complaint
# - `company_public_response`: company's optional, public-facing response to a consumer's complaint
# - `company`: complaint is about this company
# - `state`: state of the mailing address provided by the consumer
# - `zip_code`: mailing ZIP code provided by the consumer
# - `tags`: data that supports easier searching and sorting of complaints submitted by or on behalf of consumers
# - `consumer_consent_provided`: identifies whether the consumer option in to publish their complaint narrative
# - `submitted_via`: how the complaint was submitted to the CFPB
# - `date_sent_to_company`: date the CFBP sent the complaint to the company
# - `company_response_to_consumer`: how the company responded
# - `timely_response`: whether the company gave a timely response
# - `consumer_disputed`: whether the company disputed the company's response
# - `complaint_id`: unique identification number for a complaint

# %% [markdown]
# <p style = 'font-size:28px;font-family:Arial;color:#E37C4D'><b>7. Explore</b>
# <p style = 'font-size:16px;font-family:Arial'>
# Through this notebook, we saw the power and simplicity of running queries in the SQL Editor and how it can be leveraged to extract insights from the data to tell the story behind a dataset. Hopefully you've noticed how easy it is to use Vantage to write your own SQL queries.<br>You can continue to explore Vantage to extract more insights and find answers to other questions by using the preloaded dataset. Here are some suggestions:
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>What are the most common types of complaints? By grouping the <b>product</b> category, we can arrive at this answer. How does this change over time?</li>
#     <li>How are customers submitting their complaints? The column <b>submitted_via</b> can also be grouped to answer for this question.</li>
#     <li>What proportion of the customer complaints are disputed? By aggregating counts of <b>customer_disputed</b> we can answer this question.</li>
#     <li>Is there seasonality in the data? What is the reason for the seasonality? If we subtract the trend from the series we can analyze the seasonality in the dataset. Are most of the complaints filed during the week or on the weekends?</li>
#     </ul>

# %% [markdown]
# <footer style="padding:10px;background:#f9f9f9;border-bottom:3px solid #394851">©2023 Teradata. All Rights Reserved</footer>
