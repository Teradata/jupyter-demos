# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Time Series Analysis - Analyzing Consumer Complaints Over Time
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# In this example we will be analyzing the number of complaints over time received by the Consumer Financial Protection Bureau (CFPB).</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# How can we use Vantage to extract insights and tell a story behind a dataset? In this use case, you will see how powerful and simple it is to extract answers from a public dataset available through <a href="http://data.gov">Data.gov</a>. We use SQL and a visualization tool to analyze the number of complaints over time to answer the following questions:</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
#  <i>What are the trends of complaints over time? How can we interpret the outliers in the dataset?</i>
# </p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# By answering questions like the ones above, we gain a deeper understanding of the dataset, and we can explain in plain language how the number of complaints evolve over time. In the Explore section, we focus on analyzing the number of complaints over time and identifying trends and outliers in the time series to answer the questions above.
# </p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
Set query_band='DEMO=Consumer_Complaints_SQL.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Getting Data for This Demo</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We have provided data for this demo on cloud storage. In this demo since we are using Temporal table we will be creating databases and tables in local storage and use them in the notebook. Please execute the procedure in the next cell.</p>

# %%
call get_data('DEMO_Financial_cloud');    -- takes about 50 seconds, estimated space: 0 MB
--call get_data('DEMO_Financial_local');     -- takes about 4 minutes, estimated space: 300 MB
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory943159"><style>
#       table.tdhistory943159 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory943159 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory943159:last-child { text-align: left !important; }
#       tbody.tdhistory943159 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory943159 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory943159 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory943159"></th><th class="tdhistory943159">Message</th></tr></thead><tbody class="tdhistory943159 resultset-body"><tr><th class="tdhistory943159" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory943159">That ran for   0:00:36.55 with 17 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();  -- optional, takes about 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory574342"><style>
#       table.tdhistory574342 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory574342 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory574342:last-child { text-align: left !important; }
#       tbody.tdhistory574342 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory574342 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory574342 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory574342"></th><th class="tdhistory574342">Space_Report</th></tr></thead><tbody class="tdhistory574342 resultset-body"><tr><th class="tdhistory574342" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory574342">You have:  #databases=1 #tables=1 #views=27  You have used 1.1 MB of 30,678.9 MB available - 0.0%  ... Space Usage OK</td></tr><tr><th class="tdhistory574342" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory574342"> </td></tr><tr><th class="tdhistory574342" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory574342">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory574342" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory574342">   demo_user                            1      20  30,678.9 MB       1.1 MB </td></tr><tr><th class="tdhistory574342" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory574342">   DEMO_Financial                       0       7       0.0 MB       0.0 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. Querying the Data</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We have made our connection to the Vantage system, now let's start exploring the data. We'll start by counting the number of rows in the table.</p>

# %%
select count(*) from DEMO_Financial.Consumer_complaints;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory256250"><style>
#       table.tdhistory256250 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory256250 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory256250:last-child { text-align: left !important; }
#       tbody.tdhistory256250 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory256250 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory256250 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory256250"></th><th class="tdhistory256250">Count(*)</th></tr></thead><tbody class="tdhistory256250 resultset-body"><tr><th class="tdhistory256250" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory256250">1273782</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# There are just under 1.3 million rows. Not a problem to analyze large datasets using Vantage, lets take a look at a sample of the data.</p>

# %%
select TOP 5 * from DEMO_Financial.Consumer_Complaints;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory83163"><style>
#       table.tdhistory83163 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory83163 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory83163:last-child { text-align: left !important; }
#       tbody.tdhistory83163 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory83163 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory83163 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory83163"></th><th class="tdhistory83163">date_received</th><th class="tdhistory83163">product</th><th class="tdhistory83163">sub_product</th><th class="tdhistory83163">issue</th><th class="tdhistory83163">sub_issue</th><th class="tdhistory83163">consumer_complaint_narrative</th><th class="tdhistory83163">company_public_response</th><th class="tdhistory83163">company</th><th class="tdhistory83163">state</th><th class="tdhistory83163">zip_code</th><th class="tdhistory83163">tags</th><th class="tdhistory83163">consumer_consent_provided</th><th class="tdhistory83163">submitted_via</th><th class="tdhistory83163">date_sent_to_company</th><th class="tdhistory83163">company_response_to_consumer</th><th class="tdhistory83163">timely_response</th><th class="tdhistory83163">consumer_disputed</th><th class="tdhistory83163">complaint_id</th></tr></thead><tbody class="tdhistory83163 resultset-body"><tr><th class="tdhistory83163" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory83163">2016-06-08</td><td class="tdhistory83163">Mortgage</td><td class="tdhistory83163">Conventional fixed mortgage</td><td class="tdhistory83163">Credit decision / Underwriting</td><td class="tdhistory83163"></td><td class="tdhistory83163">X</td><td class="tdhistory83163">Company has responded to the consumer and the CFPB and chooses not to provide a public response</td><td class="tdhistory83163">WASHINGTON FEDERAL, NATIONAL ASSOCIATION</td><td class="tdhistory83163">AZ</td><td class="tdhistory83163">850XX</td><td class="tdhistory83163"></td><td class="tdhistory83163">Consent provided</td><td class="tdhistory83163">Web</td><td class="tdhistory83163">2016-06-08</td><td class="tdhistory83163">Closed with explanation</td><td class="tdhistory83163">Yes</td><td class="tdhistory83163">N</td><td class="tdhistory83163">1959357</td></tr><tr><th class="tdhistory83163" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory83163">2017-07-11</td><td class="tdhistory83163">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory83163">Credit reporting</td><td class="tdhistory83163">Incorrect information on your report</td><td class="tdhistory83163">Information belongs to someone else</td><td class="tdhistory83163"></td><td class="tdhistory83163">Company has responded to the consumer and the CFPB and chooses not to provide a public response</td><td class="tdhistory83163">Experian Information Solutions Inc.</td><td class="tdhistory83163">CT</td><td class="tdhistory83163">06515</td><td class="tdhistory83163"></td><td class="tdhistory83163">Consent withdrawn</td><td class="tdhistory83163">Web</td><td class="tdhistory83163">2017-07-11</td><td class="tdhistory83163">Closed with explanation</td><td class="tdhistory83163">Yes</td><td class="tdhistory83163"></td><td class="tdhistory83163">2570727</td></tr><tr><th class="tdhistory83163" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory83163">2017-07-11</td><td class="tdhistory83163">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory83163">Credit reporting</td><td class="tdhistory83163">Incorrect information on your report</td><td class="tdhistory83163">Account status incorrect</td><td class="tdhistory83163">I</td><td class="tdhistory83163"></td><td class="tdhistory83163">JPMORGAN CHASE & CO.</td><td class="tdhistory83163">NC</td><td class="tdhistory83163">275XX</td><td class="tdhistory83163"></td><td class="tdhistory83163">Consent provided</td><td class="tdhistory83163">Web</td><td class="tdhistory83163">2017-07-11</td><td class="tdhistory83163">Closed with non-monetary relief</td><td class="tdhistory83163">Yes</td><td class="tdhistory83163"></td><td class="tdhistory83163">2570736</td></tr><tr><th class="tdhistory83163" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory8 ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Visualizing the Data</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# From the query above, we notice that this dataset has a lot of information. To derive some insights, we need to start grouping the data.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# The first column is <b>date_received</b>. This is the date the complaints were received, and it means that we can look at a time series plot of the data. Let's start by grouping the counts of <b>complaint_id</b> over time, using <b>date_received</b> as our time axis.</p>

# %%
select date_received, count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
group by date_received;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory855874"><style>
#       table.tdhistory855874 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory855874 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory855874:last-child { text-align: left !important; }
#       tbody.tdhistory855874 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory855874 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory855874 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory855874"></th><th class="tdhistory855874">date_received</th><th class="tdhistory855874">counts</th></tr></thead><tbody class="tdhistory855874 resultset-body"><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory855874">2017-06-15</td><td class="tdhistory855874">728</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory855874">2014-01-04</td><td class="tdhistory855874">178</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory855874">2018-07-23</td><td class="tdhistory855874">754</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory855874">2014-08-15</td><td class="tdhistory855874">475</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory855874">2019-01-20</td><td class="tdhistory855874">233</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory855874">2016-10-07</td><td class="tdhistory855874">624</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory855874">2011-12-26</td><td class="tdhistory855874">21</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory855874">2016-03-20</td><td class="tdhistory855874">200</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory855874">2012-06-23</td><td class="tdhistory855874">66</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory855874">2018-05-12</td><td class="tdhistory855874">418</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory855874">2013-07-31</td><td class="tdhistory855874">473</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory855874">2015-09-23</td><td class="tdhistory855874">751</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory855874">2013-07-07</td><td class="tdhistory855874">57</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory855874">2012-05-08</td><td class="tdhistory855874">275</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory855874">2017-09-04</td><td class="tdhistory855874">298</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory855874">2013-08-03</td><td class="tdhistory855874">148</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory855874">2015-02-12</td><td class="tdhistory855874">593</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory855874">2018-03-01</td><td class="tdhistory855874">919</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory855874">2016-02-05</td><td class="tdhistory855874">576</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory855874">2017-04-28</td><td class="tdhistory855874">727</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistory855874">2017-04-04</td><td class="tdhistory855874">914</td></tr><tr><th class="tdhistory855874" style= "background: rgba(243, 243, 243, 0.75)">22</th><td class="tdhistory855874">2017-09-28</td><td class="tdhistory855874">886</td></tr><tr><th class="tdhistory8 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# This is great; we now have the number of complaints (<b>counts</b>) by time (<b>date_received</b>), but how do we make sense of this data? Let's plot this time series on a graph.</p>

# %%
%chart date_received, counts, title='Number of Complaints over Time', width=900, height=400

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# By visualizing the data above, we can see that the number of complaints varies a lot over time and there also seem to be more complaints as time progresses. There are also some unusual spikes in 2017. Let's understand more about our data. We start by looking at the general trend.
# <br>
# <br>
# Let's group the data by month and re-plot the graph above.</p>

# %%
select extract(year from date_received) || extract(month from date_received) as month_date, count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
group by month_date
order by month_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory116263"><style>
#       table.tdhistory116263 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory116263 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory116263:last-child { text-align: left !important; }
#       tbody.tdhistory116263 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory116263 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory116263 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory116263"></th><th class="tdhistory116263">month_date</th><th class="tdhistory116263">counts</th></tr></thead><tbody class="tdhistory116263 resultset-body"><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory116263">       2011         12</td><td class="tdhistory116263">2536</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory116263">       2012          1</td><td class="tdhistory116263">3230</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory116263">       2012          2</td><td class="tdhistory116263">3509</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory116263">       2012          3</td><td class="tdhistory116263">6230</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory116263">       2012          4</td><td class="tdhistory116263">5703</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory116263">       2012          5</td><td class="tdhistory116263">7617</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory116263">       2012          6</td><td class="tdhistory116263">7841</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory116263">       2012          7</td><td class="tdhistory116263">6755</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory116263">       2012          8</td><td class="tdhistory116263">6877</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory116263">       2012          9</td><td class="tdhistory116263">5493</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory116263">       2012         10</td><td class="tdhistory116263">6741</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory116263">       2012         11</td><td class="tdhistory116263">6139</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory116263">       2012         12</td><td class="tdhistory116263">6238</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory116263">       2013          1</td><td class="tdhistory116263">9741</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory116263">       2013          2</td><td class="tdhistory116263">8349</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory116263">       2013          3</td><td class="tdhistory116263">8784</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory116263">       2013          4</td><td class="tdhistory116263">8633</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory116263">       2013          5</td><td class="tdhistory116263">8170</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory116263">       2013          6</td><td class="tdhistory116263">8035</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory116263">       2013          7</td><td class="tdhistory116263">9271</td></tr><tr><th class="tdhistory116263" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistor ...

# %%
%chart month_date, counts, title='Number of Complaints by Month and Year', width=900, height=400, mark=line

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Looking at complaints over month and year, we see there is clearly an upward trend. One hypothesis is that as time progresses, people get more conscious and spread the word. The media can also advertise the complaint channels over time. Through this chart we can see clearly the spikes that we saw above were in January 2017 and September 2017. Let's dive deeper into these dates and draw some insights on the next step.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. Extracting Insights from the Data</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Let's narrow down the two spikes above and see exactly where they are happening. We can do this by plotting another time series plot, this time only in 2017.</p>

# %%
select date_received, count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
where year(date_received) = 2017
group by date_received
order by date_received;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory863971"><style>
#       table.tdhistory863971 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory863971 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory863971:last-child { text-align: left !important; }
#       tbody.tdhistory863971 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory863971 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory863971 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory863971"></th><th class="tdhistory863971">date_received</th><th class="tdhistory863971">counts</th></tr></thead><tbody class="tdhistory863971 resultset-body"><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory863971">2017-01-01</td><td class="tdhistory863971">105</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory863971">2017-01-02</td><td class="tdhistory863971">299</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory863971">2017-01-03</td><td class="tdhistory863971">604</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory863971">2017-01-04</td><td class="tdhistory863971">789</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory863971">2017-01-05</td><td class="tdhistory863971">718</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory863971">2017-01-06</td><td class="tdhistory863971">656</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory863971">2017-01-07</td><td class="tdhistory863971">257</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory863971">2017-01-08</td><td class="tdhistory863971">232</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory863971">2017-01-09</td><td class="tdhistory863971">585</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory863971">2017-01-10</td><td class="tdhistory863971">744</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory863971">2017-01-11</td><td class="tdhistory863971">744</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory863971">2017-01-12</td><td class="tdhistory863971">603</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory863971">2017-01-13</td><td class="tdhistory863971">691</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory863971">2017-01-14</td><td class="tdhistory863971">297</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory863971">2017-01-15</td><td class="tdhistory863971">219</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory863971">2017-01-16</td><td class="tdhistory863971">332</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory863971">2017-01-17</td><td class="tdhistory863971">625</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory863971">2017-01-18</td><td class="tdhistory863971">900</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">19</th><td class="tdhistory863971">2017-01-19</td><td class="tdhistory863971">2070</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">20</th><td class="tdhistory863971">2017-01-20</td><td class="tdhistory863971">1633</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">21</th><td class="tdhistory863971">2017-01-21</td><td class="tdhistory863971">559</td></tr><tr><th class="tdhistory863971" style= "background: rgba(243, 243, 243, 0.75)">22</th><td class="tdhistory863971">2017-01-22</td><td class="tdhistory863971">360</td></tr><tr><th class="tdhis ...

# %%
%chart date_received, counts, title='Complaints over time - 2017', width=900, height=400, mark=line

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>As we look at the peaks, we find that they occurred from January 15th to 21st and during the first week of September. To find the actual dates of the peaks, we can limit the query to pick up at least 1,500 complaints a day.</p>

# %%
select date_received,
    month(date_received) as month_date,
    count(complaint_id) as counts
from DEMO_Financial.Consumer_Complaints
where year(date_received) = 2017 and month_date in (1, 9)
group by date_received
having counts >= 1500
order by month_date, counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory973285"><style>
#       table.tdhistory973285 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory973285 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory973285:last-child { text-align: left !important; }
#       tbody.tdhistory973285 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory973285 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory973285 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory973285"></th><th class="tdhistory973285">date_received</th><th class="tdhistory973285">month_date</th><th class="tdhistory973285">counts</th></tr></thead><tbody class="tdhistory973285 resultset-body"><tr><th class="tdhistory973285" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory973285">2017-01-19</td><td class="tdhistory973285">1</td><td class="tdhistory973285">2070</td></tr><tr><th class="tdhistory973285" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory973285">2017-01-20</td><td class="tdhistory973285">1</td><td class="tdhistory973285">1633</td></tr><tr><th class="tdhistory973285" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory973285">2017-09-08</td><td class="tdhistory973285">9</td><td class="tdhistory973285">3553</td></tr><tr><th class="tdhistory973285" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory973285">2017-09-09</td><td class="tdhistory973285">9</td><td class="tdhistory973285">2709</td></tr><tr><th class="tdhistory973285" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory973285">2017-09-13</td><td class="tdhistory973285">9</td><td class="tdhistory973285">1600</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let's look at some of the issues that were reported during these dates.</p>

# %%
select date_received, company, count(company) as counts
from DEMO_Financial.Consumer_Complaints
where date_received in (
    date '2017-01-19',
    date '2017-01-20',
    date '2017-09-08',
    date '2017-09-09',
    date '2017-09-13'
)
group by date_received, company
having counts > 500
order by date_received, counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory624320"><style>
#       table.tdhistory624320 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory624320 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory624320:last-child { text-align: left !important; }
#       tbody.tdhistory624320 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory624320 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory624320 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory624320"></th><th class="tdhistory624320">date_received</th><th class="tdhistory624320">company</th><th class="tdhistory624320">counts</th></tr></thead><tbody class="tdhistory624320 resultset-body"><tr><th class="tdhistory624320" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory624320">2017-01-19</td><td class="tdhistory624320">Navient Solutions, LLC.</td><td class="tdhistory624320">1195</td></tr><tr><th class="tdhistory624320" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory624320">2017-01-20</td><td class="tdhistory624320">Navient Solutions, LLC.</td><td class="tdhistory624320">895</td></tr><tr><th class="tdhistory624320" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory624320">2017-09-08</td><td class="tdhistory624320">EQUIFAX, INC.</td><td class="tdhistory624320">2731</td></tr><tr><th class="tdhistory624320" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory624320">2017-09-09</td><td class="tdhistory624320">EQUIFAX, INC.</td><td class="tdhistory624320">2318</td></tr><tr><th class="tdhistory624320" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory624320">2017-09-13</td><td class="tdhistory624320">EQUIFAX, INC.</td><td class="tdhistory624320">547</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Interestingly, we can see that the great majority of the the complaints were directed at two companies: Navient Solutions and EQUIFAX. These seem to be highly correlated with the Navient Lawsuit and the Equifax breach events that happened around those dates, respectively. Let's recap what happened:</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <blockquote><i>Navient Lawsuit: On January 2017, the U.S. Consumer Financial Protection Bureau (CFPB) and the Illinois and Washington attorneys general sued Navient Solutions. Navient is a major servicer of private and federal student loans. According to the CFPB at least since January 2010 "Navient has misallocated payments, steered struggling borrowers toward multiple forbearances instead of income-driven repayment plans, and provided unclear information about how to re-enrol in income-driven repayment plans and how to qualify for a co-signer release"
#
# Equifax Breach: On September 7th, 2017 Equifax announced a cybersecurity breach, one of the largest in history, had happened from mid-May through July 2017. Some of the personal information that was accessed included names, social security numbers, birth dates, addresses and driver's license numbers.</i></blockquote>
# </p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Let's now look at the top issues for Navient Solutions and Equifax during those periods to confirm our hypothesis.</p>

# %%
-- analyze top issues reported against Navient Solutions on 2017-01-19 and 2017-01-20
select company, product, issue, count(issue) as counts
from DEMO_Financial.Consumer_Complaints
where date_received in (
    date '2017-01-19',
    date '2017-01-20') and
    company like 'Navient Solutions%'
group by company, product, issue
order by counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory332953"><style>
#       table.tdhistory332953 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory332953 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory332953:last-child { text-align: left !important; }
#       tbody.tdhistory332953 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory332953 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory332953 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory332953"></th><th class="tdhistory332953">company</th><th class="tdhistory332953">product</th><th class="tdhistory332953">issue</th><th class="tdhistory332953">counts</th></tr></thead><tbody class="tdhistory332953 resultset-body"><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Student loan</td><td class="tdhistory332953">Dealing with my lender or servicer</td><td class="tdhistory332953">1107</td></tr><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Student loan</td><td class="tdhistory332953">Can't repay my loan</td><td class="tdhistory332953">968</td></tr><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Student loan</td><td class="tdhistory332953">Getting a loan</td><td class="tdhistory332953">9</td></tr><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Debt collection</td><td class="tdhistory332953">Cont'd attempts collect debt not owed</td><td class="tdhistory332953">2</td></tr><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Debt collection</td><td class="tdhistory332953">False statements or representation</td><td class="tdhistory332953">2</td></tr><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Consumer Loan</td><td class="tdhistory332953">Managing the loan or lease</td><td class="tdhistory332953">1</td></tr><tr><th class="tdhistory332953" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory332953">Navient Solutions, LLC.</td><td class="tdhistory332953">Debt collection</td><td class="tdhistory332953">Communication tactics</td><td class="tdhistory332953">1</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# We can see the top two issues represent the majority of complaint counts against Navient Solutions. Furthermore, by looking at the product and issue columns we can infer that they are indeed related to the lawsuit regarding student loans. Now let's do the same analysis for the Equifax issues.</p>

# %%
-- analyze top issues reported against EQUIFAX on 2017-01-19 and 2017-01-20
select
    company,
    product,
    issue,
    count(issue) as counts
from DEMO_Financial.Consumer_Complaints
where date_received in (
    date '2017-09-08',
    date '2017-09-09',
    date '2017-09-13') and
        company like 'EQUIFAX%'
group by company, product, issue
order by counts desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory828394"><style>
#       table.tdhistory828394 { display: block !important; min-height: 483px !important; overflow: auto !important; height: 483px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory828394 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory828394:last-child { text-align: left !important; }
#       tbody.tdhistory828394 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory828394 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory828394 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory828394"></th><th class="tdhistory828394">company</th><th class="tdhistory828394">product</th><th class="tdhistory828394">issue</th><th class="tdhistory828394">counts</th></tr></thead><tbody class="tdhistory828394 resultset-body"><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Improper use of your report</td><td class="tdhistory828394">4500</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Problem with fraud alerts or security freezes</td><td class="tdhistory828394">322</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Credit monitoring or identity theft protection services</td><td class="tdhistory828394">264</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Problem with a credit reporting company's investigation into an existing problem</td><td class="tdhistory828394">234</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Incorrect information on your report</td><td class="tdhistory828394">177</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Unable to get your credit report or credit score</td><td class="tdhistory828394">35</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Identity theft protection or other monitoring services</td><td class="tdhistory828394">22</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Problem with a company's investigation into an existing issue</td><td class="tdhistory828394">10</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Debt collection</td><td class="tdhistory828394">Attempts to collect debt not owed</td><td class="tdhistory828394">7</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory828394">EQUIFAX, INC.</td><td class="tdhistory828394">Credit reporting, credit repair services, or other personal consumer reports</td><td class="tdhistory828394">Problem with customer service</td><td class="tdhistory828394">6</td></tr><tr><th class="tdhistory828394" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory828394">EQUIFAX, INC.</td><td cla ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here we can also confirm our hypothesis. The top issues talk about improper use of the credit report, fraud alerts, identity theft etc. This really does seem related to the Equifax breach that happened around the same time frame.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. Cleanup </b></p>
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Database and Tables</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_Financial');
-- takes about 10 seconds, optional if you want to use the data later
--the same data is used in UseCases/VantageAnalyticLibrary and UseCases/FSCustomerJourney
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory77118"><style>
#       table.tdhistory77118 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory77118 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory77118:last-child { text-align: left !important; }
#       tbody.tdhistory77118 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory77118 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory77118 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory77118"></th><th class="tdhistory77118">Message</th></tr></thead><tbody class="tdhistory77118 resultset-body"><tr><th class="tdhistory77118" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory77118">Removed objects related to DEMO_Financial. That ran for 0:00:04.88</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. Dataset</b>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# The Consumer Complaints Database has complaints data that was received by the Consumer Financial Protection Bureau (CFPB) on financial products and services, which include but are not limited to bank accounts, credit cards, credit reporting, debt collection, money transfers, mortgages, student loans and other types of consumer credit. The dataset is refreshed daily and contains information on the provider, the complaint, date, ZIP code and more. More information about the dataset can be found in the Consumer section of the <a href="data.gov">Data.gov</a> website.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# The <b>Demo_Financial.consumer_complaints</b> dataset has 1,273,782 rows, each representing a unique consumer complaint, and 18 columns, representing the following features:</p>
#
# - `date_received`: date that CFPB received the complaint
# - `product`: type of product the consumer identified in the complaint
# - `sub_product`: type of sub-product the consumer identified in the complaint
# - `issue`: issue the consumer identified in the complaint
# - `sub_issue`: sub-issue the consumer identified in the complaint
# - `consumer_complaint_narrative`: consumer-submitted description of "what happened" from the complaint
# - `company_public_response`: company's optional, public-facing response to a consumer's complaint
# - `company`: complaint is about this company
# - `state`: state of the mailing address provided by the consumer
# - `zip_code`: mailing ZIP code provided by the consumer
# - `tags`: data that supports easier searching and sorting of complaints submitted by or on behalf of consumers
# - `consumer_consent_provided`: identifies whether the consumer option in to publish their complaint narrative
# - `submitted_via`: how the complaint was submitted to the CFPB
# - `date_sent_to_company`: date the CFBP sent the complaint to the company
# - `company_response_to_consumer`: how the company responded
# - `timely_response`: whether the company gave a timely response
# - `consumer_disputed`: whether the company disputed the company's response
# - `complaint_id`: unique identification number for a complaint

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>7. Explore</b>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Through this notebook, we saw the power and simplicity of running queries in the SQL Editor and how it can be leveraged to extract insights from the data to tell the story behind a dataset. Hopefully you've noticed how easy it is to use Vantage to write your own SQL queries.<br>You can continue to explore Vantage to extract more insights and find answers to other questions by using the preloaded dataset. Here are some suggestions:</p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#     <li>What are the most common types of complaints? By grouping the <b>product</b> category, we can arrive at this answer. How does this change over time?</li>
#     <li>How are customers submitting their complaints? The column <b>submitted_via</b> can also be grouped to answer for this question.</li>
#     <li>What proportion of the customer complaints are disputed? By aggregating counts of <b>customer_disputed</b> we can answer this question.</li>
#     <li>Is there seasonality in the data? What is the reason for the seasonality? If we subtract the trend from the series we can analyze the seasonality in the dataset. Are most of the complaints filed during the week or on the weekends?</li>
# </ul>

# %% [markdown]
# <footer style="padding-bottom:35px; background:#f9f9f9; border-bottom:3px solid #00233C">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2023. All Rights Reserved
#         </div>
#     </div>
# </footer>
