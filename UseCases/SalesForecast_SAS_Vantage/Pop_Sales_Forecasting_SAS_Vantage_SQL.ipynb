# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Sales Forecasting :- SAS and Vantage Comparison
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# This demo walks through how a typical SAS user would use sales data to build a simple sales forecasting model and then will showcase how we can achieve the same using Vantage InDB Analytics</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Customers are finding their analytical environments difficult to manage and are looking for ways to make these environments more streamlined while adapting to more contemporary technologies. Our open source analytical ecosystem can be leveraged to simplify and apply more governance to the data flows in your analytical environment, enabling you to increase efficiency of computation, reduce cost of ownership and take advantage of any analytical tool of choice.</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Benefits our customers have received:
# <img src = 'images/SASIntro.png' width = '400' align='right' padding='padding:50px'>
#
# <li style = 'font-size:16px;font-family:Arial'>For large data extract the time reduced from 16 hours 28 minutes to 28 secs</li>
#     <br>
# <li style = 'font-size:16px;font-family:Arial'>Reduced analytic processing from 30 days to a single day.</li>
#     <br>
# <li style = 'font-size:16px;font-family:Arial'>Eliminated over 75% of redundant data in SAS environments and Reduced data latency.</li> <br>
# <li style = 'font-size:16px;font-family:Arial'>Pushed analytic processing into Teradata Database which helped eliminate 6 TB of redundant data and Improved quality of analytics.</li>
#
# </p>
#
# <br>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> This overview shows how to undertake an analytical model foundation using ClearScape Analytics that uses data from a variety of sources. Teradata Vantage™ enables enterprises to automate and post timely model outputs for use in downstream business processes.</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In this demo we will show
#     <div class="alert alert-block alert-warning">
# <p style = 'font-size:16px;font-family:Arial;color:#000000'><i>the SAS code in tan colored box and will not be executed.</i>
# </div>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>And follow that with </p>
#     <code style = 'font-size:16px;'><i>Vantage code that we will run in executable cells</i></code>
# </p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
Set query_band='DEMO=Sales_Forecasting_SAS_Vantage_SQL.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. Getting Data for This Demo</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We have provided data for this demo on cloud storage. You can either run the demo using foreign tables to access the data without any storage on your environment or download the data to local storage, which may yield faster execution. Still, there could be considerations of available storage. Two statements are in the following cell, and one of them is commented out. You may switch between the modes by changing the comment string.</p>

# %%
---call get_data('DEMO_SlsForecast_SAS_cloud');    -- takes about 20 seconds, estimated space: 0 MB
call get_data('DEMO_SlsForecast_SAS_local');     -- takes about 35 seconds, estimated space: 11 MB
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory277215"><style>
#       table.tdhistory277215 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory277215 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory277215:last-child { text-align: left !important; }
#       tbody.tdhistory277215 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory277215 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory277215 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory277215"></th><th class="tdhistory277215">Message</th></tr></thead><tbody class="tdhistory277215 resultset-body"><tr><th class="tdhistory277215" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory277215">That ran for   0:00:19.05 with 15 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();          -- Takes 5 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory774428"><style>
#       table.tdhistory774428 { display: block !important; min-height: 210px !important; overflow: auto !important; height: 210px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory774428 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory774428:last-child { text-align: left !important; }
#       tbody.tdhistory774428 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory774428 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory774428 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory774428"></th><th class="tdhistory774428">Space_Report</th></tr></thead><tbody class="tdhistory774428 resultset-body"><tr><th class="tdhistory774428" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory774428">You have:  #databases=2 #tables=5 #views=22  You have used 27.4 MB of 30,678.9 MB available - 0.1%  ... Space Usage OK</td></tr><tr><th class="tdhistory774428" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory774428"> </td></tr><tr><th class="tdhistory774428" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory774428">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory774428" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory774428">   demo_user                            3      20  30,651.4 MB       1.8 MB </td></tr><tr><th class="tdhistory774428" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory774428">   DEMO_SlsForecast_SAS                 0       2       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory774428" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory774428">   DEMO_SlsForecast_SAS_db              2       0      27.5 MB      25.6 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Explore the dataset</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Transfer and explore data in SAS </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>If we were to execute SAS code the first step would be to import all the data from Vantage to SAS. The first data step will create a new dataset named "sales_temp_data_1" in the "work" library. It will select all the data from the table "sales_ts_data_1_54M" located in the "Teradata" (we are calling it through our libname connection) teralib.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> We replicate the same process with the second data step. We fetch all the data from the table "sales_ts_data_2_54M" and store it in "sales_temp_data_2" in the "work" library. After running the second data step we’ll now see store_id, day of sale, transaction_id, product sku id, and transaction quantity and transaction weight within the SAS library.</p>

# %% [markdown]
# <code>
#
# <div class="alert alert-block alert-warning">
# <p style = 'font-size:18px;font-family:Arial;color:#000000'><b>Equivalent SAS Code</b>
# <p style = 'font-size:16px;color:#000000'>
# /* Setting up a libname for the connection with Teradata Database */
# libname teralib teradata server=barbera user=tahaw pw=tahaw database=tahaw;
# options SASTRACE=',,,ds' SASTRACELOC=SASLOG nostsuffix;
# <p style = 'font-size:16px;color:#000000'>
# /* The first Data step is to fetch all the rows from the Teradata table and create an SAS dataset in the work library */
# %let start_time = %sysfunc(datetime());
# data work.sales_temp_data_1;
# set TERALIB.sales_ts_data_1_54M;
# run;
# <p style = 'font-size:16px;color:#000000'>
# /* The second Data step is to fetch all the rows from the Teradata table for the remaining attributes */
# data work.sales_temp_data_2;
# set TERALIB.sales_ts_data_2_54M;
# run;
#     </p>
# </div>
# </code>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Explore data in Vantage </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>As the data is already in Vantage the data transfer step is <b>NOT</b> required. So, we will explore the data in both the tables</p>

# %%
Select TOP 5 * from DEMO_SlsForecast_SAS.Store_Sales_Qty;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory492627"><style>
#       table.tdhistory492627 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory492627 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory492627:last-child { text-align: left !important; }
#       tbody.tdhistory492627 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory492627 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory492627 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory492627"></th><th class="tdhistory492627">Store_id</th><th class="tdhistory492627">day_of_sale</th><th class="tdhistory492627">transaction_id</th><th class="tdhistory492627">product_sku_id</th><th class="tdhistory492627">transaction_quantity</th><th class="tdhistory492627">transaction_weight</th></tr></thead><tbody class="tdhistory492627 resultset-body"><tr><th class="tdhistory492627" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory492627">50</td><td class="tdhistory492627">2019-10-03</td><td class="tdhistory492627">469</td><td class="tdhistory492627">22160500000</td><td class="tdhistory492627">1.00</td><td class="tdhistory492627">1.34000</td></tr><tr><th class="tdhistory492627" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory492627">50</td><td class="tdhistory492627">2019-10-17</td><td class="tdhistory492627">469</td><td class="tdhistory492627">7143000096</td><td class="tdhistory492627">3.00</td><td class="tdhistory492627">.00000</td></tr><tr><th class="tdhistory492627" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory492627">50</td><td class="tdhistory492627">2019-10-24</td><td class="tdhistory492627">469</td><td class="tdhistory492627">1657191037</td><td class="tdhistory492627">3.00</td><td class="tdhistory492627">.00000</td></tr><tr><th class="tdhistory492627" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory492627">50</td><td class="tdhistory492627">2019-10-25</td><td class="tdhistory492627">469</td><td class="tdhistory492627">3040077433</td><td class="tdhistory492627">1.00</td><td class="tdhistory492627">.00000</td></tr><tr><th class="tdhistory492627" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory492627">50</td><td class="tdhistory492627">2019-10-24</td><td class="tdhistory492627">469</td><td class="tdhistory492627">7682804703</td><td class="tdhistory492627">1.00</td><td class="tdhistory492627">.00000</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>This data set contain store_id, day of sale, transaction_id, product sku id, and transaction quantity and transaction weight.</p>

# %%
Select TOP 5 * from DEMO_SlsForecast_SAS.Store_Sales_Amt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory149434"><style>
#       table.tdhistory149434 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory149434 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory149434:last-child { text-align: left !important; }
#       tbody.tdhistory149434 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory149434 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory149434 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory149434"></th><th class="tdhistory149434">Store_id</th><th class="tdhistory149434">day_of_sale</th><th class="tdhistory149434">transaction_id</th><th class="tdhistory149434">product_sku_id</th><th class="tdhistory149434">transaction_amount</th></tr></thead><tbody class="tdhistory149434 resultset-body"><tr><th class="tdhistory149434" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory149434">50</td><td class="tdhistory149434">2019-09-12</td><td class="tdhistory149434">734</td><td class="tdhistory149434">4125014948</td><td class="tdhistory149434">1.98</td></tr><tr><th class="tdhistory149434" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory149434">50</td><td class="tdhistory149434">2020-12-28</td><td class="tdhistory149434">40</td><td class="tdhistory149434">21776800000</td><td class="tdhistory149434">7.39</td></tr><tr><th class="tdhistory149434" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory149434">50</td><td class="tdhistory149434">2019-09-01</td><td class="tdhistory149434">40</td><td class="tdhistory149434">5783602104</td><td class="tdhistory149434">3.69</td></tr><tr><th class="tdhistory149434" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory149434">50</td><td class="tdhistory149434">2019-10-08</td><td class="tdhistory149434">734</td><td class="tdhistory149434">71928343968</td><td class="tdhistory149434">7.96</td></tr><tr><th class="tdhistory149434" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory149434">50</td><td class="tdhistory149434">2019-09-20</td><td class="tdhistory149434">734</td><td class="tdhistory149434">70882086883</td><td class="tdhistory149434">2.99</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>This data set contain store_id, day of sale, transaction_id, product sku id and transaction amount.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. Aggregating the Data</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Aggregate data in SAS</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>As a next step in SAS, we need to prepare the data into a single ADS to forecast sales for this particular store and aggregate the total sales by each store product and transaction id on a particular day.
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Proc SQL is used in SAS, which uses SAS’s native SQL processing capabilities. Apply the sum on the transaction amount and group by on store_id, day_of_sale, product_sku_id, transaction_id. After it executes, running it will create the dataset sales_aggregated_data_1 in the work library. This new dataset has around 52.5 million records.
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Aggregation is applied on the second data set, sales_temp_2 to do a sum on transaction quantity and weight and group by on store_id, day_of_sale, product_sku_id, transaction_id. After execution, it will create a new dataset named sales_aggregated_data_2 in the work library. This new dataset has around 52.5 million records .</p>

# %% [markdown]
# <code>
#
# <div class="alert alert-block alert-warning">
# <p style = 'font-size:18px;font-family:Arial;color:#000000'><b>Equivalent SAS Code</b>
# <p style = 'font-size:16px;color:#000000'>
# /* Aggregating the amount to calculate the total sales by each store and product on a particular day */
# proc sql;
#   create table work.sales_aggregated_data_1 as
#   select
#     store_id, day_of_sale, product_sku_id, transaction_id,
#     sum(transaction_amount) as total_sales
#   from work.sales_temp_data_1
#   group by store_id, day_of_sale, product_sku_id, transaction_id;
# quit;
# <p style = 'font-size:16px;color:#000000'>
# /* Aggregating the weight and quantity to calculate the total weight
# and total quantity by each store and product on a particular day */
# proc sql;
#   create table work.sales_aggregated_data_2 as
#   select
#     store_id, day_of_sale, product_sku_id, transaction_id,
#     sum(transaction_quantity) as total_quantity,
#     sum(transaction_weight) as total_weight
#   from work.sales_temp_data_2
#   group by store_id, day_of_sale, product_sku_id, transaction_id;
# quit;
#     </p>
#     </div>
# </code>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Aggregate data in Vantage </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>First we sum the amount using group by store_id, day_of_sale, product_sku_id, transaction_id.</p>

# %%
create multiset table sales_aggregated_data_amt as
(select 
    store_id, day_of_sale, product_sku_id, transaction_id,
    sum(transaction_amount) as total_sales
from DEMO_SlsForecast_SAS.Store_Sales_Amt
group by store_id, day_of_sale, product_sku_id, transaction_id)with data Primary index(transaction_id);
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Then, we sum the quantity and weight using group by store_id, day_of_sale, product_sku_id, transaction_id.</p>

# %%
create multiset table sales_aggregated_data_qty as
(select 
    store_id, day_of_sale, product_sku_id, transaction_id,
    sum(transaction_quantity) as total_quantity,
    sum(transaction_weight) as total_weight
from DEMO_SlsForecast_SAS.Store_Sales_Qty
group by store_id, day_of_sale, product_sku_id, transaction_id)with data Primary index(transaction_id);
# Out:
# Success: 0 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. Merging the Data</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Merging data in SAS</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>As a next step, to prepare the data into a single ADS to forecast sales for this particular store, aggregation is done of the total sales by each store product and transaction id on a particular day.
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>These 2 aggregated datasets are merged to have a single table that contains store_id, day_of_sale, product_sku_id, transaction_id, transaction_amount, transaction quantity, and transaction weight. Merge in SAS is used for the two datasets and define the join columns such as store_id, day_of_sale, product_sku_id and transaction_id. After merging the dataset will have all the required columns in one dataset. This dataset contains around 52.5 million rows.</p>

# %% [markdown]
# <code>
#
# <div class="alert alert-block alert-warning">
# <p style = 'font-size:18px;font-family:Arial;color:#000000'><b>Equivalent SAS Code</b>
# <p style = 'font-size:16px;color:#000000'>
# /* Vertically merging two datasets and creating another dataset in work library with all the required attributes */
# data work.merged_sales_data_c;
# merge  work.sales_aggregated_data_1
#        work.sales_aggregated_data_2;
#        by store_id day_of_sale product_sku_id transaction_id;
#        run;
# <p style = 'font-size:16px;color:#000000'>
# /* Aggregating the amount to calculate total sales in a particular day */
# proc sql;
#   create table work.aggregated_data as
#   select
#     day_of_sale,
#     sum(total_sales) as total_sales
#   from work.merged_sales_data_c
#   group by day_of_sale;
#     quit;</p>
#     </div>
#     </code>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Merging data in Vantage </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We merge the 2 datasets in Vantage.</p>

# %%
create MULTISET table merged_sales_data (
      store_id SMALLINT,
      day_of_sale DATE,
      transaction_id INTEGER,
      product_sku_id DECIMAL(18,0),
      transaction_amount DECIMAL(9,2),
      transaction_quantity SMALLINT,
      transaction_weight DECIMAL(9,2))
PRIMARY INDEX(transaction_id);
# Out:
# Success: 0 rows affected

# %%
INSERT INTO merged_sales_data
    SELECT A.store_id,
        A.day_of_sale,
        A.transaction_id,
        A.product_sku_id,
        A.total_sales,
        B.total_quantity,
        B.total_weight
        FROM (
        SELECT 
            store_id,
            day_of_sale,
            product_sku_id,
            transaction_id,
            total_sales
            FROM sales_aggregated_data_amt
            ) AS A
        INNER JOIN 
        (
        SELECT 
            store_id,
            day_of_sale,
            product_sku_id,
            transaction_id,
            total_quantity,
            total_weight
            FROM sales_aggregated_data_qty
            ) AS B
        ON A.day_of_sale=B.day_of_sale AND A.product_sku_id=B.product_sku_id AND A.store_id=B.store_id 
        AND A.transaction_id=B.transaction_id
# Out:
# Success: 359791 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We do a final aggregation to get the total sales by day in Vantage.</p>

# %%
create multiset table aggregated_sales_td as
  (select 
    rank() over(partition by day_of_sale order by day_of_sale) as SeriesId, ---Series Id created for using in ARIMA
    cast(day_of_sale as timestamp(0)) as day_of_sale,
    sum(transaction_amount) as total_sales
  from merged_sales_data 
  group by day_of_sale) with data;
# Out:
# Success: 0 rows affected

# %%
sel TOP 5 * from aggregated_sales_td order by day_of_sale;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory626738"><style>
#       table.tdhistory626738 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory626738 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory626738:last-child { text-align: left !important; }
#       tbody.tdhistory626738 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory626738 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory626738 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory626738"></th><th class="tdhistory626738">SeriesId</th><th class="tdhistory626738">day_of_sale</th><th class="tdhistory626738">total_sales</th></tr></thead><tbody class="tdhistory626738 resultset-body"><tr><th class="tdhistory626738" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory626738">1</td><td class="tdhistory626738">2019-09-01 00:00:00</td><td class="tdhistory626738">18504.47</td></tr><tr><th class="tdhistory626738" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory626738">1</td><td class="tdhistory626738">2019-09-02 00:00:00</td><td class="tdhistory626738">19093.48</td></tr><tr><th class="tdhistory626738" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory626738">1</td><td class="tdhistory626738">2019-09-03 00:00:00</td><td class="tdhistory626738">14852.53</td></tr><tr><th class="tdhistory626738" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory626738">1</td><td class="tdhistory626738">2019-09-04 00:00:00</td><td class="tdhistory626738">15352.39</td></tr><tr><th class="tdhistory626738" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory626738">1</td><td class="tdhistory626738">2019-09-05 00:00:00</td><td class="tdhistory626738">14616.89</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We plot the total sales by day of sales to check the series data.</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Auto Correlation Plot.</p>
# <i>* Click the cell in the <b>IMAGE</b> column and then right click the cell.  You will then be able to select <b>View Image</b> to view the graph in the result set.</i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(aggregated_sales_td),
        ROW_AXIS(TIMECODE("day_of_sale")),
        SERIES_ID(SeriesID),
        PAYLOAD (FIELDS("total_sales"),CONTENT(REAL))
    ),
    FUNC_PARAMS
    (
        PLOTS[(
            TYPE('line'),
            LEGEND('upper left'),
            TITLE('Daily Sales')
        )],
        IMAGE('png')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory826055"><style>
#       table.tdhistory826055 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory826055 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory826055:last-child { text-align: left !important; }
#       tbody.tdhistory826055 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory826055 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory826055 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory826055"></th><th class="tdhistory826055">SeriesId</th><th class="tdhistory826055">ROW_I</th><th class="tdhistory826055">IMAGE</th></tr></thead><tbody class="tdhistory826055 resultset-body"><tr><th class="tdhistory826055" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory826055">0</td><td class="tdhistory826055">0</td><td class="tdhistory826055">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><i>* Click the cell in the <b>IMAGE</b> column and then right click the cell.  You will then be able to select <b>View Image</b> to view the graph in the result set. </i>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img src="images/Org_SalesData.png" alt="Sales Data" width="400" />
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In the plot we can see that the Sales vary from September 2019 till November 2019 than it is flat till November 2020. The sales again vary from November 2020 till January 2021. After that there is a steep drop in sales and it remains below 1000 from January 2021 and March 2021.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. Using ARIMA (AutoRegressive Integrated Moving Average) model to forecast Sales</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# ARIMA functions on VANTAGE run in the following order:
# <br>
# 1. Run <b>TD_ARIMAESTIMATE</b> function to get the coefficients for the ARIMA model.
# <br>
# 2. <i>[Optional]</i> Run <b>TD_ARIMAVALIDATE</b> function to validate the "goodness of fit" of the ARIMA model, when
# FIT_PERCENTAGE is not 100 in TD_ARIMAESTIMATE.
# <br>
# 3. Run the <b>TD_ARIMAFORECAST</b> function with input from step 1 or step 2 to forecast the future periods
# beyond the last observed period.
# </p>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>6.1 Estimation step</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Estimation step in SAS</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The final step is to fit the Arima model. In the first PROC ARIMA block, it identifies the best ARIMA model for the total_sales variable with a maximum lag of 30 using the identify statement and estimates the model with one seasonal difference (q=1). The parameter estimates are saved in the arima_params dataset in the work library.</p>

# %% [markdown]
# <code>
#
# <div class="alert alert-block alert-warning">
# <p style = 'font-size:18px;font-family:Arial;color:#000000'><b>Equivalent SAS Code</b>
# <p style = 'font-size:16px;color:#000000'>
# /* Fit ARIMA model and calculating its coefficients */
# proc arima data=work.aggregated_data;
#   identify var=total_sales(1) nlag=30;
#   estimate q=1 outest=arima_params;
#     run;</p>
#     </div>
# </code>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Estimation step in Vantage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The TD_ARIMAESTIMATE function estimates the coefficients corresponding to an ARIMA model and fits a series with an existing ARIMA model. The function can also provide the "goodness of fit" and the residuals of the fitting operation. The function generates a model layer used as input for the TD_ARIMAVALIDATE and TD_ARIMAFORECAST functions. This function is for univariate series.</p>
#
# <br>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here, the previously estimated parameters, namely P (Auto-Regressive lags), d (differencing order), and Q (Moving Average lags), are required to be passed into the MODEL_ORDER function. For example, the specific values used here are MODEL_ORDER(2, 1, 8).
# <br>
# <br>
# The output of the analysis is stored in an ART (Analytical Result Table), which contains relevant information and results of the ARIMA modeling process.
# <br>
# <br>
# Furthermore, the fit percentage is determined to be 100. This fit percentage indicates that the ARIMA model is trained using 100% of the available data.</p>

# %%
EXECUTE FUNCTION INTO ART(ART_ESTSales)
TD_ARIMAESTIMATE(
    SERIES_SPEC(
        TABLE_NAME(aggregated_sales_td),
        ROW_AXIS(TIMECODE("day_of_sale")),
        SERIES_ID(seriesID),
        PAYLOAD(
            FIELDS("total_sales"),
            CONTENT(REAL))),
     FUNC_PARAMS(
        NONSEASONAL(MODEL_ORDER(2, 1, 8)),
        CONSTANT(1), COEFF_STATS(1), FIT_METRICS(1),
        RESIDUALS(1), ALGORITHM(CSS_MLE),  FIT_PERCENTAGE(100)
    )
);
# Out:
# Success: 196 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Extract residuals</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The TD_EXTRACT_RESULTS function serves the purpose of retrieving auxiliary result sets stored within an Analytical Result Table (ART). In this particular case, we focus on extracting the residuals from the ART obtained during the previous estimation step.
# <br>

# %%
CREATE TABLE AR_RESIDUALS_Sales AS (
    EXECUTE FUNCTION
    TD_EXTRACT_RESULTS(
        ART_SPEC(
            TABLE_NAME(ART_ESTSales),
            LAYER(ARTFITRESIDUALS)
        )
    )
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
select TOP 5 * from AR_RESIDUALS_Sales;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory963075"><style>
#       table.tdhistory963075 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory963075 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory963075:last-child { text-align: left !important; }
#       tbody.tdhistory963075 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory963075 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory963075 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory963075"></th><th class="tdhistory963075">SeriesId</th><th class="tdhistory963075">ROW_I</th><th class="tdhistory963075">ACTUAL_VALUE</th><th class="tdhistory963075">CALC_VALUE</th><th class="tdhistory963075">RESIDUAL</th></tr></thead><tbody class="tdhistory963075 resultset-body"><tr><th class="tdhistory963075" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory963075">1</td><td class="tdhistory963075">2</td><td class="tdhistory963075">14852.53</td><td class="tdhistory963075">18416.650614786256</td><td class="tdhistory963075">-3564.120614786255</td></tr><tr><th class="tdhistory963075" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory963075">1</td><td class="tdhistory963075">4</td><td class="tdhistory963075">14616.89</td><td class="tdhistory963075">15460.157026485622</td><td class="tdhistory963075">-843.2670264856217</td></tr><tr><th class="tdhistory963075" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory963075">1</td><td class="tdhistory963075">3</td><td class="tdhistory963075">15352.39</td><td class="tdhistory963075">14690.178970114152</td><td class="tdhistory963075">662.2110298858482</td></tr><tr><th class="tdhistory963075" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory963075">1</td><td class="tdhistory963075">1</td><td class="tdhistory963075">19093.48</td><td class="tdhistory963075">18602.27650135135</td><td class="tdhistory963075">491.20349864864903</td></tr><tr><th class="tdhistory963075" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory963075">1</td><td class="tdhistory963075">0</td><td class="tdhistory963075">18504.47</td><td class="tdhistory963075">18485.965543303526</td><td class="tdhistory963075">18.50445669647421</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The outputs above show a sample of the results of the ARIMA model estimating based on patterns from machine learning:</p>
# <li style = 'font-size:16px;font-family:Arial'>Actual value: a value from the provided data for a given ROW_I</li>
# <li style = 'font-size:16px;font-family:Arial'>Calculated value: output of the modeling</li>
# <li style = 'font-size:16px;font-family:Arial'>Residual: The difference between Actual and Estimate.</li></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# In the following cell, we extract additional metrics from the estimate phase i.e., TD_ARIMAESTIMATE.
# </p>

# %%
SELECT * FROM (
    EXECUTE FUNCTION
    TD_EXTRACT_RESULTS(
        ART_SPEC(
            TABLE_NAME(ART_ESTSales),
            LAYER(ARTFITMETADATA)
        )
    )
) AS T;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory624816"><style>
#       table.tdhistory624816 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory624816 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory624816:last-child { text-align: left !important; }
#       tbody.tdhistory624816 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory624816 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory624816 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory624816"></th><th class="tdhistory624816">SeriesId</th><th class="tdhistory624816">ROW_I</th><th class="tdhistory624816">NUM_SAMPLES</th><th class="tdhistory624816">VAR_COUNT</th><th class="tdhistory624816">R_SQUARE</th><th class="tdhistory624816">R_ADJ_SQUARE</th><th class="tdhistory624816">STD_ERROR</th><th class="tdhistory624816">STD_ERROR_DF</th><th class="tdhistory624816">ME</th><th class="tdhistory624816">MAE</th><th class="tdhistory624816">MSE</th><th class="tdhistory624816">MPE</th><th class="tdhistory624816">MAPE</th><th class="tdhistory624816">FSTAT_CALC</th><th class="tdhistory624816">P_VALUE</th><th class="tdhistory624816">NUM_DF</th><th class="tdhistory624816">DENOM_DF</th><th class="tdhistory624816">SIGNIFICANCE_LEVEL</th><th class="tdhistory624816">F_CRITICAL</th><th class="tdhistory624816">F_CRITICAL_P</th><th class="tdhistory624816">NULL_HYPOTH</th></tr></thead><tbody class="tdhistory624816 resultset-body"><tr><th class="tdhistory624816" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory624816">1</td><td class="tdhistory624816">0</td><td class="tdhistory624816">180</td><td class="tdhistory624816">10</td><td class="tdhistory624816">0.9252954285038266</td><td class="tdhistory624816">0.9213404806010881</td><td class="tdhistory624816">4.645377784824725e+06</td><td class="tdhistory624816">178</td><td class="tdhistory624816">-159.96462284886223</td><td class="tdhistory624816">1389.4791683368728</td><td class="tdhistory624816">4.59376247610445e+06</td><td class="tdhistory624816">-25.035952943092347</td><td class="tdhistory624816">47.77222816384857</td><td class="tdhistory624816">233.9589423828082</td><td class="tdhistory624816">6.996177051367498e-91</td><td class="tdhistory624816">9</td><td class="tdhistory624816">170</td><td class="tdhistory624816">0.05</td><td class="tdhistory624816">1.9353152494448054</td><td class="tdhistory624816">0.05</td><td class="tdhistory624816">REJECT</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The displayed output provides performance metrics that offer insights into the effectiveness of the trained ARIMA model. One such metric is the R-Squared value, which measures how well the model fits the data. In this instance, the R-Squared value is noted as 0.92, indicating a strong fit between the model and the data.
# <br>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Create table PLOT_ESTIMATE for plotting</b></p>
# </p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here, we'll create a table which will be used to plot the actual and estimated time series.</p>

# %%
CREATE TABLE PLOT_ESTIMATE (DatasetID VARCHAR(10), ROW_I BIGINT, FIT_MAGNITUDE FLOAT);
# Out:
# Success: 0 rows affected

# %%
INSERT INTO PLOT_ESTIMATE SELECT 'ActualSales', ROW_I, ACTUAL_VALUE FROM AR_RESIDUALS_sales WHERE ROW_I>1; 
INSERT INTO PLOT_ESTIMATE SELECT 'ESTIMATED', ROW_I, CALC_VALUE FROM AR_RESIDUALS_sales WHERE ROW_I>1;
# Out:
# Success: 0 rows affected
# Success: 356 rows affected

# %%
SELECT TOP 5 * FROM PLOT_ESTIMATE ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory464522"><style>
#       table.tdhistory464522 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory464522 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory464522:last-child { text-align: left !important; }
#       tbody.tdhistory464522 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory464522 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory464522 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory464522"></th><th class="tdhistory464522">DatasetID</th><th class="tdhistory464522">ROW_I</th><th class="tdhistory464522">FIT_MAGNITUDE</th></tr></thead><tbody class="tdhistory464522 resultset-body"><tr><th class="tdhistory464522" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory464522">ESTIMATED</td><td class="tdhistory464522">2</td><td class="tdhistory464522">18416.650614786256</td></tr><tr><th class="tdhistory464522" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory464522">ActualSale</td><td class="tdhistory464522">2</td><td class="tdhistory464522">14852.53</td></tr><tr><th class="tdhistory464522" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory464522">ESTIMATED</td><td class="tdhistory464522">3</td><td class="tdhistory464522">14690.178970114152</td></tr><tr><th class="tdhistory464522" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory464522">ActualSale</td><td class="tdhistory464522">3</td><td class="tdhistory464522">15352.39</td></tr><tr><th class="tdhistory464522" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory464522">ESTIMATED</td><td class="tdhistory464522">4</td><td class="tdhistory464522">15460.157026485622</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Actual and Estimated values by the fitted ARIMA model.</p>
# <i>* Click the cell in the <b>IMAGE</b> column and then right click the cell.  You will then be able to select <b>View Image</b> to view the graph in the result set. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC(
        TABLE_NAME(PLOT_ESTIMATE),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(DataSetID),
        ID_SEQUENCE('[{"DatasetID":"ActualSale"},{"DatasetID":"ESTIMATED"}]'),
        PAYLOAD(
            FIELDS(FIT_MAGNITUDE),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS
    (
        WIDTH(1920),
        HEIGHT(1080),
        TITLE('ARIMA ESTIMATE'),
        PLOTS[
            (
                TITLE ('ORIGINAL and ESTIMATED SERIES'),
                GRID(FORMAT('-')),
                TYPE('line'),
                SERIES[
                       (
                        ID(1),
                        FORMAT('r--')
                       ),
                       (
                        ID(2),
                        FORMAT('b-')
                       )
                     ],
                MARKER('o'),
                LEGEND('best'),
                XLABEL('X SeqNo'),
                YLABEL('Y Magnitude')
            )
        ]
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory905785"><style>
#       table.tdhistory905785 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory905785 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory905785:last-child { text-align: left !important; }
#       tbody.tdhistory905785 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory905785 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory905785 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory905785"></th><th class="tdhistory905785">DatasetID</th><th class="tdhistory905785">ROW_I</th><th class="tdhistory905785">IMAGE</th></tr></thead><tbody class="tdhistory905785 resultset-body"><tr><th class="tdhistory905785" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory905785"></td><td class="tdhistory905785">0</td><td class="tdhistory905785">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><i>* Click the cell in the <b>IMAGE</b> column and then right click the cell.  You will then be able to select <b>View Image</b> to view the graph in the result set. </i>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>If you followed the instructions above, you should have seen a graph looks like follows:</p>
# <img src="images/ARIMA_EST.png" alt="ARIMA Estimate" width="400" />
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The red line indicates the actual sales, and the blue line indicates the estimated sales. This graph shows how well the ARIMA model has learned on the training dataset.</p>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6.2 Forecast step</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Forecast step in SAS</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In the second PROC ARIMA block, it identifies and estimates the same ARIMA model as in the first block but additionally generates forecasts for the next 30 time periods (lead=30) and stores the forecasted values in the forecasted_sales dataset in the work library. Now if run this we can see the results with the log indicating it took around 2 seconds to fit the Arima model on the aggregated data. Once the small aggregated dataset is available for the SAS procedure it executes relatively fast.<p>

# %% [markdown]
# <code>
#
# <div class="alert alert-block alert-warning">
# <p style = 'font-size:18px;font-family:Arial;color:#000000'><b>Equivalent SAS Code</b>
# <p style = 'font-size:16px;color:#000000'>
# /* Forecasting future 30 values */
# proc arima data=work.aggregated_data;
#   identify var=total_sales(1) nlag=30;
#   estimate q=1 outest=arima_params;
#   forecast lead=30 out=forecasted_sales;
#     run;</p>
#     </div>
# </code>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Forecast Step in Vantage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The TD_ARIMAFORECAST function is used to forecast a user-defined number of periods based on models fitted from the TD_ARIMAESTIMATE function.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here in the next cell, we use the estimated and validated model to forecast the sales for the subsequent 30 periods, i.e., next 30 days.</p>

# %%
EXECUTE FUNCTION INTO VOLATILE ART(ARIMA_SlsFORECAST)
TD_ARIMAFORECAST(
           ART_SPEC(TABLE_NAME(ART_ESTSales)),
           FUNC_PARAMS(FORECAST_PERIODS(30)));
# Out:
# Success: 30 rows affected

# %%
SELECT TOP 5 * FROM ARIMA_SlsFORECAST;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory903029"><style>
#       table.tdhistory903029 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory903029 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory903029:last-child { text-align: left !important; }
#       tbody.tdhistory903029 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory903029 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory903029 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory903029"></th><th class="tdhistory903029">SeriesId</th><th class="tdhistory903029">ROW_I</th><th class="tdhistory903029">FORECAST_VALUE</th><th class="tdhistory903029">LO_80</th><th class="tdhistory903029">HI_80</th><th class="tdhistory903029">LO_95</th><th class="tdhistory903029">HI_95</th></tr></thead><tbody class="tdhistory903029 resultset-body"><tr><th class="tdhistory903029" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory903029">1</td><td class="tdhistory903029">0</td><td class="tdhistory903029">747.2762562030649</td><td class="tdhistory903029">-2087.4642599829353</td><td class="tdhistory903029">3582.016772389065</td><td class="tdhistory903029">-3588.0838080518206</td><td class="tdhistory903029">5082.63632045795</td></tr><tr><th class="tdhistory903029" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory903029">1</td><td class="tdhistory903029">1</td><td class="tdhistory903029">538.1429653426243</td><td class="tdhistory903029">-3142.3211011966478</td><td class="tdhistory903029">4218.607031881897</td><td class="tdhistory903029">-5090.639225087868</td><td class="tdhistory903029">6166.925155773116</td></tr><tr><th class="tdhistory903029" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory903029">1</td><td class="tdhistory903029">2</td><td class="tdhistory903029">526.2517957767121</td><td class="tdhistory903029">-3726.0496322607996</td><td class="tdhistory903029">4778.553223814224</td><td class="tdhistory903029">-5977.079880270857</td><td class="tdhistory903029">7029.583471824281</td></tr><tr><th class="tdhistory903029" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory903029">1</td><td class="tdhistory903029">3</td><td class="tdhistory903029">746.4043992918346</td><td class="tdhistory903029">-3780.442651318073</td><td class="tdhistory903029">5273.251449901742</td><td class="tdhistory903029">-6176.808433821139</td><td class="tdhistory903029">7669.6172324048075</td></tr><tr><th class="tdhistory903029" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory903029">1</td><td class="tdhistory903029">4</td><td class="tdhistory903029">949.1487081884198</td><td class="tdhistory903029">-3648.2076728242873</td><td class="tdhistory903029">5546.505089201127</td><td class="tdhistory903029">-6081.898804479961</td><td class="tdhistory903029">7980.1962208568</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The above output shows us the forecasted value for the next 30 days. Observe that we also have forecasted values with 80% and 95% confidence.</p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Create table PLOT_FORECAST for plotting</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here, we'll create a table which will be used to plot the forecasted sales in the next 30 days.</p>

# %%
CREATE TABLE PLOT_FORECAST (DatasetID VARCHAR(16), ROW_I BIGINT, FORECAST_MAGNITUDE FLOAT);
# Out:
# Success: 0 rows affected

# %%
INSERT INTO PLOT_FORECAST   SELECT 'FORECASTED', ROW_I, FORECAST_VALUE FROM ARIMA_SlsFORECAST; 
INSERT INTO PLOT_FORECAST   SELECT 'UPPER_BOUND', ROW_I, HI_80 FROM ARIMA_SlsFORECAST ; 
INSERT INTO PLOT_FORECAST   SELECT 'LOWER_BOUND', ROW_I, LO_80 FROM ARIMA_SlsFORECAST ;
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# Success: 90 rows affected

# %%
SELECT * FROM PLOT_FORECAST ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory854487"><style>
#       table.tdhistory854487 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory854487 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory854487:last-child { text-align: left !important; }
#       tbody.tdhistory854487 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory854487 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory854487 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory854487"></th><th class="tdhistory854487">DatasetID</th><th class="tdhistory854487">ROW_I</th><th class="tdhistory854487">FORECAST_MAGNITUDE</th></tr></thead><tbody class="tdhistory854487 resultset-body"><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory854487">FORECASTED</td><td class="tdhistory854487">0</td><td class="tdhistory854487">747.2762562030649</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory854487">UPPER_BOUND</td><td class="tdhistory854487">0</td><td class="tdhistory854487">3582.016772389065</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory854487">LOWER_BOUND</td><td class="tdhistory854487">0</td><td class="tdhistory854487">-2087.4642599829353</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory854487">UPPER_BOUND</td><td class="tdhistory854487">1</td><td class="tdhistory854487">4218.607031881897</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory854487">FORECASTED</td><td class="tdhistory854487">1</td><td class="tdhistory854487">538.1429653426243</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory854487">LOWER_BOUND</td><td class="tdhistory854487">1</td><td class="tdhistory854487">-3142.3211011966478</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory854487">FORECASTED</td><td class="tdhistory854487">2</td><td class="tdhistory854487">526.2517957767121</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory854487">UPPER_BOUND</td><td class="tdhistory854487">2</td><td class="tdhistory854487">4778.553223814224</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory854487">LOWER_BOUND</td><td class="tdhistory854487">2</td><td class="tdhistory854487">-3726.0496322607996</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory854487">UPPER_BOUND</td><td class="tdhistory854487">3</td><td class="tdhistory854487">5273.251449901742</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory854487">LOWER_BOUND</td><td class="tdhistory854487">3</td><td class="tdhistory854487">-3780.442651318073</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory854487">FORECASTED</td><td class="tdhistory854487">3</td><td class="tdhistory854487">746.4043992918346</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory854487">FORECASTED</td><td class="tdhistory854487">4</td><td class="tdhistory854487">949.1487081884198</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory854487">LOWER_BOUND</td><td class="tdhistory854487">4</td><td class="tdhistory854487">-3648.2076728242873</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory854487">UPPER_BOUND</td><td class="tdhistory854487">4</td><td class="tdhistory854487">5546.505089201127</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory854487">FORECASTED</td><td class="tdhistory854487">5</td><td class="tdhistory854487">950.6618369004898</td></tr><tr><th class="tdhistory854487" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory854487">UPPER_BOUND</td><td class="tdhistory854487">5</td><td class="tdhistory854487">5652.979963705752 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Forecasted values by ARIMA model.</p>
# <i>* Click the cell in the <b>IMAGE</b> column and then right click the cell.  You will then be able to select <b>View Image</b> to view the graph in the result set.</i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC(
        TABLE_NAME(PLOT_FORECAST),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(DataSetID),
        ID_SEQUENCE('[{"DatasetID":"FORECASTED"},{"DatasetID":"UPPER_BOUND"},{"DatasetID":"LOWER_BOUND"}]'),
        PAYLOAD(
            FIELDS(FORECAST_MAGNITUDE),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS
    (
        WIDTH(1920),
        HEIGHT(1080),
        TITLE('ARIMA FORECAST'),
        PLOTS[
            (
                TITLE ('Forecast'),
                GRID(FORMAT('-')),
                TYPE('line'),
                SERIES[
                       (
                        ID(1),
                        FORMAT('r--')
                       ),
                       (
                        ID(2),
                        FORMAT('b-')
                       ),
                        (
                        ID(3),
                        FORMAT('b-')
                       )
                     ],
                MARKER('o'),
                LEGEND('best'),
                XLABEL('X SeqNo'),
                YLABEL('Y Magnitude')
            )
        ]
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory78141"><style>
#       table.tdhistory78141 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory78141 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory78141:last-child { text-align: left !important; }
#       tbody.tdhistory78141 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory78141 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory78141 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory78141"></th><th class="tdhistory78141">DatasetID</th><th class="tdhistory78141">ROW_I</th><th class="tdhistory78141">IMAGE</th></tr></thead><tbody class="tdhistory78141 resultset-body"><tr><th class="tdhistory78141" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory78141"></td><td class="tdhistory78141">0</td><td class="tdhistory78141">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><i>* Click the cell in the <b>IMAGE</b> column and then right click the cell.  You will then be able to select <b>View Image</b> to view the graph in the result set. </i>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img id="fig6" src="images/ARIMA_FORECAST.png" alt="ARIMA Forecast" width="400" />
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The red line is the Forecasted Sales for the next 30 days, and the blue lines are the upper and lower confidence interval with an 80% confidence level. As seen in the original Sales graph, the sales have dropped below 1000 for the latest period. Similar sales can be observed in the forecast period, which varies around 1000.</p>
#
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>7. Conclusion:</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Moving large amounts of data between Vantage and SAS is usually the main culprit for slow running jobs and complex analytics pipelines amplifying governance issues from orphaned and exposed data in SAS environments. By executing the complete flow inside Vantage using ClearScape Analytics we are reducing the complexity and achieving greater efficiency. </p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>One of our customers cited the following benefits:</p>
# <table style = 'border:1px solid black;width:100%;:#00233C'>
#          <tr style = 'font-size:16px;font-family:Arial;border:1px solid black;:#00233C'>
#              <th style = 'border:1px solid black;color:#00233C'><b>Past Approach using SAS Alone</b></th>
#              <th style = 'border:1px solid black;color:#00233C'><b>In-Database Approach</b></th>
#          </tr>
#          <tr style = 'font-size:14px;font-family:Arial;border:1px solid black;color:#00233C'>
#             <td style = 'border:1px solid black;color:#00233C'>Daily process begins with flat file creation at 6:30am – SLA delivered at ~9:30am.</td>
#             <td style = 'border:1px solid black;color:#00233C'>Daily process begins at 4:00am with EDW load.</td>
#          </tr>
#          <tr style = 'font-size:14px;font-family:Arial;border:1px solid black;color:#00233C'>
#             <td style = 'border:1px solid black;color:#00233C'>File transferred to SQL Server,<b> limited to ~350K customer records based on  specific criteria.</b></td>
#             <td style = 'border:1px solid black;color:#00233C'>All operational data loaded directly to EDW.  No flat file or intermediate processing is needed.</td>
#          </tr>
#          <tr style = 'font-size:14px;font-family:Arial;border:1px solid black;color:#00233C'>
#              <td style = 'border:1px solid black;color:#00233C'><b>300 step process</b> to support data mining life cycle.<b>30 MINUTES TO SCORE ~350k customers</b></td>
#              <td style = 'border:1px solid black;color:#00233C'><b>10 step process</b> - Scoring and customer selection done in-database against  ALL customer rows <b>4 MINUTES TO SCORE ~40M customers</b></td>
#          </tr>
#          <tr style = 'font-size:14px;font-family:Arial;border:1px solid black;color:#00233C'>
#              <td style = 'border:1px solid black;color:#00233C'><b>Runs in ~ 3 HOURS</b></td>
#              <td style = 'border:1px solid black;color:#00233C'><b>Runs in 12 MINUTES with 114x # of customers.</b></td>
#          </tr>
#          <tr style = 'font-size:14px;font-family:Arial;border:1px solid black;color:#00233C'>
#             <td style = 'border:1px solid black;color:#00233C'><b>Cost for data mart infrastructure and support, plus lost opportunity to process all customers</b></td>
#             <td style = 'border:1px solid black;color:#00233C'><b>Uses available capacity outside of work hours with far less complexity and support cost. By processing all 40M customers vs 350K subset, increased collections $1M - $3M/month.</b></td>
#          </tr>
#          <tr>
#
# </table>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>8. Cleanup</b>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Work Tables</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Cleanup work tables to prevent errors next time. This section drops all the tables created during the demonstration.</p>

# %%
DROP TABLE sales_aggregated_data_amt;
# Out:
# Success: 19 rows affected

# %%
DROP TABLE sales_aggregated_data_qty;
# Out:
# Success: 20 rows affected

# %%
DROP TABLE merged_sales_data;
# Out:
# Success: 21 rows affected

# %%
DROP TABLE aggregated_sales_td;
# Out:
# Success: 16 rows affected

# %%
DROP TABLE ART_ESTSales;
# Out:
# Success: 46 rows affected

# %%
DROP TABLE AR_RESIDUALS_Sales;
# Out:
# Success: 18 rows affected

# %%
DROP TABLE PLOT_ESTIMATE;
# Out:
# Success: 16 rows affected

# %%
DROP TABLE ARIMA_SlsFORECAST;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE PLOT_FORECAST;
# Out:
# Success: 16 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'> <b>Databases and Tables </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_SlsForecast_SAS')        -- Takes 5 seconds
# Out:
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory711159"><style>
#       table.tdhistory711159 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory711159 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory711159:last-child { text-align: left !important; }
#       tbody.tdhistory711159 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory711159 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory711159 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory711159"></th><th class="tdhistory711159">Message</th></tr></thead><tbody class="tdhistory711159 resultset-body"><tr><th class="tdhistory711159" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory711159">Removed objects related to DEMO_SlsForecast_SAS. That ran for 0:00:02.66</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>UAF(Unbounded Array Framework) Documentation: <a href = 'https://docs.teradata.com/r/Enterprise_IntelliFlex_VMware/Teradata-VantageTM-Unbounded-Array-Framework-Time-Series-Reference-17.20/Unbounded-Array-Framework'>https://docs.teradata.com/r/Enterprise_IntelliFlex_VMware/Teradata-VantageTM-Unbounded-Array-Framework-Time-Series-Reference-17.20/Unbounded-Array-Framework</a></li>
# </ul>

# %% [markdown]
# <footer style="padding:10px;background:#f9f9f9;border-bottom:3px solid #394851">Copyright © Teradata Corporation - 2023. All Rights Reserved.</footer>
