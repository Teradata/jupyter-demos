# %% [markdown]
# <header style="padding:1px;background:#f9f9f9;border-top:3px solid #00b2b1"><img id="Teradata-logo" src="https://www.teradata.com/Teradata/Images/Rebrand/Teradata_logo-two_color.png" alt="Teradata" width="220" align="right" />
#
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>Time Series Forecasting on Number of Passengers for FlyHigh Airline</b>
# </header>
#
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Introduction:</b></p>
#
# <p style = 'font-size:16px;font-family:Arial'>Consider a startup airline <b>FlyHigh Airlines</b> as our client. The client requires us to forecast the number of passengers who fly using their airline. The ARIMA model has been widely utilized in many fields for forecasting since it is recognized as reliable, efficient, and capable of predicting short-term share market movements. Hence, we'll build an ARIMA model to forecast the demand(passenger traffic) for Airplanes.
# <br>
# <br>
# ARIMA(Auto Regressive Integrated Moving Average) is a combination of 2 models, AR(Auto Regressive) and MA(Moving Average). It has three hyperparameters - P(autoregressive lags), d(order of differentiation), and Q(moving avg.), which respectively come from the AR, I and MA components. The AR part is the correlation between previous and current periods. The MA part is used to smooth out the noise. The I part binds together the AR and MA parts.</p>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Data:</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The data for this demonstration resides on Vantage. The data consists of monthly flights between 2007 and 2018  (144 rows), which we selected to be able to understand the functionality. The same functionality can be applied to massive datasets with multiple series concurrently.
# </p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#E37C4D'><b>Steps in the analysis:</b></p>
# <ol style = 'font-size:16px;font-family:Arial'>
#     <li>Connect to Vantage</li>
#     <li>Explore the dataset</li>
#     <li>Check for Stationarity using Dickey-Fuller Test</li>
#     <li>Make series stationary using TD_DIFF (D)</li>
#     <li>Check for autocorrelation of the time series (Q)</li>
#     <li>Check for partial autocorrelation of the time series (P)</li>
#     <li>Using ARIMA(AutoRegressive Integrated Moving Average) model to forecast number of passengers</li>
#         <ul>
#             <li>7.1 Estimation step using TD_ARIMAESTIMATE</li>
#             <li>7.2 Extract residuals</li>
#             <li>7.3 Create table PLOT_ESTIMATE for plotting</li>
#             <li>7.4 Validation step using TD_ARIMAVALIDATE</li>
#             <li>7.5 Extract residuals</li>
#             <li>7.6 Create table PLOT_VALIDATE for plotting</li>
#             <li>7.7 Forecast step using TD_ARIMAFORECAST</li>
#             <li>7.8 Create table PLOT_FORECAST for plotting</li>
#         </ul>
#     <li>Cleanup</li>
# </ol>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>1. Connect to Vantage</b>
# <p style = 'font-size:16px;font-family:Arial'>You will be prompted to provide the password. Enter your password, press the Enter key, and then use the down arrow to go to the next cell.</p>

# %%
%connect local, hidewarnings=True
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
Set query_band='DEMO=AirPassengersTimeSeriesForecasting.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <b style = 'font-size:20px;font-family:Arial;color:#E37C4D'>Getting Data for This Demo
# <p style = 'font-size:16px;font-family:Arial'>We have provided data for this demo on cloud storage. You can either run the demo using foreign tables to access the data without any storage on your environment or download the data to local storage, which may yield faster execution. Still, there could be considerations of available storage. Two statements are in the following cell, and one of them is commented out. You may switch between the modes by changing the comment string.</p>

# %%
call get_data('DEMO_AirPassengers_cloud');           -- Takes 10 seconds
-- call get_data('DEMO_AirPassengers_local');           -- Takes 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory788276"><style>
#       table.tdhistory788276 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory788276 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory788276:last-child { text-align: left !important; }
#       tbody.tdhistory788276 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory788276 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory788276 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory788276"></th><th class="tdhistory788276">Message</th></tr></thead><tbody class="tdhistory788276 resultset-body"><tr><th class="tdhistory788276" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory788276">That ran for   0:00:37.50 with 5 statements and 1 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();          -- Takes 5 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory901696"><style>
#       table.tdhistory901696 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory901696 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory901696:last-child { text-align: left !important; }
#       tbody.tdhistory901696 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory901696 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory901696 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory901696"></th><th class="tdhistory901696">Space_Report</th></tr></thead><tbody class="tdhistory901696 resultset-body"><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory901696">You have:  #databases=3 #tables=7 #views=13  You have used 10.2 MB of 27,959.7 MB available - 0.0%  ... Space Usage OK</td></tr><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory901696"> </td></tr><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory901696">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory901696">   demo_user                            6      11  27,763.8 MB       3.7 MB </td></tr><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory901696">   DEMO_AirPassengers                   0       1       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory901696">   DEMO_GLM_Fraud                       0       1       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory901696" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory901696">   DEMO_GLM_Fraud_db                    1       0     195.9 MB       6.5 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>2. Explore the dataset</b>
# <p style = 'font-size:16px;font-family:Arial'>The dataset consists of time-series data that is organized by date/time and the corresponding number of passengers traveling per month. It contains two columns: <b>Date</b>, which represents the temporal information, and <b>Passengers</b>, which represents the value to be forecasted.</p>

# %%
SELECT TOP 5 * FROM DEMO_AirPassengers.airpassengers ORDER BY "Date";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory183355"><style>
#       table.tdhistory183355 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory183355 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory183355:last-child { text-align: left !important; }
#       tbody.tdhistory183355 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory183355 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory183355 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory183355"></th><th class="tdhistory183355">Date</th><th class="tdhistory183355">Passengers</th><th class="tdhistory183355">seriesID</th></tr></thead><tbody class="tdhistory183355 resultset-body"><tr><th class="tdhistory183355" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory183355">2007-01-01 01:33:36.000000</td><td class="tdhistory183355">112</td><td class="tdhistory183355">FlyHigh</td></tr><tr><th class="tdhistory183355" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory183355">2007-02-01 01:33:36.000000</td><td class="tdhistory183355">118</td><td class="tdhistory183355">FlyHigh</td></tr><tr><th class="tdhistory183355" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory183355">2007-03-01 01:33:36.000000</td><td class="tdhistory183355">132</td><td class="tdhistory183355">FlyHigh</td></tr><tr><th class="tdhistory183355" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory183355">2007-04-01 01:33:36.000000</td><td class="tdhistory183355">129</td><td class="tdhistory183355">FlyHigh</td></tr><tr><th class="tdhistory183355" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory183355">2007-05-01 01:33:36.000000</td><td class="tdhistory183355">121</td><td class="tdhistory183355">FlyHigh</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The dataset captures the monthly variation in passenger numbers over time, allowing for the analysis and prediction of passenger trends.
#     <br>
#     <br>
# The <b>TD_PLOT</b> function will return an image in the cell of the results showing the total passengers by month from 2007 to 2018.</p>
#
# <i>* Please <b> right click on the cell under the IMAGE column </b> from the output and choose view image to see the plot generated. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(DEMO_AirPassengers.airpassengers),
        ROW_AXIS(TIMECODE("Date")),
        SERIES_ID(seriesID),
        PAYLOAD (FIELDS("Passengers"),CONTENT(REAL))
    ),
    FUNC_PARAMS
    (
        PLOTS[(
            TYPE('line'),
            LEGEND('upper left'),
            TITLE('Number of Passengers Travelling Monthly')
        )],
        IMAGE('png')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory950417"><style>
#       table.tdhistory950417 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory950417 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory950417:last-child { text-align: left !important; }
#       tbody.tdhistory950417 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory950417 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory950417 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory950417"></th><th class="tdhistory950417">seriesID</th><th class="tdhistory950417">ROW_I</th><th class="tdhistory950417">IMAGE</th></tr></thead><tbody class="tdhistory950417 resultset-body"><tr><th class="tdhistory950417" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory950417"></td><td class="tdhistory950417">0</td><td class="tdhistory950417">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img id="fig1" src="images/fig1.png" alt="Number of Passengers Travelling Monthly" width="400" />
# <p style = 'font-size:16px;font-family:Arial'>This shows that the data has yearly cycles and an upward trend.</p>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>3. Check for Stationarity using Dickey-Fuller Test</b>
# <br>
# <b style = font-size:16px;font-family:Arial>What is Stationarity?</b>
# <br>
# <p style = 'font-size:16px;font-family:Arial'>Before applying any statistical model on a Time Series, the series has to be stationary, which means that, over different time periods,
# <br>
# a) It should have constant mean.
# <br>
# b) It should have constant variance or standard deviation.
# <br>
# c) Auto-covariance should not depend on time.
# </p>
# <p style = 'font-size:16px;font-family:Arial'> We can visually examine if the mean and variance are constant over different periods of time or not. Alternatively, Dickey-Fuller test is widely used to check for stationarity in the time series data.
# <br>
#
# <p style = 'font-size:16px;font-family:Arial'>The following query would check for stationarity by using Dickey-Fuller Test. If the Null Hypothesis of the Dickey-Fuller Test:
# <br>
# • <b>ACCEPT</b> means the null hypothesis is accepted. Unit roots are present, and the process is non-stationary.
# <br>
# • <b>REJECT</b> means the null hypothesis is rejected. Unit roots are present, and the process may or may not be stationary, depending on other factors.</p>

# %%
EXECUTE FUNCTION
TD_DICKEY_FULLER(
    SERIES_SPEC(
        TABLE_NAME(DEMO_AirPassengers.airpassengers),
        ROW_AXIS(TIMECODE("Date")),
        SERIES_ID("seriesID"),
        PAYLOAD(
            FIELDS("Passengers"),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS(
        ALGORITHM('NONE')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory605872"><style>
#       table.tdhistory605872 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory605872 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory605872:last-child { text-align: left !important; }
#       tbody.tdhistory605872 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory605872 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory605872 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory605872"></th><th class="tdhistory605872">seriesID</th><th class="tdhistory605872">ROW_I</th><th class="tdhistory605872">NUM_SAMPLES</th><th class="tdhistory605872">ALGORITHM</th><th class="tdhistory605872">T_STAT</th><th class="tdhistory605872">P_VALUE</th><th class="tdhistory605872">NULL_HYP</th></tr></thead><tbody class="tdhistory605872 resultset-body"><tr><th class="tdhistory605872" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory605872">FlyHigh</td><td class="tdhistory605872">0</td><td class="tdhistory605872">144</td><td class="tdhistory605872">NONE</td><td class="tdhistory605872">0.04711965847541405</td><td class="tdhistory605872">0.6997326711216104</td><td class="tdhistory605872">ACCEPT</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Examining the column labeled "NULL_HYP," we can see that the NULL hypothesis is accepted. This acceptance indicates the presence of unit roots in the series, implying that the series is non-stationary. Therefore, it is necessary to take steps to transform the series and make it stationary. By making the series stationary, we aim to remove the unit roots and create a more suitable basis for analysis and modeling.</p>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>4. Make series stationary using TD_DIFF</b>
# <p style = 'font-size:16px;font-family:Arial'>TD_DIFF is a transformation method used to convert a time series into a differenced time series. This transformation can be applied to a variety of types of time series, including stationary, seasonal, or nonstationary series.
# <br>
# <br>
# In order to assess stationarity, we will generate a new table that contains the differenced series. The differenced series helps remove trends or seasonal patterns, making the data potentially more stationary.
# <br>
# <br>
# For this analysis, we have set the parameter LAG to 12, representing 12 units of time (e.g., 12 months or one year). This choice considers the cyclical nature of the data, enabling us to capture seasonal patterns.
# <br>
# <br>
# Using the Dickey-Fuller test, we will examine whether the newly created table, which contains the differenced series, exhibits stationarity. If the test indicates non-stationarity, we will increase the DIFFERENCES parameter and repeat the test. This iterative process aims to identify the minimum number of differences required to achieve stationarity in the series. By progressively differencing the series until it becomes stationary, we can enhance the suitability of the data for further analysis and modeling.</p>

# %%
EXECUTE FUNCTION
COLUMNS(OUT_Passengers AS Passengers)
INTO VOLATILE ART(diff1_air)
TD_DIFF(
    SERIES_SPEC(
            TABLE_NAME(DEMO_AirPassengers.airpassengers),
            ROW_AXIS(TIMECODE("Date")),
            SERIES_ID("seriesID"),
            PAYLOAD(
                FIELDS("Passengers"),
                CONTENT(REAL)
            )
    ),
    FUNC_PARAMS(
          LAG(12),
          DIFFERENCES(1),
          SEASONAL_MULTIPLIER(0)
    )
);
# Out:
# Success: 132 rows affected

# %%
SELECT TOP 5 * FROM diff1_air ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory165753"><style>
#       table.tdhistory165753 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory165753 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory165753:last-child { text-align: left !important; }
#       tbody.tdhistory165753 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory165753 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory165753 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory165753"></th><th class="tdhistory165753">seriesID</th><th class="tdhistory165753">ROW_I</th><th class="tdhistory165753">Passengers</th></tr></thead><tbody class="tdhistory165753 resultset-body"><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory165753">FlyHigh</td><td class="tdhistory165753">0</td><td class="tdhistory165753">3</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory165753">FlyHigh</td><td class="tdhistory165753">1</td><td class="tdhistory165753">8</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory165753">FlyHigh</td><td class="tdhistory165753">2</td><td class="tdhistory165753">9</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory165753">FlyHigh</td><td class="tdhistory165753">3</td><td class="tdhistory165753">6</td></tr><tr><th class="tdhistory165753" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory165753">FlyHigh</td><td class="tdhistory165753">4</td><td class="tdhistory165753">4</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>In the above result, <b>ROW_I</b> is the Row identifier of the ordered result sets and <b>OUT_Passengers</b> is Transformed magnitudes of differenced time series elements.
#     <br>
#     <br>
# The following cell applies Dickey-Fuller test to check for stationarity.</p>

# %%
EXECUTE FUNCTION
TD_DICKEY_FULLER(
    SERIES_SPEC(
        TABLE_NAME(diff1_air),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID("seriesID"),
        PAYLOAD(
            FIELDS("Passengers"),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS(
        ALGORITHM('NONE')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory44717"><style>
#       table.tdhistory44717 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory44717 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory44717:last-child { text-align: left !important; }
#       tbody.tdhistory44717 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory44717 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory44717 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory44717"></th><th class="tdhistory44717">seriesID</th><th class="tdhistory44717">ROW_I</th><th class="tdhistory44717">NUM_SAMPLES</th><th class="tdhistory44717">ALGORITHM</th><th class="tdhistory44717">T_STAT</th><th class="tdhistory44717">P_VALUE</th><th class="tdhistory44717">NULL_HYP</th></tr></thead><tbody class="tdhistory44717 resultset-body"><tr><th class="tdhistory44717" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory44717">FlyHigh</td><td class="tdhistory44717">0</td><td class="tdhistory44717">132</td><td class="tdhistory44717">NONE</td><td class="tdhistory44717">-1.8845403761078852</td><td class="tdhistory44717">0.056725004082637996</td><td class="tdhistory44717">ACCEPT</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Based on the examination of the rightmost column labeled "NULL_HYP," it is evident that the NULL hypothesis has been accepted. This acceptance suggests the presence of unit roots in the series, indicating that the series is non-stationary.
# <br>
# To address this non-stationarity, we will perform differencing on the series. In this case, we will apply the differencing operation twice, as indicated by setting the DIFFERENCES parameter to 2. By differencing the series twice, we aim to further eliminate any remaining trends or patterns that contribute to non-stationarity.</p>

# %%
EXECUTE FUNCTION
COLUMNS(OUT_Passengers AS Passengers)
INTO VOLATILE ART(diff2_air)
TD_DIFF(
    SERIES_SPEC(
            TABLE_NAME(DEMO_AirPassengers.airpassengers),
            ROW_AXIS(TIMECODE("Date")),
            SERIES_ID("seriesID"),
            PAYLOAD(
                FIELDS("Passengers"),
                CONTENT(REAL)
            )
    ),
    FUNC_PARAMS(
          LAG(12),
          DIFFERENCES(2),
          SEASONAL_MULTIPLIER(0)
    )
);
# Out:
# Success: 120 rows affected

# %%
SELECT TOP 5 * FROM diff2_air ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory211861"><style>
#       table.tdhistory211861 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory211861 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory211861:last-child { text-align: left !important; }
#       tbody.tdhistory211861 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory211861 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory211861 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory211861"></th><th class="tdhistory211861">seriesID</th><th class="tdhistory211861">ROW_I</th><th class="tdhistory211861">Passengers</th></tr></thead><tbody class="tdhistory211861 resultset-body"><tr><th class="tdhistory211861" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory211861">FlyHigh</td><td class="tdhistory211861">0</td><td class="tdhistory211861">27</td></tr><tr><th class="tdhistory211861" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory211861">FlyHigh</td><td class="tdhistory211861">1</td><td class="tdhistory211861">16</td></tr><tr><th class="tdhistory211861" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory211861">FlyHigh</td><td class="tdhistory211861">2</td><td class="tdhistory211861">28</td></tr><tr><th class="tdhistory211861" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory211861">FlyHigh</td><td class="tdhistory211861">3</td><td class="tdhistory211861">22</td></tr><tr><th class="tdhistory211861" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory211861">FlyHigh</td><td class="tdhistory211861">4</td><td class="tdhistory211861">43</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>In the above result, <b>ROW_I</b> is the Row identifier of the ordered result sets and <b>OUT_Passengers</b> is Transformed magnitudes of differenced time series elements.
#     <br>
#     <br>
# The following cell applies Dickey-Fuller test to check for stationarity.</p>

# %%
EXECUTE FUNCTION
TD_DICKEY_FULLER(
    SERIES_SPEC(
        TABLE_NAME(diff2_air),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID("seriesID"),
        PAYLOAD(
            FIELDS("Passengers"),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS(
        ALGORITHM('NONE')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory371327"><style>
#       table.tdhistory371327 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory371327 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory371327:last-child { text-align: left !important; }
#       tbody.tdhistory371327 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory371327 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory371327 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory371327"></th><th class="tdhistory371327">seriesID</th><th class="tdhistory371327">ROW_I</th><th class="tdhistory371327">NUM_SAMPLES</th><th class="tdhistory371327">ALGORITHM</th><th class="tdhistory371327">T_STAT</th><th class="tdhistory371327">P_VALUE</th><th class="tdhistory371327">NULL_HYP</th></tr></thead><tbody class="tdhistory371327 resultset-body"><tr><th class="tdhistory371327" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory371327">FlyHigh</td><td class="tdhistory371327">0</td><td class="tdhistory371327">120</td><td class="tdhistory371327">NONE</td><td class="tdhistory371327">-4.133640503393215</td><td class="tdhistory371327">4.30128564824852e-05</td><td class="tdhistory371327">REJECT</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Based on the examination of the rightmost column labeled "NULL_HYP," we can see that the NULL hypothesis has been rejected. This rejection suggests that there is evidence of the presence of unit roots in the series, which indicates that the series may or may not be stationary.
# <br>
# <br>
# Additionally, analyzing the p-value, we observe that it is less than 0.05. This indicates that the observed data would occur by chance less than 5% of the time if the null hypothesis of non-stationarity were true. Therefore, based on the significant p-value, it is reasonable to suggest that the series is stationary.
# <br>
# <br>
# Consequently, in order to achieve stationarity, we will apply differences to the series. In this case, the number of differences, denoted by <b>D = 2</b>, signifies that the series will be differenced four times</p>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>5. Check for autocorrelation of the time series</b>
# <p style = 'font-size:16px;font-family:Arial'>The TD_ACF method is used to compute the autocorrelation or autocovariance of a time series. Autocorrelation measures the correlation between a time series and its lagged versions, while autocovariance measures the covariance between a time series and its lagged versions. These metrics help us understand the relationship or dependency of the time series on its past values.
# <br>
# <br>
# In this analysis, we examine the autocorrelation using a maximum lag of 12 time steps. This means we calculate the autocorrelation or autocovariance at different lagged intervals up to 12 time steps. By considering a range of lags, we gain insights into how the time series correlates or covaries with itself over different time periods.</p>

# %%
EXECUTE FUNCTION
COLUMNS(OUT_Passengers AS Auto_Correlation)
INTO VOLATILE ART(ACFDemo)
TD_ACF(
    SERIES_SPEC(
        TABLE_NAME(diff2_air),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID("seriesID"),
        PAYLOAD(
            FIELDS("Passengers"),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS(
        MAXLAGS(12),
        UNBIASED(0),    -- Use 0 for Jenkins-Watts formula, or 1 for BoxJenkins formula
        FUNC_TYPE(0),   -- Use 0 for autocorrelation, or 1 for autocovariance
        DEMEAN(1),
        QSTAT(0),
        ALPHA(0.05)
    )
);
# Out:
# Success: 13 rows affected

# %%
SELECT TOP 5 * FROM ACFDemo ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory884215"><style>
#       table.tdhistory884215 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory884215 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory884215:last-child { text-align: left !important; }
#       tbody.tdhistory884215 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory884215 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory884215 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory884215"></th><th class="tdhistory884215">seriesID</th><th class="tdhistory884215">ROW_I</th><th class="tdhistory884215">Auto_Correlation</th><th class="tdhistory884215">CONF_OFF_Passengers</th><th class="tdhistory884215">CONF_LOW_Passengers</th><th class="tdhistory884215">CONF_HI_Passengers</th></tr></thead><tbody class="tdhistory884215 resultset-body"><tr><th class="tdhistory884215" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory884215">FlyHigh</td><td class="tdhistory884215">0</td><td class="tdhistory884215">1</td><td class="tdhistory884215">0</td><td class="tdhistory884215">1</td><td class="tdhistory884215">1</td></tr><tr><th class="tdhistory884215" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory884215">FlyHigh</td><td class="tdhistory884215">1</td><td class="tdhistory884215">0.7173571430652831</td><td class="tdhistory884215">0.17891941437171568</td><td class="tdhistory884215">0.5384377286935674</td><td class="tdhistory884215">0.8962765574369987</td></tr><tr><th class="tdhistory884215" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory884215">FlyHigh</td><td class="tdhistory884215">2</td><td class="tdhistory884215">0.6230411726914503</td><td class="tdhistory884215">0.2548708496750216</td><td class="tdhistory884215">0.3681703230164287</td><td class="tdhistory884215">0.8779120223664719</td></tr><tr><th class="tdhistory884215" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory884215">FlyHigh</td><td class="tdhistory884215">3</td><td class="tdhistory884215">0.44853385579259397</td><td class="tdhistory884215">0.29968671556918897</td><td class="tdhistory884215">0.148847140223405</td><td class="tdhistory884215">0.7482205713617829</td></tr><tr><th class="tdhistory884215" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory884215">FlyHigh</td><td class="tdhistory884215">4</td><td class="tdhistory884215">0.3854780220041449</td><td class="tdhistory884215">0.3204570277663311</td><td class="tdhistory884215">0.06502099423781377</td><td class="tdhistory884215">0.7059350497704759</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Auto Correlation Plot.</p>
# <i>* Please <b> right click on the cell under the IMAGE column </b> from the output and choose view image to see the plot generated. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(ACFDemo),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(seriesID),
        PAYLOAD (FIELDS(Auto_Correlation, CONF_OFF_Passengers),CONTENT(MULTIVAR_REAL))
    ),
    FUNC_PARAMS
    (
        PLOTS[(
            TYPE('corr')
           ,LEGEND('best') 
        )],
        IMAGE('png')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory204087"><style>
#       table.tdhistory204087 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory204087 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory204087:last-child { text-align: left !important; }
#       tbody.tdhistory204087 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory204087 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory204087 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory204087"></th><th class="tdhistory204087">seriesID</th><th class="tdhistory204087">ROW_I</th><th class="tdhistory204087">IMAGE</th></tr></thead><tbody class="tdhistory204087 resultset-body"><tr><th class="tdhistory204087" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory204087"></td><td class="tdhistory204087">0</td><td class="tdhistory204087">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img id="fig2" src="images/fig2.png" alt="Auto Correlation" width="400" />
# <p style = 'font-size:16px;font-family:Arial'>To determine the value of the Moving Average or Q, we examine the lag (represented by ROW_I) where the Auto-Correlation Function (ACF) plot exhibits a value that falls just outside the significant limit. By analyzing the ACF plot, we can identify the lag at which the autocorrelation value deviates from the confidence band.
# <br>
# <br>
# Upon inspecting the graph, we observe that the Auto-Correlation value at ROW_I = 4 lies outside the confidence band and is also in close proximity to it. Based on this observation, we can reasonably conclude that the value of the Moving Average or <b>Q = 4</b>.</p>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>6. Check for partial autocorrelation of the time series</b>
# <p style = 'font-size:16px;font-family:Arial'>The TD_PACF function provides insight as to whether the modelled function is stationary or not. The partial autocorrelations measure the degree of correlation between time series sample points.
# <br>
# <br>
# In this analysis, we examine the partial autocorrelation with a maximum lag of 12 time steps. By considering a range of lags, we can assess the correlations between the current value and past values at different time intervals.</p>

# %%
EXECUTE FUNCTION
COLUMNS(OUT_Passengers AS Partial_Auto_Correlation)
INTO VOLATILE ART(PACFDemo)
TD_PACF (
    SERIES_SPEC(
        TABLE_NAME(diff2_air),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(seriesID),
        PAYLOAD(
            FIELDS("Passengers"),
            CONTENT(REAL)
        )
    ) ,
    FUNC_PARAMS(
        MAXLAGS(12),
        UNBIASED(0),    -- Use 0 for Jenkins-Watts formula, or 1 for BoxJenkins formula
        ALGORITHM(LEVINSON_DURBIN),
        ALPHA(0.05)
    )
);
# Out:
# Success: 13 rows affected

# %%
SELECT TOP 5 * FROM PACFDemo ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory711914"><style>
#       table.tdhistory711914 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory711914 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory711914:last-child { text-align: left !important; }
#       tbody.tdhistory711914 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory711914 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory711914 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory711914"></th><th class="tdhistory711914">seriesID</th><th class="tdhistory711914">ROW_I</th><th class="tdhistory711914">Partial_Auto_Correlation</th><th class="tdhistory711914">CONF_OFF_Passengers</th><th class="tdhistory711914">CONF_LOW_Passengers</th><th class="tdhistory711914">CONF_HI_Passengers</th></tr></thead><tbody class="tdhistory711914 resultset-body"><tr><th class="tdhistory711914" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory711914">FlyHigh</td><td class="tdhistory711914">0</td><td class="tdhistory711914">1</td><td class="tdhistory711914">0.1789194143717157</td><td class="tdhistory711914">1</td><td class="tdhistory711914">1</td></tr><tr><th class="tdhistory711914" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory711914">FlyHigh</td><td class="tdhistory711914">1</td><td class="tdhistory711914">0.7173571430652831</td><td class="tdhistory711914">0.1789194143717157</td><td class="tdhistory711914">0.5384377286935673</td><td class="tdhistory711914">0.8962765574369989</td></tr><tr><th class="tdhistory711914" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory711914">FlyHigh</td><td class="tdhistory711914">2</td><td class="tdhistory711914">0.2234037615684814</td><td class="tdhistory711914">0.1789194143717157</td><td class="tdhistory711914">0.044484347196765694</td><td class="tdhistory711914">0.4023231759401971</td></tr><tr><th class="tdhistory711914" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory711914">FlyHigh</td><td class="tdhistory711914">3</td><td class="tdhistory711914">-0.12754590601864632</td><td class="tdhistory711914">0.1789194143717157</td><td class="tdhistory711914">-0.306465320390362</td><td class="tdhistory711914">0.05137350835306939</td></tr><tr><th class="tdhistory711914" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory711914">FlyHigh</td><td class="tdhistory711914">4</td><td class="tdhistory711914">0.06801491589945349</td><td class="tdhistory711914">0.1789194143717157</td><td class="tdhistory711914">-0.11090449847226222</td><td class="tdhistory711914">0.2469343302711692</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Partial Auto Correlation Plot.</p>
# <i>* Please <b> right click on the cell under the IMAGE column </b> from the output and choose view image to see the plot generated. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(PACFDemo),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(seriesID),
        PAYLOAD (FIELDS(Partial_Auto_Correlation, CONF_OFF_Passengers),CONTENT(MULTIVAR_REAL))
    ),
    FUNC_PARAMS
    (
        PLOTS[(
            TYPE('corr')
           ,LEGEND('best') 
        )],
        IMAGE('png')
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory784784"><style>
#       table.tdhistory784784 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory784784 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory784784:last-child { text-align: left !important; }
#       tbody.tdhistory784784 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory784784 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory784784 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory784784"></th><th class="tdhistory784784">seriesID</th><th class="tdhistory784784">ROW_I</th><th class="tdhistory784784">IMAGE</th></tr></thead><tbody class="tdhistory784784 resultset-body"><tr><th class="tdhistory784784" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory784784"></td><td class="tdhistory784784">0</td><td class="tdhistory784784">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img id="fig3" src="images/fig3.png" alt="Partial Auto Correlation" width="400" />
# <p style = 'font-size:16px;font-family:Arial'>To determine the value of Auto-Regressive lags or P, we examine the lag (represented by Row_I) where the Partial Autocorrelation Function (PACF) plot displays a value that falls just outside the significant limit. By analyzing the PACF plot, we can identify the lag at which the partial autocorrelation value deviates from the confidence band.
# <br>
# <br>
# Upon observing the graph, we find that the Partial Autocorrelation value at Row_I = 2 falls outside the significant limit. Based on this observation, we can conclude that the value of Auto-Regressive lags or <b>P = 2</b>.</p>

# %% [markdown]
# <hr>
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>7. Using ARIMA (AutoRegressive Integrated Moving Average) model to forecast number of passengers</b>
# <p style = 'font-size:16px;font-family:Arial'>
# ARIMA functions on VANTAGE run in the following order:
# <br>
# 1. Run <b>TD_ARIMAESTIMATE</b> function to get the coefficients for the ARIMA model.
# <br>
# 2. <i>[Optional]</i> Run <b>TD_ARIMAVALIDATE</b> function to validate the the "goodness of fit" of the ARIMA model, when
# FIT_PERCENTAGE is not 100 in TD_ARIMAESTIMATE.
# <br>
# 3. Run the <b>TD_ARIMAFORECAST</b> function with input from step 1 or step 2 to forecast the future periods
# beyond the last observed period.
# </p>

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.1 Estimation step using TD_ARIMAESTIMATE</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The TD_ARIMAESTIMATE function estimates the coefficients corresponding to an ARIMA model and fits a series with an existing ARIMA model. The function can also provide the "goodness of fit" and the residuals of the fitting operation. The function generates a model layer used as input for the TD_ARIMAVALIDATE and TD_ARIMAFORECAST functions. This function is for univariate series.</p>
#
# <br>
#
# <p style = 'font-size:16px;font-family:Arial'>Here, the previously estimated parameters, namely P (Auto-Regressive lags), d (differencing order), and Q (Moving Average lags), are required to be passed into the MODEL_ORDER function. For example, the specific values used here are MODEL_ORDER(2, 2, 4).
# <br>
# <br>
# The output of the analysis is stored in an ART (Analytical Result Table), which contains relevant information and results of the ARIMA modeling process.
# <br>
# <br>
# Furthermore, the fit percentage is determined to be 80. This fit percentage indicates that the ARIMA model is trained using 80% of the available data. The remaining 20% of the data will be used for validating the model's performance.</p>

# %%
EXECUTE FUNCTION INTO VOLATILE ART(ART_EST)
TD_ARIMAESTIMATE(
    SERIES_SPEC(
        TABLE_NAME(DEMO_AirPassengers.airpassengers),
        ROW_AXIS(TIMECODE("Date")),
        SERIES_ID(seriesID),
        PAYLOAD(
            FIELDS("Passengers"),
            CONTENT(REAL))),
     FUNC_PARAMS(
        NONSEASONAL(MODEL_ORDER(2, 2, 4)),
        CONSTANT(1), COEFF_STATS(1), FIT_METRICS(1),
        RESIDUALS(1), ALGORITHM(CSS_MLE),  FIT_PERCENTAGE(80)
    )
);
# Out:
# Success: 156 rows affected

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.2 Extract residuals</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The TD_EXTRACT_RESULTS function serves the purpose of retrieving auxiliary result sets stored within an Analytical Result Table (ART). In this particular case, we focus on extracting the residuals from the ART obtained during the previous estimation step.
# <br>
# <br>
# Analytical Result Tables consist of multiple layers that store various types of data. By default, the initial layer contains model information. However, we are interested in accessing the ARTFITRESIDUALS layer, which contains crucial information about the actual values, calculated values, and residuals of the model.
# <br>
# <br>
# Additionally, the ARTFITMETADATA layer within the ART provides relevant performance metrics associated with the fitted model. These metrics help evaluate the accuracy and reliability of the model in capturing the underlying patterns and making predictions.
# </p>

# %%
CREATE TABLE AR_RESIDUALS AS (
    EXECUTE FUNCTION
    TD_EXTRACT_RESULTS(
        ART_SPEC(
            TABLE_NAME(ART_EST),
            LAYER(ARTFITRESIDUALS)
        )
    )
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
SELECT TOP 5 * FROM AR_RESIDUALS ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory281422"><style>
#       table.tdhistory281422 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory281422 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory281422:last-child { text-align: left !important; }
#       tbody.tdhistory281422 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory281422 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory281422 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory281422"></th><th class="tdhistory281422">seriesID</th><th class="tdhistory281422">ROW_I</th><th class="tdhistory281422">ACTUAL_VALUE</th><th class="tdhistory281422">CALC_VALUE</th><th class="tdhistory281422">RESIDUAL</th></tr></thead><tbody class="tdhistory281422 resultset-body"><tr><th class="tdhistory281422" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory281422">FlyHigh</td><td class="tdhistory281422">0</td><td class="tdhistory281422">112</td><td class="tdhistory281422">111.94991208756709</td><td class="tdhistory281422">0.05008791243292115</td></tr><tr><th class="tdhistory281422" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory281422">FlyHigh</td><td class="tdhistory281422">1</td><td class="tdhistory281422">118</td><td class="tdhistory281422">118.13684672121538</td><td class="tdhistory281422">-0.13684672121537142</td></tr><tr><th class="tdhistory281422" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory281422">FlyHigh</td><td class="tdhistory281422">2</td><td class="tdhistory281422">132</td><td class="tdhistory281422">126.41136630950375</td><td class="tdhistory281422">5.5886336904962555</td></tr><tr><th class="tdhistory281422" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory281422">FlyHigh</td><td class="tdhistory281422">3</td><td class="tdhistory281422">129</td><td class="tdhistory281422">139.71480976481052</td><td class="tdhistory281422">-10.714809764810521</td></tr><tr><th class="tdhistory281422" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory281422">FlyHigh</td><td class="tdhistory281422">4</td><td class="tdhistory281422">121</td><td class="tdhistory281422">127.90674222805998</td><td class="tdhistory281422">-6.906742228059977</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The output displayed above provides insights into the ARIMA model's actual values, calculated values, and residuals. In this context, the actual value represents the observed number of passengers flying, reflecting the real-world data.
# <br>
# <br>
# The calculated value corresponds to the values generated by the ARIMA model during the estimation phase. These calculated values are based on the model's learned patterns, relationships, and parameters derived from the training data.
# <br>
# <br>
# The residual value represents the discrepancy or difference between the actual value and the calculated value. It quantifies the model's prediction error or the extent to which the model's estimates deviate from the actual observations.
# <br>
# <br>
# In the following cell, we extract additional metrics from the estimate phase i.e. TD_ARIMAESTIMATE.
# </p>

# %%
SELECT * FROM (
    EXECUTE FUNCTION
    TD_EXTRACT_RESULTS(
        ART_SPEC(
            TABLE_NAME(ART_EST),
            LAYER(ARTFITMETADATA)
        )
    )
) AS T;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory414491"><style>
#       table.tdhistory414491 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory414491 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory414491:last-child { text-align: left !important; }
#       tbody.tdhistory414491 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory414491 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory414491 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory414491"></th><th class="tdhistory414491">seriesID</th><th class="tdhistory414491">ROW_I</th><th class="tdhistory414491">NUM_SAMPLES</th><th class="tdhistory414491">VAR_COUNT</th><th class="tdhistory414491">R_SQUARE</th><th class="tdhistory414491">R_ADJ_SQUARE</th><th class="tdhistory414491">STD_ERROR</th><th class="tdhistory414491">STD_ERROR_DF</th><th class="tdhistory414491">ME</th><th class="tdhistory414491">MAE</th><th class="tdhistory414491">MSE</th><th class="tdhistory414491">MPE</th><th class="tdhistory414491">MAPE</th><th class="tdhistory414491">FSTAT_CALC</th><th class="tdhistory414491">P_VALUE</th><th class="tdhistory414491">NUM_DF</th><th class="tdhistory414491">DENOM_DF</th><th class="tdhistory414491">SIGNIFICANCE_LEVEL</th><th class="tdhistory414491">F_CRITICAL</th><th class="tdhistory414491">F_CRITICAL_P</th><th class="tdhistory414491">NULL_HYPOTH</th></tr></thead><tbody class="tdhistory414491 resultset-body"><tr><th class="tdhistory414491" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory414491">FlyHigh</td><td class="tdhistory414491">0</td><td class="tdhistory414491">115</td><td class="tdhistory414491">6</td><td class="tdhistory414491">0.9467760004729487</td><td class="tdhistory414491">0.9443345326047354</td><td class="tdhistory414491">472.2627967316471</td><td class="tdhistory414491">113</td><td class="tdhistory414491">0.7428069380458072</td><td class="tdhistory414491">16.996016343213995</td><td class="tdhistory414491">464.04953070153147</td><td class="tdhistory414491">-0.015869715792044256</td><td class="tdhistory414491">7.01197298640136</td><td class="tdhistory414491">387.7896624401572</td><td class="tdhistory414491">1.0804628377646286e-67</td><td class="tdhistory414491">5</td><td class="tdhistory414491">109</td><td class="tdhistory414491">0.05</td><td class="tdhistory414491">2.2976423245433315</td><td class="tdhistory414491">0.05</td><td class="tdhistory414491">REJECT</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The displayed output provides performance metrics that offer insights into the effectiveness of the trained ARIMA model. One such metric is the R-Squared value, which measures how well the model fits the data. In this instance, the R-Squared value is noted as 0.94, indicating a strong fit between the model and the data.
# <br>
# <br>
# The R-Squared value ranges from 0 to 1, with higher values indicating a better fit. A value of 0 suggests that the model does not explain any of the variability in the data, while a value of 1 indicates that the model perfectly captures the observed data's variability.
# <br>
# <br>
# In the context of the ARIMA model, an R-Squared value of 0.94 suggests that the model accounts for a significant proportion of the variability present in the data. This implies that the model's predictions closely align with the actual data points and that the model's learned patterns and parameters effectively capture the underlying dynamics of the time series.</p>

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.3 Create table PLOT_ESTIMATE for plotting</b></p>
# </p>
# <p style = 'font-size:16px;font-family:Arial'>Here, we'll create a table which will be used to plot the actual and estimated time series.</p>

# %%
CREATE TABLE PLOT_ESTIMATE (DatasetID VARCHAR(10), ROW_I BIGINT, FIT_MAGNITUDE FLOAT);
# Out:
# Success: 0 rows affected

# %%
INSERT INTO PLOT_ESTIMATE SELECT 'FlyHigh', ROW_I, ACTUAL_VALUE FROM AR_RESIDUALS WHERE ROW_I>1; 
INSERT INTO PLOT_ESTIMATE SELECT 'ESTIMATED', ROW_I, CALC_VALUE FROM AR_RESIDUALS WHERE ROW_I>1;
# Out:
# Success: 0 rows affected
# Success: 226 rows affected

# %%
SELECT TOP 5 * FROM PLOT_ESTIMATE ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory327404"><style>
#       table.tdhistory327404 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory327404 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory327404:last-child { text-align: left !important; }
#       tbody.tdhistory327404 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory327404 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory327404 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory327404"></th><th class="tdhistory327404">DatasetID</th><th class="tdhistory327404">ROW_I</th><th class="tdhistory327404">FIT_MAGNITUDE</th></tr></thead><tbody class="tdhistory327404 resultset-body"><tr><th class="tdhistory327404" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory327404">ESTIMATED</td><td class="tdhistory327404">2</td><td class="tdhistory327404">126.41136630950375</td></tr><tr><th class="tdhistory327404" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory327404">FlyHigh</td><td class="tdhistory327404">2</td><td class="tdhistory327404">132</td></tr><tr><th class="tdhistory327404" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory327404">ESTIMATED</td><td class="tdhistory327404">3</td><td class="tdhistory327404">139.71480976481052</td></tr><tr><th class="tdhistory327404" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory327404">FlyHigh</td><td class="tdhistory327404">3</td><td class="tdhistory327404">129</td></tr><tr><th class="tdhistory327404" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory327404">FlyHigh</td><td class="tdhistory327404">4</td><td class="tdhistory327404">121</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Actual and Estimated values by the fitted ARIMA model.</p>
# <i>* Please <b> right click on the cell under the IMAGE column </b> from the output and choose view image to see the plot generated. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC(
        TABLE_NAME(PLOT_ESTIMATE),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(DataSetID),
        ID_SEQUENCE('[{"DatasetID":"FlyHigh"},{"DatasetID":"ESTIMATED"}]'),
        PAYLOAD(
            FIELDS(FIT_MAGNITUDE),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS
    (
        WIDTH(1920),
        HEIGHT(1080),
        TITLE('ARIMA ESTIMATE'),
        PLOTS[
            (
                TITLE ('ORIGINAL and ESTIMATED SERIES'),
                GRID(FORMAT('-')),
                TYPE('line'),
                SERIES[
                       (
                        ID(1),
                        FORMAT('r--')
                       ),
                       (
                        ID(2),
                        FORMAT('b-')
                       )
                     ],
                MARKER('o'),
                LEGEND('best'),
                XLABEL('X SeqNo'),
                YLABEL('Y Magnitude')
            )
        ]
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory658597"><style>
#       table.tdhistory658597 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory658597 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory658597:last-child { text-align: left !important; }
#       tbody.tdhistory658597 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory658597 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory658597 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory658597"></th><th class="tdhistory658597">DatasetID</th><th class="tdhistory658597">ROW_I</th><th class="tdhistory658597">IMAGE</th></tr></thead><tbody class="tdhistory658597 resultset-body"><tr><th class="tdhistory658597" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory658597"></td><td class="tdhistory658597">0</td><td class="tdhistory658597">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>If you followed the instructions above, you should have seen a graph looks like follows:</p>
# <img id="fig4" src="images/fig4.png" alt="ARIMA Estimate" width="400" />
# <p style = 'font-size:16px;font-family:Arial'>The red line indicates the actual number of passengers who travelled, and the blue line indicates the estimated number of passengers who travelled. This graph shows how well the ARIMA model has learned on the training dataset.</p>

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.4 Validation step using TD_ARIMAVALIDATE</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The TD_ARIMAVALIDATE function provides data scientists with a metrics collection for model selection and the produced residuals, such that several model validation tests can be performed. The TD_ARIMAVALIDATE function performs in-sample forecasting for seasonal and non-seasonal auto-regressive (AR), moving-average (MA), and ARIMA models. It also supports the extended Box Jenkins seasonal ARIMA model formula.
# </p>
# <p style = 'font-size:16px;font-family:Arial'>We'll use the output of the previous estimation step to validate the model. The train-validate split here for the dataset is 80:20. Hence 20% of the data will be used to validate the estimated model.</p>

# %%
EXECUTE FUNCTION 
INTO VOLATILE ART(AR_VALIDATE)
TD_ARIMAVALIDATE(
    ART_SPEC(TABLE_NAME(ART_EST)),
    FUNC_PARAMS(
        FIT_METRICS(1),
        RESIDUALS(1)
    )
);
# Out:
# Success: 36 rows affected

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.5 Extract residuals</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The TD_EXTRACT_RESULTS function retrieves auxiliary result sets stored in an ART. Here we extract the residuals from the ART table output of the previous validation step.
# </p>

# %%
CREATE TABLE AR_VALIDATE_RESIDUALS AS (
    EXECUTE FUNCTION 
    TD_EXTRACT_RESULTS(
        ART_SPEC(
            TABLE_NAME(AR_VALIDATE),
            LAYER(ARTFITRESIDUALS)
        )
    )
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
SELECT TOP 5 * FROM AR_VALIDATE_RESIDUALS ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory808461"><style>
#       table.tdhistory808461 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory808461 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory808461:last-child { text-align: left !important; }
#       tbody.tdhistory808461 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory808461 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory808461 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory808461"></th><th class="tdhistory808461">seriesID</th><th class="tdhistory808461">ROW_I</th><th class="tdhistory808461">ACTUAL_VALUE</th><th class="tdhistory808461">CALC_VALUE</th><th class="tdhistory808461">RESIDUAL</th></tr></thead><tbody class="tdhistory808461 resultset-body"><tr><th class="tdhistory808461" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory808461">FlyHigh</td><td class="tdhistory808461">113</td><td class="tdhistory808461">505</td><td class="tdhistory808461">504.75296695667356</td><td class="tdhistory808461">0.24703304332644183</td></tr><tr><th class="tdhistory808461" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory808461">FlyHigh</td><td class="tdhistory808461">114</td><td class="tdhistory808461">404</td><td class="tdhistory808461">404.85583223153515</td><td class="tdhistory808461">-0.8558322315351644</td></tr><tr><th class="tdhistory808461" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory808461">FlyHigh</td><td class="tdhistory808461">115</td><td class="tdhistory808461">359</td><td class="tdhistory808461">297.32400505213565</td><td class="tdhistory808461">61.67599494786435</td></tr><tr><th class="tdhistory808461" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory808461">FlyHigh</td><td class="tdhistory808461">116</td><td class="tdhistory808461">310</td><td class="tdhistory808461">301.968008664176</td><td class="tdhistory808461">8.031991335823964</td></tr><tr><th class="tdhistory808461" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory808461">FlyHigh</td><td class="tdhistory808461">117</td><td class="tdhistory808461">337</td><td class="tdhistory808461">272.2919863505058</td><td class="tdhistory808461">64.70801364949419</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The provided output displays the actual value, calculated value, and residual of the ARIMA model during the validation phase. In this context, the actual value represents the number of passengers from the unseen or validation data. These values serve as the ground truth against which the model's performance will be evaluated.
# <br>
# <br>
# The calculated value represents the predicted value generated by the ARIMA model on the unseen validation data. These predicted values are obtained by applying the trained model's learned patterns, relationships, and parameters to the new data points. The calculated values provide an estimation of what the model predicts the number of passengers to be based on the unseen data.
# <br>
# <br>
# The residual represents the difference between the actual value and the calculated value. It quantifies the prediction error of the ARIMA model for each data point in the validation set.
# <br>
# <br>
# In the following step, we again pull the metadata from the ART, which is the output of the validation phase.
# </p>

# %%
SELECT * FROM (
    EXECUTE FUNCTION
    TD_EXTRACT_RESULTS(
        ART_SPEC(
            TABLE_NAME(AR_VALIDATE),
            LAYER(ARTFITMETADATA)
        )
    )
) AS T;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory756737"><style>
#       table.tdhistory756737 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory756737 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory756737:last-child { text-align: left !important; }
#       tbody.tdhistory756737 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory756737 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory756737 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory756737"></th><th class="tdhistory756737">seriesID</th><th class="tdhistory756737">ROW_I</th><th class="tdhistory756737">NUM_SAMPLES</th><th class="tdhistory756737">VAR_COUNT</th><th class="tdhistory756737">R_SQUARE</th><th class="tdhistory756737">R_ADJ_SQUARE</th><th class="tdhistory756737">STD_ERROR</th><th class="tdhistory756737">STD_ERROR_DF</th><th class="tdhistory756737">ME</th><th class="tdhistory756737">MAE</th><th class="tdhistory756737">MSE</th><th class="tdhistory756737">MPE</th><th class="tdhistory756737">MAPE</th><th class="tdhistory756737">F_STAT</th><th class="tdhistory756737">F_STAT_P</th><th class="tdhistory756737">NUM_DF</th><th class="tdhistory756737">DENOM_DF</th><th class="tdhistory756737">SIGNIFICANCE_LEVEL</th><th class="tdhistory756737">F_CRITICAL</th><th class="tdhistory756737">F_CRITICAL_P</th><th class="tdhistory756737">NULL_HYPOTH</th></tr></thead><tbody class="tdhistory756737 resultset-body"><tr><th class="tdhistory756737" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory756737">FlyHigh</td><td class="tdhistory756737">0</td><td class="tdhistory756737">29</td><td class="tdhistory756737">6</td><td class="tdhistory756737">0.820843347348391</td><td class="tdhistory756737">0.7818962489458674</td><td class="tdhistory756737">2088.067885112639</td><td class="tdhistory756737">27</td><td class="tdhistory756737">11.664301944019215</td><td class="tdhistory756737">35.66023842148748</td><td class="tdhistory756737">1944.0632033807326</td><td class="tdhistory756737">3.0180049294068256</td><td class="tdhistory756737">8.012434475812402</td><td class="tdhistory756737">21.075853684011584</td><td class="tdhistory756737">6.750046728255135e-08</td><td class="tdhistory756737">5</td><td class="tdhistory756737">23</td><td class="tdhistory756737">0.05</td><td class="tdhistory756737">2.639999426052996</td><td class="tdhistory756737">0.05</td><td class="tdhistory756737">REJECT翾</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The displayed output presents performance metrics that allow us to assess the effectiveness of our model on the unseen dataset, specifically the validation dataset. These metrics offer valuable insights into how well our model performs in making predictions on previously unseen data.
# <br>
# <br>
# One such metric is the R-Squared value, which is noted as 0.82 in the provided output. The R-Squared value is a widely used measure of how well the model fits the validation data. A higher R-Squared value indicates a stronger fit between the model's predictions and the actual values observed in the validation dataset.
# <br>
# <br>
# The R-Squared value ranges from 0 to 1, where 0 indicates that the model does not explain any of the variability in the validation data, and 1 indicates a perfect fit where the model captures all the variability. In our case, an R-Squared value of 0.82 suggests that our model performs well, as it explains a significant portion of the variability present in the validation dataset.</p>

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.6 Create table PLOT_VALIDATE for plotting</b></p>
# </p>
# <p style = 'font-size:16px;font-family:Arial'>Here, we'll create a table which will be used to plot the actual and validated time series.</p>

# %%
CREATE TABLE PLOT_VALIDATE (DatasetID VARCHAR(10), ROW_I BIGINT, FIT_MAGNITUDE FLOAT);
# Out:
# Success: 0 rows affected

# %%
INSERT INTO PLOT_VALIDATE SELECT 'FlyHigh', ROW_I, ACTUAL_VALUE FROM AR_VALIDATE_RESIDUALS WHERE ROW_I>0; 
INSERT INTO PLOT_VALIDATE SELECT 'PREDICTED', ROW_I, CALC_VALUE FROM AR_VALIDATE_RESIDUALS WHERE ROW_I>0;
# Out:
# Success: 0 rows affected
# Success: 58 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Actual and Predicted values by ARIMA model.</p>
# <i>* Please <b> right click on the cell under the IMAGE column </b> from the output and choose view image to see the plot generated. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC(
        TABLE_NAME(PLOT_VALIDATE),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(DataSetID),
        ID_SEQUENCE('[{"DatasetID":"FlyHigh"},{"DatasetID":"PREDICTED"}]'),
        PAYLOAD(
            FIELDS(FIT_MAGNITUDE),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS
    (
        WIDTH(1920),
        HEIGHT(1080),
        TITLE('ARIMA VALIDATE'),
        PLOTS[
            (
                TITLE ('ORIGINAL and PREDICTED SERIES'),
                GRID(FORMAT('-')),
                TYPE('line'),
                SERIES[
                       (
                        ID(1),
                        FORMAT('r--')
                       ),
                       (
                        ID(2),
                        FORMAT('b-')
                       )
                     ],
                MARKER('o'),
                LEGEND('best'),
                XLABEL('X SeqNo'),
                YLABEL('Y Magnitude')
            )
        ]
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory667251"><style>
#       table.tdhistory667251 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory667251 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory667251:last-child { text-align: left !important; }
#       tbody.tdhistory667251 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory667251 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory667251 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory667251"></th><th class="tdhistory667251">DatasetID</th><th class="tdhistory667251">ROW_I</th><th class="tdhistory667251">IMAGE</th></tr></thead><tbody class="tdhistory667251 resultset-body"><tr><th class="tdhistory667251" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory667251"></td><td class="tdhistory667251">0</td><td class="tdhistory667251">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img id="fig5" src="images/fig5.png" alt="ARIMA Validate" width="400" />
# <p style = 'font-size:16px;font-family:Arial'>The red line indicates the actual number of passengers who travelled, and the blue line indicates the predicted number of passengers who travelled. This graph shows how well the ARIMA model predicts on the validation data.</p>

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.7 Forecast step using TD_ARIMAFORECAST</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The TD_ARIMAFORECAST function is used to forecast a user-defined number of periods based on models fitted from the TD_ARIMAESTIMATE function.</p>
# <p style = 'font-size:16px;font-family:Arial'>Here in the next cell, we use the estimated and validated model to forecast the number of passengers for the subsequent six periods, i.e. next six months.</p>

# %%
EXECUTE FUNCTION INTO VOLATILE ART(ARMA_FORECAST)
TD_ARIMAFORECAST(
           ART_SPEC(TABLE_NAME(AR_VALIDATE)),
           FUNC_PARAMS(FORECAST_PERIODS(6)));
# Out:
# Success: 6 rows affected

# %%
SELECT * FROM ARMA_FORECAST;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory755711"><style>
#       table.tdhistory755711 { display: block !important; min-height: 210px !important; overflow: auto !important; height: 210px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory755711 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory755711:last-child { text-align: left !important; }
#       tbody.tdhistory755711 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory755711 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory755711 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory755711"></th><th class="tdhistory755711">seriesID</th><th class="tdhistory755711">ROW_I</th><th class="tdhistory755711">FORECAST_VALUE</th><th class="tdhistory755711">LO_80</th><th class="tdhistory755711">HI_80</th><th class="tdhistory755711">LO_95</th><th class="tdhistory755711">HI_95</th></tr></thead><tbody class="tdhistory755711 resultset-body"><tr><th class="tdhistory755711" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory755711">FlyHigh</td><td class="tdhistory755711">0</td><td class="tdhistory755711">466.6728590161805</td><td class="tdhistory755711">437.54015778509387</td><td class="tdhistory755711">495.8055602472671</td><td class="tdhistory755711">422.1182520742184</td><td class="tdhistory755711">511.2274659581426</td></tr><tr><th class="tdhistory755711" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory755711">FlyHigh</td><td class="tdhistory755711">1</td><td class="tdhistory755711">430.36321999998916</td><td class="tdhistory755711">376.27127884976034</td><td class="tdhistory755711">484.455161150218</td><td class="tdhistory755711">347.6367622795322</td><td class="tdhistory755711">513.0896777204462</td></tr><tr><th class="tdhistory755711" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory755711">FlyHigh</td><td class="tdhistory755711">2</td><td class="tdhistory755711">455.6417429409845</td><td class="tdhistory755711">380.5849750995153</td><td class="tdhistory755711">530.6985107824537</td><td class="tdhistory755711">340.85236028180464</td><td class="tdhistory755711">570.4311256001644</td></tr><tr><th class="tdhistory755711" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory755711">FlyHigh</td><td class="tdhistory755711">3</td><td class="tdhistory755711">451.48033461798286</td><td class="tdhistory755711">356.7219930932277</td><td class="tdhistory755711">546.238676142738</td><td class="tdhistory755711">306.56000513605375</td><td class="tdhistory755711">596.400664099912</td></tr><tr><th class="tdhistory755711" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory755711">FlyHigh</td><td class="tdhistory755711">4</td><td class="tdhistory755711">423.51121512012514</td><td class="tdhistory755711">315.53809763150025</td><td class="tdhistory755711">531.48433260875</td><td class="tdhistory755711">258.3806365361307</td><td class="tdhistory755711">588.6417937041197</td></tr><tr><th class="tdhistory755711" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory755711">FlyHigh</td><td class="tdhistory755711">5</td><td class="tdhistory755711">439.38153664172967</td><td class="tdhistory755711">317.5708617102512</td><td class="tdhistory755711">561.192211573208</td><td class="tdhistory755711">253.08824719159406</td><td class="tdhistory755711">625.6748260918653</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The above output shows us the forecasted value for the next six months. Observe that we also have forecasted values with 80% and 95% confidence.</p>

# %% [markdown]
# <hr>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>7.8 Create table PLOT_FORECAST for plotting</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Here, we'll create a table which will be used to plot the forecasted number of passengers in the next 6 months.</p>

# %%
CREATE TABLE PLOT_FORECAST (DatasetID VARCHAR(16), ROW_I BIGINT, FORECAST_MAGNITUDE FLOAT);
# Out:
# Success: 0 rows affected

# %%
INSERT INTO PLOT_FORECAST   SELECT 'FORECASTED', ROW_I, FORECAST_VALUE FROM ARMA_FORECAST; 
INSERT INTO PLOT_FORECAST   SELECT 'UPPER_BOUND', ROW_I, HI_80 FROM ARMA_FORECAST ; 
INSERT INTO PLOT_FORECAST   SELECT 'LOWER_BOUND', ROW_I, LO_80 FROM ARMA_FORECAST ;
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# Success: 18 rows affected

# %%
SELECT * FROM PLOT_FORECAST ORDER BY ROW_I;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory280859"><style>
#       table.tdhistory280859 { display: block !important; min-height: 462px !important; overflow: auto !important; height: 462px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory280859 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory280859:last-child { text-align: left !important; }
#       tbody.tdhistory280859 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory280859 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory280859 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory280859"></th><th class="tdhistory280859">DatasetID</th><th class="tdhistory280859">ROW_I</th><th class="tdhistory280859">FORECAST_MAGNITUDE</th></tr></thead><tbody class="tdhistory280859 resultset-body"><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory280859">UPPER_BOUND</td><td class="tdhistory280859">0</td><td class="tdhistory280859">495.8055602472671</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory280859">LOWER_BOUND</td><td class="tdhistory280859">0</td><td class="tdhistory280859">437.54015778509387</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory280859">FORECASTED</td><td class="tdhistory280859">0</td><td class="tdhistory280859">466.6728590161805</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory280859">UPPER_BOUND</td><td class="tdhistory280859">1</td><td class="tdhistory280859">484.455161150218</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory280859">LOWER_BOUND</td><td class="tdhistory280859">1</td><td class="tdhistory280859">376.27127884976034</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory280859">FORECASTED</td><td class="tdhistory280859">1</td><td class="tdhistory280859">430.36321999998916</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory280859">UPPER_BOUND</td><td class="tdhistory280859">2</td><td class="tdhistory280859">530.6985107824537</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory280859">LOWER_BOUND</td><td class="tdhistory280859">2</td><td class="tdhistory280859">380.5849750995153</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory280859">FORECASTED</td><td class="tdhistory280859">2</td><td class="tdhistory280859">455.6417429409845</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory280859">UPPER_BOUND</td><td class="tdhistory280859">3</td><td class="tdhistory280859">546.238676142738</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory280859">LOWER_BOUND</td><td class="tdhistory280859">3</td><td class="tdhistory280859">356.7219930932277</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory280859">FORECASTED</td><td class="tdhistory280859">3</td><td class="tdhistory280859">451.48033461798286</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory280859">UPPER_BOUND</td><td class="tdhistory280859">4</td><td class="tdhistory280859">531.48433260875</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory280859">LOWER_BOUND</td><td class="tdhistory280859">4</td><td class="tdhistory280859">315.53809763150025</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory280859">FORECASTED</td><td class="tdhistory280859">4</td><td class="tdhistory280859">423.51121512012514</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory280859">UPPER_BOUND</td><td class="tdhistory280859">5</td><td class="tdhistory280859">561.192211573208</td></tr><tr><th class="tdhistory280859" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory280859">LOWER_BOUND</td><td class="tdhistory280859">5</td><td class="tdhistory280859">317.5708617102512</td></ ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The <b>TD_PLOT</b> function will return an image in the cell of the results showing the Forecasted values by ARIMA model.</p>
# <i>* Please <b> right click on the cell under the IMAGE column </b> from the output and choose view image to see the plot generated. </i>

# %%
EXECUTE FUNCTION
TD_Plot
(
    SERIES_SPEC(
        TABLE_NAME(PLOT_FORECAST),
        ROW_AXIS(SEQUENCE(ROW_I)),
        SERIES_ID(DataSetID),
        ID_SEQUENCE('[{"DatasetID":"FORECASTED"},{"DatasetID":"UPPER_BOUND"},{"DatasetID":"LOWER_BOUND"}]'),
        PAYLOAD(
            FIELDS(FORECAST_MAGNITUDE),
            CONTENT(REAL)
        )
    ),
    FUNC_PARAMS
    (
        WIDTH(1920),
        HEIGHT(1080),
        TITLE('ARIMA FORECAST'),
        PLOTS[
            (
                TITLE ('Forecast'),
                GRID(FORMAT('-')),
                TYPE('line'),
                SERIES[
                       (
                        ID(1),
                        FORMAT('r--')
                       ),
                       (
                        ID(2),
                        FORMAT('b-')
                       ),
                        (
                        ID(3),
                        FORMAT('b-')
                       )
                     ],
                MARKER('o'),
                LEGEND('best'),
                XLABEL('X SeqNo'),
                YLABEL('Y Magnitude')
            )
        ]
    )
);
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory697739"><style>
#       table.tdhistory697739 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory697739 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory697739:last-child { text-align: left !important; }
#       tbody.tdhistory697739 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory697739 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory697739 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory697739"></th><th class="tdhistory697739">DatasetID</th><th class="tdhistory697739">ROW_I</th><th class="tdhistory697739">IMAGE</th></tr></thead><tbody class="tdhistory697739 resultset-body"><tr><th class="tdhistory697739" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory697739"></td><td class="tdhistory697739">0</td><td class="tdhistory697739">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>If you followed the instructions above, you should have seen a graph that looks like follows:</p>
# <img id="fig6" src="images/fig6.png" alt="ARIMA Forecast" width="400" />
# <p style = 'font-size:16px;font-family:Arial'>The red line is the Forecasted number of passengers for the next six months, and the blue lines are the upper and lower confidence interval with an 80% confidence level.</p>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Conclusion:</b></p>
# <p style = 'font-size:16px;font-family:Arial'>
# After training and validating the ARIMA model on the air passengers dataset, we observe that the model's predictions closely align with the actual data. This indicates that the model has successfully learned the underlying patterns and relationships within the dataset.
# <br>
# <br>
# Based on the close alignment of the model's predictions with the actual data and the favorable goodness of fit metrics, we can confidently conclude that our ARIMA model is well-trained and capable of making accurate forecasts for the air passengers dataset.</p>

# %% [markdown]
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>8. Cleanup</b>
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'><b>Work Tables</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Cleanup work tables to prevent errors next time. This section drops all the tables created during the demonstration.</p>

# %%
DROP TABLE diff1_air;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE diff2_air;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE ACFDemo;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE PACFDemo;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE ART_EST;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE AR_RESIDUALS;
# Out:
# Success: 19 rows affected

# %%
DROP TABLE PLOT_ESTIMATE;
# Out:
# Success: 17 rows affected

# %%
DROP TABLE AR_VALIDATE;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE AR_VALIDATE_RESIDUALS;
# Out:
# Success: 19 rows affected

# %%
DROP TABLE PLOT_VALIDATE;
# Out:
# Success: 17 rows affected

# %%
DROP TABLE ARMA_FORECAST;
# Out:
# Success: 0 rows affected

# %%
DROP TABLE PLOT_FORECAST;
# Out:
# Success: 17 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'> <b>Databases and Tables </b></p>
# <p style = 'font-size:16px;font-family:Arial'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_AirPassengers');          -- Takes 5 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory99783"><style>
#       table.tdhistory99783 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99783 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99783:last-child { text-align: left !important; }
#       tbody.tdhistory99783 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory99783 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory99783 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory99783"></th><th class="tdhistory99783">Message</th></tr></thead><tbody class="tdhistory99783 resultset-body"><tr><th class="tdhistory99783" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory99783">Removed objects related to DEMO_AirPassengers. That ran for 0:00:00.90</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#E37C4D'><b>Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial'>
#     <li>UAF(Unbounded Array Framework) Documentation: <a href = 'https://docs.teradata.com/r/Enterprise_IntelliFlex_VMware/Teradata-VantageTM-Unbounded-Array-Framework-Time-Series-Reference-17.20/Unbounded-Array-Framework'>https://docs.teradata.com/r/Enterprise_IntelliFlex_VMware/Teradata-VantageTM-Unbounded-Array-Framework-Time-Series-Reference-17.20/Unbounded-Array-Framework</a></li>
# </ul>

# %% [markdown]
# <footer style="padding:10px;background:#f9f9f9;border-bottom:3px solid #394851">Copyright © Teradata Corporation - 2023. All Rights Reserved.</footer>
