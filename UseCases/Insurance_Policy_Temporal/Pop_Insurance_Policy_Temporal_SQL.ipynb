# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Insurance Analysis Using Temporal
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>
#
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Applications require to design and build databases dependent on time or data changes over time.  Building such applications is possible but becomes easier with Temporal
#
# </p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'> <b>WHY TEMPORAL? </b> </p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Things You No Longer Have To Do in the Time-Aware Teradata Database
# Data Maintenance : </p>
#
# <li style = 'font-size:16px;font-family:Arial'> Update effective dates in data.</li></<li style = 'font-size:16px;font-family:Arial'> <li style = 'font-size:16px;font-family:Arial'> Specify “transaction time” timestamp when data are entered or updated. </li>
# <li style = 'font-size:16px;font-family:Arial'> Insert new data rows for updates. </li>
# <li style = 'font-size:16px;font-family:Arial'> Manage temporal history storage space. </li>

# %% [markdown]
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Query and Application Development: </p>
#
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Write complex period based condition clauses. </li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Add effective date qualifications to “current queries.” </li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Train users and application developers in effective date columns and processing for “AS OF” query development.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Save old reports or database snapshots to facilitate looking back for analysis, compliance reporting, or audit trails.</li>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here we are considering the example of Insurance company storing data for various policies whose validity, conditions , premium amount and many other factors will change over Time period.</p>

# %% [markdown]
#
#
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Some scenarios that can be handled using temporal features are as below </p>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>    Consider the scenario where there is a hail storm striking on a particular date. The As of date feature can be used to check the validity of the policy and then the incident date can be used to check which claims fall in the validity period of the policies.</li>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>    Another scenario is that the customer has sold the vehicle and the closure of the policy happened a week late as the customer informed late about the sale , so based on the transaction time the validity of the policies will change. </li>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
SET query_band='DEMO=Insurance_Policy_Temporal_SQL.ipynb;' UPDATE FOR SESSION;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. Getting Data for This Demo:</b></p>
# <p style = 'font-size:16px;font-family:Arial'>We have provided data for this demo on cloud storage. In this demo since we are using Temporal table we will be creating databases and tables in local storage and use them in the notebook. Please execute the procedure in the next cell.</p>

# %%
call get_data('DEMO_Insurance_local');    -- Takes about 90 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory12161"><style>
#       table.tdhistory12161 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory12161 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory12161:last-child { text-align: left !important; }
#       tbody.tdhistory12161 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory12161 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory12161 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory12161"></th><th class="tdhistory12161">Message</th></tr></thead><tbody class="tdhistory12161 resultset-body"><tr><th class="tdhistory12161" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory12161">That ran for   0:00:08.61 with 17 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();  -- optional, takes about 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory272261"><style>
#       table.tdhistory272261 { display: block !important; min-height: 252px !important; overflow: auto !important; height: 252px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory272261 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory272261:last-child { text-align: left !important; }
#       tbody.tdhistory272261 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory272261 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory272261 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory272261"></th><th class="tdhistory272261">Space_Report</th></tr></thead><tbody class="tdhistory272261 resultset-body"><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory272261">You have:  #databases=4 #tables=7 #views=25  You have used 2.4 MB of 30,678.9 MB available - 0.0%  ... Space Usage OK</td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory272261"> </td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory272261">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory272261">   demo_user                            3      20  30,142.2 MB       1.5 MB </td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory272261">   DEMO_CancerPrediction                0       1       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory272261">   DEMO_CancerPrediction_db             1       0     534.9 MB       0.3 MB </td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory272261">   DEMO_Insurance                       0       4       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory272261" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory272261">   DEMO_Insurance_DB                    3       0       1.9 MB       0.6 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Comparison of Temporal and Non-Temporal:</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>To understand how Temporal can be helpful we will consider a simple example where we need to check policies which were valid on 31st December 2020 and had a premium amount less than 1000. for a normal table with start and end date columns the query will be as below:</p>

# %%
SELECT
    Policy_ID,
    Customer_ID,
    Policy_premium_Amt,
    policy_state,
    Policy_start_date,
    policy_end_date
FROM
    DEMO_Insurance.Policy_Details_Org
WHERE
    policy_start_date <= '2020-12-31'
    AND policy_end_date >= '2020-12-31'
    AND Policy_premium_Amt < 1000;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory640272"><style>
#       table.tdhistory640272 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory640272 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory640272:last-child { text-align: left !important; }
#       tbody.tdhistory640272 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory640272 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory640272 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory640272"></th><th class="tdhistory640272">Policy_ID</th><th class="tdhistory640272">Customer_ID</th><th class="tdhistory640272">Policy_premium_Amt</th><th class="tdhistory640272">Policy_State</th><th class="tdhistory640272">Policy_start_date</th><th class="tdhistory640272">Policy_end_date</th></tr></thead><tbody class="tdhistory640272 resultset-body"><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory640272">444422</td><td class="tdhistory640272">2660358</td><td class="tdhistory640272">882</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2017-09-28</td><td class="tdhistory640272">2022-09-28</td></tr><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory640272">444427</td><td class="tdhistory640272">6999975</td><td class="tdhistory640272">932</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2018-03-28</td><td class="tdhistory640272">2023-03-28</td></tr><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory640272">171147</td><td class="tdhistory640272">7478283</td><td class="tdhistory640272">814</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2016-08-29</td><td class="tdhistory640272">2021-08-29</td></tr><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory640272">171152</td><td class="tdhistory640272">5703051</td><td class="tdhistory640272">864</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2017-02-28</td><td class="tdhistory640272">2022-02-28</td></tr><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory640272">555374</td><td class="tdhistory640272">5353898</td><td class="tdhistory640272">976</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2019-01-05</td><td class="tdhistory640272">2024-01-05</td></tr><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory640272">555374</td><td class="tdhistory640272">5353898</td><td class="tdhistory640272">976</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2019-01-05</td><td class="tdhistory640272">9999-12-31</td></tr><tr><th class="tdhistory640272" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory640272">555374</td><td class="tdhistory640272">5353898</td><td class="tdhistory640272">976</td><td class="tdhistory640272">IL</td><td class="tdhistory640272">2019-01-05</td><td class="tdhistory640272">9999-12-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The same query with Temporal table would be as below:</p>

# %%
VALIDTIME AS OF DATE '2020-12-31'
SELECT
    Policy_ID,
    Customer_ID,
    Policy_premium_Amt,
    policy_state,
    Policy_Validity
FROM
    DEMO_Insurance.Policy_Details
WHERE
    Policy_premium_Amt < 1000;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory202483"><style>
#       table.tdhistory202483 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory202483 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory202483:last-child { text-align: left !important; }
#       tbody.tdhistory202483 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory202483 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory202483 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory202483"></th><th class="tdhistory202483">Policy_ID</th><th class="tdhistory202483">Customer_ID</th><th class="tdhistory202483">Policy_premium_Amt</th><th class="tdhistory202483">Policy_State</th><th class="tdhistory202483">Policy_Validity</th></tr></thead><tbody class="tdhistory202483 resultset-body"><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory202483">444427</td><td class="tdhistory202483">6999975</td><td class="tdhistory202483">932</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2018-03-28,2023-03-28</td></tr><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory202483">171152</td><td class="tdhistory202483">5703051</td><td class="tdhistory202483">864</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2017-02-28,2022-02-28</td></tr><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory202483">171147</td><td class="tdhistory202483">7478283</td><td class="tdhistory202483">814</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2016-08-29,2021-08-29</td></tr><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory202483">555374</td><td class="tdhistory202483">5353898</td><td class="tdhistory202483">976</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2019-01-05,9999-12-31</td></tr><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory202483">555374</td><td class="tdhistory202483">5353898</td><td class="tdhistory202483">976</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2019-01-05,2024-01-05</td></tr><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory202483">555374</td><td class="tdhistory202483">5353898</td><td class="tdhistory202483">976</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2019-01-05,9999-12-31</td></tr><tr><th class="tdhistory202483" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory202483">444422</td><td class="tdhistory202483">2660358</td><td class="tdhistory202483">882</td><td class="tdhistory202483">IL  </td><td class="tdhistory202483">2017-09-28,2022-09-28</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b> Now let's check how temporal can help simplify queries in a complex scenario:</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Consider scenario where we have to check all valid policies whose validity period is similar to the Policy of the Mercedes -ML350 in the state IL. In a table without the temporal columns the query would have to collect data for various scenarios where the policy_start_date and policy_end_date for other policies lie in the range of the policy_start_date and policy_end_date of the policy of Mercedes-ML350 in state of IL. So, the query will have to do a UNION ALL with different date checks for checking the start and end date of the policies looks like the below: </p>

# %%
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date <= OthPol.Policy_start_date
    AND MercPol.Policy_end_date > OthPol.Policy_start_date
    AND MercPol.Policy_end_date <= OthPol.Policy_end_date
UNION ALL
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date <= OthPol.Policy_start_date
    AND MercPol.Policy_end_date >= OthPol.Policy_end_date
UNION ALL
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date >= OthPol.Policy_start_date
    AND MercPol.Policy_end_date <= OthPol.Policy_end_date
UNION ALL
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date >= OthPol.Policy_start_date
    AND MercPol.Policy_start_date < OthPol.Policy_end_date
    AND MercPol.Policy_end_date >= OthPol.Policy_end_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory888746"><style>
#       table.tdhistory888746 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory888746 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory888746:last-child { text-align: left !important; }
#       tbody.tdhistory888746 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory888746 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory888746 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory888746"></th><th class="tdhistory888746">Policy_ID</th><th class="tdhistory888746">Customer_ID</th><th class="tdhistory888746">auto_make</th><th class="tdhistory888746">Policy_start_date</th><th class="tdhistory888746">Policy_end_date</th></tr></thead><tbody class="tdhistory888746 resultset-body"><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory888746">113521</td><td class="tdhistory888746">2294600</td><td class="tdhistory888746">Ford</td><td class="tdhistory888746">1991-04-13</td><td class="tdhistory888746">1992-04-13</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory888746">369786</td><td class="tdhistory888746">2645288</td><td class="tdhistory888746">Saab</td><td class="tdhistory888746">2011-11-25</td><td class="tdhistory888746">2012-11-25</td></tr><tr><th class="tdhistory888746" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistor ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Use the Temporal ValidTime function to display similar results as the query written above on table without Period datatype. </p>

# %%
VALIDTIME SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make
FROM
    DEMO_Insurance.policy_details MercPol
JOIN
    DEMO_Insurance.policy_details OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory708314"><style>
#       table.tdhistory708314 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory708314 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory708314:last-child { text-align: left !important; }
#       tbody.tdhistory708314 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory708314 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory708314 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory708314"></th><th class="tdhistory708314">Policy_ID</th><th class="tdhistory708314">Customer_ID</th><th class="tdhistory708314">auto_make</th><th class="tdhistory708314">VALIDTIME</th></tr></thead><tbody class="tdhistory708314 resultset-body"><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory708314">369786</td><td class="tdhistory708314">2645288</td><td class="tdhistory708314">Saab</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory708314">241562</td><td class="tdhistory708314">7017277</td><td class="tdhistory708314">Accura</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory708314">722747</td><td class="tdhistory708314">5900891</td><td class="tdhistory708314">Suburu</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory708314">596790</td><td class="tdhistory708314">4781149</td><td class="tdhistory708314">Accura</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory708314">533940</td><td class="tdhistory708314">4585664</td><td class="tdhistory708314">Audi</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory708314">976650</td><td class="tdhistory708314">5128749</td><td class="tdhistory708314">Ford</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory708314">369048</td><td class="tdhistory708314">8120451</td><td class="tdhistory708314">Dodge</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory708314">596790</td><td class="tdhistory708314">4781149</td><td class="tdhistory708314">Accura</td><td class="tdhistory708314">2023-10-24,2025-09-04</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory708314">490601</td><td class="tdhistory708314">6986977</td><td class="tdhistory708314">Nissan</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory708314">787351</td><td class="tdhistory708314">5940419</td><td class="tdhistory708314">Saab</td><td class="tdhistory708314">2023-10-24,2024-04-28</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory708314">137680</td><td class="tdhistory708314">8971909</td><td class="tdhistory708314">Volkswagen</td><td class="tdhistory708314">2024-06-03,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory708314">596790</td><td class="tdhistory708314">4781149</td><td class="tdhistory708314">Accura</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory708314">908940</td><td class="tdhistory708314">3829512</td><td class="tdhistory708314">Suburu</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><tr><th class="tdhistory708314" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory708314">787351</td><td class="tdhistory708314">5940419</td><td class="tdhistory708314">Saab</td><td class="tdhistory708314">2023-10-24,9999-12-31</td></tr><t ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. Comparison for Queries with and without Temporal </b></p>

# %% [markdown]
# <table>
# <tr>
# <td style = 'font-size:18px;font-family:Arial;color:#00233C;font-weight:bold'>WITH TEMPORAL</td>
# <td style = 'font-size:16px;font-family:Arial;color:#00233C;font-weight:bold'>WITHOUT TEMPORAL</td>
# </tr>
#
# <tr>
# <td style = 'font-size:16px;font-family:Arial;color:#00233C'>Validtime select b.Policy_id, b.Customer_id, b.auto_make from policy_details a , policy_details b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state; </td>
# <td style = 'font-size:16px;font-family:Arial;color:#00233C'>select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date b.policy_start_date AND a.policy_end_date    UNION ALL
# select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date <= b.policy_start_date AND a.policy_end_date >= b.policy_end_date
#
#    UNION ALL
# select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date >= b.policy_start_date AND a.policy_end_date <= b.policy_end_date
#
#    UNION ALL
# select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date >= b.policy_start_date AND a.policy_start_date < b.policy_end_date AND a.policy_end_date >= b.policy_end_date;</td>
# </tr>
# </table>

# %% [markdown]
#  <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Performance Comparison for above queries </b> </p>

# %% [markdown]
# <img src="images/PerformanceMetrics.png" style="width:1000px;height:200px;">

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. Temporal concepts:- Aggregations </b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Comparing the Validity and VALIDTIME columns demonstrates that the
#     valid-time period of the result set is the intersection of the valid-time period in the original Policy table Validity
#     column with the Period specified in the sequenced select statement.</p>

# %%
SEQUENCED VALIDTIME PERIOD '(2009-01-01, 2009-12-31)'
SELECT
    Policy_ID,
    Customer_ID,
    Policy_Validity
FROM
    (
        SEQUENCED VALIDTIME SELECT
            Policy_details.*
        FROM
            DEMO_Insurance.Policy_Details
        WHERE
            policy_state = 'IN'
    ) AS my_derived_table;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory529588"><style>
#       table.tdhistory529588 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory529588 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory529588:last-child { text-align: left !important; }
#       tbody.tdhistory529588 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory529588 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory529588 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory529588"></th><th class="tdhistory529588">Policy_ID</th><th class="tdhistory529588">Customer_ID</th><th class="tdhistory529588">Policy_Validity</th><th class="tdhistory529588">VALIDTIME</th></tr></thead><tbody class="tdhistory529588 resultset-body"><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory529588">237423</td><td class="tdhistory529588">1133354</td><td class="tdhistory529588">2008-06-04,2009-06-04</td><td class="tdhistory529588">2009-01-01,2009-06-04</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory529588">550132</td><td class="tdhistory529588">3964730</td><td class="tdhistory529588">2008-01-04,2009-01-04</td><td class="tdhistory529588">2009-01-01,2009-01-04</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory529588">332897</td><td class="tdhistory529588">2540822</td><td class="tdhistory529588">2008-04-25,2009-04-25</td><td class="tdhistory529588">2009-01-01,2009-04-25</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory529588">535879</td><td class="tdhistory529588">8040359</td><td class="tdhistory529588">2009-03-05,2010-03-05</td><td class="tdhistory529588">2009-03-05,2009-12-31</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory529588">853360</td><td class="tdhistory529588">7409287</td><td class="tdhistory529588">2009-06-26,2010-06-26</td><td class="tdhistory529588">2009-06-26,2009-12-31</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory529588">582973</td><td class="tdhistory529588">8045031</td><td class="tdhistory529588">2008-06-11,2009-06-11</td><td class="tdhistory529588">2009-01-01,2009-06-11</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory529588">615121</td><td class="tdhistory529588">7625391</td><td class="tdhistory529588">2009-05-09,2010-05-09</td><td class="tdhistory529588">2009-05-09,2009-12-31</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory529588">866936</td><td class="tdhistory529588">4627650</td><td class="tdhistory529588">2008-07-07,2009-07-07</td><td class="tdhistory529588">2009-01-01,2009-07-07</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory529588">250833</td><td class="tdhistory529588">7877784</td><td class="tdhistory529588">2008-07-28,2009-07-28</td><td class="tdhistory529588">2009-01-01,2009-07-28</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory529588">913464</td><td class="tdhistory529588">6446834</td><td class="tdhistory529588">2009-01-21,2010-01-21</td><td class="tdhistory529588">2009-01-21,2009-12-31</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory529588">794956</td><td class="tdhistory529588">5647061</td><td class="tdhistory529588">2008-10-21,2009-10-21</td><td class="tdhistory529588">2009-01-01,2009-10-21</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory529588">698475</td><td class="tdhistory529588">6944752</td><td class="tdhistory529588">2008-12-17,2009-12-17</td><td class="tdhistory529588">2009-01-01,2009-12-17</td></tr><tr><th class="tdhistory529588" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory529588">751617</td><td class="tdhistory529588">2814337</td><td class="tdhistory529588">2009-12-22,2010-12-22</td><td class="tdhistory529588">2009-12-22,2009-12-31</td></tr><tr><th class="tdhistory529588" style= "background: rgba( ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Aggregations can be used for analysis of the data based on the validity period.
# Comparisons of data between different validity periods can be achieved with Temporal. Like the minimum and maximum premium amounts for a particular state based on the model of the cars.</p>

# %%
SEQUENCED VALIDTIME PERIOD (DATE '2011-01-01', DATE '2020-12-31')
SELECT
    auto_make,
    MIN(Policy_premium_Amt) AS MinPremium,
    MAX(Policy_premium_Amt) AS MaxPremium
FROM
    DEMO_Insurance.Policy_Details
WHERE
    policy_state = 'OH'
GROUP BY 1
ORDER BY VALIDTIME;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory562280"><style>
#       table.tdhistory562280 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory562280 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory562280:last-child { text-align: left !important; }
#       tbody.tdhistory562280 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory562280 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory562280 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory562280"></th><th class="tdhistory562280">auto_make</th><th class="tdhistory562280">MinPremium</th><th class="tdhistory562280">MaxPremium</th><th class="tdhistory562280">VALIDTIME</th></tr></thead><tbody class="tdhistory562280 resultset-body"><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory562280">Honda</td><td class="tdhistory562280">1203</td><td class="tdhistory562280">1453</td><td class="tdhistory562280">2011-01-01,2011-01-06</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory562280">Suburu</td><td class="tdhistory562280">1038</td><td class="tdhistory562280">1088</td><td class="tdhistory562280">2011-01-01,2011-01-12</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory562280">Mercedes</td><td class="tdhistory562280">667</td><td class="tdhistory562280">1783</td><td class="tdhistory562280">2011-01-01,2011-01-24</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory562280">Audi</td><td class="tdhistory562280">1050</td><td class="tdhistory562280">1714</td><td class="tdhistory562280">2011-01-01,2011-01-28</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory562280">Accura</td><td class="tdhistory562280">1489</td><td class="tdhistory562280">1489</td><td class="tdhistory562280">2011-01-01,2011-02-02</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory562280">BMW</td><td class="tdhistory562280">1052</td><td class="tdhistory562280">1307</td><td class="tdhistory562280">2011-01-01,2011-02-03</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory562280">Jeep</td><td class="tdhistory562280">830</td><td class="tdhistory562280">880</td><td class="tdhistory562280">2011-01-01,2011-02-11</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory562280">Toyota</td><td class="tdhistory562280">1338</td><td class="tdhistory562280">1338</td><td class="tdhistory562280">2011-01-01,2011-02-21</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory562280">Saab</td><td class="tdhistory562280">1484</td><td class="tdhistory562280">1539</td><td class="tdhistory562280">2011-01-01,2011-03-11</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory562280">Dodge</td><td class="tdhistory562280">998</td><td class="tdhistory562280">1305</td><td class="tdhistory562280">2011-01-01,2011-03-17</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory562280">Chevrolet</td><td class="tdhistory562280">1266</td><td class="tdhistory562280">1878</td><td class="tdhistory562280">2011-01-01,2011-05-04</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory562280">Nissan</td><td class="tdhistory562280">1080</td><td class="tdhistory562280">1405</td><td class="tdhistory562280">2011-01-01,2011-05-08</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory562280">Honda</td><td class="tdhistory562280">1203</td><td class="tdhistory562280">1453</td><td class="tdhistory562280">2011-01-06,2011-02-17</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory562280">Suburu</td><td class="tdhistory562280">1088</td><td class="tdhistory562280">1088</td><td class="tdhistory562280">2011-01-12,2011-06-06</td></tr><tr><th class="tdhistory562280" style= "background: rgba(243, 243, 243, 0.75 ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. Temporal concepts:- Validtime usage </b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b> Time line for various Policies:-    Analysis can be done for </b> </p>
#
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Policies valid during a particular period.</li>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Validity period of various policies.</li>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Premium amount collected during a particular period </li>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Using the As Of concept to verify the active policies on a particular date</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>On a given date, there was a hailstorm and we want to determine the count of policies in effect on that date
# The scenario mentioned here can be solved by the below query using the As of Date feature of Temporal tables
#  </p>

# %% [markdown]
# <img src="images/TemporalTimePeriod.png" style="width:600px;height:400px;">

# %%
VALIDTIME AS OF DATE '2022-02-15'
SELECT
    Policy_ID,
    Customer_ID,
    Policy_premium_Amt,
    Policy_Validity
FROM
    DEMO_Insurance.Policy_Details
WHERE
    policy_state = 'IL';
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory117088"><style>
#       table.tdhistory117088 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory117088 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory117088:last-child { text-align: left !important; }
#       tbody.tdhistory117088 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory117088 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory117088 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory117088"></th><th class="tdhistory117088">Policy_ID</th><th class="tdhistory117088">Customer_ID</th><th class="tdhistory117088">Policy_premium_Amt</th><th class="tdhistory117088">Policy_Validity</th></tr></thead><tbody class="tdhistory117088 resultset-body"><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory117088">369786</td><td class="tdhistory117088">2645288</td><td class="tdhistory117088">1316</td><td class="tdhistory117088">2017-11-25,2022-11-25</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory117088">241562</td><td class="tdhistory117088">7017277</td><td class="tdhistory117088">2197</td><td class="tdhistory117088">2021-01-28,9999-12-31</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory117088">722747</td><td class="tdhistory117088">5900891</td><td class="tdhistory117088">1582</td><td class="tdhistory117088">2017-09-02,2022-09-02</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory117088">596790</td><td class="tdhistory117088">4781149</td><td class="tdhistory117088">1254</td><td class="tdhistory117088">2020-09-04,9999-12-31</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory117088">533940</td><td class="tdhistory117088">4585664</td><td class="tdhistory117088">1456</td><td class="tdhistory117088">2017-11-18,2022-11-18</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory117088">976650</td><td class="tdhistory117088">5128749</td><td class="tdhistory117088">1247</td><td class="tdhistory117088">2021-08-28,9999-12-31</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory117088">369048</td><td class="tdhistory117088">8120451</td><td class="tdhistory117088">1627</td><td class="tdhistory117088">2017-06-05,2022-06-05</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory117088">596790</td><td class="tdhistory117088">4781149</td><td class="tdhistory117088">1254</td><td class="tdhistory117088">2020-09-04,2025-09-04</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory117088">490601</td><td class="tdhistory117088">6986977</td><td class="tdhistory117088">1348</td><td class="tdhistory117088">2017-08-04,2022-08-04</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory117088">787351</td><td class="tdhistory117088">5940419</td><td class="tdhistory117088">1830</td><td class="tdhistory117088">2019-04-28,2024-04-28</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory117088">137680</td><td class="tdhistory117088">8971909</td><td class="tdhistory117088">1986</td><td class="tdhistory117088">2019-06-03,9999-12-31</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory117088">596790</td><td class="tdhistory117088">4781149</td><td class="tdhistory117088">1254</td><td class="tdhistory117088">2020-09-04,9999-12-31</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory117088">908940</td><td class="tdhistory117088">3829512</td><td class="tdhistory117088">1561</td><td class="tdhistory117088">2021-06-11,9999-12-31</td></tr><tr><th class="tdhistory117088" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory117088">787351</td><td class="tdhistory117088">5940419</td><td class="tdhistory117088">1830</td><td class="tdhistory117088">2019-04-28,9999-12-31</td></tr><tr><th  ...

# %%
SELECT
    COUNT(*) AS "no of Policies"
FROM
    (
        VALIDTIME AS OF DATE '2022-02-15'
        SELECT
            Policy_ID,
            Customer_ID,
            Policy_premium_Amt,
            Policy_Validity
        FROM
            DEMO_Insurance.Policy_Details
        WHERE
            policy_state = 'IL'
    ) AS DerivTbl;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory253432"><style>
#       table.tdhistory253432 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory253432 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory253432:last-child { text-align: left !important; }
#       tbody.tdhistory253432 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory253432 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory253432 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory253432"></th><th class="tdhistory253432">no of Policies</th></tr></thead><tbody class="tdhistory253432 resultset-body"><tr><th class="tdhistory253432" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory253432">367</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Consider scenario where we need to check that for a particular period (here for year 2021) how many policies are valid for each auto make type and then compare the no of policies which are valid in the current period. This helps us in the comparison in the increase or decrease of policies for the current year as compared to the past year of validity
#  </p>

# %%
SELECT
    auto_make,
    COUNT(*) AS "no of Policies"
FROM
    (
        VALIDTIME PERIOD (DATE '2021-01-01', DATE '2021-12-31')
        SELECT
            Policy_ID,
            Customer_ID,
            Policy_premium_Amt,
            auto_make
        FROM
            DEMO_Insurance.Policy_Details
    ) AS DerivTbl
GROUP BY
    auto_make;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory44382"><style>
#       table.tdhistory44382 { display: block !important; min-height: 378px !important; overflow: auto !important; height: 378px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory44382 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory44382:last-child { text-align: left !important; }
#       tbody.tdhistory44382 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory44382 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory44382 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory44382"></th><th class="tdhistory44382">auto_make</th><th class="tdhistory44382">no of Policies</th></tr></thead><tbody class="tdhistory44382 resultset-body"><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory44382">Chevrolet</td><td class="tdhistory44382">23</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory44382">Honda</td><td class="tdhistory44382">13</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory44382">Mercedes</td><td class="tdhistory44382">10</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory44382">Ford</td><td class="tdhistory44382">28</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory44382">Suburu</td><td class="tdhistory44382">21</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory44382">Volkswagen</td><td class="tdhistory44382">28</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory44382">Dodge</td><td class="tdhistory44382">27</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory44382">Accura</td><td class="tdhistory44382">30</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory44382">Saab</td><td class="tdhistory44382">50</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory44382">Audi</td><td class="tdhistory44382">46</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory44382">BMW</td><td class="tdhistory44382">53</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory44382">Toyota</td><td class="tdhistory44382">31</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory44382">Jeep</td><td class="tdhistory44382">12</td></tr><tr><th class="tdhistory44382" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory44382">Nissan</td><td class="tdhistory44382">40</td></tr></tbody></table></div>

# %%
%chart x = auto_make, y = "no of Policies", title = 'Valid Number of Policies last year'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Now we check how many policies are still valid for each type using the current functionality
#  </p>

# %%
SELECT
    auto_make,
    COUNT(*) AS "no of Policies"
FROM
    (
        CURRENT VALIDTIME
        SELECT
            Policy_ID,
            Customer_ID,
            Policy_premium_Amt,
            auto_make
        FROM
            DEMO_Insurance.Policy_Details
    ) AS DerivTbl
GROUP BY
    auto_make;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory99167"><style>
#       table.tdhistory99167 { display: block !important; min-height: 378px !important; overflow: auto !important; height: 378px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99167 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99167:last-child { text-align: left !important; }
#       tbody.tdhistory99167 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory99167 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory99167 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory99167"></th><th class="tdhistory99167">auto_make</th><th class="tdhistory99167">no of Policies</th></tr></thead><tbody class="tdhistory99167 resultset-body"><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory99167">Chevrolet</td><td class="tdhistory99167">23</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory99167">Honda</td><td class="tdhistory99167">12</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory99167">Mercedes</td><td class="tdhistory99167">8</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory99167">Ford</td><td class="tdhistory99167">22</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory99167">Suburu</td><td class="tdhistory99167">20</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory99167">Volkswagen</td><td class="tdhistory99167">27</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory99167">Dodge</td><td class="tdhistory99167">25</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory99167">Accura</td><td class="tdhistory99167">26</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory99167">Saab</td><td class="tdhistory99167">47</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory99167">Audi</td><td class="tdhistory99167">41</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory99167">BMW</td><td class="tdhistory99167">44</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory99167">Toyota</td><td class="tdhistory99167">25</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory99167">Jeep</td><td class="tdhistory99167">10</td></tr><tr><th class="tdhistory99167" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory99167">Nissan</td><td class="tdhistory99167">38</td></tr></tbody></table></div>

# %%
%chart x = auto_make, y = "no of Policies", title = 'Current Valid Number of Policies'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In this scenario we are considering that there are a number of claims raised against policies on various incident dates. Below queries help to identify which claims made are in the validity period and which are not and which policies are valid at the time of the incidents. There are total 69 claims in the Insurance Claims tables and based on the incident date we can verify which claims are valid and which are not valid.
#  </p>

# %%
SELECT * FROM DEMO_Insurance.Insurance_Claims_Details;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory625157"><style>
#       table.tdhistory625157 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory625157 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory625157:last-child { text-align: left !important; }
#       tbody.tdhistory625157 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory625157 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory625157 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory625157"></th><th class="tdhistory625157">Policy_id</th><th class="tdhistory625157">Claim_id</th><th class="tdhistory625157">Incident_date</th><th class="tdhistory625157">claim_date</th><th class="tdhistory625157">Claim_amount</th></tr></thead><tbody class="tdhistory625157 resultset-body"><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory625157">369786</td><td class="tdhistory625157">22482</td><td class="tdhistory625157">2017-12-05</td><td class="tdhistory625157">2022-10-20</td><td class="tdhistory625157">453</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory625157">241562</td><td class="tdhistory625157">25331</td><td class="tdhistory625157">2016-01-24</td><td class="tdhistory625157">2020-12-29</td><td class="tdhistory625157">2586</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory625157">722747</td><td class="tdhistory625157">77517</td><td class="tdhistory625157">2017-09-19</td><td class="tdhistory625157">2022-07-29</td><td class="tdhistory625157">1717</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory625157">515222</td><td class="tdhistory625157">78799</td><td class="tdhistory625157">2017-01-04</td><td class="tdhistory625157">2021-12-09</td><td class="tdhistory625157">2059</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory625157">533940</td><td class="tdhistory625157">88159</td><td class="tdhistory625157">2017-11-28</td><td class="tdhistory625157">2022-11-02</td><td class="tdhistory625157">1576</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory625157">976650</td><td class="tdhistory625157">25879</td><td class="tdhistory625157">2016-09-01</td><td class="tdhistory625157">2021-08-01</td><td class="tdhistory625157">1169</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory625157">369048</td><td class="tdhistory625157">60881</td><td class="tdhistory625157">2017-06-15</td><td class="tdhistory625157">2022-05-05</td><td class="tdhistory625157">1480</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory625157">212585</td><td class="tdhistory625157">45440</td><td class="tdhistory625157">2016-01-01</td><td class="tdhistory625157">2021-01-08</td><td class="tdhistory625157">2332</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory625157">490601</td><td class="tdhistory625157">74688</td><td class="tdhistory625157">2017-08-06</td><td class="tdhistory625157">2022-07-30</td><td class="tdhistory625157">437</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory625157">235869</td><td class="tdhistory625157">35914</td><td class="tdhistory625157">2017-02-11</td><td class="tdhistory625157">2021-12-29</td><td class="tdhistory625157">605</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory625157">427204</td><td class="tdhistory625157">85098</td><td class="tdhistory625157">2017-04-17</td><td class="tdhistory625157">2022-03-18</td><td class="tdhistory625157">2246</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory625157">212585</td><td class="tdhistory625157">16710</td><td class="tdhistory625157">2016-01-25</td><td class="tdhistory625157">2020-12-04</td><td class="tdhistory625157">2805</td></tr><tr><th class="tdhistory625157" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory625157">908940</td><td class="tdhis ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Based on the Claims made, we need to validate which claims are valid on the incident date mentioned. Below query helps in the analysis. Only the rows that qualify for the claims are displayed.
#  </p>

# %%
SELECT
    'Valid Claims' AS ClaimType,
    Policy.customer_id,
    Policy.Policy_id,
    Insurance_Claims_Details.Claim_Id,
    Claim_amount
FROM
    (
        CURRENT VALIDTIME
        SELECT
            Policy_Details.*
        FROM
            DEMO_Insurance.Policy_Details
    ) Policy
INNER JOIN
    DEMO_Insurance.Insurance_Claims_Details
ON
    Policy.Policy_id = Insurance_Claims_Details.Policy_id
WHERE
    Policy.Policy_Validity CONTAINS Insurance_Claims_Details.Incident_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory33909"><style>
#       table.tdhistory33909 { display: block !important; min-height: 420px !important; overflow: auto !important; height: 420px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory33909 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory33909:last-child { text-align: left !important; }
#       tbody.tdhistory33909 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory33909 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory33909 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory33909"></th><th class="tdhistory33909">ClaimType</th><th class="tdhistory33909">Customer_ID</th><th class="tdhistory33909">Policy_ID</th><th class="tdhistory33909">Claim_id</th><th class="tdhistory33909">Claim_amount</th></tr></thead><tbody class="tdhistory33909 resultset-body"><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">1529583</td><td class="tdhistory33909">987529</td><td class="tdhistory33909">14575</td><td class="tdhistory33909">2061</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">3309391</td><td class="tdhistory33909">420948</td><td class="tdhistory33909">26730</td><td class="tdhistory33909">2124</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">7273220</td><td class="tdhistory33909">998870</td><td class="tdhistory33909">77652</td><td class="tdhistory33909">2958</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">8369854</td><td class="tdhistory33909">212585</td><td class="tdhistory33909">16710</td><td class="tdhistory33909">2805</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">6136627</td><td class="tdhistory33909">425636</td><td class="tdhistory33909">75895</td><td class="tdhistory33909">270</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">7273220</td><td class="tdhistory33909">998870</td><td class="tdhistory33909">32550</td><td class="tdhistory33909">2501</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">4578802</td><td class="tdhistory33909">924323</td><td class="tdhistory33909">33688</td><td class="tdhistory33909">1887</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">6136627</td><td class="tdhistory33909">425636</td><td class="tdhistory33909">25143</td><td class="tdhistory33909">1137</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">1681345</td><td class="tdhistory33909">264226</td><td class="tdhistory33909">51109</td><td class="tdhistory33909">342</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">4578802</td><td class="tdhistory33909">924323</td><td class="tdhistory33909">44301</td><td class="tdhistory33909">2929</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">6534846</td><td class="tdhistory33909">180013</td><td class="tdhistory33909">59211</td><td class="tdhistory33909">424</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">1024630</td><td class="tdhistory33909">925133</td><td class="tdhistory33909">82409</td><td class="tdhistory33909">2113</td></tr><tr><th class="tdhistory33909" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory33909">Valid Claims</td><td class="tdhistory33909">1024630</td><td class="tdhistory33909">925133</td><td class="tdhistory33909">58 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Below query displays the Invalid rows from Claims table
#  </p>

# %%
SELECT
    customer_id,
    Policy.Policy_id,
    Claim_Id,
    Claim_amount
FROM
    DEMO_Insurance.Insurance_Claims_Details
INNER JOIN
    DEMO_Insurance.Policy_Details Policy
ON
    Policy.Policy_id = Insurance_Claims_Details.Policy_id
MINUS
SELECT
    Policy.customer_id,
    Policy.Policy_id,
    Insurance_Claims_Details.Claim_Id,
    Claim_amount
FROM
    (
        CURRENT VALIDTIME
        SELECT
            Policy_Details.*
        FROM
            DEMO_Insurance.Policy_Details
    ) Policy
INNER JOIN
    DEMO_Insurance.Insurance_Claims_Details
ON
    Policy.Policy_id = Insurance_Claims_Details.Policy_id
WHERE
    Policy.Policy_Validity CONTAINS Insurance_Claims_Details.Incident_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory427593"><style>
#       table.tdhistory427593 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory427593 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory427593:last-child { text-align: left !important; }
#       tbody.tdhistory427593 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory427593 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory427593 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory427593"></th><th class="tdhistory427593">Customer_ID</th><th class="tdhistory427593">Policy_ID</th><th class="tdhistory427593">Claim_id</th><th class="tdhistory427593">Claim_amount</th></tr></thead><tbody class="tdhistory427593 resultset-body"><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory427593">2594003</td><td class="tdhistory427593">106186</td><td class="tdhistory427593">27761</td><td class="tdhistory427593">859</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory427593">3048175</td><td class="tdhistory427593">651866</td><td class="tdhistory427593">83893</td><td class="tdhistory427593">2527</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory427593">2205539</td><td class="tdhistory427593">735312</td><td class="tdhistory427593">25606</td><td class="tdhistory427593">957</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory427593">3309391</td><td class="tdhistory427593">420948</td><td class="tdhistory427593">55707</td><td class="tdhistory427593">255</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory427593">4169839</td><td class="tdhistory427593">231513</td><td class="tdhistory427593">19271</td><td class="tdhistory427593">993</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory427593">3829512</td><td class="tdhistory427593">908940</td><td class="tdhistory427593">55199</td><td class="tdhistory427593">402</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory427593">5128749</td><td class="tdhistory427593">976650</td><td class="tdhistory427593">25879</td><td class="tdhistory427593">1169</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory427593">6548681</td><td class="tdhistory427593">806086</td><td class="tdhistory427593">81096</td><td class="tdhistory427593">682</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory427593">1681345</td><td class="tdhistory427593">264226</td><td class="tdhistory427593">51232</td><td class="tdhistory427593">1915</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory427593">4315254</td><td class="tdhistory427593">694667</td><td class="tdhistory427593">10622</td><td class="tdhistory427593">990</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory427593">7087338</td><td class="tdhistory427593">516959</td><td class="tdhistory427593">37088</td><td class="tdhistory427593">1283</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory427593">7427104</td><td class="tdhistory427593">241567</td><td class="tdhistory427593">83123</td><td class="tdhistory427593">2107</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory427593">4585664</td><td class="tdhistory427593">533940</td><td class="tdhistory427593">88159</td><td class="tdhistory427593">1576</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory427593">7478283</td><td class="tdhistory427593">171147</td><td class="tdhistory427593">24664</td><td class="tdhistory427593">445</td></tr><tr><th class="tdhistory427593" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory427593">2153692</td><td class="tdhistory427593">356768</td><td class="tdhistory427593">12087</td><td class="tdhistory427593">1003</td></tr><tr><th  ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>7. Explaining the Temporal Concepts of Inserts /Deletes </b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Customer 1 has policy 1 with Validity Period . In between the validity period the customer decides to change some factors which causes the premium to increase , so there will be a new addition which will insert a new row having validity period from changed date to the end of period. </p>
#
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Customer 2 has Policy 1 with validity period. In between the company decides to increase the premium which also increases the validity period.
#  </p>

# %% [markdown]
# <img src="images/Temporal_Inserts_Updates.png" style="width:600px;height:400px;">

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Inserting data into temporal table is simple for current validtime. </p>

# %%
CURRENT VALIDTIME INSERT DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
VALUES
    (203914, 2316038, 'OH', 1200, 'Audi', 'A3');
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Inserting history rows will need Temporal Qualifier. </p>

# %%
SEQUENCED VALIDTIME INSERT DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
VALUES
    (203914, 2316038, 'OH', 1050, 'Audi', 'A3', PERIOD(DATE '2002-06-10', DATE '2012-06-09'));

SEQUENCED VALIDTIME INSERT DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
VALUES
    (203914, 2316038, 'OH', 1150, 'Audi', 'A3', PERIOD(DATE '2012-06-10', DATE '2022-06-27'));
# Out:
# Success: 1 rows affected
# Success: 1 rows affected

# %%
SEQUENCED VALIDTIME
SELECT * 
FROM
    DEMO_Insurance.Policy_Details 
WHERE
    customer_id = 2316038 
ORDER BY
    validtime;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory502326"><style>
#       table.tdhistory502326 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory502326 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory502326:last-child { text-align: left !important; }
#       tbody.tdhistory502326 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory502326 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory502326 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory502326"></th><th class="tdhistory502326">Policy_ID</th><th class="tdhistory502326">Customer_ID</th><th class="tdhistory502326">Policy_State</th><th class="tdhistory502326">Policy_premium_Amt</th><th class="tdhistory502326">auto_make</th><th class="tdhistory502326">auto_model</th><th class="tdhistory502326">Policy_Validity</th><th class="tdhistory502326">VALIDTIME</th></tr></thead><tbody class="tdhistory502326 resultset-body"><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1000</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2001-06-09,2002-06-09</td><td class="tdhistory502326">2001-06-09,2002-06-09</td></tr><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1050</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2002-06-10,2012-06-09</td><td class="tdhistory502326">2002-06-10,2012-06-09</td></tr><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1050</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2002-06-10,2012-06-09</td><td class="tdhistory502326">2002-06-10,2012-06-09</td></tr><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1150</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2012-06-10,2022-06-27</td><td class="tdhistory502326">2012-06-10,2022-06-27</td></tr><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1150</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2012-06-10,2022-06-27</td><td class="tdhistory502326">2012-06-10,2022-06-27</td></tr><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1200</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2022-06-28,9999-12-31</td><td class="tdhistory502326">2022-06-28,9999-12-31</td></tr><tr><th class="tdhistory502326" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory502326">203914</td><td class="tdhistory502326">2316038</td><td class="tdhistory502326">OH  </td><td class="tdhistory502326">1200</td><td class="tdhistory502326">Audi</td><td class="tdhistory502326">A3</td><td class="tdhistory502326">2024-09-05,9999-12-31</td><td class="tdhistory502326">2024-09-05,9999-12-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Without Temporal Qualifier the select will display only current rows. </p>

# %%
SET SESSION CURRENT VALIDTIME;
# Out:
# Success: 1 rows affected

# %%
SELECT *
FROM 
    DEMO_Insurance.Policy_Details
WHERE
    customer_id = 2316038
ORDER BY
    Policy_validity;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory207501"><style>
#       table.tdhistory207501 { display: block !important; min-height: 126px !important; overflow: auto !important; height: 126px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory207501 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory207501:last-child { text-align: left !important; }
#       tbody.tdhistory207501 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory207501 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory207501 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory207501"></th><th class="tdhistory207501">Policy_ID</th><th class="tdhistory207501">Customer_ID</th><th class="tdhistory207501">Policy_State</th><th class="tdhistory207501">Policy_premium_Amt</th><th class="tdhistory207501">auto_make</th><th class="tdhistory207501">auto_model</th><th class="tdhistory207501">Policy_Validity</th></tr></thead><tbody class="tdhistory207501 resultset-body"><tr><th class="tdhistory207501" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory207501">203914</td><td class="tdhistory207501">2316038</td><td class="tdhistory207501">OH  </td><td class="tdhistory207501">1200</td><td class="tdhistory207501">Audi</td><td class="tdhistory207501">A3</td><td class="tdhistory207501">2022-06-28,9999-12-31</td></tr><tr><th class="tdhistory207501" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory207501">203914</td><td class="tdhistory207501">2316038</td><td class="tdhistory207501">OH  </td><td class="tdhistory207501">1200</td><td class="tdhistory207501">Audi</td><td class="tdhistory207501">A3</td><td class="tdhistory207501">2024-09-05,9999-12-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>When period is specified , Delete will only delete rows for that specific period (highlighted row in the above dataset) and the validity period for rows will change to the end of period specified in the delete. </p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Display rows for Specific Valid Period.</p>

# %%
SEQUENCED VALIDTIME PERIOD '(1990-01-01, 1990-03-31)'
SELECT * 
FROM
    DEMO_Insurance.Policy_details
WHERE
    policy_state = 'IN'
ORDER BY
    validtime;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory780922"><style>
#       table.tdhistory780922 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory780922 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory780922:last-child { text-align: left !important; }
#       tbody.tdhistory780922 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory780922 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory780922 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory780922"></th><th class="tdhistory780922">Policy_ID</th><th class="tdhistory780922">Customer_ID</th><th class="tdhistory780922">Policy_State</th><th class="tdhistory780922">Policy_premium_Amt</th><th class="tdhistory780922">auto_make</th><th class="tdhistory780922">auto_model</th><th class="tdhistory780922">Policy_Validity</th><th class="tdhistory780922">VALIDTIME</th></tr></thead><tbody class="tdhistory780922 resultset-body"><tr><th class="tdhistory780922" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory780922">529112</td><td class="tdhistory780922">1965883</td><td class="tdhistory780922">IN  </td><td class="tdhistory780922">1240</td><td class="tdhistory780922">Honda</td><td class="tdhistory780922">Civic</td><td class="tdhistory780922">1990-01-30,1991-01-08</td><td class="tdhistory780922">1990-01-30,1990-03-31</td></tr><tr><th class="tdhistory780922" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory780922">171183</td><td class="tdhistory780922">3976603</td><td class="tdhistory780922">IN  </td><td class="tdhistory780922">671</td><td class="tdhistory780922">Ford</td><td class="tdhistory780922">Escape</td><td class="tdhistory780922">1990-02-01,1991-02-01</td><td class="tdhistory780922">1990-02-01,1990-03-31</td></tr><tr><th class="tdhistory780922" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory780922">598554</td><td class="tdhistory780922">7535602</td><td class="tdhistory780922">IN  </td><td class="tdhistory780922">795</td><td class="tdhistory780922">Nissan</td><td class="tdhistory780922">Maxima</td><td class="tdhistory780922">1990-02-14,1991-02-14</td><td class="tdhistory780922">1990-02-14,1990-03-31</td></tr><tr><th class="tdhistory780922" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory780922">728025</td><td class="tdhistory780922">4414390</td><td class="tdhistory780922">IN  </td><td class="tdhistory780922">1935</td><td class="tdhistory780922">Mercedes</td><td class="tdhistory780922">E400</td><td class="tdhistory780922">1990-02-15,1991-02-15</td><td class="tdhistory780922">1990-02-15,1990-03-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Delete rows for Specific Valid Period will change the validity period to the end date specified in delete. </p>

# %%
SEQUENCED VALIDTIME PERIOD '(1990-01-01, 1990-01-30)'
DELETE FROM
    DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
WHERE
    policy_state = 'IN';
# Out:
# Success: 0 rows affected

# %%
SEQUENCED VALIDTIME PERIOD '(1990-01-01, 1990-03-31)'
SELECT * 
FROM
    DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
WHERE
    policy_state = 'IN'
ORDER BY
    validtime;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory753221"><style>
#       table.tdhistory753221 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory753221 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory753221:last-child { text-align: left !important; }
#       tbody.tdhistory753221 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory753221 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory753221 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory753221"></th><th class="tdhistory753221">Policy_ID</th><th class="tdhistory753221">Customer_ID</th><th class="tdhistory753221">Policy_State</th><th class="tdhistory753221">Policy_premium_Amt</th><th class="tdhistory753221">auto_make</th><th class="tdhistory753221">auto_model</th><th class="tdhistory753221">VALIDTIME</th></tr></thead><tbody class="tdhistory753221 resultset-body"><tr><th class="tdhistory753221" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory753221">529112</td><td class="tdhistory753221">1965883</td><td class="tdhistory753221">IN  </td><td class="tdhistory753221">1240</td><td class="tdhistory753221">Honda</td><td class="tdhistory753221">Civic</td><td class="tdhistory753221">1990-01-30,1990-03-31</td></tr><tr><th class="tdhistory753221" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory753221">171183</td><td class="tdhistory753221">3976603</td><td class="tdhistory753221">IN  </td><td class="tdhistory753221">671</td><td class="tdhistory753221">Ford</td><td class="tdhistory753221">Escape</td><td class="tdhistory753221">1990-02-01,1990-03-31</td></tr><tr><th class="tdhistory753221" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory753221">598554</td><td class="tdhistory753221">7535602</td><td class="tdhistory753221">IN  </td><td class="tdhistory753221">795</td><td class="tdhistory753221">Nissan</td><td class="tdhistory753221">Maxima</td><td class="tdhistory753221">1990-02-14,1990-03-31</td></tr><tr><th class="tdhistory753221" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory753221">728025</td><td class="tdhistory753221">4414390</td><td class="tdhistory753221">IN  </td><td class="tdhistory753221">1935</td><td class="tdhistory753221">Mercedes</td><td class="tdhistory753221">E400</td><td class="tdhistory753221">1990-02-15,1990-03-31</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>8. Bi-Temporal Table with ValidTime and TransactionTime Columns and its usage.</b> </p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Bi-Temporal tables or Transaction time tables have both Valid Date(Date) Columns and Transaction Time (Timestamp) Columns. Transaction time is the time period during which a fact, represented by all the information in a row, is or was known to be in effect in the database. It models the database reality, recording when rows have been added, modified, and changed in the database. Transaction-time periods are stored in a transaction-time column:</p>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>The beginning of the transaction-time period is the time when the database became aware of a row, when the row was first recorded in the database. This is when the row was added to a table.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>The end of a transaction time period reflects when the fact was superseded by an update to the row, or when the row was deleted from the database. Rows containing information that is currently in effect have transaction-time periods with indefinite ending bounds, represented as UNTIL_CLOSED.</li>
# </p>
#
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Thus, temporal features can help in simplifying time dependent applications. Temporal and Bi-Temporal tables can be analyzed and used in various scenarios.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>9. Cleanup </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_Insurance');    -- Takes about 10 seconds, optional if you want to use the data later
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory405182"><style>
#       table.tdhistory405182 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory405182 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory405182:last-child { text-align: left !important; }
#       tbody.tdhistory405182 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory405182 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory405182 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory405182"></th><th class="tdhistory405182">Message</th></tr></thead><tbody class="tdhistory405182 resultset-body"><tr><th class="tdhistory405182" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory405182">Removed objects related to DEMO_Insurance. That ran for 0:00:02.08</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Reference Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#     <li>Information about Temporal datatype can be found at: <a href = 'https://docs.teradata.com/search/all?query=Tempora<hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>able+Support&content-lang=en-US'>https://docs.teradata.com/search/all?query=Temporal+Table+Support&content-lang=en-US</a></li>
# </ul>

# %% [markdown]
# <footer style="padding-bottom:35px; background:#f9f9f9; border-bottom:3px solid #00233C">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2023. All Rights Reserved
#         </div>
#     </div>
# </footer>
