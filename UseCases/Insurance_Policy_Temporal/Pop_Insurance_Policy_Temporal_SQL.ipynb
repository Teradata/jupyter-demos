# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Insurance Analysis Using Temporal
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>
#
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Applications require to design and build databases dependent on time or data changes over time.  Building such applications is possible but becomes easier with Temporal
#
# </p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'> <b>WHY TEMPORAL? </b> </p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# Things You No Longer Have To Do in the Time-Aware Teradata Database
# Data Maintenance : </p>
#
# <li style = 'font-size:16px;font-family:Arial'> Update effective dates in data.</li></<li style = 'font-size:16px;font-family:Arial'> <li style = 'font-size:16px;font-family:Arial'> Specify “transaction time” timestamp when data are entered or updated. </li>
# <li style = 'font-size:16px;font-family:Arial'> Insert new data rows for updates. </li>
# <li style = 'font-size:16px;font-family:Arial'> Manage temporal history storage space. </li>

# %% [markdown]
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Query and Application Development: </p>
#
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Write complex period based condition clauses. </li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Add effective date qualifications to “current queries.” </li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Train users and application developers in effective date columns and processing for “AS OF” query development.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'> Save old reports or database snapshots to facilitate looking back for analysis, compliance reporting, or audit trails.</li>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Here we are considering the example of Insurance company storing data for various policies whose validity, conditions , premium amount and many other factors will change over Time period.</p>

# %% [markdown]
#
#
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Some scenarios that can be handled using temporal features are as below </p>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>    Consider the scenario where there is a hail storm striking on a particular date. The As of date feature can be used to check the validity of the policy and then the incident date can be used to check which claims fall in the validity period of the policies.</li>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>    Another scenario is that the customer has sold the vehicle and the closure of the policy happened a week late as the customer informed late about the sale , so based on the transaction time the validity of the policies will change. </li>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
SET query_band='DEMO=Insurance_Policy_Temporal_SQL.ipynb;' UPDATE FOR SESSION;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. Getting Data for This Demo:</b></p>
# <p style = 'font-size:16px;font-family:Arial'>We have provided data for this demo on cloud storage. In this demo since we are using Temporal table we will be creating databases and tables in local storage and use them in the notebook. Please execute the procedure in the next cell.</p>

# %%
call get_data('DEMO_Insurance_local');    -- Takes about 90 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory687519"><style>
#       table.tdhistory687519 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory687519 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory687519:last-child { text-align: left !important; }
#       tbody.tdhistory687519 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory687519 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory687519 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory687519"></th><th class="tdhistory687519">Message</th></tr></thead><tbody class="tdhistory687519 resultset-body"><tr><th class="tdhistory687519" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory687519">That ran for   0:00:19.94 with 17 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();  -- optional, takes about 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory968016"><style>
#       table.tdhistory968016 { display: block !important; min-height: 252px !important; overflow: auto !important; height: 252px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory968016 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory968016:last-child { text-align: left !important; }
#       tbody.tdhistory968016 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory968016 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory968016 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory968016"></th><th class="tdhistory968016">Space_Report</th></tr></thead><tbody class="tdhistory968016 resultset-body"><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory968016">You have:  #databases=4 #tables=56 #views=7  You have used 15.6 MB of 27,890.4 MB available - 0.1%  ... Space Usage OK</td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory968016"> </td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory968016">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory968016">   demo_user                           52       2  27,878.4 MB      14.8 MB </td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory968016">   DEMO_GraphAnalysis                   0       1       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory968016">   DEMO_GraphAnalysis_db                1       0      10.1 MB       0.2 MB </td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory968016">   DEMO_Insurance                       0       4       0.0 MB       0.0 MB </td></tr><tr><th class="tdhistory968016" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory968016">   DEMO_Insurance_DB                    3       0       1.9 MB       0.6 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Comparison of Temporal and Non-Temporal:</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>To understand how Temporal can be helpful we will consider a simple example where we need to check policies which were valid on 31st December 2020 and had a premium amount less than 1000. for a normal table with start and end date columns the query will be as below:</p>

# %%
SELECT
    Policy_ID,
    Customer_ID,
    Policy_premium_Amt,
    policy_state,
    Policy_start_date,
    policy_end_date
FROM
    DEMO_Insurance.Policy_Details_Org
WHERE
    policy_start_date <= '2020-12-31'
    AND policy_end_date >= '2020-12-31'
    AND Policy_premium_Amt < 1000;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory695812"><style>
#       table.tdhistory695812 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory695812 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory695812:last-child { text-align: left !important; }
#       tbody.tdhistory695812 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory695812 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory695812 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory695812"></th><th class="tdhistory695812">Policy_ID</th><th class="tdhistory695812">Customer_ID</th><th class="tdhistory695812">Policy_premium_Amt</th><th class="tdhistory695812">Policy_State</th><th class="tdhistory695812">Policy_start_date</th><th class="tdhistory695812">Policy_end_date</th></tr></thead><tbody class="tdhistory695812 resultset-body"><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory695812">444422</td><td class="tdhistory695812">2660358</td><td class="tdhistory695812">882</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2017-09-28</td><td class="tdhistory695812">2022-09-28</td></tr><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory695812">444427</td><td class="tdhistory695812">6999975</td><td class="tdhistory695812">932</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2018-03-28</td><td class="tdhistory695812">2023-03-28</td></tr><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory695812">171147</td><td class="tdhistory695812">7478283</td><td class="tdhistory695812">814</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2016-08-29</td><td class="tdhistory695812">2021-08-29</td></tr><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory695812">171152</td><td class="tdhistory695812">5703051</td><td class="tdhistory695812">864</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2017-02-28</td><td class="tdhistory695812">2022-02-28</td></tr><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory695812">555374</td><td class="tdhistory695812">5353898</td><td class="tdhistory695812">976</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2019-01-05</td><td class="tdhistory695812">2024-01-05</td></tr><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory695812">555374</td><td class="tdhistory695812">5353898</td><td class="tdhistory695812">976</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2019-01-05</td><td class="tdhistory695812">9999-12-31</td></tr><tr><th class="tdhistory695812" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory695812">555374</td><td class="tdhistory695812">5353898</td><td class="tdhistory695812">976</td><td class="tdhistory695812">IL</td><td class="tdhistory695812">2019-01-05</td><td class="tdhistory695812">9999-12-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The same query with Temporal table would be as below:</p>

# %%
VALIDTIME AS OF DATE '2020-12-31'
SELECT
    Policy_ID,
    Customer_ID,
    Policy_premium_Amt,
    policy_state,
    Policy_Validity
FROM
    DEMO_Insurance.Policy_Details
WHERE
    Policy_premium_Amt < 1000;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory642237"><style>
#       table.tdhistory642237 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory642237 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory642237:last-child { text-align: left !important; }
#       tbody.tdhistory642237 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory642237 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory642237 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory642237"></th><th class="tdhistory642237">Policy_ID</th><th class="tdhistory642237">Customer_ID</th><th class="tdhistory642237">Policy_premium_Amt</th><th class="tdhistory642237">Policy_State</th><th class="tdhistory642237">Policy_Validity</th></tr></thead><tbody class="tdhistory642237 resultset-body"><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory642237">444427</td><td class="tdhistory642237">6999975</td><td class="tdhistory642237">932</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2018-03-28,2023-03-28</td></tr><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory642237">171152</td><td class="tdhistory642237">5703051</td><td class="tdhistory642237">864</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2017-02-28,2022-02-28</td></tr><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory642237">171147</td><td class="tdhistory642237">7478283</td><td class="tdhistory642237">814</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2016-08-29,2021-08-29</td></tr><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory642237">555374</td><td class="tdhistory642237">5353898</td><td class="tdhistory642237">976</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2019-01-05,9999-12-31</td></tr><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory642237">555374</td><td class="tdhistory642237">5353898</td><td class="tdhistory642237">976</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2019-01-05,2024-01-05</td></tr><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory642237">555374</td><td class="tdhistory642237">5353898</td><td class="tdhistory642237">976</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2019-01-05,9999-12-31</td></tr><tr><th class="tdhistory642237" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory642237">444422</td><td class="tdhistory642237">2660358</td><td class="tdhistory642237">882</td><td class="tdhistory642237">IL  </td><td class="tdhistory642237">2017-09-28,2022-09-28</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b> Now let's check how temporal can help simplify queries in a complex scenario:</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Consider scenario where we have to check all valid policies whose validity period is similar to the Policy of the Mercedes -ML350 in the state IL. In a table without the temporal columns the query would have to collect data for various scenarios where the policy_start_date and policy_end_date for other policies lie in the range of the policy_start_date and policy_end_date of the policy of Mercedes-ML350 in state of IL. So, the query will have to do a UNION ALL with different date checks for checking the start and end date of the policies looks like the below: </p>

# %%
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date <= OthPol.Policy_start_date
    AND MercPol.Policy_end_date > OthPol.Policy_start_date
    AND MercPol.Policy_end_date <= OthPol.Policy_end_date
UNION ALL
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date <= OthPol.Policy_start_date
    AND MercPol.Policy_end_date >= OthPol.Policy_end_date
UNION ALL
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date >= OthPol.Policy_start_date
    AND MercPol.Policy_end_date <= OthPol.Policy_end_date
UNION ALL
SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make,
    OthPol.Policy_start_date,
    OthPol.Policy_end_date
FROM
    DEMO_Insurance.policy_details_org MercPol
JOIN
    DEMO_Insurance.policy_details_org OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state
    AND MercPol.Policy_start_date >= OthPol.Policy_start_date
    AND MercPol.Policy_start_date < OthPol.Policy_end_date
    AND MercPol.Policy_end_date >= OthPol.Policy_end_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory798237"><style>
#       table.tdhistory798237 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory798237 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory798237:last-child { text-align: left !important; }
#       tbody.tdhistory798237 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory798237 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory798237 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory798237"></th><th class="tdhistory798237">Policy_ID</th><th class="tdhistory798237">Customer_ID</th><th class="tdhistory798237">auto_make</th><th class="tdhistory798237">Policy_start_date</th><th class="tdhistory798237">Policy_end_date</th></tr></thead><tbody class="tdhistory798237 resultset-body"><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory798237">113521</td><td class="tdhistory798237">2294600</td><td class="tdhistory798237">Ford</td><td class="tdhistory798237">1991-04-13</td><td class="tdhistory798237">1992-04-13</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory798237">369786</td><td class="tdhistory798237">2645288</td><td class="tdhistory798237">Saab</td><td class="tdhistory798237">2011-11-25</td><td class="tdhistory798237">2012-11-25</td></tr><tr><th class="tdhistory798237" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistor ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Use the Temporal ValidTime function to display similar results as the query written above on table without Period datatype. </p>

# %%
VALIDTIME SELECT
    OthPol.Policy_id,
    OthPol.Customer_id,
    OthPol.auto_make
FROM
    DEMO_Insurance.policy_details MercPol
JOIN
    DEMO_Insurance.policy_details OthPol
ON
    MercPol.auto_make = 'Mercedes'
    AND MercPol.policy_state = 'IL'
    AND MercPol.auto_model = 'ML350'
    AND MercPol.policy_state = OthPol.Policy_state;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory301138"><style>
#       table.tdhistory301138 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory301138 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory301138:last-child { text-align: left !important; }
#       tbody.tdhistory301138 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory301138 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory301138 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory301138"></th><th class="tdhistory301138">Policy_ID</th><th class="tdhistory301138">Customer_ID</th><th class="tdhistory301138">auto_make</th><th class="tdhistory301138">VALIDTIME</th></tr></thead><tbody class="tdhistory301138 resultset-body"><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory301138">369786</td><td class="tdhistory301138">2645288</td><td class="tdhistory301138">Saab</td><td class="tdhistory301138">2022-11-25,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory301138">241562</td><td class="tdhistory301138">7017277</td><td class="tdhistory301138">Accura</td><td class="tdhistory301138">2022-01-22,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory301138">722747</td><td class="tdhistory301138">5900891</td><td class="tdhistory301138">Suburu</td><td class="tdhistory301138">2022-01-22,2022-09-02</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory301138">596790</td><td class="tdhistory301138">4781149</td><td class="tdhistory301138">Accura</td><td class="tdhistory301138">2022-01-22,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory301138">369786</td><td class="tdhistory301138">2645288</td><td class="tdhistory301138">Saab</td><td class="tdhistory301138">2022-01-22,2022-11-25</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory301138">976650</td><td class="tdhistory301138">5128749</td><td class="tdhistory301138">Ford</td><td class="tdhistory301138">2022-01-22,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory301138">722747</td><td class="tdhistory301138">5900891</td><td class="tdhistory301138">Suburu</td><td class="tdhistory301138">2022-09-02,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory301138">596790</td><td class="tdhistory301138">4781149</td><td class="tdhistory301138">Accura</td><td class="tdhistory301138">2022-01-22,2025-09-04</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory301138">533940</td><td class="tdhistory301138">4585664</td><td class="tdhistory301138">Audi</td><td class="tdhistory301138">2022-11-18,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory301138">787351</td><td class="tdhistory301138">5940419</td><td class="tdhistory301138">Saab</td><td class="tdhistory301138">2022-01-22,2024-04-28</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory301138">369048</td><td class="tdhistory301138">8120451</td><td class="tdhistory301138">Dodge</td><td class="tdhistory301138">2022-01-22,2022-06-05</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory301138">596790</td><td class="tdhistory301138">4781149</td><td class="tdhistory301138">Accura</td><td class="tdhistory301138">2022-01-22,9999-12-31</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory301138">533940</td><td class="tdhistory301138">4585664</td><td class="tdhistory301138">Audi</td><td class="tdhistory301138">2022-01-22,2022-11-18</td></tr><tr><th class="tdhistory301138" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory301138">787351</td><td class="tdhistory301138">5940419</td><td class="tdhistory301138">Saab</td><td class="tdhistory301138">2022-01-22,9999-12-31</td></tr><tr><th cl ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. Comparison for Queries with and without Temporal </b></p>

# %% [markdown]
# <table>
# <tr>
# <td style = 'font-size:18px;font-family:Arial;color:#00233C;font-weight:bold'>WITH TEMPORAL</td>
# <td style = 'font-size:16px;font-family:Arial;color:#00233C;font-weight:bold'>WITHOUT TEMPORAL</td>
# </tr>
#
# <tr>
# <td style = 'font-size:16px;font-family:Arial;color:#00233C'>Validtime select b.Policy_id, b.Customer_id, b.auto_make from policy_details a , policy_details b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state; </td>
# <td style = 'font-size:16px;font-family:Arial;color:#00233C'>select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date b.policy_start_date AND a.policy_end_date    UNION ALL
# select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date <= b.policy_start_date AND a.policy_end_date >= b.policy_end_date
#
#    UNION ALL
# select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date >= b.policy_start_date AND a.policy_end_date <= b.policy_end_date
#
#    UNION ALL
# select b.Policy_id, b.Customer_id, b.auto_make , b.Policy_start_date,b.Policy_end_date from policy_details_org_extrapolate a , policy_details_org_extrapolate b where a.auto_make = 'Mercedes' and a.policy_state = 'IL' and a.auto_model = 'ML350' and a.policy_state = b.Policy_state AND a.policy_start_date >= b.policy_start_date AND a.policy_start_date < b.policy_end_date AND a.policy_end_date >= b.policy_end_date;</td>
# </tr>
# </table>

# %% [markdown]
#  <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Performance Comparison for above queries </b> </p>

# %% [markdown]
# <img src="images/PerformanceMetrics.png" style="width:1000px;height:200px;">

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. Temporal concepts:- Aggregations </b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Comparing the Validity and VALIDTIME columns demonstrates that the
#     valid-time period of the result set is the intersection of the valid-time period in the original Policy table Validity
#     column with the Period specified in the sequenced select statement.</p>

# %%
SEQUENCED VALIDTIME PERIOD '(2009-01-01, 2009-12-31)'
SELECT
    Policy_ID,
    Customer_ID,
    Policy_Validity
FROM
    (
        SEQUENCED VALIDTIME SELECT
            Policy_details.*
        FROM
            DEMO_Insurance.Policy_Details
        WHERE
            policy_state = 'IN'
    ) AS my_derived_table;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory378169"><style>
#       table.tdhistory378169 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory378169 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory378169:last-child { text-align: left !important; }
#       tbody.tdhistory378169 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory378169 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory378169 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory378169"></th><th class="tdhistory378169">Policy_ID</th><th class="tdhistory378169">Customer_ID</th><th class="tdhistory378169">Policy_Validity</th><th class="tdhistory378169">VALIDTIME</th></tr></thead><tbody class="tdhistory378169 resultset-body"><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory378169">237423</td><td class="tdhistory378169">1133354</td><td class="tdhistory378169">2008-06-04,2009-06-04</td><td class="tdhistory378169">2009-01-01,2009-06-04</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory378169">550132</td><td class="tdhistory378169">3964730</td><td class="tdhistory378169">2008-01-04,2009-01-04</td><td class="tdhistory378169">2009-01-01,2009-01-04</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory378169">332897</td><td class="tdhistory378169">2540822</td><td class="tdhistory378169">2008-04-25,2009-04-25</td><td class="tdhistory378169">2009-01-01,2009-04-25</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory378169">535879</td><td class="tdhistory378169">8040359</td><td class="tdhistory378169">2009-03-05,2010-03-05</td><td class="tdhistory378169">2009-03-05,2009-12-31</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory378169">853360</td><td class="tdhistory378169">7409287</td><td class="tdhistory378169">2009-06-26,2010-06-26</td><td class="tdhistory378169">2009-06-26,2009-12-31</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory378169">582973</td><td class="tdhistory378169">8045031</td><td class="tdhistory378169">2008-06-11,2009-06-11</td><td class="tdhistory378169">2009-01-01,2009-06-11</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory378169">615121</td><td class="tdhistory378169">7625391</td><td class="tdhistory378169">2009-05-09,2010-05-09</td><td class="tdhistory378169">2009-05-09,2009-12-31</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory378169">866936</td><td class="tdhistory378169">4627650</td><td class="tdhistory378169">2008-07-07,2009-07-07</td><td class="tdhistory378169">2009-01-01,2009-07-07</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory378169">250833</td><td class="tdhistory378169">7877784</td><td class="tdhistory378169">2008-07-28,2009-07-28</td><td class="tdhistory378169">2009-01-01,2009-07-28</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory378169">913464</td><td class="tdhistory378169">6446834</td><td class="tdhistory378169">2009-01-21,2010-01-21</td><td class="tdhistory378169">2009-01-21,2009-12-31</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory378169">794956</td><td class="tdhistory378169">5647061</td><td class="tdhistory378169">2008-10-21,2009-10-21</td><td class="tdhistory378169">2009-01-01,2009-10-21</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory378169">698475</td><td class="tdhistory378169">6944752</td><td class="tdhistory378169">2008-12-17,2009-12-17</td><td class="tdhistory378169">2009-01-01,2009-12-17</td></tr><tr><th class="tdhistory378169" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory378169">751617</td><td class="tdhistory378169">2814337</td><td class="tdhistory378169">2009-12-22,2010-12-22</td><td class="tdhistory378169">2009-12-22,2009-12-31</td></tr><tr><th class="tdhistory378169" style= "background: rgba( ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Aggregations can be used for analysis of the data based on the validity period.
# Comparisons of data between different validity periods can be achieved with Temporal. Like the minimum and maximum premium amounts for a particular state based on the model of the cars.</p>

# %%
SEQUENCED VALIDTIME PERIOD (DATE '2011-01-01', DATE '2020-12-31')
SELECT
    auto_make,
    MIN(Policy_premium_Amt) AS MinPremium,
    MAX(Policy_premium_Amt) AS MaxPremium
FROM
    DEMO_Insurance.Policy_Details
WHERE
    policy_state = 'OH'
GROUP BY 1
ORDER BY VALIDTIME;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory138523"><style>
#       table.tdhistory138523 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory138523 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory138523:last-child { text-align: left !important; }
#       tbody.tdhistory138523 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory138523 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory138523 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory138523"></th><th class="tdhistory138523">auto_make</th><th class="tdhistory138523">MinPremium</th><th class="tdhistory138523">MaxPremium</th><th class="tdhistory138523">VALIDTIME</th></tr></thead><tbody class="tdhistory138523 resultset-body"><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory138523">Honda</td><td class="tdhistory138523">1203</td><td class="tdhistory138523">1453</td><td class="tdhistory138523">2011-01-01,2011-01-06</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory138523">Suburu</td><td class="tdhistory138523">1038</td><td class="tdhistory138523">1088</td><td class="tdhistory138523">2011-01-01,2011-01-12</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory138523">Mercedes</td><td class="tdhistory138523">667</td><td class="tdhistory138523">1783</td><td class="tdhistory138523">2011-01-01,2011-01-24</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory138523">Audi</td><td class="tdhistory138523">1050</td><td class="tdhistory138523">1714</td><td class="tdhistory138523">2011-01-01,2011-01-28</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory138523">Accura</td><td class="tdhistory138523">1489</td><td class="tdhistory138523">1489</td><td class="tdhistory138523">2011-01-01,2011-02-02</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory138523">BMW</td><td class="tdhistory138523">1052</td><td class="tdhistory138523">1307</td><td class="tdhistory138523">2011-01-01,2011-02-03</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory138523">Jeep</td><td class="tdhistory138523">830</td><td class="tdhistory138523">880</td><td class="tdhistory138523">2011-01-01,2011-02-11</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory138523">Toyota</td><td class="tdhistory138523">1338</td><td class="tdhistory138523">1338</td><td class="tdhistory138523">2011-01-01,2011-02-21</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory138523">Saab</td><td class="tdhistory138523">1484</td><td class="tdhistory138523">1539</td><td class="tdhistory138523">2011-01-01,2011-03-11</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory138523">Dodge</td><td class="tdhistory138523">998</td><td class="tdhistory138523">1305</td><td class="tdhistory138523">2011-01-01,2011-03-17</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory138523">Chevrolet</td><td class="tdhistory138523">1266</td><td class="tdhistory138523">1878</td><td class="tdhistory138523">2011-01-01,2011-05-04</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory138523">Nissan</td><td class="tdhistory138523">1080</td><td class="tdhistory138523">1405</td><td class="tdhistory138523">2011-01-01,2011-05-08</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory138523">Honda</td><td class="tdhistory138523">1203</td><td class="tdhistory138523">1453</td><td class="tdhistory138523">2011-01-06,2011-02-17</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory138523">Suburu</td><td class="tdhistory138523">1088</td><td class="tdhistory138523">1088</td><td class="tdhistory138523">2011-01-12,2011-06-06</td></tr><tr><th class="tdhistory138523" style= "background: rgba(243, 243, 243, 0.75 ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. Temporal concepts:- Validtime usage </b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b> Time line for various Policies:-    Analysis can be done for </b> </p>
#
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Policies valid during a particular period.</li>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Validity period of various policies.</li>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Premium amount collected during a particular period </li>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Using the As Of concept to verify the active policies on a particular date</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>On a given date, there was a hailstorm and we want to determine the count of policies in effect on that date
# The scenario mentioned here can be solved by the below query using the As of Date feature of Temporal tables
#  </p>

# %% [markdown]
# <img src="images/TemporalTimePeriod.png" style="width:600px;height:400px;">

# %%
VALIDTIME AS OF DATE '2022-02-15'
SELECT
    Policy_ID,
    Customer_ID,
    Policy_premium_Amt,
    Policy_Validity
FROM
    DEMO_Insurance.Policy_Details
WHERE
    policy_state = 'IL';
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory870887"><style>
#       table.tdhistory870887 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory870887 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory870887:last-child { text-align: left !important; }
#       tbody.tdhistory870887 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory870887 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory870887 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory870887"></th><th class="tdhistory870887">Policy_ID</th><th class="tdhistory870887">Customer_ID</th><th class="tdhistory870887">Policy_premium_Amt</th><th class="tdhistory870887">Policy_Validity</th></tr></thead><tbody class="tdhistory870887 resultset-body"><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory870887">369786</td><td class="tdhistory870887">2645288</td><td class="tdhistory870887">1316</td><td class="tdhistory870887">2017-11-25,2022-11-25</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory870887">241562</td><td class="tdhistory870887">7017277</td><td class="tdhistory870887">2197</td><td class="tdhistory870887">2021-01-28,9999-12-31</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory870887">722747</td><td class="tdhistory870887">5900891</td><td class="tdhistory870887">1582</td><td class="tdhistory870887">2017-09-02,2022-09-02</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory870887">596790</td><td class="tdhistory870887">4781149</td><td class="tdhistory870887">1254</td><td class="tdhistory870887">2020-09-04,9999-12-31</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory870887">533940</td><td class="tdhistory870887">4585664</td><td class="tdhistory870887">1456</td><td class="tdhistory870887">2017-11-18,2022-11-18</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory870887">976650</td><td class="tdhistory870887">5128749</td><td class="tdhistory870887">1247</td><td class="tdhistory870887">2021-08-28,9999-12-31</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory870887">369048</td><td class="tdhistory870887">8120451</td><td class="tdhistory870887">1627</td><td class="tdhistory870887">2017-06-05,2022-06-05</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory870887">596790</td><td class="tdhistory870887">4781149</td><td class="tdhistory870887">1254</td><td class="tdhistory870887">2020-09-04,2025-09-04</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory870887">490601</td><td class="tdhistory870887">6986977</td><td class="tdhistory870887">1348</td><td class="tdhistory870887">2017-08-04,2022-08-04</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory870887">787351</td><td class="tdhistory870887">5940419</td><td class="tdhistory870887">1830</td><td class="tdhistory870887">2019-04-28,2024-04-28</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory870887">137680</td><td class="tdhistory870887">8971909</td><td class="tdhistory870887">1986</td><td class="tdhistory870887">2019-06-03,9999-12-31</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory870887">596790</td><td class="tdhistory870887">4781149</td><td class="tdhistory870887">1254</td><td class="tdhistory870887">2020-09-04,9999-12-31</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory870887">908940</td><td class="tdhistory870887">3829512</td><td class="tdhistory870887">1561</td><td class="tdhistory870887">2021-06-11,9999-12-31</td></tr><tr><th class="tdhistory870887" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory870887">787351</td><td class="tdhistory870887">5940419</td><td class="tdhistory870887">1830</td><td class="tdhistory870887">2019-04-28,9999-12-31</td></tr><tr><th  ...

# %%
SELECT
    COUNT(*) AS "no of Policies"
FROM
    (
        VALIDTIME AS OF DATE '2022-02-15'
        SELECT
            Policy_ID,
            Customer_ID,
            Policy_premium_Amt,
            Policy_Validity
        FROM
            DEMO_Insurance.Policy_Details
        WHERE
            policy_state = 'IL'
    ) AS DerivTbl;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory415451"><style>
#       table.tdhistory415451 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory415451 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory415451:last-child { text-align: left !important; }
#       tbody.tdhistory415451 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory415451 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory415451 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory415451"></th><th class="tdhistory415451">no of Policies</th></tr></thead><tbody class="tdhistory415451 resultset-body"><tr><th class="tdhistory415451" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory415451">367</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Consider scenario where we need to check that for a particular period (here for year 2021) how many policies are valid for each auto make type and then compare the no of policies which are valid in the current period. This helps us in the comparison in the increase or decrease of policies for the current year as compared to the past year of validity
#  </p>

# %%
SELECT
    auto_make,
    COUNT(*) AS "no of Policies"
FROM
    (
        VALIDTIME PERIOD (DATE '2021-01-01', DATE '2021-12-31')
        SELECT
            Policy_ID,
            Customer_ID,
            Policy_premium_Amt,
            auto_make
        FROM
            DEMO_Insurance.Policy_Details
    ) AS DerivTbl
GROUP BY
    auto_make;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory654907"><style>
#       table.tdhistory654907 { display: block !important; min-height: 378px !important; overflow: auto !important; height: 378px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory654907 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory654907:last-child { text-align: left !important; }
#       tbody.tdhistory654907 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory654907 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory654907 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory654907"></th><th class="tdhistory654907">auto_make</th><th class="tdhistory654907">no of Policies</th></tr></thead><tbody class="tdhistory654907 resultset-body"><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory654907">Chevrolet</td><td class="tdhistory654907">23</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory654907">Honda</td><td class="tdhistory654907">13</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory654907">Mercedes</td><td class="tdhistory654907">10</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory654907">Ford</td><td class="tdhistory654907">28</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory654907">Suburu</td><td class="tdhistory654907">21</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory654907">Volkswagen</td><td class="tdhistory654907">28</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory654907">Dodge</td><td class="tdhistory654907">27</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory654907">Accura</td><td class="tdhistory654907">30</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory654907">Saab</td><td class="tdhistory654907">50</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory654907">Audi</td><td class="tdhistory654907">46</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory654907">BMW</td><td class="tdhistory654907">53</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory654907">Toyota</td><td class="tdhistory654907">31</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory654907">Jeep</td><td class="tdhistory654907">12</td></tr><tr><th class="tdhistory654907" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory654907">Nissan</td><td class="tdhistory654907">40</td></tr></tbody></table></div>

# %%
%chart x = auto_make, y = "no of Policies", title = 'Valid Number of Policies last year'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Now we check how many policies are still valid for each type using the current functionality
#  </p>

# %%
SELECT
    auto_make,
    COUNT(*) AS "no of Policies"
FROM
    (
        CURRENT VALIDTIME
        SELECT
            Policy_ID,
            Customer_ID,
            Policy_premium_Amt,
            auto_make
        FROM
            DEMO_Insurance.Policy_Details
    ) AS DerivTbl
GROUP BY
    auto_make;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory247657"><style>
#       table.tdhistory247657 { display: block !important; min-height: 378px !important; overflow: auto !important; height: 378px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory247657 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory247657:last-child { text-align: left !important; }
#       tbody.tdhistory247657 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory247657 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory247657 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory247657"></th><th class="tdhistory247657">auto_make</th><th class="tdhistory247657">no of Policies</th></tr></thead><tbody class="tdhistory247657 resultset-body"><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory247657">Chevrolet</td><td class="tdhistory247657">23</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory247657">Honda</td><td class="tdhistory247657">12</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory247657">Mercedes</td><td class="tdhistory247657">8</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory247657">Ford</td><td class="tdhistory247657">22</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory247657">Suburu</td><td class="tdhistory247657">20</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory247657">Volkswagen</td><td class="tdhistory247657">27</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory247657">Dodge</td><td class="tdhistory247657">25</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory247657">Accura</td><td class="tdhistory247657">26</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory247657">Saab</td><td class="tdhistory247657">47</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory247657">Audi</td><td class="tdhistory247657">41</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory247657">BMW</td><td class="tdhistory247657">44</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory247657">Toyota</td><td class="tdhistory247657">25</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory247657">Jeep</td><td class="tdhistory247657">10</td></tr><tr><th class="tdhistory247657" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory247657">Nissan</td><td class="tdhistory247657">38</td></tr></tbody></table></div>

# %%
%chart x = auto_make, y = "no of Policies", title = 'Current Valid Number of Policies'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In this scenario we are considering that there are a number of claims raised against policies on various incident dates. Below queries help to identify which claims made are in the validity period and which are not and which policies are valid at the time of the incidents. There are total 69 claims in the Insurance Claims tables and based on the incident date we can verify which claims are valid and which are not valid.
#  </p>

# %%
SELECT * FROM DEMO_Insurance.Insurance_Claims_Details;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory808087"><style>
#       table.tdhistory808087 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory808087 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory808087:last-child { text-align: left !important; }
#       tbody.tdhistory808087 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory808087 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory808087 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory808087"></th><th class="tdhistory808087">Policy_id</th><th class="tdhistory808087">Claim_id</th><th class="tdhistory808087">Incident_date</th><th class="tdhistory808087">claim_date</th><th class="tdhistory808087">Claim_amount</th></tr></thead><tbody class="tdhistory808087 resultset-body"><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory808087">369786</td><td class="tdhistory808087">81643</td><td class="tdhistory808087">2017-12-09</td><td class="tdhistory808087">2022-10-29</td><td class="tdhistory808087">2690</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory808087">241562</td><td class="tdhistory808087">50104</td><td class="tdhistory808087">2016-01-29</td><td class="tdhistory808087">2021-01-04</td><td class="tdhistory808087">897</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory808087">722747</td><td class="tdhistory808087">40408</td><td class="tdhistory808087">2017-09-19</td><td class="tdhistory808087">2022-07-30</td><td class="tdhistory808087">340</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory808087">515222</td><td class="tdhistory808087">42143</td><td class="tdhistory808087">2016-12-19</td><td class="tdhistory808087">2021-11-24</td><td class="tdhistory808087">2357</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory808087">533940</td><td class="tdhistory808087">44840</td><td class="tdhistory808087">2017-11-28</td><td class="tdhistory808087">2022-10-30</td><td class="tdhistory808087">333</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory808087">976650</td><td class="tdhistory808087">20789</td><td class="tdhistory808087">2016-08-24</td><td class="tdhistory808087">2021-07-31</td><td class="tdhistory808087">1917</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory808087">369048</td><td class="tdhistory808087">73048</td><td class="tdhistory808087">2017-06-11</td><td class="tdhistory808087">2022-05-31</td><td class="tdhistory808087">598</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory808087">212585</td><td class="tdhistory808087">73798</td><td class="tdhistory808087">2016-01-18</td><td class="tdhistory808087">2021-01-06</td><td class="tdhistory808087">2871</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory808087">490601</td><td class="tdhistory808087">61065</td><td class="tdhistory808087">2017-08-24</td><td class="tdhistory808087">2022-07-19</td><td class="tdhistory808087">1895</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory808087">235869</td><td class="tdhistory808087">30923</td><td class="tdhistory808087">2017-02-05</td><td class="tdhistory808087">2022-01-04</td><td class="tdhistory808087">680</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory808087">427204</td><td class="tdhistory808087">89437</td><td class="tdhistory808087">2017-04-02</td><td class="tdhistory808087">2022-03-17</td><td class="tdhistory808087">1723</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory808087">212585</td><td class="tdhistory808087">70760</td><td class="tdhistory808087">2016-01-17</td><td class="tdhistory808087">2020-12-27</td><td class="tdhistory808087">953</td></tr><tr><th class="tdhistory808087" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory808087">908940</td><td class="tdhistor ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Based on the Claims made, we need to validate which claims are valid on the incident date mentioned. Below query helps in the analysis. Only the rows that qualify for the claims are displayed.
#  </p>

# %%
SELECT
    'Valid Claims' AS ClaimType,
    Policy.customer_id,
    Policy.Policy_id,
    Insurance_Claims_Details.Claim_Id,
    Claim_amount
FROM
    (
        CURRENT VALIDTIME
        SELECT
            Policy_Details.*
        FROM
            DEMO_Insurance.Policy_Details
    ) Policy
INNER JOIN
    DEMO_Insurance.Insurance_Claims_Details
ON
    Policy.Policy_id = Insurance_Claims_Details.Policy_id
WHERE
    Policy.Policy_Validity CONTAINS Insurance_Claims_Details.Incident_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory310067"><style>
#       table.tdhistory310067 { display: block !important; min-height: 462px !important; overflow: auto !important; height: 462px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory310067 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory310067:last-child { text-align: left !important; }
#       tbody.tdhistory310067 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory310067 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory310067 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory310067"></th><th class="tdhistory310067">ClaimType</th><th class="tdhistory310067">Customer_ID</th><th class="tdhistory310067">Policy_ID</th><th class="tdhistory310067">Claim_id</th><th class="tdhistory310067">Claim_amount</th></tr></thead><tbody class="tdhistory310067 resultset-body"><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">1529583</td><td class="tdhistory310067">987529</td><td class="tdhistory310067">26822</td><td class="tdhistory310067">1718</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">3309391</td><td class="tdhistory310067">420948</td><td class="tdhistory310067">10845</td><td class="tdhistory310067">1725</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">7273220</td><td class="tdhistory310067">998870</td><td class="tdhistory310067">73876</td><td class="tdhistory310067">1668</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">8369854</td><td class="tdhistory310067">212585</td><td class="tdhistory310067">73798</td><td class="tdhistory310067">2871</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">1529583</td><td class="tdhistory310067">987529</td><td class="tdhistory310067">87775</td><td class="tdhistory310067">2686</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">6136627</td><td class="tdhistory310067">425636</td><td class="tdhistory310067">48934</td><td class="tdhistory310067">2061</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">7273220</td><td class="tdhistory310067">998870</td><td class="tdhistory310067">72944</td><td class="tdhistory310067">2404</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">8369854</td><td class="tdhistory310067">212585</td><td class="tdhistory310067">70760</td><td class="tdhistory310067">953</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">1024630</td><td class="tdhistory310067">925133</td><td class="tdhistory310067">87891</td><td class="tdhistory310067">1930</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">1681345</td><td class="tdhistory310067">264226</td><td class="tdhistory310067">43795</td><td class="tdhistory310067">417</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">4578802</td><td class="tdhistory310067">924323</td><td class="tdhistory310067">12122</td><td class="tdhistory310067">1601</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory310067">1024630</td><td class="tdhistory310067">925133</td><td class="tdhistory310067">51961</td><td class="tdhistory310067">1499</td></tr><tr><th class="tdhistory310067" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory310067">Valid Claims</td><td class="tdhistory3100 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Below query displays the Invalid rows from Claims table
#  </p>

# %%
SELECT
    customer_id,
    Policy.Policy_id,
    Claim_Id,
    Claim_amount
FROM
    DEMO_Insurance.Insurance_Claims_Details
INNER JOIN
    DEMO_Insurance.Policy_Details Policy
ON
    Policy.Policy_id = Insurance_Claims_Details.Policy_id
MINUS
SELECT
    Policy.customer_id,
    Policy.Policy_id,
    Insurance_Claims_Details.Claim_Id,
    Claim_amount
FROM
    (
        CURRENT VALIDTIME
        SELECT
            Policy_Details.*
        FROM
            DEMO_Insurance.Policy_Details
    ) Policy
INNER JOIN
    DEMO_Insurance.Insurance_Claims_Details
ON
    Policy.Policy_id = Insurance_Claims_Details.Policy_id
WHERE
    Policy.Policy_Validity CONTAINS Insurance_Claims_Details.Incident_date;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory249671"><style>
#       table.tdhistory249671 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory249671 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory249671:last-child { text-align: left !important; }
#       tbody.tdhistory249671 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory249671 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory249671 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory249671"></th><th class="tdhistory249671">Customer_ID</th><th class="tdhistory249671">Policy_ID</th><th class="tdhistory249671">Claim_id</th><th class="tdhistory249671">Claim_amount</th></tr></thead><tbody class="tdhistory249671 resultset-body"><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory249671">2205539</td><td class="tdhistory249671">735312</td><td class="tdhistory249671">67905</td><td class="tdhistory249671">844</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory249671">2660358</td><td class="tdhistory249671">444422</td><td class="tdhistory249671">80340</td><td class="tdhistory249671">2159</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory249671">4169839</td><td class="tdhistory249671">231513</td><td class="tdhistory249671">21119</td><td class="tdhistory249671">2927</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory249671">3048175</td><td class="tdhistory249671">651866</td><td class="tdhistory249671">75277</td><td class="tdhistory249671">2661</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory249671">5431902</td><td class="tdhistory249671">890333</td><td class="tdhistory249671">18394</td><td class="tdhistory249671">1216</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory249671">2153692</td><td class="tdhistory249671">356768</td><td class="tdhistory249671">41733</td><td class="tdhistory249671">2990</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory249671">5128749</td><td class="tdhistory249671">976650</td><td class="tdhistory249671">20789</td><td class="tdhistory249671">1917</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory249671">5646069</td><td class="tdhistory249671">651861</td><td class="tdhistory249671">48442</td><td class="tdhistory249671">2395</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory249671">5759783</td><td class="tdhistory249671">636550</td><td class="tdhistory249671">76261</td><td class="tdhistory249671">946</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory249671">6136627</td><td class="tdhistory249671">425636</td><td class="tdhistory249671">74004</td><td class="tdhistory249671">2485</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory249671">7706982</td><td class="tdhistory249671">426713</td><td class="tdhistory249671">10648</td><td class="tdhistory249671">1020</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory249671">1791348</td><td class="tdhistory249671">427204</td><td class="tdhistory249671">89437</td><td class="tdhistory249671">1723</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory249671">3829512</td><td class="tdhistory249671">908940</td><td class="tdhistory249671">36528</td><td class="tdhistory249671">998</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory249671">6151938</td><td class="tdhistory249671">594783</td><td class="tdhistory249671">62332</td><td class="tdhistory249671">2490</td></tr><tr><th class="tdhistory249671" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory249671">6901083</td><td class="tdhistory249671">932502</td><td class="tdhistory249671">82363</td><td class="tdhistory249671">2897</td></tr><tr ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>7. Explaining the Temporal Concepts of Inserts /Deletes </b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Customer 1 has policy 1 with Validity Period . In between the validity period the customer decides to change some factors which causes the premium to increase , so there will be a new addition which will insert a new row having validity period from changed date to the end of period. </p>
#
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Customer 2 has Policy 1 with validity period. In between the company decides to increase the premium which also increases the validity period.
#  </p>

# %% [markdown]
# <img src="images/Temporal_Inserts_Updates.png" style="width:600px;height:400px;">

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Inserting data into temporal table is simple for current validtime. </p>

# %%
CURRENT VALIDTIME INSERT DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
VALUES
    (203914, 2316038, 'OH', 1200, 'Audi', 'A3');
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Inserting history rows will need Temporal Qualifier. </p>

# %%
SEQUENCED VALIDTIME INSERT DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
VALUES
    (203914, 2316038, 'OH', 1050, 'Audi', 'A3', PERIOD(DATE '2002-06-10', DATE '2012-06-09'));

SEQUENCED VALIDTIME INSERT DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
VALUES
    (203914, 2316038, 'OH', 1150, 'Audi', 'A3', PERIOD(DATE '2012-06-10', DATE '2022-06-27'));
# Out:
# Success: 1 rows affected
# Success: 1 rows affected

# %%
SEQUENCED VALIDTIME
SELECT * 
FROM
    DEMO_Insurance.Policy_Details 
WHERE
    customer_id = 2316038 
ORDER BY
    validtime;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory180644"><style>
#       table.tdhistory180644 { display: block !important; min-height: 231px !important; overflow: auto !important; height: 231px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory180644 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory180644:last-child { text-align: left !important; }
#       tbody.tdhistory180644 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory180644 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory180644 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory180644"></th><th class="tdhistory180644">Policy_ID</th><th class="tdhistory180644">Customer_ID</th><th class="tdhistory180644">Policy_State</th><th class="tdhistory180644">Policy_premium_Amt</th><th class="tdhistory180644">auto_make</th><th class="tdhistory180644">auto_model</th><th class="tdhistory180644">Policy_Validity</th><th class="tdhistory180644">VALIDTIME</th></tr></thead><tbody class="tdhistory180644 resultset-body"><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1000</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2001-06-09,2002-06-09</td><td class="tdhistory180644">2001-06-09,2002-06-09</td></tr><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1050</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2002-06-10,2012-06-09</td><td class="tdhistory180644">2002-06-10,2012-06-09</td></tr><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1050</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2002-06-10,2012-06-09</td><td class="tdhistory180644">2002-06-10,2012-06-09</td></tr><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1150</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2012-06-10,2022-06-27</td><td class="tdhistory180644">2012-06-10,2022-06-27</td></tr><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1150</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2012-06-10,2022-06-27</td><td class="tdhistory180644">2012-06-10,2022-06-27</td></tr><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1200</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2022-06-28,9999-12-31</td><td class="tdhistory180644">2022-06-28,9999-12-31</td></tr><tr><th class="tdhistory180644" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory180644">203914</td><td class="tdhistory180644">2316038</td><td class="tdhistory180644">OH  </td><td class="tdhistory180644">1200</td><td class="tdhistory180644">Audi</td><td class="tdhistory180644">A3</td><td class="tdhistory180644">2023-12-21,9999-12-31</td><td class="tdhistory180644">2023-12-21,9999-12-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Without Temporal Qualifier the select will display only current rows. </p>

# %%
SET SESSION CURRENT VALIDTIME;
# Out:
# Success: 1 rows affected

# %%
SELECT *
FROM 
    DEMO_Insurance.Policy_Details
WHERE
    customer_id = 2316038
ORDER BY
    Policy_validity;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory643887"><style>
#       table.tdhistory643887 { display: block !important; min-height: 126px !important; overflow: auto !important; height: 126px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory643887 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory643887:last-child { text-align: left !important; }
#       tbody.tdhistory643887 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory643887 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory643887 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory643887"></th><th class="tdhistory643887">Policy_ID</th><th class="tdhistory643887">Customer_ID</th><th class="tdhistory643887">Policy_State</th><th class="tdhistory643887">Policy_premium_Amt</th><th class="tdhistory643887">auto_make</th><th class="tdhistory643887">auto_model</th><th class="tdhistory643887">Policy_Validity</th></tr></thead><tbody class="tdhistory643887 resultset-body"><tr><th class="tdhistory643887" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory643887">203914</td><td class="tdhistory643887">2316038</td><td class="tdhistory643887">OH  </td><td class="tdhistory643887">1200</td><td class="tdhistory643887">Audi</td><td class="tdhistory643887">A3</td><td class="tdhistory643887">2022-06-28,9999-12-31</td></tr><tr><th class="tdhistory643887" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory643887">203914</td><td class="tdhistory643887">2316038</td><td class="tdhistory643887">OH  </td><td class="tdhistory643887">1200</td><td class="tdhistory643887">Audi</td><td class="tdhistory643887">A3</td><td class="tdhistory643887">2023-12-21,9999-12-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>When period is specified , Delete will only delete rows for that specific period (highlighted row in the above dataset) and the validity period for rows will change to the end of period specified in the delete. </p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Display rows for Specific Valid Period.</p>

# %%
SEQUENCED VALIDTIME PERIOD '(1990-01-01, 1990-03-31)'
SELECT * 
FROM
    DEMO_Insurance.Policy_details
WHERE
    policy_state = 'IN'
ORDER BY
    validtime;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory498299"><style>
#       table.tdhistory498299 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory498299 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory498299:last-child { text-align: left !important; }
#       tbody.tdhistory498299 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory498299 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory498299 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory498299"></th><th class="tdhistory498299">Policy_ID</th><th class="tdhistory498299">Customer_ID</th><th class="tdhistory498299">Policy_State</th><th class="tdhistory498299">Policy_premium_Amt</th><th class="tdhistory498299">auto_make</th><th class="tdhistory498299">auto_model</th><th class="tdhistory498299">Policy_Validity</th><th class="tdhistory498299">VALIDTIME</th></tr></thead><tbody class="tdhistory498299 resultset-body"><tr><th class="tdhistory498299" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory498299">529112</td><td class="tdhistory498299">1965883</td><td class="tdhistory498299">IN  </td><td class="tdhistory498299">1240</td><td class="tdhistory498299">Honda</td><td class="tdhistory498299">Civic</td><td class="tdhistory498299">1990-01-30,1991-01-08</td><td class="tdhistory498299">1990-01-30,1990-03-31</td></tr><tr><th class="tdhistory498299" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory498299">171183</td><td class="tdhistory498299">3976603</td><td class="tdhistory498299">IN  </td><td class="tdhistory498299">671</td><td class="tdhistory498299">Ford</td><td class="tdhistory498299">Escape</td><td class="tdhistory498299">1990-02-01,1991-02-01</td><td class="tdhistory498299">1990-02-01,1990-03-31</td></tr><tr><th class="tdhistory498299" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory498299">598554</td><td class="tdhistory498299">7535602</td><td class="tdhistory498299">IN  </td><td class="tdhistory498299">795</td><td class="tdhistory498299">Nissan</td><td class="tdhistory498299">Maxima</td><td class="tdhistory498299">1990-02-14,1991-02-14</td><td class="tdhistory498299">1990-02-14,1990-03-31</td></tr><tr><th class="tdhistory498299" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory498299">728025</td><td class="tdhistory498299">4414390</td><td class="tdhistory498299">IN  </td><td class="tdhistory498299">1935</td><td class="tdhistory498299">Mercedes</td><td class="tdhistory498299">E400</td><td class="tdhistory498299">1990-02-15,1991-02-15</td><td class="tdhistory498299">1990-02-15,1990-03-31</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Delete rows for Specific Valid Period will change the validity period to the end date specified in delete. </p>

# %%
SEQUENCED VALIDTIME PERIOD '(1990-01-01, 1990-01-30)'
DELETE FROM
    DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
WHERE
    policy_state = 'IN';
# Out:
# Success: 0 rows affected

# %%
SEQUENCED VALIDTIME PERIOD '(1990-01-01, 1990-03-31)'
SELECT * 
FROM
    DEMO_Insurance_DB.DEMO_Insurance_Policy_Det
WHERE
    policy_state = 'IN'
ORDER BY
    validtime;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory618110"><style>
#       table.tdhistory618110 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory618110 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory618110:last-child { text-align: left !important; }
#       tbody.tdhistory618110 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory618110 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory618110 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory618110"></th><th class="tdhistory618110">Policy_ID</th><th class="tdhistory618110">Customer_ID</th><th class="tdhistory618110">Policy_State</th><th class="tdhistory618110">Policy_premium_Amt</th><th class="tdhistory618110">auto_make</th><th class="tdhistory618110">auto_model</th><th class="tdhistory618110">VALIDTIME</th></tr></thead><tbody class="tdhistory618110 resultset-body"><tr><th class="tdhistory618110" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory618110">529112</td><td class="tdhistory618110">1965883</td><td class="tdhistory618110">IN  </td><td class="tdhistory618110">1240</td><td class="tdhistory618110">Honda</td><td class="tdhistory618110">Civic</td><td class="tdhistory618110">1990-01-30,1990-03-31</td></tr><tr><th class="tdhistory618110" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory618110">171183</td><td class="tdhistory618110">3976603</td><td class="tdhistory618110">IN  </td><td class="tdhistory618110">671</td><td class="tdhistory618110">Ford</td><td class="tdhistory618110">Escape</td><td class="tdhistory618110">1990-02-01,1990-03-31</td></tr><tr><th class="tdhistory618110" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory618110">598554</td><td class="tdhistory618110">7535602</td><td class="tdhistory618110">IN  </td><td class="tdhistory618110">795</td><td class="tdhistory618110">Nissan</td><td class="tdhistory618110">Maxima</td><td class="tdhistory618110">1990-02-14,1990-03-31</td></tr><tr><th class="tdhistory618110" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory618110">728025</td><td class="tdhistory618110">4414390</td><td class="tdhistory618110">IN  </td><td class="tdhistory618110">1935</td><td class="tdhistory618110">Mercedes</td><td class="tdhistory618110">E400</td><td class="tdhistory618110">1990-02-15,1990-03-31</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>8. Bi-Temporal Table with ValidTime and TransactionTime Columns and its usage.</b> </p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Bi-Temporal tables or Transaction time tables have both Valid Date(Date) Columns and Transaction Time (Timestamp) Columns. Transaction time is the time period during which a fact, represented by all the information in a row, is or was known to be in effect in the database. It models the database reality, recording when rows have been added, modified, and changed in the database. Transaction-time periods are stored in a transaction-time column:</p>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>The beginning of the transaction-time period is the time when the database became aware of a row, when the row was first recorded in the database. This is when the row was added to a table.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>The end of a transaction time period reflects when the fact was superseded by an update to the row, or when the row was deleted from the database. Rows containing information that is currently in effect have transaction-time periods with indefinite ending bounds, represented as UNTIL_CLOSED.</li>
# </p>
#
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Thus, temporal features can help in simplifying time dependent applications. Temporal and Bi-Temporal tables can be analyzed and used in various scenarios.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>9. Cleanup </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_Insurance');    -- Takes about 10 seconds, optional if you want to use the data later
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory360390"><style>
#       table.tdhistory360390 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory360390 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory360390:last-child { text-align: left !important; }
#       tbody.tdhistory360390 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory360390 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory360390 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory360390"></th><th class="tdhistory360390">Message</th></tr></thead><tbody class="tdhistory360390 resultset-body"><tr><th class="tdhistory360390" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory360390">Removed objects related to DEMO_Insurance. That ran for 0:00:02.61</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Reference Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#     <li>Information about Temporal datatype can be found at: <a href = 'https://docs.teradata.com/search/all?query=Tempora<hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>able+Support&content-lang=en-US'>https://docs.teradata.com/search/all?query=Temporal+Table+Support&content-lang=en-US</a></li>
# </ul>

# %% [markdown]
# <footer style="padding-bottom:35px; background:#f9f9f9; border-bottom:3px solid #00233C">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2023. All Rights Reserved
#         </div>
#     </div>
# </footer>
