# %%
%connect local
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user'

# %%
DROP TABLE pd_speech_features
# Out:
# Success: 770 rows affected

# %%
CREATE MULTISET TABLE pd_speech_features ,FALLBACK ,
     NO BEFORE JOURNAL,
     NO AFTER JOURNAL,
     CHECKSUM = DEFAULT,
     DEFAULT MERGEBLOCKRATIO,
     MAP = TD_MAP1
     (
      id BIGINT,
      gender BIGINT,
      PPE FLOAT,
      DFA FLOAT,
      RPDE FLOAT,
      numPulses BIGINT,
      numPeriodsPulses BIGINT,
      meanPeriodPulses FLOAT,
      stdDevPeriodPulses FLOAT,
      locPctJitter FLOAT,
      locAbsJitter FLOAT,
      rapJitter FLOAT,
      ppq5Jitter FLOAT,
      ddpJitter FLOAT,
      locShimmer FLOAT,
      locDbShimmer FLOAT,
      apq3Shimmer FLOAT,
      apq5Shimmer FLOAT,
      apq11Shimmer FLOAT,
      ddaShimmer FLOAT,
      meanAutoCorrHarmonicity FLOAT,
      meanNoiseToHarmHarmonicity FLOAT,
      meanHarmToNoiseHarmonicity FLOAT,
      minIntensity FLOAT,
      maxIntensity FLOAT,
      meanIntensity FLOAT,
      f1 FLOAT,
      f2 FLOAT,
      f3 FLOAT,
      f4 FLOAT,
      b1 FLOAT,
      b2 FLOAT,
      b3 FLOAT,
      b4 FLOAT,
      GQ_prc5_95 FLOAT,
      GQ_std_cycle_open FLOAT,
      GQ_std_cycle_closed FLOAT,
      GNE_mean FLOAT,
      GNE_std FLOAT,
      GNE_SNR_TKEO FLOAT,
      GNE_SNR_SEO FLOAT,
      GNE_NSR_TKEO FLOAT,
      GNE_NSR_SEO FLOAT,
      VFER_mean FLOAT,
      VFER_std FLOAT,
      VFER_entropy FLOAT,
      VFER_SNR_TKEO FLOAT,
      VFER_SNR_SEO FLOAT,
      VFER_NSR_TKEO FLOAT,
      VFER_NSR_SEO FLOAT,
      IMF_SNR_SEO FLOAT,
      IMF_SNR_TKEO FLOAT,
      IMF_SNR_entropy FLOAT,
      IMF_NSR_SEO FLOAT,
      IMF_NSR_TKEO FLOAT,
      IMF_NSR_entropy FLOAT,
      mean_Log_energy FLOAT,
      mean_MFCC_0th_coef FLOAT,
      mean_MFCC_1st_coef FLOAT,
      mean_MFCC_2nd_coef FLOAT,
      mean_MFCC_3rd_coef FLOAT,
      mean_MFCC_4th_coef FLOAT,
      mean_MFCC_5th_coef FLOAT,
      mean_MFCC_6th_coef FLOAT,
      mean_MFCC_7th_coef FLOAT,
      mean_MFCC_8th_coef FLOAT,
      mean_MFCC_9th_coef FLOAT,
      mean_MFCC_10th_coef FLOAT,
      mean_MFCC_11th_coef FLOAT,
      mean_MFCC_12th_coef FLOAT,
      mean_delta_log_energy FLOAT,
      mean_0th_delta FLOAT,
      mean_1st_delta FLOAT,
      mean_2nd_delta FLOAT,
      mean_3rd_delta FLOAT,
      mean_4th_delta FLOAT,
      mean_5th_delta FLOAT,
      mean_6th_delta FLOAT,
      mean_7th_delta FLOAT,
      mean_8th_delta FLOAT,
      mean_9th_delta FLOAT,
      mean_10th_delta FLOAT,
      mean_11th_delta FLOAT,
      mean_12th_delta FLOAT,
      mean_delta_delta_log_energy FLOAT,
      mean_delta_delta_0th FLOAT,
      mean_1st_delta_delta FLOAT,
      mean_2nd_delta_delta FLOAT,
      mean_3rd_delta_delta FLOAT,
      mean_4th_delta_delta FLOAT,
      mean_5th_delta_delta FLOAT,
      mean_6th_delta_delta FLOAT,
      mean_7th_delta_delta FLOAT,
      mean_8th_delta_delta FLOAT,
      mean_9th_delta_delta FLOAT,
      mean_10th_delta_delta FLOAT,
      mean_11th_delta_delta FLOAT,
      mean_12th_delta_delta FLOAT,
      std_Log_energy FLOAT,
      std_MFCC_0th_coef FLOAT,
      std_MFCC_1st_coef FLOAT,
      std_MFCC_2nd_coef FLOAT,
      std_MFCC_3rd_coef FLOAT,
      std_MFCC_4th_coef FLOAT,
      std_MFCC_5th_coef FLOAT,
      std_MFCC_6th_coef FLOAT,
      std_MFCC_7th_coef FLOAT,
      std_MFCC_8th_coef FLOAT,
      std_MFCC_9th_coef FLOAT,
      std_MFCC_10th_coef FLOAT,
      std_MFCC_11th_coef FLOAT,
      std_MFCC_12th_coef FLOAT,
      std_delta_log_energy FLOAT,
      std_0th_delta FLOAT,
      std_1st_delta FLOAT,
      std_2nd_delta FLOAT,
      std_3rd_delta FLOAT,
      std_4th_delta FLOAT,
      std_5th_delta FLOAT,
      std_6th_delta FLOAT,
      std_7th_delta FLOAT,
      std_8th_delta FLOAT,
      std_9th_delta FLOAT,
      std_10th_delta FLOAT,
      std_11th_delta FLOAT,
      std_12th_delta FLOAT,
      std_delta_delta_log_energy FLOAT,
      std_delta_delta_0th FLOAT,
      std_1st_delta_delta FLOAT,
      std_2nd_delta_delta FLOAT,
      std_3rd_delta_delta FLOAT,
      std_4th_delta_delta FLOAT,
      std_5th_delta_delta FLOAT,
      std_6th_delta_delta FLOAT,
      std_7th_delta_delta FLOAT,
      std_8th_delta_delta FLOAT,
      std_9th_delta_delta FLOAT,
      std_10th_delta_delta FLOAT,
      std_11th_delta_delta FLOAT,
      std_12th_delta_delta FLOAT,
      Ea FLOAT,
      Ed_1_coef FLOAT,
      Ed_2_coef FLOAT,
      Ed_3_coef FLOAT,
      Ed_4_coef FLOAT,
      Ed_5_coef FLOAT,
      Ed_6_coef FLOAT,
      Ed_7_coef FLOAT,
      Ed_8_coef FLOAT,
      Ed_9_coef FLOAT,
      Ed_10_coef FLOAT,
      det_entropy_shannon_1_coef FLOAT,
      det_entropy_shannon_2_coef FLOAT,
      det_entropy_shannon_3_coef FLOAT,
      det_entropy_shannon_4_coef FLOAT,
      det_entropy_shannon_5_coef FLOAT,
      det_entropy_shannon_6_coef FLOAT,
      det_entropy_shannon_7_coef FLOAT,
      det_entropy_shannon_8_coef FLOAT,
      det_entropy_shannon_9_coef FLOAT,
      det_entropy_shannon_10_coef FLOAT,
      det_entropy_log_1_coef FLOAT,
      det_entropy_log_2_coef FLOAT,
      det_entropy_log_3_coef FLOAT,
      det_entropy_log_4_coef FLOAT,
      det_entropy_log_5_coef FLOAT,
      det_entropy_log_6_coef FLOAT,
      det_entropy_log_7_coef FLOAT,
      det_entropy_log_8_coef FLOAT,
      det_entropy_log_9_coef FLOAT,
      det_entropy_log_10_coef FLOAT,
      det_TKEO_mean_1_coef FLOAT,
      det_TKEO_mean_2_coef FLOAT,
      det_TKEO_mean_3_coef FLOAT,
      det_TKEO_mean_4_coef FLOAT,
      det_TKEO_mean_5_coef FLOAT,
      det_TKEO_mean_6_coef FLOAT,
      det_TKEO_mean_7_coef FLOAT,
      det_TKEO_mean_8_coef FLOAT,
      det_TKEO_mean_9_coef FLOAT,
      det_TKEO_mean_10_coef FLOAT,
      det_TKEO_std_1_coef FLOAT,
      det_TKEO_std_2_coef FLOAT,
      det_TKEO_std_3_coef FLOAT,
      det_TKEO_std_4_coef FLOAT,
      det_TKEO_std_5_coef FLOAT,
      det_TKEO_std_6_coef FLOAT,
      det_TKEO_std_7_coef FLOAT,
      det_TKEO_std_8_coef FLOAT,
      det_TKEO_std_9_coef FLOAT,
      det_TKEO_std_10_coef FLOAT,
      app_entropy_shannon_1_coef FLOAT,
      app_entropy_shannon_2_coef FLOAT,
      app_entropy_shannon_3_coef FLOAT,
      app_entropy_shannon_4_coef FLOAT,
      app_entropy_shannon_5_coef FLOAT,
      app_entropy_shannon_6_coef FLOAT,
      app_entropy_shannon_7_coef FLOAT,
      app_entropy_shannon_8_coef FLOAT,
      app_entropy_shannon_9_coef FLOAT,
      app_entropy_shannon_10_coef BIGINT,
      app_entropy_log_1_coef FLOAT,
      app_entropy_log_2_coef FLOAT,
      app_entropy_log_3_coef FLOAT,
      app_entropy_log_4_coef FLOAT,
      app_entropy_log_5_coef FLOAT,
      app_entropy_log_6_coef FLOAT,
      app_entropy_log_7_coef FLOAT,
      app_entropy_log_8_coef FLOAT,
      app_entropy_log_9_coef FLOAT,
      app_entropy_log_10_coef FLOAT,
      app_det_TKEO_mean_1_coef FLOAT,
      app_det_TKEO_mean_2_coef FLOAT,
      app_det_TKEO_mean_3_coef FLOAT,
      app_det_TKEO_mean_4_coef FLOAT,
      app_det_TKEO_mean_5_coef FLOAT,
      app_det_TKEO_mean_6_coef FLOAT,
      app_det_TKEO_mean_7_coef FLOAT,
      app_det_TKEO_mean_8_coef FLOAT,
      app_det_TKEO_mean_9_coef FLOAT,
      app_det_TKEO_mean_10_coef FLOAT,
      app_TKEO_std_1_coef FLOAT,
      app_TKEO_std_2_coef FLOAT,
      app_TKEO_std_3_coef FLOAT,
      app_TKEO_std_4_coef FLOAT,
      app_TKEO_std_5_coef FLOAT,
      app_TKEO_std_6_coef FLOAT,
      app_TKEO_std_7_coef FLOAT,
      app_TKEO_std_8_coef FLOAT,
      app_TKEO_std_9_coef FLOAT,
      app_TKEO_std_10_coef FLOAT,
      Ea2 FLOAT,
      Ed2_1_coef FLOAT,
      Ed2_2_coef FLOAT,
      Ed2_3_coef FLOAT,
      Ed2_4_coef FLOAT,
      Ed2_5_coef FLOAT,
      Ed2_6_coef FLOAT,
      Ed2_7_coef FLOAT,
      Ed2_8_coef FLOAT,
      Ed2_9_coef FLOAT,
      Ed2_10_coef FLOAT,
      det_LT_entropy_shannon_1_coef FLOAT,
      det_LT_entropy_shannon_2_coef FLOAT,
      det_LT_entropy_shannon_3_coef FLOAT,
      det_LT_entropy_shannon_4_coef FLOAT,
      det_LT_entropy_shannon_5_coef FLOAT,
      det_LT_entropy_shannon_6_coef FLOAT,
      det_LT_entropy_shannon_7_coef FLOAT,
      det_LT_entropy_shannon_8_coef FLOAT,
      det_LT_entropy_shannon_9_coef FLOAT,
      det_LT_entropy_shannon_10_coef FLOAT,
      det_LT_entropy_log_1_coef FLOAT,
      det_LT_entropy_log_2_coef FLOAT,
      det_LT_entropy_log_3_coef FLOAT,
      det_LT_entropy_log_4_coef FLOAT,
      det_LT_entropy_log_5_coef FLOAT,
      det_LT_entropy_log_6_coef FLOAT,
      det_LT_entropy_log_7_coef FLOAT,
      det_LT_entropy_log_8_coef FLOAT,
      det_LT_entropy_log_9_coef FLOAT,
      det_LT_entropy_log_10_coef FLOAT,
      det_LT_TKEO_mean_1_coef FLOAT,
      det_LT_TKEO_mean_2_coef FLOAT,
      det_LT_TKEO_mean_3_coef FLOAT,
      det_LT_TKEO_mean_4_coef FLOAT,
      det_LT_TKEO_mean_5_coef FLOAT,
      det_LT_TKEO_mean_6_coef FLOAT,
      det_LT_TKEO_mean_7_coef FLOAT,
      det_LT_TKEO_mean_8_coef FLOAT,
      det_LT_TKEO_mean_9_coef FLOAT,
      det_LT_TKEO_mean_10_coef FLOAT,
      det_LT_TKEO_std_1_coef FLOAT,
      det_LT_TKEO_std_2_coef FLOAT,
      det_LT_TKEO_std_3_coef FLOAT,
      det_LT_TKEO_std_4_coef FLOAT,
      det_LT_TKEO_std_5_coef FLOAT,
      det_LT_TKEO_std_6_coef FLOAT,
      det_LT_TKEO_std_7_coef FLOAT,
      det_LT_TKEO_std_8_coef FLOAT,
      det_LT_TKEO_std_9_coef FLOAT,
      det_LT_TKEO_std_10_coef FLOAT,
      app_LT_entropy_shannon_1_coef FLOAT,
      app_LT_entropy_shannon_2_coef FLOAT,
      app_LT_entropy_shannon_3_coef FLOAT,
      app_LT_entropy_shannon_4_coef FLOAT,
      app_LT_entropy_shannon_5_coef FLOAT,
      app_LT_entropy_shannon_6_coef FLOAT,
      app_LT_entropy_shannon_7_coef FLOAT,
      app_LT_entropy_shannon_8_coef FLOAT,
      app_LT_entropy_shannon_9_coef FLOAT,
      app_LT_entropy_shannon_10_coef FLOAT,
      app_LT_entropy_log_1_coef FLOAT,
      app_LT_entropy_log_2_coef FLOAT,
      app_LT_entropy_log_3_coef FLOAT,
      app_LT_entropy_log_4_coef FLOAT,
      app_LT_entropy_log_5_coef FLOAT,
      app_LT_entropy_log_6_coef FLOAT,
      app_LT_entropy_log_7_coef FLOAT,
      app_LT_entropy_log_8_coef FLOAT,
      app_LT_entropy_log_9_coef FLOAT,
      app_LT_entropy_log_10_coef FLOAT,
      app_LT_TKEO_mean_1_coef FLOAT,
      app_LT_TKEO_mean_2_coef FLOAT,
      app_LT_TKEO_mean_3_coef FLOAT,
      app_LT_TKEO_mean_4_coef FLOAT,
      app_LT_TKEO_mean_5_coef FLOAT,
      app_LT_TKEO_mean_6_coef FLOAT,
      app_LT_TKEO_mean_7_coef FLOAT,
      app_LT_TKEO_mean_8_coef FLOAT,
      app_LT_TKEO_mean_9_coef FLOAT,
      app_LT_TKEO_mean_10_coef FLOAT,
      app_LT_TKEO_std_1_coef FLOAT,
      app_LT_TKEO_std_2_coef FLOAT,
      app_LT_TKEO_std_3_coef FLOAT,
      app_LT_TKEO_std_4_coef FLOAT,
      app_LT_TKEO_std_5_coef FLOAT,
      app_LT_TKEO_std_6_coef FLOAT,
      app_LT_TKEO_std_7_coef FLOAT,
      app_LT_TKEO_std_8_coef FLOAT,
      app_LT_TKEO_std_9_coef FLOAT,
      app_LT_TKEO_std_10_coef FLOAT,
      tqwt_energy_dec_1 FLOAT,
      tqwt_energy_dec_2 FLOAT,
      tqwt_energy_dec_3 FLOAT,
      tqwt_energy_dec_4 FLOAT,
      tqwt_energy_dec_5 FLOAT,
      tqwt_energy_dec_6 FLOAT,
      tqwt_energy_dec_7 FLOAT,
      tqwt_energy_dec_8 FLOAT,
      tqwt_energy_dec_9 FLOAT,
      tqwt_energy_dec_10 FLOAT,
      tqwt_energy_dec_11 FLOAT,
      tqwt_energy_dec_12 FLOAT,
      tqwt_energy_dec_13 FLOAT,
      tqwt_energy_dec_14 FLOAT,
      tqwt_energy_dec_15 FLOAT,
      tqwt_energy_dec_16 FLOAT,
      tqwt_energy_dec_17 FLOAT,
      tqwt_energy_dec_18 FLOAT,
      tqwt_energy_dec_19 FLOAT,
      tqwt_energy_dec_20 FLOAT,
      tqwt_energy_dec_21 FLOAT,
      tqwt_energy_dec_22 FLOAT,
      tqwt_energy_dec_23 FLOAT,
      tqwt_energy_dec_24 FLOAT,
      tqwt_energy_dec_25 FLOAT,
      tqwt_energy_dec_26 FLOAT,
      tqwt_energy_dec_27 FLOAT,
      tqwt_energy_dec_28 FLOAT,
      tqwt_energy_dec_29 FLOAT,
      tqwt_energy_dec_30 FLOAT,
      tqwt_energy_dec_31 FLOAT,
      tqwt_energy_dec_32 FLOAT,
      tqwt_energy_dec_33 FLOAT,
      tqwt_energy_dec_34 FLOAT,
      tqwt_energy_dec_35 FLOAT,
      tqwt_energy_dec_36 FLOAT,
      tqwt_entropy_shannon_dec_1 FLOAT,
      tqwt_entropy_shannon_dec_2 FLOAT,
      tqwt_entropy_shannon_dec_3 FLOAT,
      tqwt_entropy_shannon_dec_4 FLOAT,
      tqwt_entropy_shannon_dec_5 FLOAT,
      tqwt_entropy_shannon_dec_6 FLOAT,
      tqwt_entropy_shannon_dec_7 FLOAT,
      tqwt_entropy_shannon_dec_8 FLOAT,
      tqwt_entropy_shannon_dec_9 FLOAT,
      tqwt_entropy_shannon_dec_10 FLOAT,
      tqwt_entropy_shannon_dec_11 FLOAT,
      tqwt_entropy_shannon_dec_12 FLOAT,
      tqwt_entropy_shannon_dec_13 FLOAT,
      tqwt_entropy_shannon_dec_14 FLOAT,
      tqwt_entropy_shannon_dec_15 FLOAT,
      tqwt_entropy_shannon_dec_16 FLOAT,
      tqwt_entropy_shannon_dec_17 FLOAT,
      tqwt_entropy_shannon_dec_18 FLOAT,
      tqwt_entropy_shannon_dec_19 FLOAT,
      tqwt_entropy_shannon_dec_20 FLOAT,
      tqwt_entropy_shannon_dec_21 FLOAT,
      tqwt_entropy_shannon_dec_22 FLOAT,
      tqwt_entropy_shannon_dec_23 FLOAT,
      tqwt_entropy_shannon_dec_24 FLOAT,
      tqwt_entropy_shannon_dec_25 FLOAT,
      tqwt_entropy_shannon_dec_26 FLOAT,
      tqwt_entropy_shannon_dec_27 FLOAT,
      tqwt_entropy_shannon_dec_28 FLOAT,
      tqwt_entropy_shannon_dec_29 FLOAT,
      tqwt_entropy_shannon_dec_30 FLOAT,
      tqwt_entropy_shannon_dec_31 FLOAT,
      tqwt_entropy_shannon_dec_32 FLOAT,
      tqwt_entropy_shannon_dec_33 FLOAT,
      tqwt_entropy_shannon_dec_34 FLOAT,
      tqwt_entropy_shannon_dec_35 FLOAT,
      tqwt_entropy_shannon_dec_36 FLOAT,
      tqwt_entropy_log_dec_1 FLOAT,
      tqwt_entropy_log_dec_2 FLOAT,
      tqwt_entropy_log_dec_3 FLOAT,
      tqwt_entropy_log_dec_4 FLOAT,
      tqwt_entropy_log_dec_5 FLOAT,
      tqwt_entropy_log_dec_6 FLOAT,
      tqwt_entropy_log_dec_7 FLOAT,
      tqwt_entropy_log_dec_8 FLOAT,
      tqwt_entropy_log_dec_9 FLOAT,
      tqwt_entropy_log_dec_10 FLOAT,
      tqwt_entropy_log_dec_11 FLOAT,
      tqwt_entropy_log_dec_12 FLOAT,
      tqwt_entropy_log_dec_13 FLOAT,
      tqwt_entropy_log_dec_14 FLOAT,
      tqwt_entropy_log_dec_15 FLOAT,
      tqwt_entropy_log_dec_16 FLOAT,
      tqwt_entropy_log_dec_17 FLOAT,
      tqwt_entropy_log_dec_18 FLOAT,
      tqwt_entropy_log_dec_19 FLOAT,
      tqwt_entropy_log_dec_20 FLOAT,
      tqwt_entropy_log_dec_21 FLOAT,
      tqwt_entropy_log_dec_22 FLOAT,
      tqwt_entropy_log_dec_23 FLOAT,
      tqwt_entropy_log_dec_24 FLOAT,
      tqwt_entropy_log_dec_25 FLOAT,
      tqwt_entropy_log_dec_26 FLOAT,
      tqwt_entropy_log_dec_27 FLOAT,
      tqwt_entropy_log_dec_28 FLOAT,
      tqwt_entropy_log_dec_29 FLOAT,
      tqwt_entropy_log_dec_30 FLOAT,
      tqwt_entropy_log_dec_31 FLOAT,
      tqwt_entropy_log_dec_32 FLOAT,
      tqwt_entropy_log_dec_33 FLOAT,
      tqwt_entropy_log_dec_34 FLOAT,
      tqwt_entropy_log_dec_35 FLOAT,
      tqwt_entropy_log_dec_36 FLOAT,
      tqwt_TKEO_mean_dec_1 FLOAT,
      tqwt_TKEO_mean_dec_2 FLOAT,
      tqwt_TKEO_mean_dec_3 FLOAT,
      tqwt_TKEO_mean_dec_4 FLOAT,
      tqwt_TKEO_mean_dec_5 FLOAT,
      tqwt_TKEO_mean_dec_6 FLOAT,
      tqwt_TKEO_mean_dec_7 FLOAT,
      tqwt_TKEO_mean_dec_8 FLOAT,
      tqwt_TKEO_mean_dec_9 FLOAT,
      tqwt_TKEO_mean_dec_10 FLOAT,
      tqwt_TKEO_mean_dec_11 FLOAT,
      tqwt_TKEO_mean_dec_12 FLOAT,
      tqwt_TKEO_mean_dec_13 FLOAT,
      tqwt_TKEO_mean_dec_14 FLOAT,
      tqwt_TKEO_mean_dec_15 FLOAT,
      tqwt_TKEO_mean_dec_16 FLOAT,
      tqwt_TKEO_mean_dec_17 FLOAT,
      tqwt_TKEO_mean_dec_18 FLOAT,
      tqwt_TKEO_mean_dec_19 FLOAT,
      tqwt_TKEO_mean_dec_20 FLOAT,
      tqwt_TKEO_mean_dec_21 FLOAT,
      tqwt_TKEO_mean_dec_22 FLOAT,
      tqwt_TKEO_mean_dec_23 FLOAT,
      tqwt_TKEO_mean_dec_24 FLOAT,
      tqwt_TKEO_mean_dec_25 FLOAT,
      tqwt_TKEO_mean_dec_26 FLOAT,
      tqwt_TKEO_mean_dec_27 FLOAT,
      tqwt_TKEO_mean_dec_28 FLOAT,
      tqwt_TKEO_mean_dec_29 FLOAT,
      tqwt_TKEO_mean_dec_30 FLOAT,
      tqwt_TKEO_mean_dec_31 FLOAT,
      tqwt_TKEO_mean_dec_32 FLOAT,
      tqwt_TKEO_mean_dec_33 FLOAT,
      tqwt_TKEO_mean_dec_34 FLOAT,
      tqwt_TKEO_mean_dec_35 FLOAT,
      tqwt_TKEO_mean_dec_36 FLOAT,
      tqwt_TKEO_std_dec_1 FLOAT,
      tqwt_TKEO_std_dec_2 FLOAT,
      tqwt_TKEO_std_dec_3 FLOAT,
      tqwt_TKEO_std_dec_4 FLOAT,
      tqwt_TKEO_std_dec_5 FLOAT,
      tqwt_TKEO_std_dec_6 FLOAT,
      tqwt_TKEO_std_dec_7 FLOAT,
      tqwt_TKEO_std_dec_8 FLOAT,
      tqwt_TKEO_std_dec_9 FLOAT,
      tqwt_TKEO_std_dec_10 FLOAT,
      tqwt_TKEO_std_dec_11 FLOAT,
      tqwt_TKEO_std_dec_12 FLOAT,
      tqwt_TKEO_std_dec_13 FLOAT,
      tqwt_TKEO_std_dec_14 FLOAT,
      tqwt_TKEO_std_dec_15 FLOAT,
      tqwt_TKEO_std_dec_16 FLOAT,
      tqwt_TKEO_std_dec_17 FLOAT,
      tqwt_TKEO_std_dec_18 FLOAT,
      tqwt_TKEO_std_dec_19 FLOAT,
      tqwt_TKEO_std_dec_20 FLOAT,
      tqwt_TKEO_std_dec_21 FLOAT,
      tqwt_TKEO_std_dec_22 FLOAT,
      tqwt_TKEO_std_dec_23 FLOAT,
      tqwt_TKEO_std_dec_24 FLOAT,
      tqwt_TKEO_std_dec_25 FLOAT,
      tqwt_TKEO_std_dec_26 FLOAT,
      tqwt_TKEO_std_dec_27 FLOAT,
      tqwt_TKEO_std_dec_28 FLOAT,
      tqwt_TKEO_std_dec_29 FLOAT,
      tqwt_TKEO_std_dec_30 FLOAT,
      tqwt_TKEO_std_dec_31 FLOAT,
      tqwt_TKEO_std_dec_32 FLOAT,
      tqwt_TKEO_std_dec_33 FLOAT,
      tqwt_TKEO_std_dec_34 FLOAT,
      tqwt_TKEO_std_dec_35 FLOAT,
      tqwt_TKEO_std_dec_36 FLOAT,
      tqwt_medianValue_dec_1 FLOAT,
      tqwt_medianValue_dec_2 FLOAT,
      tqwt_medianValue_dec_3 FLOAT,
      tqwt_medianValue_dec_4 FLOAT,
      tqwt_medianValue_dec_5 FLOAT,
      tqwt_medianValue_dec_6 FLOAT,
      tqwt_medianValue_dec_7 FLOAT,
      tqwt_medianValue_dec_8 FLOAT,
      tqwt_medianValue_dec_9 FLOAT,
      tqwt_medianValue_dec_10 FLOAT,
      tqwt_medianValue_dec_11 FLOAT,
      tqwt_medianValue_dec_12 FLOAT,
      tqwt_medianValue_dec_13 FLOAT,
      tqwt_medianValue_dec_14 FLOAT,
      tqwt_medianValue_dec_15 FLOAT,
      tqwt_medianValue_dec_16 FLOAT,
      tqwt_medianValue_dec_17 FLOAT,
      tqwt_medianValue_dec_18 FLOAT,
      tqwt_medianValue_dec_19 FLOAT,
      tqwt_medianValue_dec_20 FLOAT,
      tqwt_medianValue_dec_21 FLOAT,
      tqwt_medianValue_dec_22 FLOAT,
      tqwt_medianValue_dec_23 FLOAT,
      tqwt_medianValue_dec_24 FLOAT,
      tqwt_medianValue_dec_25 FLOAT,
      tqwt_medianValue_dec_26 FLOAT,
      tqwt_medianValue_dec_27 FLOAT,
      tqwt_medianValue_dec_28 FLOAT,
      tqwt_medianValue_dec_29 FLOAT,
      tqwt_medianValue_dec_30 FLOAT,
      tqwt_medianValue_dec_31 FLOAT,
      tqwt_medianValue_dec_32 FLOAT,
      tqwt_medianValue_dec_33 FLOAT,
      tqwt_medianValue_dec_34 FLOAT,
      tqwt_medianValue_dec_35 FLOAT,
      tqwt_medianValue_dec_36 FLOAT,
      tqwt_meanValue_dec_1 FLOAT,
      tqwt_meanValue_dec_2 FLOAT,
      tqwt_meanValue_dec_3 FLOAT,
      tqwt_meanValue_dec_4 FLOAT,
      tqwt_meanValue_dec_5 FLOAT,
      tqwt_meanValue_dec_6 FLOAT,
      tqwt_meanValue_dec_7 FLOAT,
      tqwt_meanValue_dec_8 FLOAT,
      tqwt_meanValue_dec_9 FLOAT,
      tqwt_meanValue_dec_10 FLOAT,
      tqwt_meanValue_dec_11 FLOAT,
      tqwt_meanValue_dec_12 FLOAT,
      tqwt_meanValue_dec_13 FLOAT,
      tqwt_meanValue_dec_14 FLOAT,
      tqwt_meanValue_dec_15 FLOAT,
      tqwt_meanValue_dec_16 FLOAT,
      tqwt_meanValue_dec_17 FLOAT,
      tqwt_meanValue_dec_18 FLOAT,
      tqwt_meanValue_dec_19 FLOAT,
      tqwt_meanValue_dec_20 FLOAT,
      tqwt_meanValue_dec_21 FLOAT,
      tqwt_meanValue_dec_22 FLOAT,
      tqwt_meanValue_dec_23 FLOAT,
      tqwt_meanValue_dec_24 FLOAT,
      tqwt_meanValue_dec_25 FLOAT,
      tqwt_meanValue_dec_26 FLOAT,
      tqwt_meanValue_dec_27 FLOAT,
      tqwt_meanValue_dec_28 FLOAT,
      tqwt_meanValue_dec_29 FLOAT,
      tqwt_meanValue_dec_30 FLOAT,
      tqwt_meanValue_dec_31 FLOAT,
      tqwt_meanValue_dec_32 FLOAT,
      tqwt_meanValue_dec_33 FLOAT,
      tqwt_meanValue_dec_34 FLOAT,
      tqwt_meanValue_dec_35 FLOAT,
      tqwt_meanValue_dec_36 FLOAT,
      tqwt_stdValue_dec_1 FLOAT,
      tqwt_stdValue_dec_2 FLOAT,
      tqwt_stdValue_dec_3 FLOAT,
      tqwt_stdValue_dec_4 FLOAT,
      tqwt_stdValue_dec_5 FLOAT,
      tqwt_stdValue_dec_6 FLOAT,
      tqwt_stdValue_dec_7 FLOAT,
      tqwt_stdValue_dec_8 FLOAT,
      tqwt_stdValue_dec_9 FLOAT,
      tqwt_stdValue_dec_10 FLOAT,
      tqwt_stdValue_dec_11 FLOAT,
      tqwt_stdValue_dec_12 FLOAT,
      tqwt_stdValue_dec_13 FLOAT,
      tqwt_stdValue_dec_14 FLOAT,
      tqwt_stdValue_dec_15 FLOAT,
      tqwt_stdValue_dec_16 FLOAT,
      tqwt_stdValue_dec_17 FLOAT,
      tqwt_stdValue_dec_18 FLOAT,
      tqwt_stdValue_dec_19 FLOAT,
      tqwt_stdValue_dec_20 FLOAT,
      tqwt_stdValue_dec_21 FLOAT,
      tqwt_stdValue_dec_22 FLOAT,
      tqwt_stdValue_dec_23 FLOAT,
      tqwt_stdValue_dec_24 FLOAT,
      tqwt_stdValue_dec_25 FLOAT,
      tqwt_stdValue_dec_26 FLOAT,
      tqwt_stdValue_dec_27 FLOAT,
      tqwt_stdValue_dec_28 FLOAT,
      tqwt_stdValue_dec_29 FLOAT,
      tqwt_stdValue_dec_30 FLOAT,
      tqwt_stdValue_dec_31 FLOAT,
      tqwt_stdValue_dec_32 FLOAT,
      tqwt_stdValue_dec_33 FLOAT,
      tqwt_stdValue_dec_34 FLOAT,
      tqwt_stdValue_dec_35 FLOAT,
      tqwt_stdValue_dec_36 FLOAT,
      tqwt_minValue_dec_1 FLOAT,
      tqwt_minValue_dec_2 FLOAT,
      tqwt_minValue_dec_3 FLOAT,
      tqwt_minValue_dec_4 FLOAT,
      tqwt_minValue_dec_5 FLOAT,
      tqwt_minValue_dec_6 FLOAT,
      tqwt_minValue_dec_7 FLOAT,
      tqwt_minValue_dec_8 FLOAT,
      tqwt_minValue_dec_9 FLOAT,
      tqwt_minValue_dec_10 FLOAT,
      tqwt_minValue_dec_11 FLOAT,
      tqwt_minValue_dec_12 FLOAT,
      tqwt_minValue_dec_13 FLOAT,
      tqwt_minValue_dec_14 FLOAT,
      tqwt_minValue_dec_15 FLOAT,
      tqwt_minValue_dec_16 FLOAT,
      tqwt_minValue_dec_17 FLOAT,
      tqwt_minValue_dec_18 FLOAT,
      tqwt_minValue_dec_19 FLOAT,
      tqwt_minValue_dec_20 FLOAT,
      tqwt_minValue_dec_21 FLOAT,
      tqwt_minValue_dec_22 FLOAT,
      tqwt_minValue_dec_23 FLOAT,
      tqwt_minValue_dec_24 FLOAT,
      tqwt_minValue_dec_25 FLOAT,
      tqwt_minValue_dec_26 FLOAT,
      tqwt_minValue_dec_27 FLOAT,
      tqwt_minValue_dec_28 FLOAT,
      tqwt_minValue_dec_29 FLOAT,
      tqwt_minValue_dec_30 FLOAT,
      tqwt_minValue_dec_31 FLOAT,
      tqwt_minValue_dec_32 FLOAT,
      tqwt_minValue_dec_33 FLOAT,
      tqwt_minValue_dec_34 FLOAT,
      tqwt_minValue_dec_35 FLOAT,
      tqwt_minValue_dec_36 FLOAT,
      tqwt_maxValue_dec_1 FLOAT,
      tqwt_maxValue_dec_2 FLOAT,
      tqwt_maxValue_dec_3 FLOAT,
      tqwt_maxValue_dec_4 FLOAT,
      tqwt_maxValue_dec_5 FLOAT,
      tqwt_maxValue_dec_6 FLOAT,
      tqwt_maxValue_dec_7 FLOAT,
      tqwt_maxValue_dec_8 FLOAT,
      tqwt_maxValue_dec_9 FLOAT,
      tqwt_maxValue_dec_10 FLOAT,
      tqwt_maxValue_dec_11 FLOAT,
      tqwt_maxValue_dec_12 FLOAT,
      tqwt_maxValue_dec_13 FLOAT,
      tqwt_maxValue_dec_14 FLOAT,
      tqwt_maxValue_dec_15 FLOAT,
      tqwt_maxValue_dec_16 FLOAT,
      tqwt_maxValue_dec_17 FLOAT,
      tqwt_maxValue_dec_18 FLOAT,
      tqwt_maxValue_dec_19 FLOAT,
      tqwt_maxValue_dec_20 FLOAT,
      tqwt_maxValue_dec_21 FLOAT,
      tqwt_maxValue_dec_22 FLOAT,
      tqwt_maxValue_dec_23 FLOAT,
      tqwt_maxValue_dec_24 FLOAT,
      tqwt_maxValue_dec_25 FLOAT,
      tqwt_maxValue_dec_26 FLOAT,
      tqwt_maxValue_dec_27 FLOAT,
      tqwt_maxValue_dec_28 FLOAT,
      tqwt_maxValue_dec_29 FLOAT,
      tqwt_maxValue_dec_30 FLOAT,
      tqwt_maxValue_dec_31 FLOAT,
      tqwt_maxValue_dec_32 FLOAT,
      tqwt_maxValue_dec_33 FLOAT,
      tqwt_maxValue_dec_34 FLOAT,
      tqwt_maxValue_dec_35 FLOAT,
      tqwt_maxValue_dec_36 FLOAT,
      tqwt_skewnessValue_dec_1 FLOAT,
      tqwt_skewnessValue_dec_2 FLOAT,
      tqwt_skewnessValue_dec_3 FLOAT,
      tqwt_skewnessValue_dec_4 FLOAT,
      tqwt_skewnessValue_dec_5 FLOAT,
      tqwt_skewnessValue_dec_6 FLOAT,
      tqwt_skewnessValue_dec_7 FLOAT,
      tqwt_skewnessValue_dec_8 FLOAT,
      tqwt_skewnessValue_dec_9 FLOAT,
      tqwt_skewnessValue_dec_10 FLOAT,
      tqwt_skewnessValue_dec_11 FLOAT,
      tqwt_skewnessValue_dec_12 FLOAT,
      tqwt_skewnessValue_dec_13 FLOAT,
      tqwt_skewnessValue_dec_14 FLOAT,
      tqwt_skewnessValue_dec_15 FLOAT,
      tqwt_skewnessValue_dec_16 FLOAT,
      tqwt_skewnessValue_dec_17 FLOAT,
      tqwt_skewnessValue_dec_18 FLOAT,
      tqwt_skewnessValue_dec_19 FLOAT,
      tqwt_skewnessValue_dec_20 FLOAT,
      tqwt_skewnessValue_dec_21 FLOAT,
      tqwt_skewnessValue_dec_22 FLOAT,
      tqwt_skewnessValue_dec_23 FLOAT,
      tqwt_skewnessValue_dec_24 FLOAT,
      tqwt_skewnessValue_dec_25 FLOAT,
      tqwt_skewnessValue_dec_26 FLOAT,
      tqwt_skewnessValue_dec_27 FLOAT,
      tqwt_skewnessValue_dec_28 FLOAT,
      tqwt_skewnessValue_dec_29 FLOAT,
      tqwt_skewnessValue_dec_30 FLOAT,
      tqwt_skewnessValue_dec_31 FLOAT,
      tqwt_skewnessValue_dec_32 FLOAT,
      tqwt_skewnessValue_dec_33 FLOAT,
      tqwt_skewnessValue_dec_34 FLOAT,
      tqwt_skewnessValue_dec_35 FLOAT,
      tqwt_skewnessValue_dec_36 FLOAT,
      tqwt_kurtosisValue_dec_1 FLOAT,
      tqwt_kurtosisValue_dec_2 FLOAT,
      tqwt_kurtosisValue_dec_3 FLOAT,
      tqwt_kurtosisValue_dec_4 FLOAT,
      tqwt_kurtosisValue_dec_5 FLOAT,
      tqwt_kurtosisValue_dec_6 FLOAT,
      tqwt_kurtosisValue_dec_7 FLOAT,
      tqwt_kurtosisValue_dec_8 FLOAT,
      tqwt_kurtosisValue_dec_9 FLOAT,
      tqwt_kurtosisValue_dec_10 FLOAT,
      tqwt_kurtosisValue_dec_11 FLOAT,
      tqwt_kurtosisValue_dec_12 FLOAT,
      tqwt_kurtosisValue_dec_13 FLOAT,
      tqwt_kurtosisValue_dec_14 FLOAT,
      tqwt_kurtosisValue_dec_15 FLOAT,
      tqwt_kurtosisValue_dec_16 FLOAT,
      tqwt_kurtosisValue_dec_17 FLOAT,
      tqwt_kurtosisValue_dec_18 FLOAT,
      tqwt_kurtosisValue_dec_19 FLOAT,
      tqwt_kurtosisValue_dec_20 FLOAT,
      tqwt_kurtosisValue_dec_21 FLOAT,
      tqwt_kurtosisValue_dec_22 FLOAT,
      tqwt_kurtosisValue_dec_23 FLOAT,
      tqwt_kurtosisValue_dec_24 FLOAT,
      tqwt_kurtosisValue_dec_25 FLOAT,
      tqwt_kurtosisValue_dec_26 FLOAT,
      tqwt_kurtosisValue_dec_27 FLOAT,
      tqwt_kurtosisValue_dec_28 FLOAT,
      tqwt_kurtosisValue_dec_29 FLOAT,
      tqwt_kurtosisValue_dec_30 FLOAT,
      tqwt_kurtosisValue_dec_31 FLOAT,
      tqwt_kurtosisValue_dec_32 FLOAT,
      tqwt_kurtosisValue_dec_33 FLOAT,
      tqwt_kurtosisValue_dec_34 FLOAT,
      tqwt_kurtosisValue_dec_35 FLOAT,
      tqwt_kurtosisValue_dec_36 FLOAT,
      "class" BYTEINT)
PRIMARY INDEX (id);
# Out:
# Success: 0 rows affected
# [Teradata Database] [Warning 4332] Map 'TD_MAP1' is overridden by map 'TD_MAP2'.

# %%
%dataload table=pd_speech_features, database=demo_user, mode=batch, filepath=UseCases/Parkinson's Disease/speech_features.csv
# Out:
# Using database: demo_user
# 2022-06-16T00:09:20.520 Start Batch Loading...
#
# Data Load: Number Rows Loaded = 756, Elapsed Time = 00:00:04.712, History ID = 304
# Success Loading Data: from file,'/home/jovyan/JupyterLabRoot/UseCases/Parkinson's Disease/speech_features.csv', into table, demo_user.pd_speech_features.
