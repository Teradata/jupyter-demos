# %%
import numpy as np
import pandas as pd
import timeit
import boto3
from tqdm import tqdm
from teradataml import *
from langchain.llms.bedrock import Bedrock

display.max_rows = 5

# %%
# %run -i ../startup.ipynb
eng = create_context(host = 'host.docker.internal', username='demo_user', password = password)
print(eng)
execute_sql('''SET query_band='DEMO=Topic_Modelling.ipynb;' UPDATE FOR SESSION;''')
# Out:
# Performing setup ...
# Setup complete
# Enter password:  ········
# ... Logon successful
# Connected as: xxxxxsql://demo_user:xxxxx@host.docker.internal/dbc
# Engine(teradatasql://demo_user:***@host.docker.internal)
# TeradataCursor uRowsHandle=15 bClosed=False

# %%
# %run -i ../run_procedure.py "call get_data('DEMO_ComplaintAnalysis_cloud');"        # Takes 1 minute
# %run -i ../run_procedure.py "call get_data('DEMO_ComplaintAnalysis_local');"        # Takes 2 minutes
# Out:
# Database DEMO_ComplaintAnalysis_local exists

# %%
df = DataFrame(in_schema('DEMO_ComplaintAnalysis', 'Consumer_Complaints'))

# %%
def configure_aws():
    print("configure the AWS CLI")
    # enter the access_key/secret_key
    access_key = getpass.getpass("aws_access_key_id ")
    secret_key = getpass.getpass("aws_secret_access_key ")
    region_name = getpass.getpass("region name")

    #set to the env
    # !aws configure set aws_access_key_id {access_key}
    # !aws configure set aws_secret_access_key {secret_key}
    # !aws configure set default.region {region_name}

# %%
does_access_key_exists = !aws configure get aws_access_key_id

if len(does_access_key_exists) == 0:
    configure_aws()

# %%
# !aws configure list
# Out:
#       Name                    Value             Type    Location
#       ----                    -----             ----    --------
#    profile                <not set>             None    None
# access_key     ****************GXKN shared-credentials-file
# secret_key     ****************u8mf shared-credentials-file
#     region                us-east-1      config-file    ~/.aws/config

# %%
df = df[df.product == 'Mortgage']

# %%
df.select(['issue', 'sub_issue', 'complaint_id']).groupby(['issue', 'sub_issue']).agg(['count']).sort('count_complaint_id', ascending = False)
# Out:
#                                                          issue                      sub_issue  count_complaint_id
# 0  Applying for a mortgage or refinancing an existing mortgage                           None                  15
# 1                               Trouble during payment process                           None                  11
# 2                                        Closing on a mortgage                           None                   3
# 3                                   Struggling to pay mortgage                           None                   2
# 4                         Incorrect information on your report  Account information incorrect                   2

# %% [markdown]
# <!-- - Incorrect information on your report: Information belongs to someone else
# - Problem with a purchase shown on your statement: Credit card company isn't resolving a dispute about a purchase on your statement
# - Problem with a credit reporting company's investigation into an existing problem: Their investigation did not fix an error on your report
# - Improper use of your report: Reporting company used your report improperly
# - Improper use of your report: Credit inquiries on your report that you don't recognize
#
# <hr>
# <hr>
#
# - Incorrect Information: Belongs to someone else.
# - Purchase Dispute: Credit card company issue.
# - Credit Report Error: Investigation didn’t fix it.
# - Improper Use: Reporting company misuse.
# - Unauthorized Inquiries: Unrecognized credit inquiries. -->
#
# - Applying for a mortgage or refinancing an existing mortgage
# - Trouble during payment process
# - Closing on a mortgage
# - Incorrect information on your report
# - Struggling to pay mortgage
#
# <hr>
# <hr>
#
# - Mortgage Application: Applying or refinancing.
# - Payment Trouble: Issues during payment.
# - Mortgage Closing: Finalizing the mortgage.
# - Report Inaccuracy: Incorrect information.
# - Payment Struggle: Difficulty paying.

# %%
## Bedrock Clients
bedrock=boto3.client(service_name="bedrock-runtime", region_name='us-east-1')

def get_llm():
    return Bedrock(model_id="ai21.j2-mid-v1",client=bedrock,
                model_kwargs={'temperature': 0.9, 'maxTokens': 5, "stopSequences":["$$"],"countPenalty":{"scale":0},"presencePenalty":{"scale":0}})

# %%
ai21 = get_llm()

# %%
pd_df = df.to_pandas()

# %%
prompt = f'''
    User prompt:
    The following is text from a complaint:

    “{pd_df['consumer_complaint_narrative'][0]}”

    Identify the topic of the complaint and categorize into one of the following topics. Only output one of the following options:

    - Mortgage Application
    - Payment Trouble
    - Mortgage Closing
    - Report Inaccuracy
    - Payment Struggle
    
    Return just one of the above options
'''

ai21(prompt = prompt)
# Out:
# 'Mortgage Application'

# %%
pd_df['Predicted_Topic'] = ''

# %%
for i in tqdm(range(len(pd_df))):
    prompt = f'''
    User prompt:
    The following is text from a complaint:

    “{pd_df['consumer_complaint_narrative'][i]}”

    Identify the topic of the complaint and categorize into one of the following topics. Only output one of the following options:

    - Mortgage Application
    - Payment Trouble
    - Mortgage Closing
    - Report Inaccuracy
    - Payment Struggle
    
    Return just one of the above options
'''
    c = ai21(prompt = prompt)
    pd_df['Predicted_Topic'][i] = c
# Out:
# 100%|██████████| 43/43 [00:21<00:00,  2.02it/s]

# %%
pd_df
# Out:
#    date_received   product                                 sub_product  \
# 0     2022-12-04  Mortgage  Home equity loan or line of credit (HELOC)
# 1     2024-01-11  Mortgage  Home equity loan or line of credit (HELOC)
# 2     2022-08-10  Mortgage  Home equity loan or line of credit (HELOC)
# 3     2022-11-14  Mortgage  Home equity loan or line of credit (HELOC)
# 4     2018-01-23  Mortgage  Home equity loan or line of credit (HELOC)
# 5     2022-03-08  Mortgage  Home equity loan or line of credit (HELOC)
# 6     2018-10-14  Mortgage  Home equity loan or line of credit (HELOC)
# 7     2015-10-13  Mortgage          Home equity loan or line of credit
# 8     2019-11-11  Mortgage  Home equity loan or line of credit (HELOC)
# 9     2017-01-12  Mortgage          Home equity loan or line of credit
# 10    2019-12-12  Mortgage  Home equity loan or line of credit (HELOC)
# 11    2016-10-26  Mortgage          Home equity loan or line of credit
# 12    2020-06-06  Mortgage  Home equity loan or line of credit (HELOC)
# 13    2017-10-13  Mortgage                      Other type of mortgage
# 14    2020-02-26  Mortgage  Home equity loan or line of credit (HELOC)
# 15    2017-08-06  Mortgage                      Other type of mortgage
# 16    2020-11-16  Mortgage                      Other type of mortgage
# 17    2019-05-13  Mortgage  Home equity loan or line of credit (HELOC)
# 18    2023-09-25  Mortgage  Home equity loan or line of credit (HELOC)
# 19    2017-08-17  Mortgage  Home equity loan or line of credit (HELOC)
# 20    2021-01-22  Mortgage  Home equity loan or line of credit (HELOC)
# 21    2019-12-02  Mortgage  Home equity loan or line of credit (HELOC)
# 22    2023-11-07  Mortgage  Home equity loan or line of credit (HELOC)
# 23    2018-07-20  Mortgage  Home equity loan or line of credit (HELOC)
# 24    2021-03-18  Mortgage  Home equity loan or line of credit (HELOC)
# 25    2020-11-24  Mortgage  Home equity loan or line of credit (HELOC)
# 26    2021-01-08  Mortgage  Home equity loan or line of credit (HELOC)
# 27    2021-05-20  Mortgage  Home equity loan or line of credit (HELOC)
# 28    2021-07-24  Mortgage                  Conventional home mortgage
# 29    2021-03-05  Mortgage  Home equity loan or line of credit (HELOC)
# 30    2023-02-05  Mortgage  Home equity loan or line of credit (HELOC)
# 31    2021-07-30  Mortgage                                FHA mortgage
# 32    2021-05-11  Mortgage                  Conventional home mortgage
# 33    2023-05-09  Mortgage  Home equity loan or line of credit (HELOC)
# 34    2023-05-23  Mortgage  Home equity loan or line of credit (HELOC)
# 35    2023-06-18  Mortgage  Home equity loan or line of credit (HELOC)
# 36    2023-08-04  Mortgage  Home equity loan or line of credit (HELOC)
# 37    2023-07-24  Mortgage  Home equity loan or line of credit (HELOC)
# 38    2023-07-23  Mortgage  Home equity loan or line of credit (HELOC)
# 39    2023-09-04  Mortgage  Home equity loan or line of credit (HELOC)
# 40    2023-09-07  Mortgage  Home equity loan or line of credit (HELOC)
# 41    2023-09-07  Mortgage                  Conventional home mortgage
# 42    2023-11-22  Mortgage  Home equity loan or line of credit (HELOC)
#
#                                                 issue  \
# 0   Applying for a mortgage or refinancing an exis...
# 1                               Closing on a mortgage
# 2                          Struggling to pay mortgage
# 3                      Trouble during payment process
# 4                               Closing on a mortgage
# 5   Applying for a mortgage or refinancing an exis...
# 6   Applying for a mortgage or refinancing an exis...
# 7            Loan servicing, payments, escrow account
# 8   Applying for a mortgage or refinancing an exis...
# 9            Application, originator, mortgage broker
# 10                     Trouble during payment process
# 11                     Credit decision / Underwriting
# 12                         Struggling to pay mortgage
# 13                     Trouble during payment process
# 14  Applying for a mortgage or refinancing an exis...
# 15                     Trouble during payment process
# 16  Applying for a mortgage or refinancing an exis...
# 17                              Closing on a mortgage
# 18  Applying for a mortgage or refinancing an exis...
# 19                     Trouble during payment process
# 20                     Trouble during payment process
# 21                     Trouble during payment process
# 22  Applying for a mortgage or refinancing an exis...
# 23  Applying for a mortgage or refinancing an exis...
# 24  Applying for a mortgage or refinancing an exis...
# 25               Incorrect information on your report
# 26  Applying for a mortgage or refinancing an exis...
# 27  Applying for a mortgage or refinancing an exis...
# 28  Applying for a mortgage or refinancing an exis...
# 29                     Trouble during payment process
# 30                     Trouble during payment process
# 31  Applying for a mortgage or refinancing an exis...
# 32                              Closing on a mortgage
# 33                     Trouble during payment process
# 34               Incorrect information on your report
# 35  Applying for a mortgage or refinancing an exis...
# 36  Applying for a mortgage or refinancing an exis...
# 37                     Trouble during payment process
# 38  Applying for a mortgage or refinancing an exis...
# 39  Applying for a mortgage or refinancing an exis...
# 40               Incorrect information on your report
# 41                     Trouble during payment process
# 42                        Improper use of your report
#
#                                             sub_issue  \
# 0                                                None
# 1                     Delays with the closing process
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  Trying to communicate with the company to fix ...
# 19                                               None
# 20                                               None
# 21                                               None
# 22  Changes in loan terms during the application p...
# 23                                               None
# 24                                               None
# 25                      Account information incorrect
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                      Account information incorrect
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                Application denials
# 40                Information belongs to someone else
# 41                                    Payment process
# 42      Reporting company used your report improperly
#
#                          consumer_complaint_narrative company_public_response  \
# 0   I received a postcard from XXXX about a Home E...                    None
# 1   I received an email from XXXX XXXX the senior ...                    None
# 2   I have a mortgage with Discover Home Loans. I ...                    None
# 3   On XX/XX/2022 - Discover took duplicate paymen...                    None
# 4   I am employed as a XXXX XXXX for a XXXX XXXX X...                    None
# 5   Discover Bank advertises Home Equity loan rate...                    None
# 6   Our first mortgage is privately held. It is re...                    None
# 7   I am currently in the process of a refinance. ...                    None
# 8   Discover Home Loans  advertisers a process in ...                    None
# 9   I applied for a Home Equity Loan through Disco...                    None
# 10  I had a home equity loan with Discover Bank fo...                    None
# 11  I applied for a Home Equity loan from Discover...                    None
# 12  Due to loss of job from Covid-19 I spoke with ...                    None
# 13  For about the last 6 to 8 months Discover Bank...                    None
# 14  Application # XXXX I have applied for a home e...                    None
# 15  I am a XXXX veteran and for the past 5 years I...                    None
# 16  On XX/XX/XXXX I submitted documents for a 2nd ...                    None
# 17  I applied for a home equity on XX/XX/2018 and ...                    None
# 18  I applied for a small home equity loan from Di...                    None
# 19  I was a XXXX hired to do the signing for a Dis...                    None
# 20  Attempting to pay the mortgage in full and ser...                    None
# 21  Hello, I had a second mortgage with Discover a...                    None
# 22  I started a application with Discovery Home Lo...                    None
# 23  I have been working to obtain a home equity lo...                    None
# 24  Discover Home Loans took our application XX/XX...                    None
# 25  My HELOC with Discover Home Loans ( Loan # XXX...                    None
# 26  I applied for a home equity loan with Discover...                    None
# 27  On XX/XX/2021 I spoke with senior loan process...                    None
# 28  My mortgage was in forbearance under the Cares...                    None
# 29  On XX/XX/21 I contacted Discover Home Loans fo...                    None
# 30  Due to XXXX  and reckless misinformation on th...                    None
# 31  I applied at discover mortgage loan pre qualif...                    None
# 32  Mortgage was paid off on XX/XX/2021. Home was ...                    None
# 33  Discover Home Loans I have FEMA proof that I d...                    None
# 34  I applied for a heloc on XX/XX/2023 - my infor...                    None
# 35  I can provide proof that Discover financial gr...                    None
# 36  I receive a mail package on home equality loan...                    None
# 37  The escrow portion of my loan was written up i...                    None
# 38  Discover is requiring me to have my husband al...                    None
# 39  I went to apply for XXXX home equity loan on X...                    None
# 40  This complaint is against Discover Home XXXX L...                    None
# 41  We have a 3rd party making our mortgage paymen...                    None
# 42  Hard credit inquiry by Discover Financial with...                    None
#
#           company state zip_code                           tags  \
# 0   DISCOVER BANK    FL    33771                           None
# 1   DISCOVER BANK    PA    183XX                  Servicemember
# 2   DISCOVER BANK    FL    34982                 Older American
# 3   DISCOVER BANK    GA    30040                  Servicemember
# 4   DISCOVER BANK    FL    33193                           None
# 5   DISCOVER BANK    TX    75043                           None
# 6   DISCOVER BANK    CA    91730                           None
# 7   DISCOVER BANK    CA    91913                           None
# 8   DISCOVER BANK    AL    350XX                           None
# 9   DISCOVER BANK    OH    44313                           None
# 10  DISCOVER BANK    IL    60302                           None
# 11  DISCOVER BANK    UT    84040                           None
# 12  DISCOVER BANK    NY    10308                           None
# 13  DISCOVER BANK    MI    48220  Older American, Servicemember
# 14  DISCOVER BANK    VA    20147                           None
# 15  DISCOVER BANK    MI    48220  Older American, Servicemember
# 16  DISCOVER BANK    NC    28504                           None
# 17  DISCOVER BANK    NJ    08053                           None
# 18  DISCOVER BANK    CA    92596                           None
# 19  DISCOVER BANK    CA    94704                           None
# 20  DISCOVER BANK    AL    365XX                           None
# 21  DISCOVER BANK    FL    XXXXX                           None
# 22  DISCOVER BANK    GA    XXXXX  Older American, Servicemember
# 23  DISCOVER BANK    MO    65802                           None
# 24  DISCOVER BANK    AZ    85008                           None
# 25  DISCOVER BANK    NY    11554                           None
# 26  DISCOVER BANK    CA    91107                           None
# 27  DISCOVER BANK    FL    33709                           None
# 28  DISCOVER BANK    DC    20008                           None
# 29  DISCOVER BANK    GA    315XX                  Servicemember
# 30  DISCOVER BANK    NC    28208                           None
# 31  DISCOVER BANK    FL    33351                           None
# 32  DISCOVER BANK    FL    328XX                           None
# 33  DISCOVER BANK    AL    36575  Older American, Servicemember
# 34  DISCOVER BANK    TX    77379                 Older American
# 35  DISCOVER BANK    TX    XXXXX                  Servicemember
# 36  DISCOVER BANK    MA    02115                           None
# 37  DISCOVER BANK    FL    33426                           None
# 38  DISCOVER BANK    NV    89135                           None
# 39  DISCOVER BANK    WY    82801                           None
# 40  DISCOVER BANK    GA    30519                 Older American
# 41  DISCOVER BANK    FL    34982                 Older American
# 42  DISCOVER BANK    TX    75028                           None
#
#    consumer_consent_provided submitted_via date_sent_to_company  \
# 0           Consent provided           Web           2022-12-04
# 1           Consent provided           Web           2024-01-11
# 2           Consent provided           Web           2022-08-10
# 3           Consent provided           Web           2022-11-14
# 4           Consent provided           Web           2018-01-23
# 5           Consent provided           Web           2022-03-08
# 6           Consent provided           Web           2018-10-14
# 7           Consent provided           Web           2015-10-15
# 8           Consent provided           Web           2019-11-11
# 9           Consent provided           Web           2017-01-17
# 10          Consent provided           Web           2019-12-12
# 11          Consent provided           Web           2016-10-27
# 12          Consent provided           Web           2020-06-11
# 13          Consent provided           Web           2017-10-13
# 14          Consent provided           Web           2020-02-26
# 15          Consent provided           Web           2017-08-06
# 16          Consent provided           Web           2020-12-01
# 17          Consent provided           Web           2019-05-13
# 18          Consent provided           Web           2023-09-25
# 19          Consent provided           Web           2017-08-17
# 20          Consent provided           Web           2021-01-22
# 21          Consent provided           Web           2019-12-02
# 22          Consent provided           Web           2023-11-07
# 23          Consent provided           Web           2018-07-25
# 24          Consent provided           Web           2021-03-18
# 25          Consent provided           Web           2020-11-24
# 26          Consent provided           Web           2021-01-08
# 27          Consent provided           Web           2021-05-20
# 28          Consent provided           Web           2021-07-24
# 29          Consent provided           Web           2021-03-05
# 30          Consent provided           Web           2023-02-05
# 31          Consent provided           Web           2021-07-30
# 32          Consent provided           Web           2021-05-11
# 33          Consent provided           Web           2023-05-09
# 34          Consent provided           Web           2023-05-23
# 35          Consent provided           Web           2023-06-18
# 36          Consent provided           Web           2023-08-05
# 37          Consent provided           Web           2023-07-24
# 38          Consent provided           Web           2023-07-23
# 39          Consent provided           Web           2023-09-04
# 40          Consent provided           Web           2023-09-07
# 41          Consent provided           Web           2023-09-07
# 42          Consent provided           Web           2023-11-22
#
#        company_response_to_consumer timely_response consumer_disputed  \
# 0   Closed with non-monetary relief             Yes              None
# 1           Closed with explanation             Yes              None
# 2           Closed with explanation             Yes              None
# 3           Closed with explanation             Yes              None
# 4           Closed with explanation             Yes              None
# 5           Closed with explanation             Yes              None
# 6           Closed with explanation             Yes              None
# 7       Closed with monetary relief             Yes                No
# 8           Closed with explanation             Yes              None
# 9           Closed with explanation             Yes               Yes
# 10      Closed with monetary relief             Yes              None
# 11          Closed with explanation             Yes               Yes
# 12          Closed with explanation             Yes              None
# 13          Closed with explanation             Yes              None
# 14          Closed with explanation             Yes              None
# 15          Closed with explanation             Yes              None
# 16          Closed with explanation             Yes              None
# 17          Closed with explanation             Yes              None
# 18  Closed with non-monetary relief             Yes              None
# 19          Closed with explanation             Yes              None
# 20          Closed with explanation             Yes              None
# 21          Closed with explanation             Yes              None
# 22  Closed with non-monetary relief             Yes              None
# 23          Closed with explanation             Yes              None
# 24          Closed with explanation             Yes              None
# 25      Closed with monetary relief             Yes              None
# 26          Closed with explanation             Yes              None
# 27          Closed with explanation             Yes              None
# 28          Closed with explanation             Yes              None
# 29          Closed with explanation             Yes              None
# 30          Closed with explanation             Yes              None
# 31          Closed with explanation             Yes              None
# 32      Closed with monetary relief             Yes              None
# 33  Closed with non-monetary relief             Yes              None
# 34          Closed with explanation             Yes              None
# 35          Closed with explanation             Yes              None
# 36          Closed with explanation             Yes              None
# 37          Closed with explanation             Yes              None
# 38          Closed with explanation             Yes              None
# 39          Closed with explanation             Yes              None
# 40          Closed with explanation             Yes              None
# 41          Closed with explanation             Yes              None
# 42          Closed with explanation             Yes              None
#
#     complaint_id       Predicted_Topic
# 0        6279246  Mortgage Application
# 1        8150578  Mortgage Application
# 2        5859414       Payment Trouble
# 3        6200804       Payment Trouble
# 4        2790846       Payment Trouble
# 5        5298752  Mortgage Application
# 6        3045578  Mortgage Application
# 7        1604243  Mortgage Application
# 8        3434676  Mortgage Application
# 9        2286272  Mortgage Application
# 10       3466832      Mortgage Closing
# 11       2180136  Mortgage Application
# 12       3686319       Payment Trouble
# 13       2700900      Payment Struggle
# 14       3545818  Mortgage Application
# 15       2596615      Payment Struggle
# 16       3957975  Mortgage Application
# 17       3241275      Mortgage Closing
# 18       7604131  Mortgage Application
# 19       2633282       Payment Trouble
# 20       4086368       Payment Trouble
# 21       3455874       Payment Trouble
# 22       7817215  Mortgage Application
# 23       2968810  Mortgage Application
# 24       4225134  Mortgage Application
# 25       3972772       Payment Trouble
# 26       4056104  Mortgage Application
# 27       4391374  Mortgage Application
# 28       4570985       Payment Trouble
# 29       4187732       Payment Trouble
# 30       6522890       Payment Trouble
# 31       4588298  Mortgage Application
# 32       4368877       Payment Trouble
# 33       6954662  Mortgage Application
# 34       7017058     Report Inaccuracy
# 35       7133606  Mortgage Application
# 36       7352115  Mortgage Application
# 37       7297297     Report Inaccuracy
# 38       7288641  Mortgage Application
# 39       7494116  Mortgage Application
# 40       7516394     Report Inaccuracy
# 41       7516202       Payment Trouble
# 42       7889747  Mortgage Application

# %%
copy_to_sql(df = pd_df, table_name = 'topic_prediction', if_exists = 'replace')

# %%
remove_context()
# Out:
# True
