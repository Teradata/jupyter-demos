# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        5G Quality of Experience using ClearScape Analytics
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Due to the exponential increase in 5G cellular network users, providing extensive coverage and ensuring maximum Quality of Experience (QoE) has become a significant challenge for global telecommunications. The demand for high-speed connectivity, low latency, and massive data transfer poses obstacles in delivering seamless 5G coverage across diverse geographical areas. Furthermore, transitioning from 4G/LTE to 5G technology introduces complexities in terms of compatibility and network integration. Addressing these challenges is essential to meet the evolving expectations of end-users and ensure optimal QoE.<br>
# To tackle these challenges, an analysis of Key Performance Indicators (KPIs) and channel level metrics is conducted to understand their impact on user's perceived QoE. Moreover, we gain valuable insights by investigating YouTube streaming QoE, KPIs, using commercial 4G and 5G cellular networks under different mobility and static scenarios. The demo shows the power of Vantage by utilizing its In-DB analytics capabilities to address a critical challenge in telecommunication industry: <br>Predicting quality of experience (QoE) in 5G networks.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage and explore the dataset</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>After executing this cell you will be prompted to provide the password. Enter your password, press the Enter key, then <b>use down arrow</b> to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %%
Set query_band='DEMO=Telco_5G_QOE_Analysis_SQL.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Getting Data for This Demo</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# We have provided data for this demo on cloud storage. You have the option of either running the demo using foreign tables to access the data without using any storage on your environment or downloading the data to local storage which may yield somewhat faster execution, but will consume some of your available storage.
# <br> There are two statements in the following cell -- one is commented out. You may switch the location of your data's storage by changing the comment string.</p>

# %%
call get_data('DEMO_5G_cloud');    -- takes about 20 seconds, estimated space: 0 MB
--call get_data('DEMO_5G_local');     -- takes about 40 seconds, estimated space: 1MB
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory655365"><style>
#       table.tdhistory655365 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory655365 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory655365:last-child { text-align: left !important; }
#       tbody.tdhistory655365 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory655365 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory655365 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory655365"></th><th class="tdhistory655365">Message</th></tr></thead><tbody class="tdhistory655365 resultset-body"><tr><th class="tdhistory655365" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory655365">That ran for   0:00:17.71 with 9 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Next is an optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();  -- optional, takes about 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory313290"><style>
#       table.tdhistory313290 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory313290 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory313290:last-child { text-align: left !important; }
#       tbody.tdhistory313290 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory313290 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory313290 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory313290"></th><th class="tdhistory313290">Space_Report</th></tr></thead><tbody class="tdhistory313290 resultset-body"><tr><th class="tdhistory313290" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory313290">You have:  #databases=1 #tables=0 #views=12  You have used 0.7 MB of 27,890.4 MB available - 0.0%  ... Space Usage OK</td></tr><tr><th class="tdhistory313290" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory313290"> </td></tr><tr><th class="tdhistory313290" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory313290">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory313290" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory313290">   demo_user                            0       9  27,890.4 MB       0.7 MB </td></tr><tr><th class="tdhistory313290" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory313290">   DEMO_5G                              0       3       0.0 MB       0.0 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. Exploring source data</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b>5G Quality of Experience Data <br><br>CLM</b>: Refers to measurements and indicators that provide information about the quality and characteristics of the wireless communication channel between a base station (eNodeB/gNB) and a user equipment (UE) device. These metrics help in assessing the channel conditions and performance of the wireless link. Channel level metrics with 1-second granularity collected using Gnetrack Pro under different scenarios includes CQI, SNR, RSRP, RSRQ, Download & Upload bitrate, Cellid, etc. <br><b>QoE</b>: YouTube Quality of Experience information collected after every 1-second, i.e., Current quality, Video bytes downloaded, Loaded percentage. <br><b>Events</b>: YouTube player events, i.e., Stall, Quality Shift, Paused, Played, Ended<br></p>

# %% [markdown]
# ![Dataset%20Desc%20Vr2.png](attachment:Dataset%20Desc%20Vr2.png)

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Data Collection</b>The KPIs (CQI, SNR, RSRP, RSRQ) etc on 4G and 5G cell networks were collected for different scenarios. The channel level metrics were captured using G Network Pro which is a wireless network monitor. Using both android and iphone the youtube video was played, paused and queued. The buffering information and download bit rate was also captured. Four experiments that were conducted were mobility, pedestrian user that was walking outdoor and indoor sitting.</p>

# %%
select top 10 * from Demo_5G.YouTube_QoE;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory480963"><style>
#       table.tdhistory480963 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory480963 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory480963:last-child { text-align: left !important; }
#       tbody.tdhistory480963 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory480963 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory480963 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory480963"></th><th class="tdhistory480963">Video</th><th class="tdhistory480963">Quality</th><th class="tdhistory480963">Video_Bytes_Downloaded</th><th class="tdhistory480963">Loaded_Percentage</th><th class="tdhistory480963">Eid</th><th class="tdhistory480963">Dates</th><th class="tdhistory480963">Times</th></tr></thead><tbody class="tdhistory480963 resultset-body"><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory480963">9jrP7460a4o</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.101660925</td><td class="tdhistory480963">10.2</td><td class="tdhistory480963">14augs</td><td class="tdhistory480963">14/08/2022</td><td class="tdhistory480963">17:25:54</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory480963">9jrP7460a4o</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.101660925</td><td class="tdhistory480963">10.2</td><td class="tdhistory480963">14augs</td><td class="tdhistory480963">14/08/2022</td><td class="tdhistory480963">17:25:56</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory480963">9jrP7460a4o</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.101660925</td><td class="tdhistory480963">10.2</td><td class="tdhistory480963">14augs</td><td class="tdhistory480963">14/08/2022</td><td class="tdhistory480963">17:25:57</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory480963">9jrP7460a4o</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.101660925</td><td class="tdhistory480963">10.2</td><td class="tdhistory480963">14augs</td><td class="tdhistory480963">14/08/2022</td><td class="tdhistory480963">17:25:58</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory480963">9jrP7460a4o</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.112118234</td><td class="tdhistory480963">11.2</td><td class="tdhistory480963">14augs</td><td class="tdhistory480963">14/08/2022</td><td class="tdhistory480963">17:26:00</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory480963">9jrP7460a4o</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.079290227</td><td class="tdhistory480963">7.9</td><td class="tdhistory480963">14augs</td><td class="tdhistory480963">14/08/2022</td><td class="tdhistory480963">17:25:52</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory480963">JMbBjKnUoC4</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.115204518</td><td class="tdhistory480963">11.5</td><td class="tdhistory480963">m12aug</td><td class="tdhistory480963">08/12/2022</td><td class="tdhistory480963">14:40:01</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory480963">JMbBjKnUoC4</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.115204518</td><td class="tdhistory480963">11.5</td><td class="tdhistory480963">m12aug</td><td class="tdhistory480963">08/12/2022</td><td class="tdhistory480963">14:40:02</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory480963">JMbBjKnUoC4</td><td class="tdhistory480963">hd2160</td><td class="tdhistory480963">0.115204518</td><td class="tdhistory480963">11.5</td><td class="tdhistory480963">m12aug</td><td class="tdhistory480963">08/12/2022</td><td class="tdhistory480963">14:40:03</td></tr><tr><th class="tdhistory480963" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory480963">JMbBjKnUoC4</td><td class="tdhistory4 ...

# %%
select top 10 * from Demo_5G.YouTube_Player_Events;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory768433"><style>
#       table.tdhistory768433 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory768433 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory768433:last-child { text-align: left !important; }
#       tbody.tdhistory768433 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory768433 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory768433 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory768433"></th><th class="tdhistory768433">Video</th><th class="tdhistory768433">Quality</th><th class="tdhistory768433">Status</th><th class="tdhistory768433">TimeStall</th><th class="tdhistory768433">Eid</th><th class="tdhistory768433">Dates</th><th class="tdhistory768433">Times</th><th class="tdhistory768433">Category</th></tr></thead><tbody class="tdhistory768433 resultset-body"><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory768433">9jrP7460a4o</td><td class="tdhistory768433">hd2160,</td><td class="tdhistory768433">1</td><td class="tdhistory768433">0.060263095</td><td class="tdhistory768433">14augs</td><td class="tdhistory768433">14/08/2022</td><td class="tdhistory768433">17:25:41</td><td class="tdhistory768433">playing</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory768433">jAa58N4Jlos</td><td class="tdhistory768433">unknown,</td><td class="tdhistory768433">3</td><td class="tdhistory768433">0</td><td class="tdhistory768433">28airport5g</td><td class="tdhistory768433">28/09/2022</td><td class="tdhistory768433">12:05:39</td><td class="tdhistory768433">buffering</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory768433">jAa58N4Jlos</td><td class="tdhistory768433">hd2160,</td><td class="tdhistory768433">1</td><td class="tdhistory768433">0.062922093</td><td class="tdhistory768433">28airport5g</td><td class="tdhistory768433">28/09/2022</td><td class="tdhistory768433">12:05:40</td><td class="tdhistory768433">playing</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory768433">9jrP7460a4o</td><td class="tdhistory768433">unknown,</td><td class="tdhistory768433">-1</td><td class="tdhistory768433">0</td><td class="tdhistory768433">2a19aug</td><td class="tdhistory768433">19/08/2022</td><td class="tdhistory768433">16:03:52</td><td class="tdhistory768433">unstarted</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory768433">9jrP7460a4o</td><td class="tdhistory768433">hd2160,</td><td class="tdhistory768433">1</td><td class="tdhistory768433">0.044575773</td><td class="tdhistory768433">2a19aug</td><td class="tdhistory768433">19/08/2022</td><td class="tdhistory768433">16:03:54</td><td class="tdhistory768433">playing</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory768433">9jrP7460a4o</td><td class="tdhistory768433">hd2160,</td><td class="tdhistory768433">0</td><td class="tdhistory768433">302.181</td><td class="tdhistory768433">2a19aug</td><td class="tdhistory768433">19/08/2022</td><td class="tdhistory768433">16:08:56</td><td class="tdhistory768433">ended</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory768433">9jrP7460a4o</td><td class="tdhistory768433">unknown,</td><td class="tdhistory768433">3</td><td class="tdhistory768433">0</td><td class="tdhistory768433">2a19aug</td><td class="tdhistory768433">19/08/2022</td><td class="tdhistory768433">16:03:52</td><td class="tdhistory768433">buffering</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory768433">jAa58N4Jlos</td><td class="tdhistory768433">unknown,</td><td class="tdhistory768433">-1</td><td class="tdhistory768433">0</td><td class="tdhistory768433">28airport5g</td><td class="tdhistory768433">28/09/2022</td><td class="tdhistory768433">12:05:39</td><td class="tdhistory768433">unstarted</td></tr><tr><th class="tdhistory768433" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory768433">9jrP7460a4o</td><td class="tdhistory768433">unknown,</td><td class="tdhistory768433">-1</td><td class="tdh ...

# %%
select top 10 * from Demo_5G.Channel_Level_Metrics;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory213632"><style>
#       table.tdhistory213632 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory213632 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory213632:last-child { text-align: left !important; }
#       tbody.tdhistory213632 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory213632 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory213632 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory213632"></th><th class="tdhistory213632">Longitude</th><th class="tdhistory213632">Latitude</th><th class="tdhistory213632">NetworkTech</th><th class="tdhistory213632">NetworkMode</th><th class="tdhistory213632">Level</th><th class="tdhistory213632">Qual</th><th class="tdhistory213632">SNR</th><th class="tdhistory213632">CQI</th><th class="tdhistory213632">LTERSSI</th><th class="tdhistory213632">DL_bitrate</th><th class="tdhistory213632">UL_bitrate</th><th class="tdhistory213632">Altitude</th><th class="tdhistory213632">Height</th><th class="tdhistory213632">State</th><th class="tdhistory213632">EVENT</th><th class="tdhistory213632">SecondCell_RSRP</th><th class="tdhistory213632">SecondCell_RSRQ</th><th class="tdhistory213632">SecondCell_SNR</th><th class="tdhistory213632">Eid</th><th class="tdhistory213632">Experiment_Type</th><th class="tdhistory213632">Dates</th><th class="tdhistory213632">Times</th></tr></thead><tbody class="tdhistory213632 resultset-body"><tr><th class="tdhistory213632" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory213632">7.042226</td><td class="tdhistory213632">43.625951</td><td class="tdhistory213632">5G</td><td class="tdhistory213632">5G</td><td class="tdhistory213632">-118</td><td class="tdhistory213632">-6</td><td class="tdhistory213632">7</td><td class="tdhistory213632">7</td><td class="tdhistory213632">0</td><td class="tdhistory213632">5</td><td class="tdhistory213632">8</td><td class="tdhistory213632">223</td><td class="tdhistory213632">223</td><td class="tdhistory213632">D </td><td class="tdhistory213632"></td><td class="tdhistory213632">-101</td><td class="tdhistory213632">-14</td><td class="tdhistory213632">4</td><td class="tdhistory213632">4m27o</td><td class="tdhistory213632">Mobility</td><td class="tdhistory213632">27/10/2022</td><td class="tdhistory213632">10:22:18</td></tr><tr><th class="tdhistory213632" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory213632">7.06891</td><td class="tdhistory213632">43.615242</td><td class="tdhistory213632">4G</td><td class="tdhistory213632">LTE</td><td class="tdhistory213632">-105</td><td class="tdhistory213632">-6</td><td class="tdhistory213632">15</td><td class="tdhistory213632">13</td><td class="tdhistory213632">-105</td><td class="tdhistory213632">8264</td><td class="tdhistory213632">57</td><td class="tdhistory213632">174</td><td class="tdhistory213632">174</td><td class="tdhistory213632">D </td><td class="tdhistory213632">PERIODIC</td><td class="tdhistory213632">0</td><td class="tdhistory213632">0</td><td class="tdhistory213632">0</td><td class="tdhistory213632">i24aug</td><td class="tdhistory213632">Indoor</td><td class="tdhistory213632">24/08/2022</td><td class="tdhistory213632">17:03:05</td></tr><tr><th class="tdhistory213632" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory213632">7.06891</td><td class="tdhistory213632">43.615242</td><td class="tdhistory213632">4G</td><td class="tdhistory213632">LTE</td><td class="tdhistory213632">-105</td><td class="tdhistory213632">-6</td><td class="tdhistory213632">15</td><td class="tdhistory213632">13</td><td class="tdhistory213632">-105</td><td class="tdhistory213632">3</td><td class="tdhistory213632">6</td><td class="tdhistory213632">174</td><td class="tdhistory213632">174</td><td class="tdhistory213632">D </td><td class="tdhistory213632">PERIODIC</td><td class="tdhistory213632">0</td><td class="tdhistory213632">0</td><td class="tdhistory213632">0</td><td class="tdhistory213632">i24aug</td><td class="tdhistory213632">Indoor</td><td class="tdhistory213632">24/08/2022</td><td class="tdhistory213632">17:03:06</td></tr><tr><th class="tdhistory213632" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory213632">7.042317</td><td class="tdhistory213632">43.618827</td><td class="tdhistory213632">4G</td><td class="tdhistory213632">L ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Data Preparation</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let us first create a combined table of Youtube QoE and Channel level metrics.</p>

# %%
CREATE TABLE CLM_QOE AS (
    SELECT 
        QoE."Times" AS QoE_Time, 
        QoE."Dates" AS QoE_Date, 
        QoE."Eid" AS  Eid, 
        QoE."Video_Bytes_Downloaded",
        QoE."Video",
        QoE."Quality",
        QoE."Loaded_Percentage",
        CLM."Longitude",
        CLM."Latitude",
        CLM."NetworkTech",
        CLM."NetworkMode",
        CLM."Level",
        CLM."Qual",
        CLM."SNR",
        CLM."CQI",
        CLM."LTERSSI",
        CLM."DL_bitrate",
        CLM."UL_bitrate",
        CLM."Altitude",
        CLM."Height",
        CLM."State",
        CLM."Event",
        CLM."SecondCell_RSRP",
        CLM."SecondCell_RSRQ",
        CLM."SecondCell_SNR",
        CLM."Experiment_Type",    
        QoE."Dates" || ' ' ||QoE."Times" AS DateTime
    FROM Demo_5G.YouTube_QoE QoE
    INNER JOIN Demo_5G.Channel_Level_Metrics CLM
        ON QoE."Times" = CLM."Times"
        AND QoE."Dates" = CLM."Dates"
        AND QoE."Eid" = CLM."Eid"
) WITH DATA NO PRIMARY INDEX;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_QOE;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory811462"><style>
#       table.tdhistory811462 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory811462 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory811462:last-child { text-align: left !important; }
#       tbody.tdhistory811462 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory811462 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory811462 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory811462"></th><th class="tdhistory811462">QoE_Time</th><th class="tdhistory811462">QoE_Date</th><th class="tdhistory811462">Eid</th><th class="tdhistory811462">Video_Bytes_Downloaded</th><th class="tdhistory811462">Video</th><th class="tdhistory811462">Quality</th><th class="tdhistory811462">Loaded_Percentage</th><th class="tdhistory811462">Longitude</th><th class="tdhistory811462">Latitude</th><th class="tdhistory811462">NetworkTech</th><th class="tdhistory811462">NetworkMode</th><th class="tdhistory811462">Level</th><th class="tdhistory811462">Qual</th><th class="tdhistory811462">SNR</th><th class="tdhistory811462">CQI</th><th class="tdhistory811462">LTERSSI</th><th class="tdhistory811462">DL_bitrate</th><th class="tdhistory811462">UL_bitrate</th><th class="tdhistory811462">Altitude</th><th class="tdhistory811462">Height</th><th class="tdhistory811462">State</th><th class="tdhistory811462">EVENT</th><th class="tdhistory811462">SecondCell_RSRP</th><th class="tdhistory811462">SecondCell_RSRQ</th><th class="tdhistory811462">SecondCell_SNR</th><th class="tdhistory811462">Experiment_Type</th><th class="tdhistory811462">DateTime</th></tr></thead><tbody class="tdhistory811462 resultset-body"><tr><th class="tdhistory811462" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory811462">10:22:50</td><td class="tdhistory811462">27/10/2022</td><td class="tdhistory811462">4m27o</td><td class="tdhistory811462">0</td><td class="tdhistory811462">CHSnz0bCaUk</td><td class="tdhistory811462">hd720</td><td class="tdhistory811462">0</td><td class="tdhistory811462">7.044636</td><td class="tdhistory811462">43.62407</td><td class="tdhistory811462">5G</td><td class="tdhistory811462">5G</td><td class="tdhistory811462">-127</td><td class="tdhistory811462">-12</td><td class="tdhistory811462">-1</td><td class="tdhistory811462">11</td><td class="tdhistory811462">0</td><td class="tdhistory811462">3</td><td class="tdhistory811462">5</td><td class="tdhistory811462">209</td><td class="tdhistory811462">209</td><td class="tdhistory811462">D </td><td class="tdhistory811462">PERIODIC</td><td class="tdhistory811462">-108</td><td class="tdhistory811462">-13</td><td class="tdhistory811462">4</td><td class="tdhistory811462">Mobility</td><td class="tdhistory811462">27/10/2022 10:22:50</td></tr><tr><th class="tdhistory811462" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory811462">10:23:18</td><td class="tdhistory811462">27/10/2022</td><td class="tdhistory811462">4m27o</td><td class="tdhistory811462">0.355361153</td><td class="tdhistory811462">CHSnz0bCaUk</td><td class="tdhistory811462">small</td><td class="tdhistory811462">35.5</td><td class="tdhistory811462">7.044937</td><td class="tdhistory811462">43.623717</td><td class="tdhistory811462">4G</td><td class="tdhistory811462">4G</td><td class="tdhistory811462">-108</td><td class="tdhistory811462">-14</td><td class="tdhistory811462">2</td><td class="tdhistory811462">9</td><td class="tdhistory811462">-109</td><td class="tdhistory811462">6</td><td class="tdhistory811462">14</td><td class="tdhistory811462">207</td><td class="tdhistory811462">207</td><td class="tdhistory811462">D </td><td class="tdhistory811462">PERIODIC</td><td class="tdhistory811462">0</td><td class="tdhistory811462">0</td><td class="tdhistory811462">0</td><td class="tdhistory811462">Mobility</td><td class="tdhistory811462">27/10/2022 10:23:18</td></tr><tr><th class="tdhistory811462" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory811462">10:23:40</td><td class="tdhistory811462">27/10/2022</td><td class="tdhistory811462">4m27o</td><td class="tdhistory811462">0.430174028</td><td class="tdhistory811462">CHSnz0bCaUk</td><td class="tdhistory811462">medium</td><td class="tdhistory811462">43</td><td class="tdhistory811462">7.046261</td><td class="tdhistory811462">43.623772</td><td class="tdhistory811462"> ...

# %%
SELECT COUNT(*) AS total_rows FROM CLM_QOE;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory433889"><style>
#       table.tdhistory433889 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory433889 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory433889:last-child { text-align: left !important; }
#       tbody.tdhistory433889 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory433889 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory433889 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory433889"></th><th class="tdhistory433889">total_rows</th></tr></thead><tbody class="tdhistory433889 resultset-body"><tr><th class="tdhistory433889" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory433889">91748</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. Data Exploration</b></p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>TD_CategoricalSummary</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_CATEGORICALSUMMARY </b>function   displays the distinct values and their counts for each specified input table column</p>

# %%
SELECT * FROM TD_CategoricalSummary (
ON CLM_QOE AS InputTable
USING
    TargetColumns ('Experiment_Type','NetworkTech','NetworkMode','Event','State','Eid') 
) AS dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory105213"><style>
#       table.tdhistory105213 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory105213 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory105213:last-child { text-align: left !important; }
#       tbody.tdhistory105213 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory105213 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory105213 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory105213"></th><th class="tdhistory105213">ColumnName</th><th class="tdhistory105213">DistinctValue</th><th class="tdhistory105213">DistinctValueCount</th></tr></thead><tbody class="tdhistory105213 resultset-body"><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2m11aug</td><td class="tdhistory105213">876</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">28airport5g</td><td class="tdhistory105213">218</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">14augs</td><td class="tdhistory105213">51</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2i25auglte</td><td class="tdhistory105213">398</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2m16aug</td><td class="tdhistory105213">345</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2a19aug</td><td class="tdhistory105213">310</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2p9aug</td><td class="tdhistory105213">293</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2p23aug</td><td class="tdhistory105213">280</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2m20aug</td><td class="tdhistory105213">412</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2paug8</td><td class="tdhistory105213">492</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">3a25auglte</td><td class="tdhistory105213">91</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">4a26</td><td class="tdhistory105213">216</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2m23auglte</td><td class="tdhistory105213">482</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">3m16aug</td><td class="tdhistory105213">554</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">4a31</td><td class="tdhistory105213">224</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">4a30</td><td class="tdhistory105213">212</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">2m25auglte</td><td class="tdhistory105213">245</td></tr><tr><th class="tdhistory105213" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory105213">Eid</td><td class="tdhistory105213">3m25auglte</td><td class="tdhistory105213">395</td></tr><tr><th class="tdhistory105213" style= "backgrou ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>TD_ColumnSummary</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_ColumnSummary </b>function  displays Column name, datatype and other demographics like count of NULLs etc for each specified input table column</p>

# %%
SELECT * FROM TD_ColumnSummary (
  ON CLM_QOE AS InputTable
  USING
  TargetColumns ('Longitude','Latitude','LTERSSI','Level')
) AS dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory719575"><style>
#       table.tdhistory719575 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory719575 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory719575:last-child { text-align: left !important; }
#       tbody.tdhistory719575 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory719575 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory719575 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory719575"></th><th class="tdhistory719575">ColumnName</th><th class="tdhistory719575">Datatype</th><th class="tdhistory719575">NonNullCount</th><th class="tdhistory719575">NullCount</th><th class="tdhistory719575">BlankCount</th><th class="tdhistory719575">ZeroCount</th><th class="tdhistory719575">PositiveCount</th><th class="tdhistory719575">NegativeCount</th><th class="tdhistory719575">NullPercentage</th><th class="tdhistory719575">NonNullPercentage</th></tr></thead><tbody class="tdhistory719575 resultset-body"><tr><th class="tdhistory719575" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory719575">Latitude</td><td class="tdhistory719575">FLOAT</td><td class="tdhistory719575">91748</td><td class="tdhistory719575">0</td><td class="tdhistory719575"></td><td class="tdhistory719575">1298</td><td class="tdhistory719575">90450</td><td class="tdhistory719575">0</td><td class="tdhistory719575">0</td><td class="tdhistory719575">100</td></tr><tr><th class="tdhistory719575" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory719575">Longitude</td><td class="tdhistory719575">FLOAT</td><td class="tdhistory719575">91748</td><td class="tdhistory719575">0</td><td class="tdhistory719575"></td><td class="tdhistory719575">1298</td><td class="tdhistory719575">90045</td><td class="tdhistory719575">405</td><td class="tdhistory719575">0</td><td class="tdhistory719575">100</td></tr><tr><th class="tdhistory719575" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory719575">Level</td><td class="tdhistory719575">INTEGER</td><td class="tdhistory719575">91748</td><td class="tdhistory719575">0</td><td class="tdhistory719575"></td><td class="tdhistory719575">0</td><td class="tdhistory719575">0</td><td class="tdhistory719575">91748</td><td class="tdhistory719575">0</td><td class="tdhistory719575">100</td></tr><tr><th class="tdhistory719575" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory719575">LTERSSI</td><td class="tdhistory719575">INTEGER</td><td class="tdhistory719575">91748</td><td class="tdhistory719575">0</td><td class="tdhistory719575"></td><td class="tdhistory719575">42680</td><td class="tdhistory719575">0</td><td class="tdhistory719575">49068</td><td class="tdhistory719575">0</td><td class="tdhistory719575">100</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>4.1 Exploratory Data Analysis using TD_Plot</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_Plot</b> provides the ability to generate charts. The generated charts can be in the JPG, PNG, or SVG formats.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     Bar Chart - Video Quality Distribution</b></p>

# %%
CREATE MULTISET VOLATILE TABLE BAR_Graph_Videos_4G AS (
    SELECT Video, Quality,Video_Bytes_Downloaded,
        AVG(Loaded_Percentage) OVER (PARTITION BY Quality) AS Average_Loaded_Percentage, 
        Eid, DateTime,
        CASE 
            WHEN Quality = 'hd2160' THEN 1
            WHEN Quality = 'hd1440' THEN 2
            WHEN Quality = 'hd1080' THEN 3
            WHEN Quality = 'hd720' THEN 4
            WHEN Quality IN ('unknown', 'medium', 'large') THEN 5
        END AS Quality_Code,
        1 AS series
    FROM CLM_QOE
    WHERE Eid LIKE '4%'
    GROUP BY Video, Quality, Video_Bytes_Downloaded, Loaded_Percentage, Eid, DateTime
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In table BAR_Graph_Videos_4G we have the metrics for 4G videos</p>

# %%
CREATE MULTISET VOLATILE TABLE BAR_Graph_Videos_5G AS (
    SELECT Video, Quality,Video_Bytes_Downloaded, 
        AVG(Loaded_Percentage) OVER (PARTITION BY Quality) AS Average_Loaded_Percentage, 
        Eid, DateTime,
        CASE 
            WHEN Quality = 'hd2160' THEN 1
            WHEN Quality = 'hd1440' THEN 2
            WHEN Quality = 'hd1080' THEN 3
            WHEN Quality = 'hd720' THEN 4
            WHEN Quality IN ('unknown', 'medium', 'large') THEN 5
        END AS Quality_Code,
        1 AS series
    FROM CLM_QOE
    WHERE Eid LIKE '5%'
    GROUP BY Video, Quality, Video_Bytes_Downloaded,Loaded_Percentage, Eid, DateTime
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In table BAR_Graph_Videos_5G we have the metrics for 5G videos</p>

# %%
EXECUTE FUNCTION INTO VOLATILE ART(barGraph)
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(BAR_Graph_Videos_4G),
        ROW_AXIS(SEQUENCE(Quality_Code)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS("Average_Loaded_Percentage"),
           CONTENT(REAL)
        )
    ) where Quality_Code IN (1,2,3,4),
    
    
    SERIES_SPEC
    (
        TABLE_NAME(BAR_Graph_Videos_5G),
        ROW_AXIS(SEQUENCE(Quality_Code)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS("Average_Loaded_Percentage"),
           CONTENT(REAL)
        )
    ) where Quality_Code IN (1,2,3,4),
    
    
    
    FUNC_PARAMS
    (
        LAYOUT(2,1),
        WIDTH(900),
        HEIGHT(600),
        TITLE('Video Quality Distribution'),
        PLOTS[
            (
                ID(1),
                CELL(1,1),
                TITLE ('Video Quality Distribution on 4G Smartphone'),
                TYPE('bar'),
                LEGEND('best'),
                XLABEL('Quality Threshold'),
                YLABEL('Average_Loaded_Percentage')
            ),
            
             (
                ID(2),
                CELL(2,1),
                TITLE ('Video Quality Distribution on 5G Smartphone'),
                TYPE('bar'),
                LEGEND('best'),
                XLABEL('Quality Threshold'),
                YLABEL('Average_Loaded_Percentage')
            )
        ]
    )
);
# Out:
# Success: 1 rows affected

# %%
Select * from barGraph;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory952452"><style>
#       table.tdhistory952452 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory952452 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory952452:last-child { text-align: left !important; }
#       tbody.tdhistory952452 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory952452 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory952452 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory952452"></th><th class="tdhistory952452">Quality</th><th class="tdhistory952452">ROW_I</th><th class="tdhistory952452">IMAGE</th></tr></thead><tbody class="tdhistory952452 resultset-body"><tr><th class="tdhistory952452" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory952452"></td><td class="tdhistory952452">0</td><td class="tdhistory952452">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Click on the cell in the IMAGE column to select it, then right click on the cell and select View Image.</b></i> <br>The image should look like below.</p>

# %% [markdown]
# <center><img src="images/bargraph.png"/></center>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>From the above Bar Chart we can infer that</p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li> hd1440 consistently shows higher average loaded percentages on both 4G and 5G smartphones. </li>
# <li> hd1440 provides a better user experience in terms of loading time compared to other quality categories on both networks.</li>
# <li> These findings also suggest that network performance can vary for different video quality categories on different networks.</li>
#     <li> Optimal quality choices may depend on the smartphone's network capabilities.</li></ul>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Scatter Plot - 5G Vs 4G Mobility and Indoor Stalling Events</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Let us create subsets of 4G & 5G data for our analysis</p>

# %%
CREATE MULTISET VOLATILE TABLE "5g_time_stall_Mobility" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '5'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'M'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "4g_time_stall_Mobility" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '4'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'M'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA               
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "4g_time_stall_Indoor" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '4'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'I'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "5g_time_stall_Indoor" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '5'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'I'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let us check if our timeseries is regular or irregular series.<br>Irregular time series are data sequences where the observations or data points are not uniformly spaced in time. This may happen due to missing data or uneven data collection.

# %%
WITH time_diffs AS (
  SELECT
    Eid,
    MIN(Times) AS Min_Times,
    MAX(Times) AS Max_Times,
    Max_Times - LAG(Max_Times) OVER (ORDER BY Max_Times) AS Time_Diff
  FROM Demo_5G.YouTube_Player_Events
  GROUP BY Eid
)
SELECT
  CASE
    WHEN COUNT(DISTINCT Time_Diff) > 1 THEN 'Irregular'
    ELSE 'Regular' 
  END AS Time_Series_Type
FROM time_diffs;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory76801"><style>
#       table.tdhistory76801 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory76801 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory76801:last-child { text-align: left !important; }
#       tbody.tdhistory76801 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory76801 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory76801 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory76801"></th><th class="tdhistory76801">Time_Series_Type</th></tr></thead><tbody class="tdhistory76801 resultset-body"><tr><th class="tdhistory76801" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory76801">Irregular</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Our series is irregular, first let us make the series regular by resampling our data.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>TD_Resample</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
#     <b>TD_Resample</b> function Transforms converts irregular time series into a regular time series and performs linear interpolation.TD_Resample can also be used to alter the sampling interval for a time series.<br>Finding the minimum date, so that we can re-sample the dates from this date onwards which will convert irregular time series into a regular time series.

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "5g_time_stall_Mobility";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory731028"><style>
#       table.tdhistory731028 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory731028 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory731028:last-child { text-align: left !important; }
#       tbody.tdhistory731028 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory731028 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory731028 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory731028"></th><th class="tdhistory731028">Min_Date</th><th class="tdhistory731028">Max_Date</th><th class="tdhistory731028">Total_Count</th><th class="tdhistory731028">Unique_Count</th><th class="tdhistory731028">Repetitions_Status</th></tr></thead><tbody class="tdhistory731028 resultset-body"><tr><th class="tdhistory731028" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory731028">2022-07-09 03:58:12.000000</td><td class="tdhistory731028">2022-10-09 17:13:48.000000</td><td class="tdhistory731028">96</td><td class="tdhistory731028">94</td><td class="tdhistory731028">Repetitions Detected</td></tr></tbody></table></div>

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "4g_time_stall_Mobility";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory346654"><style>
#       table.tdhistory346654 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory346654 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory346654:last-child { text-align: left !important; }
#       tbody.tdhistory346654 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory346654 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory346654 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory346654"></th><th class="tdhistory346654">Min_Date</th><th class="tdhistory346654">Max_Date</th><th class="tdhistory346654">Total_Count</th><th class="tdhistory346654">Unique_Count</th><th class="tdhistory346654">Repetitions_Status</th></tr></thead><tbody class="tdhistory346654 resultset-body"><tr><th class="tdhistory346654" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory346654">2022-07-09 04:01:34.000000</td><td class="tdhistory346654">2022-10-28 12:23:24.000000</td><td class="tdhistory346654">264</td><td class="tdhistory346654">247</td><td class="tdhistory346654">Repetitions Detected</td></tr></tbody></table></div>

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "5g_time_stall_Indoor";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory169197"><style>
#       table.tdhistory169197 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory169197 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory169197:last-child { text-align: left !important; }
#       tbody.tdhistory169197 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory169197 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory169197 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory169197"></th><th class="tdhistory169197">Min_Date</th><th class="tdhistory169197">Max_Date</th><th class="tdhistory169197">Total_Count</th><th class="tdhistory169197">Unique_Count</th><th class="tdhistory169197">Repetitions_Status</th></tr></thead><tbody class="tdhistory169197 resultset-body"><tr><th class="tdhistory169197" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory169197">2022-08-09 15:24:44.000000</td><td class="tdhistory169197">2022-12-09 13:58:35.000000</td><td class="tdhistory169197">23</td><td class="tdhistory169197">23</td><td class="tdhistory169197">No Repetitions Found</td></tr></tbody></table></div>

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "4g_time_stall_Indoor";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory711732"><style>
#       table.tdhistory711732 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory711732 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory711732:last-child { text-align: left !important; }
#       tbody.tdhistory711732 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory711732 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory711732 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory711732"></th><th class="tdhistory711732">Min_Date</th><th class="tdhistory711732">Max_Date</th><th class="tdhistory711732">Total_Count</th><th class="tdhistory711732">Unique_Count</th><th class="tdhistory711732">Repetitions_Status</th></tr></thead><tbody class="tdhistory711732 resultset-body"><tr><th class="tdhistory711732" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory711732">2022-08-09 15:31:35.000000</td><td class="tdhistory711732">2022-12-09 13:58:33.000000</td><td class="tdhistory711732">331</td><td class="tdhistory711732">310</td><td class="tdhistory711732">Repetitions Detected</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Using the resample function to convert irregular time series into a regular time series

# %%
EXECUTE FUNCTION INTO VOLATILE ART("4g_resampled_time_stall_Mobility")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("4g_time_stall_Mobility"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-07-09 04:01:34'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 379539 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART("5g_resampled_time_stall_Mobility")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("5g_time_stall_Mobility"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-07-09 03:58:12'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 280704 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART("5g_resampled_time_stall_Indoor")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("5g_time_stall_Indoor"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-08-09 15:24:44'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 408815 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART("4g_resampled_time_stall_Indoor")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("4g_time_stall_Indoor"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-08-09 15:31:35'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 367069 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART(scatter_graph_timestall)
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME("4g_resampled_time_stall_Mobility"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME("5g_resampled_time_stall_Mobility"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    

     SERIES_SPEC
    (
        TABLE_NAME("4g_resampled_time_stall_Indoor"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME("5g_resampled_time_stall_Indoor"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    
    FUNC_PARAMS
    (
        LAYOUT(4, 1),
        WIDTH(1500),
        HEIGHT(600),
        TITLE('SCATTER GRAPH'),
        PLOTS[
            (
                ID(1),
                CELL(1, 1),
                TITLE ('4G Stalling on Video Resolutions Mobility'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            ),
            
            (
                ID(2),
                CELL(2, 1),
                TITLE ('5G Stalling on Video Resolutions Mobility'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            ),
            
            (
                ID(3),
                CELL(3, 1),
                TITLE ('4G Stalling on Video Resolutions Indoor'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            ),
            
            (
                ID(4),
                CELL(4, 1),
                TITLE ('5G Stalling on Video Resolutions Indoor'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            )
        ]
    )
);
# Out:
# Success: 1 rows affected

# %%
select * from scatter_graph_timestall;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory680034"><style>
#       table.tdhistory680034 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory680034 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory680034:last-child { text-align: left !important; }
#       tbody.tdhistory680034 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory680034 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory680034 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory680034"></th><th class="tdhistory680034">Quality</th><th class="tdhistory680034">ROW_I</th><th class="tdhistory680034">IMAGE</th></tr></thead><tbody class="tdhistory680034 resultset-body"><tr><th class="tdhistory680034" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory680034"></td><td class="tdhistory680034">0</td><td class="tdhistory680034">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Click on the cell in the IMAGE column to select it, then right click on the cell and select View Image.</b></i> <br>The image should look like below.

# %% [markdown]
# <center><img src="images/scatter.png"/></center>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>From the above Scatter Plot we can infer that</p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li> 4G on mobility, hd1440 exhibited the highest stalling duration over time, while hd720 experienced the least stalling. On 5G in mobility, hd2160 had brief but high stalling, while hd1440 showed less stalling but played for longer durations. </li>
# <li>Shifting to indoor settings on 4G, hd2160 initially had the highest stalling and hd1440 had minimal stalling.</li>
# <li>Indoor scenario on 5G, hd2160 had persistent stalling, hd1440 had the least stalling, and both hd1080 and hd720 showed minimal interruptions.</li>
#  <li> This indicates that higher video qualities tend to experience more stalling, especially in challenging network conditions, while lower qualities offer smoother playback</li></ul>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Line Graph - 5G vs 4G ( CQI, RSRP, RSRQ, SNR)</b></p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_5G_CQI AS (
  SELECT
    CQI,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      CQI,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY CQI)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY CQI), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        CQI,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '5G'
      GROUP BY CQI, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
CREATE  MULTISET VOLATILE TABLE CLM_4G_CQI AS (
  SELECT
    CQI,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      CQI,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY CQI)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY CQI), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        CQI,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '4G'
      GROUP BY CQI, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_5G_Level AS (
  SELECT
    Level,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      Level,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY Level)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY Level), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        Level,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '5G'
      GROUP BY Level, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_4G_Level AS (
  SELECT
    Level,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      Level,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY Level)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY Level), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        Level,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '4G'
      GROUP BY Level, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART(Benchamrking_CLM)
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(CLM_5G_CQI),
        ROW_AXIS(SEQUENCE(CQI)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL)
        )
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME(CLM_4G_CQI ),
        ROW_AXIS(SEQUENCE(CQI)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL))
    
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME(CLM_5G_Level ),
        ROW_AXIS(SEQUENCE(Level)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL))
    
    ),
    SERIES_SPEC
    (
        TABLE_NAME(CLM_4G_Level ),
        ROW_AXIS(SEQUENCE(Level)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL))
    
    ),
    
    
    FUNC_PARAMS
    (
        LAYOUT(2,2),
        WIDTH(1000),
        HEIGHT(800),
        TITLE('4G Vs 5G Channel Level Metric Performance '),
        PLOTS[
            (
                ID(1),
                CELL(1,1),
                TYPE('line'),
                Title('5G CQI'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('CQI'),
                YLABEL('Frequecny')
            ),(
                ID(2),
                CELL(1,2),
                TYPE('line'),
                Title('4G CQI'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('CQI'),
                YLABEL('Frequecny')
            ),
            
            (
                ID(3),
                CELL(2,1),
                TYPE('line'),
                Title('5G RSRP'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('RSRP'),
                YLABEL('Frequecny')
            ),
            (
                ID(4),
                CELL(2,2),
                TYPE('line'),
                Title('4G RSRP'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('RSRP'),
                YLABEL('Frequecny')
            )

        ]
    )
);
# Out:
# Success: 1 rows affected

# %%
select * from Benchamrking_CLM;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory975759"><style>
#       table.tdhistory975759 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory975759 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory975759:last-child { text-align: left !important; }
#       tbody.tdhistory975759 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory975759 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory975759 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory975759"></th><th class="tdhistory975759">Experiment_Type</th><th class="tdhistory975759">ROW_I</th><th class="tdhistory975759">IMAGE</th></tr></thead><tbody class="tdhistory975759 resultset-body"><tr><th class="tdhistory975759" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory975759"></td><td class="tdhistory975759">0</td><td class="tdhistory975759">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Click on the cell in the IMAGE column to select it, then right click on the cell and select View Image.</b></i> <br>The image should look like below.

# %% [markdown]
# <center><img src="images/line.png"/></center>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>From the above line chart we can infer that
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li> The spread-out distribution in the 5G and 4G CQI graphs indicates that the CQI values vary across different experiments, higher values indicating better signal quality.</li>
# <li>In the case of RSRP, the presence of frequent spikes in both the 5G and 4G RSRP graphs suggests significant fluctuations in signal strength. The spikes indicate instances where the RSRP values deviate from the average or expected levels. Negative values of RSRP indicating relatively weaker signal power.</li>
# <li>Overall, these observations provide insights into the performance of CQI and RSRP metrics across different experiments and network technologies. The variations and patterns in CQI and RSRP values reflect the changing channel conditions, signal quality, and signal power, which can impact the overall network performance and user experience.</li>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. Feature Engineering and Selection</b></p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     Target Variable</b></p>

# %% [markdown]
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li>To identify a user's quality of experience using youtube video statistics we derive "load rate", a metric can be used to represent how smooth the video is playing. </li>
#     <li>If the load rate will is low there will be more buffering time and in turn will impact user's overall viewing  experience and vice versa</li>
#     </ul>
#  <ul style = 'font-size:16px;font-family:Arial;color:#00233C'> Derive Features Include
#     <li><b>Load_rate</b>  = loaded percentage/ (current time)-(start time of the experiment) i.e Duration of Experiment</li>
#     <li><b>Rate_category</b> = (Less Then 0.3 = Low),  (Between  0.3 and 0.5 = Medium), (Above 0.5 - High)</li>
#     <li><b>Distance</b> = Total Haversine Distance for EIDs </li></ul>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS AS (
  SELECT dt.*,  
    CASE
      WHEN dt.load_rate >= 0 AND dt.load_rate <= 0.30 THEN 'low'
      WHEN dt.load_rate >= 0.30 AND dt.load_rate < 0.50 THEN 'med'
      ELSE 'high'
    END AS rate_category
    
  FROM (
    select CLM_QOE.*,  
     TO_TIMESTAMP(CLM_QOE."DateTime",'DD/MM/YYYY HH24:MI:SS') AS OTHER_TIME,
     MIN(TO_TIMESTAMP(CLM_QOE."DateTime",'DD/MM/YYYY HH24:MI:SS')) 
     OVER (PARTITION BY CLM_QOE."Eid") AS MIN_TIME,
     (OTHER_TIME - MIN_TIME) HOUR(2) TO SECOND AS TIME_DIFF,
     CAST(EXTRACT(HOUR  FROM TIME_DIFF) * 3600
     + EXTRACT(MINUTE FROM TIME_DIFF) * 60
      + EXTRACT(SECOND FROM TIME_DIFF) AS INT) AS TIME_DIFF_SECS,
      CLM_QOE.Loaded_Percentage / NULLIFZERO (TIME_DIFF_SECS) AS LOAD_RATE
      FROM CLM_QOE
  ) AS dt
) WITH DATA
On commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_ADS;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory319184"><style>
#       table.tdhistory319184 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory319184 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory319184:last-child { text-align: left !important; }
#       tbody.tdhistory319184 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory319184 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory319184 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory319184"></th><th class="tdhistory319184">QoE_Time</th><th class="tdhistory319184">QoE_Date</th><th class="tdhistory319184">Eid</th><th class="tdhistory319184">Video_Bytes_Downloaded</th><th class="tdhistory319184">Video</th><th class="tdhistory319184">Quality</th><th class="tdhistory319184">Loaded_Percentage</th><th class="tdhistory319184">Longitude</th><th class="tdhistory319184">Latitude</th><th class="tdhistory319184">NetworkTech</th><th class="tdhistory319184">NetworkMode</th><th class="tdhistory319184">Level</th><th class="tdhistory319184">Qual</th><th class="tdhistory319184">SNR</th><th class="tdhistory319184">CQI</th><th class="tdhistory319184">LTERSSI</th><th class="tdhistory319184">DL_bitrate</th><th class="tdhistory319184">UL_bitrate</th><th class="tdhistory319184">Altitude</th><th class="tdhistory319184">Height</th><th class="tdhistory319184">State</th><th class="tdhistory319184">EVENT</th><th class="tdhistory319184">SecondCell_RSRP</th><th class="tdhistory319184">SecondCell_RSRQ</th><th class="tdhistory319184">SecondCell_SNR</th><th class="tdhistory319184">Experiment_Type</th><th class="tdhistory319184">DateTime</th><th class="tdhistory319184">OTHER_TIME</th><th class="tdhistory319184">MIN_TIME</th><th class="tdhistory319184">TIME_DIFF</th><th class="tdhistory319184">TIME_DIFF_SECS</th><th class="tdhistory319184">LOAD_RATE</th><th class="tdhistory319184">rate_category</th></tr></thead><tbody class="tdhistory319184 resultset-body"><tr><th class="tdhistory319184" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory319184">12:06:42</td><td class="tdhistory319184">28/09/2022</td><td class="tdhistory319184">28airport5g</td><td class="tdhistory319184">0.352907118</td><td class="tdhistory319184">jAa58N4Jlos</td><td class="tdhistory319184">hd2160</td><td class="tdhistory319184">35.3</td><td class="tdhistory319184">7.214106</td><td class="tdhistory319184">43.66486</td><td class="tdhistory319184">4G</td><td class="tdhistory319184">LTE</td><td class="tdhistory319184">-113</td><td class="tdhistory319184">-15</td><td class="tdhistory319184">1</td><td class="tdhistory319184">7</td><td class="tdhistory319184">-113</td><td class="tdhistory319184">25040</td><td class="tdhistory319184">157</td><td class="tdhistory319184">56</td><td class="tdhistory319184">56</td><td class="tdhistory319184">D </td><td class="tdhistory319184">PERIODIC</td><td class="tdhistory319184">0</td><td class="tdhistory319184">0</td><td class="tdhistory319184">0</td><td class="tdhistory319184">Outdoor</td><td class="tdhistory319184">28/09/2022 12:06:42</td><td class="tdhistory319184">2022-09-28 12:06:42.000000</td><td class="tdhistory319184">2022-09-28 12:05:41.000000</td><td class="tdhistory319184">  0:01:01.000000</td><td class="tdhistory319184">61</td><td class="tdhistory319184">0.5786885245901638</td><td class="tdhistory319184">high</td></tr><tr><th class="tdhistory319184" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory319184">12:06:40</td><td class="tdhistory319184">28/09/2022</td><td class="tdhistory319184">28airport5g</td><td class="tdhistory319184">0.352907118</td><td class="tdhistory319184">jAa58N4Jlos</td><td class="tdhistory319184">hd2160</td><td class="tdhistory319184">35.3</td><td class="tdhistory319184">7.214106</td><td class="tdhistory319184">43.66486</td><td class="tdhistory319184">4G</td><td class="tdhistory319184">LTE</td><td class="tdhistory319184">-114</td><td class="tdhistory319184">-15</td><td class="tdhistory319184">2</td><td class="tdhistory319184">8</td><td class="tdhistory319184">-113</td><td class="tdhistory319184">223</td><td class="tdhistory319184">104</td><td class="tdhistory319184">56</td><td class="tdhistory319184">56</td><td class="tdhistory319184">D </td><td class="tdhistory319184">PERIODIC</td><td class="tdhistory319184">0</td><td class="tdhistory319184">0</td><td class="tdhistory319184">0</td ...

# %%
SELECT * FROM TD_CategoricalSummary (
ON CLM_ADS AS InputTable
USING
    TargetColumns ('rate_category') 
) AS dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory812828"><style>
#       table.tdhistory812828 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory812828 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory812828:last-child { text-align: left !important; }
#       tbody.tdhistory812828 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory812828 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory812828 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory812828"></th><th class="tdhistory812828">ColumnName</th><th class="tdhistory812828">DistinctValue</th><th class="tdhistory812828">DistinctValueCount</th></tr></thead><tbody class="tdhistory812828 resultset-body"><tr><th class="tdhistory812828" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory812828">rate_category</td><td class="tdhistory812828">low</td><td class="tdhistory812828">29338</td></tr><tr><th class="tdhistory812828" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory812828">rate_category</td><td class="tdhistory812828">high</td><td class="tdhistory812828">27452</td></tr><tr><th class="tdhistory812828" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory812828">rate_category</td><td class="tdhistory812828">med</td><td class="tdhistory812828">34958</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Rate_Category column is our target variable for the models we'll create in next steps. We will classify our test data in one of the above category(cluster).</p>

# %%
%chart x=DistinctValue,y=DistinctValueCount,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster",height= 400,width=400

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     Data Preparation</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Before we can use the data in models we will perform some data preparation steps.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Label Encoding </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_OrdinalEncodingFit </b>function identifies distinct categorical values from an input table or a user-defined list and returns the distinct categorical values along with the ordinal value for each category.The <b>TD_OrdinalEncodingTransform</b> function maps the categorical value to a specified ordinal value using the TD_OrdinalEncodingFit output.</p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_ENCODED AS (
SELECT * FROM TD_OrdinalEncodingFit (
ON CLM_ADS AS InputTable
USING
TargetColumn('Quality','NetworkTech','NetworkMode','Experiment_Type','rate_category')
Approach ('AUTO')
StartValue (0,0,0,0,0)
DefaultValue (-1,-1,-1,-1,-1)
) AS dt
) WITH DATA
On commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_ADS_ENCODED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory160764"><style>
#       table.tdhistory160764 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory160764 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory160764:last-child { text-align: left !important; }
#       tbody.tdhistory160764 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory160764 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory160764 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory160764"></th><th class="tdhistory160764">TD_ColumnName_ORDFIT</th><th class="tdhistory160764">TD_Category_ORDFIT</th><th class="tdhistory160764">TD_Value_ORDFIT</th><th class="tdhistory160764">TD_Index_ORDFIT</th><th class="tdhistory160764">Quality</th><th class="tdhistory160764">NetworkTech</th><th class="tdhistory160764">NetworkMode</th><th class="tdhistory160764">Experiment_Type</th><th class="tdhistory160764">rate_category</th></tr></thead><tbody class="tdhistory160764 resultset-body"><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory160764">Quality</td><td class="tdhistory160764">hd2160</td><td class="tdhistory160764">2</td><td class="tdhistory160764">0</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory160764">Quality</td><td class="tdhistory160764">large</td><td class="tdhistory160764">4</td><td class="tdhistory160764">0</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory160764">Quality</td><td class="tdhistory160764">medium</td><td class="tdhistory160764">5</td><td class="tdhistory160764">0</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory160764">Quality</td><td class="tdhistory160764">small</td><td class="tdhistory160764">6</td><td class="tdhistory160764">0</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory160764">Quality</td><td class="tdhistory160764">unknown</td><td class="tdhistory160764">8</td><td class="tdhistory160764">0</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory160764">Quality</td><td class="tdhistory160764">TD_CATEGORY_COUNT</td><td class="tdhistory160764">9</td><td class="tdhistory160764">-1</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory160764">NetworkTech</td><td class="tdhistory160764">3G</td><td class="tdhistory160764">0</td><td class="tdhistory160764">1</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory160764">NetworkTech</td><td class="tdhistory160764">4G</td><td class="tdhistory160764">1</td><td class="tdhistory160764">1</td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td><td class="tdhistory160764"></td></tr><tr><th class="tdhistory160764" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory160764">NetworkTech</td><td class="tdhistory160764">5G</td><td class="tdhistory16076 ...

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_TRANSFORMED AS (
SELECT * FROM TD_OrdinalEncodingTransform (
ON CLM_ADS as InputTable
ON CLM_ADS_ENCODED as FitTable Dimension
USING
ACCUMULATE('QoE_Time','QoE_Date','Eid','Video_Bytes_Downloaded','Video','Loaded_Percentage', 'Longitude','Latitude','Level','Qual','SNR','CQI', 'LTERSSI', 'DL_bitrate','UL_bitrate','Altitude','Height','State','EVENT','SecondCell_RSRP','SecondCell_RSRQ','SecondCell_SNR', 'DateTime','OTHER_TIME', 'MIN_TIME', 'TIME_DIFF','TIME_DIFF_SECS','Load_Rate')
) AS dt
) WITH DATA
On commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_ADS_TRANSFORMED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory795437"><style>
#       table.tdhistory795437 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory795437 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory795437:last-child { text-align: left !important; }
#       tbody.tdhistory795437 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory795437 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory795437 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory795437"></th><th class="tdhistory795437">QoE_Time</th><th class="tdhistory795437">QoE_Date</th><th class="tdhistory795437">Eid</th><th class="tdhistory795437">Video_Bytes_Downloaded</th><th class="tdhistory795437">Video</th><th class="tdhistory795437">Loaded_Percentage</th><th class="tdhistory795437">Longitude</th><th class="tdhistory795437">Latitude</th><th class="tdhistory795437">Level</th><th class="tdhistory795437">Qual</th><th class="tdhistory795437">SNR</th><th class="tdhistory795437">CQI</th><th class="tdhistory795437">LTERSSI</th><th class="tdhistory795437">DL_bitrate</th><th class="tdhistory795437">UL_bitrate</th><th class="tdhistory795437">Altitude</th><th class="tdhistory795437">Height</th><th class="tdhistory795437">State</th><th class="tdhistory795437">EVENT</th><th class="tdhistory795437">SecondCell_RSRP</th><th class="tdhistory795437">SecondCell_RSRQ</th><th class="tdhistory795437">SecondCell_SNR</th><th class="tdhistory795437">DateTime</th><th class="tdhistory795437">OTHER_TIME</th><th class="tdhistory795437">MIN_TIME</th><th class="tdhistory795437">TIME_DIFF</th><th class="tdhistory795437">TIME_DIFF_SECS</th><th class="tdhistory795437">LOAD_RATE</th><th class="tdhistory795437">Quality</th><th class="tdhistory795437">NetworkTech</th><th class="tdhistory795437">NetworkMode</th><th class="tdhistory795437">Experiment_Type</th><th class="tdhistory795437">rate_category</th></tr></thead><tbody class="tdhistory795437 resultset-body"><tr><th class="tdhistory795437" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory795437">12:06:42</td><td class="tdhistory795437">28/09/2022</td><td class="tdhistory795437">28airport5g</td><td class="tdhistory795437">0.352907118</td><td class="tdhistory795437">jAa58N4Jlos</td><td class="tdhistory795437">35.3</td><td class="tdhistory795437">7.214106</td><td class="tdhistory795437">43.66486</td><td class="tdhistory795437">-113</td><td class="tdhistory795437">-15</td><td class="tdhistory795437">1</td><td class="tdhistory795437">7</td><td class="tdhistory795437">-113</td><td class="tdhistory795437">25040</td><td class="tdhistory795437">157</td><td class="tdhistory795437">56</td><td class="tdhistory795437">56</td><td class="tdhistory795437">D </td><td class="tdhistory795437">PERIODIC</td><td class="tdhistory795437">0</td><td class="tdhistory795437">0</td><td class="tdhistory795437">0</td><td class="tdhistory795437">28/09/2022 12:06:42</td><td class="tdhistory795437">2022-09-28 12:06:42.000000</td><td class="tdhistory795437">2022-09-28 12:05:41.000000</td><td class="tdhistory795437">  0:01:01.000000</td><td class="tdhistory795437">61</td><td class="tdhistory795437">0.5786885245901638</td><td class="tdhistory795437">2</td><td class="tdhistory795437">1</td><td class="tdhistory795437">3</td><td class="tdhistory795437">2</td><td class="tdhistory795437">0</td></tr><tr><th class="tdhistory795437" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory795437">12:06:40</td><td class="tdhistory795437">28/09/2022</td><td class="tdhistory795437">28airport5g</td><td class="tdhistory795437">0.352907118</td><td class="tdhistory795437">jAa58N4Jlos</td><td class="tdhistory795437">35.3</td><td class="tdhistory795437">7.214106</td><td class="tdhistory795437">43.66486</td><td class="tdhistory795437">-114</td><td class="tdhistory795437">-15</td><td class="tdhistory795437">2</td><td class="tdhistory795437">8</td><td class="tdhistory795437">-113</td><td class="tdhistory795437">223</td><td class="tdhistory795437">104</td><td class="tdhistory795437">56</td><td class="tdhistory795437">56</td><td class="tdhistory795437">D </td><td class="tdhistory795437">PERIODIC</td><td class="tdhistory795437">0</td><td class="tdhistory795437">0</td><td class="tdhistory795437">0</td><td class="tdhistory795437">28/09/2022 12:06:40</td><td class="tdhistory795437">2022-09-28 12:06:40.000000</td><td class="tdhi ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_TrainTestSplit </b>The function randomly divides the data sets into train and test subsets to evaluate machine learning algorithms and validation processes. The first subset is used to train the model. The second subset is used to make predictions and compare the predictions to actual values. </p>

# %%
CREATE MULTISET TABLE CLM_ADS_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_TRANSFORMED AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET TABLE CLM_ADS_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_TRANSFORMED AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
select rate_category, count(*) from CLM_ADS_TEST group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory93260"><style>
#       table.tdhistory93260 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory93260 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory93260:last-child { text-align: left !important; }
#       tbody.tdhistory93260 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory93260 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory93260 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory93260"></th><th class="tdhistory93260">rate_category</th><th class="tdhistory93260">Count(*)</th></tr></thead><tbody class="tdhistory93260 resultset-body"><tr><th class="tdhistory93260" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory93260">1</td><td class="tdhistory93260">8882</td></tr><tr><th class="tdhistory93260" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory93260">0</td><td class="tdhistory93260">8088</td></tr><tr><th class="tdhistory93260" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory93260">2</td><td class="tdhistory93260">10555</td></tr></tbody></table></div>

# %%
select rate_category, count(*) as counts from CLM_ADS_TEST group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory298747"><style>
#       table.tdhistory298747 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory298747 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory298747:last-child { text-align: left !important; }
#       tbody.tdhistory298747 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory298747 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory298747 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory298747"></th><th class="tdhistory298747">rate_category</th><th class="tdhistory298747">counts</th></tr></thead><tbody class="tdhistory298747 resultset-body"><tr><th class="tdhistory298747" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory298747">1</td><td class="tdhistory298747">8882</td></tr><tr><th class="tdhistory298747" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory298747">0</td><td class="tdhistory298747">8088</td></tr><tr><th class="tdhistory298747" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory298747">2</td><td class="tdhistory298747">10555</td></tr></tbody></table></div>

# %%
%chart x=rate_category,y=counts,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster in Test data",height= 400,width=400

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. Model Training and Evaluation </b> </p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     6.1 Decision Forest</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_DecisionForest</b> function is an ensemble algorithm used for classification and regression predictive modeling problems. It is an extension of bootstrap aggregation (bagging) of decision trees.
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>This function takes the training data as input, as well as the following function parameters</p>
#     <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#         <li>InputColumns; list or range of columns used as features (we used an ordinal reference of columns 2:217)</li>
#         <li>ResponseColumn; the dependent or target value (we used “class”, the first column)</li>
#         <li>TreeType; either CLASSIFICATION or REGRESSION</li>
#     <li>Other hyperparameter values detailed in the documentation</li>
#         </ul>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates model.  Due to the limited resources of this VM, processing this step may take up to 4 minutes to run.</b></i>

# %%
CREATE MULTISET TABLE CLM_ADS_MDL_DF AS (
select * from TD_DecisionForest (
ON CLM_ADS_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode','Experiment_Type')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType('classification')
) as dt
) WITH DATA
;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     6.2 XGboost</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
#  The <b>TD_XGBoost </b>is an implementation of the gradient boosted decision tree designed for speed and performance. In gradient boosting, each iteration fits a model to the residuals (errors) of the previous iteration to correct the errors made by existing models. The predicted residual is multiplied by this learning rate and then added to the previous prediction. Models are added sequentially until no further improvements can be made. It is called gradient boosting because it uses a gradient descent algorithm to minimize the loss when adding new models.</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 1 minute to run.</b></i>

# %%
CREATE MULTISET TABLE CLM_ADS_MDL_XGB AS (
select * from TD_XGBoost (
ON CLM_ADS_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode','Experiment_Type')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)    
   ModelType('classification')
) as dt
) WITH DATA;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>
#     7. Macro Model - Combined</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Run predictions based on the models created above.

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Decision Forest</b></p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_PRED_DF AS (
SELECT * FROM TD_DecisionForestPredict (
ON CLM_ADS_TEST AS InputTable PARTITION BY ANY
ON CLM_ADS_MDL_DF AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from CLM_ADS_PRED_DF;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory415549"><style>
#       table.tdhistory415549 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory415549 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory415549:last-child { text-align: left !important; }
#       tbody.tdhistory415549 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory415549 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory415549 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory415549"></th><th class="tdhistory415549">rate_category</th><th class="tdhistory415549">DateTime</th><th class="tdhistory415549">prediction</th><th class="tdhistory415549">confidence_lower</th><th class="tdhistory415549">confidence_upper</th></tr></thead><tbody class="tdhistory415549 resultset-body"><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory415549">2</td><td class="tdhistory415549">23/08/2022 19:06:25</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.68</td><td class="tdhistory415549">0.68</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory415549">1</td><td class="tdhistory415549">23/08/2022 19:08:41</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.46</td><td class="tdhistory415549">0.46</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory415549">2</td><td class="tdhistory415549">23/08/2022 19:06:18</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.67</td><td class="tdhistory415549">0.67</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory415549">1</td><td class="tdhistory415549">23/08/2022 19:08:23</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.47</td><td class="tdhistory415549">0.47</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory415549">1</td><td class="tdhistory415549">23/08/2022 19:08:08</td><td class="tdhistory415549">1</td><td class="tdhistory415549">0.45</td><td class="tdhistory415549">0.45</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory415549">1</td><td class="tdhistory415549">23/08/2022 19:07:36</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.45</td><td class="tdhistory415549">0.45</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory415549">0</td><td class="tdhistory415549">23/08/2022 19:04:40</td><td class="tdhistory415549">1</td><td class="tdhistory415549">0.39</td><td class="tdhistory415549">0.39</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory415549">1</td><td class="tdhistory415549">23/08/2022 19:07:43</td><td class="tdhistory415549">1</td><td class="tdhistory415549">0.44</td><td class="tdhistory415549">0.44</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory415549">1</td><td class="tdhistory415549">23/08/2022 19:09:23</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.46</td><td class="tdhistory415549">0.46</td></tr><tr><th class="tdhistory415549" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory415549">2</td><td class="tdhistory415549">23/08/2022 19:06:12</td><td class="tdhistory415549">2</td><td class="tdhistory415549">0.77</td><td class="tdhistory415549">0.77</td></tr></tbody></table></div>

# %%
select prediction as rate_category, count(*) as counts from CLM_ADS_PRED_DF group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory290437"><style>
#       table.tdhistory290437 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory290437 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory290437:last-child { text-align: left !important; }
#       tbody.tdhistory290437 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory290437 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory290437 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory290437"></th><th class="tdhistory290437">rate_category</th><th class="tdhistory290437">counts</th></tr></thead><tbody class="tdhistory290437 resultset-body"><tr><th class="tdhistory290437" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory290437">1</td><td class="tdhistory290437">7817</td></tr><tr><th class="tdhistory290437" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory290437">0</td><td class="tdhistory290437">9868</td></tr><tr><th class="tdhistory290437" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory290437">2</td><td class="tdhistory290437">9840</td></tr></tbody></table></div>

# %%
%chart x=rate_category,y=counts,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster in Test data by Decision Forest Model",height= 400,width=400

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can compare the counts categorized by DF model and the test data category counts.</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>XG-boost</b></p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_PRED_XGB AS (
SELECT * FROM TD_XGBoostPredict (
ON CLM_ADS_TEST AS InputTable PARTITION BY ANY
ON CLM_ADS_MDL_XGB AS ModelTable DIMENSION ORDER BY task_index, tree_num, iter, class_num, 
tree_order
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
    ModelType('Classification')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from CLM_ADS_PRED_XGB;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory851472"><style>
#       table.tdhistory851472 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory851472 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory851472:last-child { text-align: left !important; }
#       tbody.tdhistory851472 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory851472 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory851472 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory851472"></th><th class="tdhistory851472">rate_category</th><th class="tdhistory851472">DateTime</th><th class="tdhistory851472">Prediction</th><th class="tdhistory851472">Confidence_Lower</th><th class="tdhistory851472">Confidence_upper</th></tr></thead><tbody class="tdhistory851472 resultset-body"><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:06:10</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.39473684210526316</td><td class="tdhistory851472">0.39473684210526316</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:08:39</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.40789473684210525</td><td class="tdhistory851472">0.40789473684210525</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:07:32</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.3815789473684211</td><td class="tdhistory851472">0.3815789473684211</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:08:16</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.3815789473684211</td><td class="tdhistory851472">0.3815789473684211</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:08:18</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.3815789473684211</td><td class="tdhistory851472">0.3815789473684211</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:07:21</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.40789473684210525</td><td class="tdhistory851472">0.40789473684210525</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:06:43</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.3815789473684211</td><td class="tdhistory851472">0.3815789473684211</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:07:11</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.3815789473684211</td><td class="tdhistory851472">0.3815789473684211</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:06:02</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.3684210526315789</td><td class="tdhistory851472">0.3684210526315789</td></tr><tr><th class="tdhistory851472" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory851472">0</td><td class="tdhistory851472">28/09/2022 12:06:42</td><td class="tdhistory851472">1</td><td class="tdhistory851472">0.39473684210526316</td><td class="tdhistory851472">0.39473684210526316</td></tr></tbody></table></div>

# %%
select prediction as rate_category, count(*) as counts from CLM_ADS_PRED_XGB group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory387730"><style>
#       table.tdhistory387730 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory387730 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory387730:last-child { text-align: left !important; }
#       tbody.tdhistory387730 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory387730 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory387730 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory387730"></th><th class="tdhistory387730">rate_category</th><th class="tdhistory387730">counts</th></tr></thead><tbody class="tdhistory387730 resultset-body"><tr><th class="tdhistory387730" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory387730">1</td><td class="tdhistory387730">3341</td></tr><tr><th class="tdhistory387730" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory387730">0</td><td class="tdhistory387730">17270</td></tr><tr><th class="tdhistory387730" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory387730">2</td><td class="tdhistory387730">6914</td></tr></tbody></table></div>

# %%
%chart x=rate_category,y=counts,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster in Test data by XGB Model",height= 400,width=400

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can compare the counts categorized by DF model and the test data category counts.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>
#     8. Model Evaluation</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_ClassificationEvaluator</b> In classification problems, a confusion matrix is used to visualize the performance of a classifier. The confusion matrix contains predicted labels represented across the row-axis and actual labels represented across the column-axis. Each cell in the confusion matrix corresponds to the count of occurrences of labels in the test data. TD_ClassificationEvaluator functions creates the confusion matrix. </p>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  CLM_ADS_PRED_DF AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory125723"><style>
#       table.tdhistory125723 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory125723 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory125723:last-child { text-align: left !important; }
#       tbody.tdhistory125723 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory125723 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory125723 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory125723"></th><th class="tdhistory125723">SeqNum</th><th class="tdhistory125723">Prediction</th><th class="tdhistory125723">Mapping</th><th class="tdhistory125723">CLASS_1</th><th class="tdhistory125723">CLASS_2</th><th class="tdhistory125723">CLASS_3</th><th class="tdhistory125723">Precision</th><th class="tdhistory125723">Recall</th><th class="tdhistory125723">F1</th><th class="tdhistory125723">Support</th></tr></thead><tbody class="tdhistory125723 resultset-body"><tr><th class="tdhistory125723" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory125723">0</td><td class="tdhistory125723">0</td><td class="tdhistory125723">CLASS_1</td><td class="tdhistory125723">5599</td><td class="tdhistory125723">1531</td><td class="tdhistory125723">2738</td><td class="tdhistory125723">0.56738954195379</td><td class="tdhistory125723">0.6922601384767557</td><td class="tdhistory125723">0.6236355535754066</td><td class="tdhistory125723">8088</td></tr><tr><th class="tdhistory125723" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory125723">1</td><td class="tdhistory125723">1</td><td class="tdhistory125723">CLASS_2</td><td class="tdhistory125723">992</td><td class="tdhistory125723">5343</td><td class="tdhistory125723">1482</td><td class="tdhistory125723">0.6835102980683126</td><td class="tdhistory125723">0.6015537041206935</td><td class="tdhistory125723">0.639918557997485</td><td class="tdhistory125723">8882</td></tr><tr><th class="tdhistory125723" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory125723">2</td><td class="tdhistory125723">2</td><td class="tdhistory125723">CLASS_3</td><td class="tdhistory125723">1497</td><td class="tdhistory125723">2008</td><td class="tdhistory125723">6335</td><td class="tdhistory125723">0.6438008130081301</td><td class="tdhistory125723">0.6001894836570346</td><td class="tdhistory125723">0.6212306937974995</td><td class="tdhistory125723">10555</td></tr></tbody></table></div>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  CLM_ADS_PRED_XGB AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory718981"><style>
#       table.tdhistory718981 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory718981 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory718981:last-child { text-align: left !important; }
#       tbody.tdhistory718981 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory718981 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory718981 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory718981"></th><th class="tdhistory718981">SeqNum</th><th class="tdhistory718981">Prediction</th><th class="tdhistory718981">Mapping</th><th class="tdhistory718981">CLASS_1</th><th class="tdhistory718981">CLASS_2</th><th class="tdhistory718981">CLASS_3</th><th class="tdhistory718981">Precision</th><th class="tdhistory718981">Recall</th><th class="tdhistory718981">F1</th><th class="tdhistory718981">Support</th></tr></thead><tbody class="tdhistory718981 resultset-body"><tr><th class="tdhistory718981" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory718981">0</td><td class="tdhistory718981">0</td><td class="tdhistory718981">CLASS_1</td><td class="tdhistory718981">6208</td><td class="tdhistory718981">4282</td><td class="tdhistory718981">6780</td><td class="tdhistory718981">0.35946728430804864</td><td class="tdhistory718981">0.7675568743818002</td><td class="tdhistory718981">0.48962851959933745</td><td class="tdhistory718981">8088</td></tr><tr><th class="tdhistory718981" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory718981">1</td><td class="tdhistory718981">1</td><td class="tdhistory718981">CLASS_2</td><td class="tdhistory718981">602</td><td class="tdhistory718981">1840</td><td class="tdhistory718981">899</td><td class="tdhistory718981">0.5507333133792278</td><td class="tdhistory718981">0.207160549425805</td><td class="tdhistory718981">0.3010717499795468</td><td class="tdhistory718981">8882</td></tr><tr><th class="tdhistory718981" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory718981">2</td><td class="tdhistory718981">2</td><td class="tdhistory718981">CLASS_3</td><td class="tdhistory718981">1278</td><td class="tdhistory718981">2760</td><td class="tdhistory718981">2876</td><td class="tdhistory718981">0.4159676019670234</td><td class="tdhistory718981">0.27247749881572714</td><td class="tdhistory718981">0.3292689907836739</td><td class="tdhistory718981">10555</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The above output shows recall, and F1-score values of confusion matrix.</p>
# <table style = 'font-size:16px;font-family:Arial;color:#00233C'>
#   <tr>
#     <th>Column</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>Precision</td>
#     <td>The positive predictive value. Refers to the fraction of relevant instances among
# the total retrieved instances.
#         Precision answers the following question: what proportion of predicted Positives is truly Positive?
#         Precision = (TP)/(TP+FP)</td>
#   </tr>
#   <tr>
#     <td>Recall</td>
#     <td>Refers to the fraction of relevant instances retrieved over the total amount of
# relevant instances. Recall answers a different question: what proportion of actual Positives is correctly classified?
# Recall = (TP)/(TP+FN)</td>
#   </tr>
#   <tr>
#     <td>F1</td>
#     <td>F1 score, defined as the harmonic mean of the precision and recall and is a number between 0 and 1. F1 score maintains a balance between the precision and recall for your classifier.
#                       F1 = 2*(precision*recall/precision+recall)</td>
#   </tr>
#   <tr>
#     <td>Support</td>
#     <td>The number of times a label displays in the Observation Column.</td>
#   </tr>
# </table>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>**TP:- True Positive , FP :- False Positive, TN :- True Negative , FN :- False Negative</p>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>
# Feature selection using GLM</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can use GLM for chosing the significant features

# %%
CREATE VOLATILE TABLE TD_Glm_FeatureSelection AS(
SELECT * FROM TD_GLM (
ON CLM_ADS_TRANSFORMED
USING
InputColumns('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode','Experiment_Type')
ResponseColumn('rate_category')
MaxIterNum(100)
RegularizationLambda(0.027)
Alpha(0)
IterNumNoChange(50)
Intercept('true')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select * from TD_Glm_FeatureSelection order by attribute;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory858697"><style>
#       table.tdhistory858697 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory858697 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory858697:last-child { text-align: left !important; }
#       tbody.tdhistory858697 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory858697 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory858697 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory858697"></th><th class="tdhistory858697">attribute</th><th class="tdhistory858697">predictor</th><th class="tdhistory858697">estimate</th><th class="tdhistory858697">value</th></tr></thead><tbody class="tdhistory858697 resultset-body"><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory858697">-13</td><td class="tdhistory858697">LocalSGD Iterations</td><td class="tdhistory858697">0</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory858697">-12</td><td class="tdhistory858697">Nesterov</td><td class="tdhistory858697"></td><td class="tdhistory858697">FALSE</td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory858697">-11</td><td class="tdhistory858697">Momentum</td><td class="tdhistory858697">0</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory858697">-10</td><td class="tdhistory858697">Learning Rate (Final)</td><td class="tdhistory858697">0.018710158230410626</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory858697">-9</td><td class="tdhistory858697">Learning Rate (Initial)</td><td class="tdhistory858697">0.05</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory858697">-8</td><td class="tdhistory858697">Number of Iterations</td><td class="tdhistory858697">51</td><td class="tdhistory858697">CONVERGED</td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory858697">-7</td><td class="tdhistory858697">Alpha</td><td class="tdhistory858697">0</td><td class="tdhistory858697">L2</td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory858697">-6</td><td class="tdhistory858697">Regularization</td><td class="tdhistory858697">0.027</td><td class="tdhistory858697">ENABLED</td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory858697">-5</td><td class="tdhistory858697">BIC</td><td class="tdhistory858697">7.871772662691916e+06</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory858697">-4</td><td class="tdhistory858697">AIC</td><td class="tdhistory858697">7.871640687478374e+06</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory858697">-3</td><td class="tdhistory858697">Number of Observations</td><td class="tdhistory858697">91748</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory858697">-2</td><td class="tdhistory858697">MSE</td><td class="tdhistory858697">1.8227849152715503e+37</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory858697">-1</td><td class="tdhistory858697">Loss Function</td><td class="tdhistory858697"></td><td class="tdhistory858697">SQUARED_ERROR</td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory858697">0</td><td class="tdhistory858697">(Intercept)</td><td class="tdhistory858697">-1.6167620776646715e+10</td><td class="tdhistory858697"></td></tr><tr><th class="tdhistory858697" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory858697">1</td><td class="tdhistory858697">Level</td><td class="tdhistory858697">1.37311904 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can see the estimates column to see its significance of the attribute on the model.  </p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>
#     9. Micro-models (dividing the dataset on experiment types)</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let us divide our dataset based on experiment types.

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_INDOOR AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_MOBILITY AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_OUTDOOR AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 2
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_PEDESTRIAN AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 3
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Indoor</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =0 i.e Indoor

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_INDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_INDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Indoor</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>As we have seen earlier in macro models that Decision Forest model gave better results, hence we will use Decision forest for micro models.

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 2 minutes to run.</b></i>

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_MDL AS (
select * from TD_DecisionForest (
ON INDOOR_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Prediction for Indoor</h3>

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON INDOOR_TEST AS InputTable PARTITION BY ANY
ON INDOOR_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from INDOOR_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory745707"><style>
#       table.tdhistory745707 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory745707 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory745707:last-child { text-align: left !important; }
#       tbody.tdhistory745707 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory745707 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory745707 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory745707"></th><th class="tdhistory745707">rate_category</th><th class="tdhistory745707">DateTime</th><th class="tdhistory745707">prediction</th><th class="tdhistory745707">confidence_lower</th><th class="tdhistory745707">confidence_upper</th></tr></thead><tbody class="tdhistory745707 resultset-body"><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory745707">0</td><td class="tdhistory745707">24/09/2022 9:31:33</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.9</td><td class="tdhistory745707">0.9</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:32:28</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.82</td><td class="tdhistory745707">0.82</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:35:41</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.74</td><td class="tdhistory745707">0.74</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:31:48</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.79</td><td class="tdhistory745707">0.79</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:32:38</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.79</td><td class="tdhistory745707">0.79</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:34:27</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.78</td><td class="tdhistory745707">0.78</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:33:00</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.79</td><td class="tdhistory745707">0.79</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory745707">0</td><td class="tdhistory745707">24/09/2022 9:31:07</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.82</td><td class="tdhistory745707">0.82</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:34:56</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.73</td><td class="tdhistory745707">0.73</td></tr><tr><th class="tdhistory745707" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory745707">2</td><td class="tdhistory745707">24/09/2022 9:35:08</td><td class="tdhistory745707">2</td><td class="tdhistory745707">0.77</td><td class="tdhistory745707">0.77</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Indoor</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  INDOOR_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory484142"><style>
#       table.tdhistory484142 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory484142 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory484142:last-child { text-align: left !important; }
#       tbody.tdhistory484142 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory484142 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory484142 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory484142"></th><th class="tdhistory484142">SeqNum</th><th class="tdhistory484142">Prediction</th><th class="tdhistory484142">Mapping</th><th class="tdhistory484142">CLASS_1</th><th class="tdhistory484142">CLASS_2</th><th class="tdhistory484142">CLASS_3</th><th class="tdhistory484142">Precision</th><th class="tdhistory484142">Recall</th><th class="tdhistory484142">F1</th><th class="tdhistory484142">Support</th></tr></thead><tbody class="tdhistory484142 resultset-body"><tr><th class="tdhistory484142" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory484142">0</td><td class="tdhistory484142">0</td><td class="tdhistory484142">CLASS_1</td><td class="tdhistory484142">610</td><td class="tdhistory484142">305</td><td class="tdhistory484142">538</td><td class="tdhistory484142">0.4198210598761184</td><td class="tdhistory484142">0.6630434782608695</td><td class="tdhistory484142">0.5141171512852929</td><td class="tdhistory484142">920</td></tr><tr><th class="tdhistory484142" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory484142">1</td><td class="tdhistory484142">1</td><td class="tdhistory484142">CLASS_2</td><td class="tdhistory484142">62</td><td class="tdhistory484142">177</td><td class="tdhistory484142">33</td><td class="tdhistory484142">0.6507352941176471</td><td class="tdhistory484142">0.1638888888888889</td><td class="tdhistory484142">0.2618343195266272</td><td class="tdhistory484142">1080</td></tr><tr><th class="tdhistory484142" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory484142">2</td><td class="tdhistory484142">2</td><td class="tdhistory484142">CLASS_3</td><td class="tdhistory484142">248</td><td class="tdhistory484142">598</td><td class="tdhistory484142">1429</td><td class="tdhistory484142">0.6281318681318682</td><td class="tdhistory484142">0.7145</td><td class="tdhistory484142">0.6685380116959065</td><td class="tdhistory484142">2000</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Outdoor</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =1 i.e Outdoor

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_OUTDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_OUTDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Outdoor</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 2 minute to run.</b></i>

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_MDL AS (
select * from TD_DecisionForest (
ON OUTDOOR_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Predicition for Outdoor</h3>

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON OUTDOOR_TEST AS InputTable PARTITION BY ANY
ON OUTDOOR_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from OUTDOOR_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory984893"><style>
#       table.tdhistory984893 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory984893 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory984893:last-child { text-align: left !important; }
#       tbody.tdhistory984893 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory984893 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory984893 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory984893"></th><th class="tdhistory984893">rate_category</th><th class="tdhistory984893">DateTime</th><th class="tdhistory984893">prediction</th><th class="tdhistory984893">confidence_lower</th><th class="tdhistory984893">confidence_upper</th></tr></thead><tbody class="tdhistory984893 resultset-body"><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:25:55</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.49</td><td class="tdhistory984893">0.49</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:26:14</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.53</td><td class="tdhistory984893">0.53</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:26:04</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.45</td><td class="tdhistory984893">0.45</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:25:41</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.56</td><td class="tdhistory984893">0.56</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:25:50</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.43</td><td class="tdhistory984893">0.43</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:25:52</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.49</td><td class="tdhistory984893">0.49</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:25:56</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.5</td><td class="tdhistory984893">0.5</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:25:51</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.42</td><td class="tdhistory984893">0.42</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:26:03</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.45</td><td class="tdhistory984893">0.45</td></tr><tr><th class="tdhistory984893" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory984893">0</td><td class="tdhistory984893">14/08/2022 17:26:06</td><td class="tdhistory984893">0</td><td class="tdhistory984893">0.56</td><td class="tdhistory984893">0.56</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Outdoor</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  OUTDOOR_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory422391"><style>
#       table.tdhistory422391 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory422391 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory422391:last-child { text-align: left !important; }
#       tbody.tdhistory422391 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory422391 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory422391 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory422391"></th><th class="tdhistory422391">SeqNum</th><th class="tdhistory422391">Prediction</th><th class="tdhistory422391">Mapping</th><th class="tdhistory422391">CLASS_1</th><th class="tdhistory422391">CLASS_2</th><th class="tdhistory422391">CLASS_3</th><th class="tdhistory422391">Precision</th><th class="tdhistory422391">Recall</th><th class="tdhistory422391">F1</th><th class="tdhistory422391">Support</th></tr></thead><tbody class="tdhistory422391 resultset-body"><tr><th class="tdhistory422391" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory422391">0</td><td class="tdhistory422391">0</td><td class="tdhistory422391">CLASS_1</td><td class="tdhistory422391">1993</td><td class="tdhistory422391">551</td><td class="tdhistory422391">1042</td><td class="tdhistory422391">0.5557724484104852</td><td class="tdhistory422391">0.8672758920800696</td><td class="tdhistory422391">0.677430319510537</td><td class="tdhistory422391">2298</td></tr><tr><th class="tdhistory422391" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory422391">1</td><td class="tdhistory422391">1</td><td class="tdhistory422391">CLASS_2</td><td class="tdhistory422391">48</td><td class="tdhistory422391">394</td><td class="tdhistory422391">101</td><td class="tdhistory422391">0.7255985267034991</td><td class="tdhistory422391">0.30191570881226054</td><td class="tdhistory422391">0.42640692640692646</td><td class="tdhistory422391">1305</td></tr><tr><th class="tdhistory422391" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory422391">2</td><td class="tdhistory422391">2</td><td class="tdhistory422391">CLASS_3</td><td class="tdhistory422391">257</td><td class="tdhistory422391">360</td><td class="tdhistory422391">1042</td><td class="tdhistory422391">0.6280892103676914</td><td class="tdhistory422391">0.4768878718535469</td><td class="tdhistory422391">0.5421436004162331</td><td class="tdhistory422391">2185</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Mobility</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =2 i.e Mobility

# %%
CREATE MULTISET VOLATILE TABLE MOBILITY_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_MOBILITY AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE VOLATILE TABLE MOBILITY_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_MOBILITY AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Mobility</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 12 minutes to run.</b></i>

# %%
CREATE MULTISET VOLATILE TABLE MOBILITY_MDL AS (
select * from TD_DecisionForest (
ON MOBILITY_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Predicition for Mobility</h3>

# %%
CREATE MULTISET VOLATILE TABLE MOBILITY_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON MOBILITY_TEST AS InputTable PARTITION BY ANY
ON MOBILITY_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from MOBILITY_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory824381"><style>
#       table.tdhistory824381 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory824381 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory824381:last-child { text-align: left !important; }
#       tbody.tdhistory824381 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory824381 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory824381 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory824381"></th><th class="tdhistory824381">rate_category</th><th class="tdhistory824381">DateTime</th><th class="tdhistory824381">prediction</th><th class="tdhistory824381">confidence_lower</th><th class="tdhistory824381">confidence_upper</th></tr></thead><tbody class="tdhistory824381 resultset-body"><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory824381">0</td><td class="tdhistory824381">23/08/2022 19:04:36</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.44</td><td class="tdhistory824381">0.44</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory824381">1</td><td class="tdhistory824381">23/08/2022 19:11:02</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.63</td><td class="tdhistory824381">0.63</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory824381">0</td><td class="tdhistory824381">23/08/2022 19:04:40</td><td class="tdhistory824381">2</td><td class="tdhistory824381">0.5</td><td class="tdhistory824381">0.5</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory824381">1</td><td class="tdhistory824381">23/08/2022 19:09:40</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.64</td><td class="tdhistory824381">0.64</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory824381">1</td><td class="tdhistory824381">23/08/2022 19:10:42</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.45</td><td class="tdhistory824381">0.45</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory824381">1</td><td class="tdhistory824381">23/08/2022 19:10:01</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.5</td><td class="tdhistory824381">0.5</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory824381">0</td><td class="tdhistory824381">23/08/2022 19:04:54</td><td class="tdhistory824381">2</td><td class="tdhistory824381">0.66</td><td class="tdhistory824381">0.66</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory824381">2</td><td class="tdhistory824381">23/08/2022 19:06:25</td><td class="tdhistory824381">2</td><td class="tdhistory824381">0.65</td><td class="tdhistory824381">0.65</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory824381">1</td><td class="tdhistory824381">23/08/2022 19:07:44</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.51</td><td class="tdhistory824381">0.51</td></tr><tr><th class="tdhistory824381" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory824381">1</td><td class="tdhistory824381">23/08/2022 19:07:59</td><td class="tdhistory824381">1</td><td class="tdhistory824381">0.59</td><td class="tdhistory824381">0.59</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Mobility</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  MOBILITY_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory502257"><style>
#       table.tdhistory502257 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory502257 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory502257:last-child { text-align: left !important; }
#       tbody.tdhistory502257 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory502257 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory502257 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory502257"></th><th class="tdhistory502257">SeqNum</th><th class="tdhistory502257">Prediction</th><th class="tdhistory502257">Mapping</th><th class="tdhistory502257">CLASS_1</th><th class="tdhistory502257">CLASS_2</th><th class="tdhistory502257">CLASS_3</th><th class="tdhistory502257">Precision</th><th class="tdhistory502257">Recall</th><th class="tdhistory502257">F1</th><th class="tdhistory502257">Support</th></tr></thead><tbody class="tdhistory502257 resultset-body"><tr><th class="tdhistory502257" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory502257">0</td><td class="tdhistory502257">0</td><td class="tdhistory502257">CLASS_1</td><td class="tdhistory502257">1482</td><td class="tdhistory502257">359</td><td class="tdhistory502257">391</td><td class="tdhistory502257">0.6639784946236559</td><td class="tdhistory502257">0.5434543454345434</td><td class="tdhistory502257">0.5977011494252873</td><td class="tdhistory502257">2727</td></tr><tr><th class="tdhistory502257" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory502257">1</td><td class="tdhistory502257">1</td><td class="tdhistory502257">CLASS_2</td><td class="tdhistory502257">874</td><td class="tdhistory502257">3843</td><td class="tdhistory502257">1304</td><td class="tdhistory502257">0.6382660687593423</td><td class="tdhistory502257">0.8016270337922403</td><td class="tdhistory502257">0.7106796116504854</td><td class="tdhistory502257">4794</td></tr><tr><th class="tdhistory502257" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory502257">2</td><td class="tdhistory502257">2</td><td class="tdhistory502257">CLASS_3</td><td class="tdhistory502257">371</td><td class="tdhistory502257">592</td><td class="tdhistory502257">1758</td><td class="tdhistory502257">0.6460859977949284</td><td class="tdhistory502257">0.5091225021720244</td><td class="tdhistory502257">0.5694849368318757</td><td class="tdhistory502257">3453</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Pedestrian</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =3 i.e Pedestrian

# %%
CREATE MULTISET VOLATILE TABLE PEDESTRIAN_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_PEDESTRIAN AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE PEDESTRIAN_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_PEDESTRIAN AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Pedestrian</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates model.  Due to limited resources of this VM, processing may up to 3 minutes to complete.</b></i>

# %%
CREATE VOLATILE TABLE PEDESTRIAN_MDL AS (
select * from TD_DecisionForest (
ON PEDESTRIAN_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Predicition for Pedestrian</h3>

# %%
CREATE MULTISET VOLATILE TABLE PEDESTRIAN_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON PEDESTRIAN_TEST AS InputTable PARTITION BY ANY
ON PEDESTRIAN_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from PEDESTRIAN_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory108888"><style>
#       table.tdhistory108888 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory108888 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory108888:last-child { text-align: left !important; }
#       tbody.tdhistory108888 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory108888 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory108888 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory108888"></th><th class="tdhistory108888">rate_category</th><th class="tdhistory108888">DateTime</th><th class="tdhistory108888">prediction</th><th class="tdhistory108888">confidence_lower</th><th class="tdhistory108888">confidence_upper</th></tr></thead><tbody class="tdhistory108888 resultset-body"><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory108888">0</td><td class="tdhistory108888">27/08/2022 14:01:42</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.41</td><td class="tdhistory108888">0.41</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory108888">0</td><td class="tdhistory108888">27/08/2022 14:02:10</td><td class="tdhistory108888">0</td><td class="tdhistory108888">0.37</td><td class="tdhistory108888">0.37</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory108888">2</td><td class="tdhistory108888">27/08/2022 14:02:48</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.39</td><td class="tdhistory108888">0.39</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory108888">0</td><td class="tdhistory108888">27/08/2022 14:01:49</td><td class="tdhistory108888">0</td><td class="tdhistory108888">0.38</td><td class="tdhistory108888">0.38</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory108888">0</td><td class="tdhistory108888">27/08/2022 14:01:26</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.43</td><td class="tdhistory108888">0.43</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory108888">2</td><td class="tdhistory108888">27/08/2022 14:04:53</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.41</td><td class="tdhistory108888">0.41</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory108888">0</td><td class="tdhistory108888">27/08/2022 14:01:32</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.35</td><td class="tdhistory108888">0.35</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory108888">2</td><td class="tdhistory108888">27/08/2022 14:02:34</td><td class="tdhistory108888">1</td><td class="tdhistory108888">0.38</td><td class="tdhistory108888">0.38</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory108888">0</td><td class="tdhistory108888">27/08/2022 14:02:01</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.55</td><td class="tdhistory108888">0.55</td></tr><tr><th class="tdhistory108888" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory108888">2</td><td class="tdhistory108888">27/08/2022 14:02:24</td><td class="tdhistory108888">2</td><td class="tdhistory108888">0.41</td><td class="tdhistory108888">0.41</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Pedestrian</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  PEDESTRIAN_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory420369"><style>
#       table.tdhistory420369 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory420369 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory420369:last-child { text-align: left !important; }
#       tbody.tdhistory420369 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory420369 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory420369 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory420369"></th><th class="tdhistory420369">SeqNum</th><th class="tdhistory420369">Prediction</th><th class="tdhistory420369">Mapping</th><th class="tdhistory420369">CLASS_1</th><th class="tdhistory420369">CLASS_2</th><th class="tdhistory420369">CLASS_3</th><th class="tdhistory420369">Precision</th><th class="tdhistory420369">Recall</th><th class="tdhistory420369">F1</th><th class="tdhistory420369">Support</th></tr></thead><tbody class="tdhistory420369 resultset-body"><tr><th class="tdhistory420369" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory420369">0</td><td class="tdhistory420369">0</td><td class="tdhistory420369">CLASS_1</td><td class="tdhistory420369">1742</td><td class="tdhistory420369">364</td><td class="tdhistory420369">896</td><td class="tdhistory420369">0.5802798134576949</td><td class="tdhistory420369">0.7663880334359877</td><td class="tdhistory420369">0.6604739336492891</td><td class="tdhistory420369">2273</td></tr><tr><th class="tdhistory420369" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory420369">1</td><td class="tdhistory420369">1</td><td class="tdhistory420369">CLASS_2</td><td class="tdhistory420369">94</td><td class="tdhistory420369">739</td><td class="tdhistory420369">126</td><td class="tdhistory420369">0.7705943691345151</td><td class="tdhistory420369">0.4365032486709982</td><td class="tdhistory420369">0.557315233785822</td><td class="tdhistory420369">1693</td></tr><tr><th class="tdhistory420369" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory420369">2</td><td class="tdhistory420369">2</td><td class="tdhistory420369">CLASS_3</td><td class="tdhistory420369">437</td><td class="tdhistory420369">590</td><td class="tdhistory420369">1776</td><td class="tdhistory420369">0.6336068498037817</td><td class="tdhistory420369">0.6347390993566834</td><td class="tdhistory420369">0.6341724692019284</td><td class="tdhistory420369">2798</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>10. Conclusion </b> </p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> We have seen that for macro model Decision Forest is performing better than the XGBoost model. Also pridicition of micro models is better than the macro model.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>11. Cleanup</b> </p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Worktables</b></p>

# %%
DROP TABLE CLM_QOE;
# Out:
# Success: 40 rows affected

# %%
DROP TABLE CLM_ADS_TEST;
# Out:
# Success: 47 rows affected

# %%
DROP TABLE CLM_ADS_TRAIN;
# Out:
# Success: 47 rows affected

# %%
DROP TABLE CLM_ADS_MDL_DF;
# Out:
# Success: 17 rows affected

# %%
DROP TABLE CLM_ADS_MDL_XGB;
# Out:
# Success: 19 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Database and Tables</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_5G');-- takes about 5 seconds, optional if you want to use the data later
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory312977"><style>
#       table.tdhistory312977 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory312977 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory312977:last-child { text-align: left !important; }
#       tbody.tdhistory312977 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory312977 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory312977 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory312977"></th><th class="tdhistory312977">Message</th></tr></thead><tbody class="tdhistory312977 resultset-body"><tr><th class="tdhistory312977" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory312977">Removed objects related to DEMO_5G. That ran for 0:00:02.98</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Reference Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#         <li>Teradata Analytic Function Reference:
#         <a href = 'https://docs.teradata.com/r/Teradata-VantageCloud-Lake/Analyzing-Your-Data/Analytics-Database-Analytic-Functions/Analytics-Database-Analytic-Functions-Overview'>
#         https://docs.teradata.com/r/Teradata-VantageCloud-Lake/Analyzing-Your-Data/Analytics-Database-Analytic-Functions/Analytics-Database-Analytic-Functions-Overview</a></li>
#      <li>TD_Plot
#         <a href = 'https://docs.teradata.com/search/all?query=TD_PLOT&content-lang=en-US'>
#        TD_Plot</a></li>
#          <li>Unbounded Array Framework
#         <a href = 'https://docs.teradata.com/search/all?query=Unbounded+Array+Framework+&content-lang=en-US'>
#        UAF</a></li>
#
# </ul>

# %% [markdown]
# <footer style="padding-bottom:35px; background:#f9f9f9; border-bottom:3px solid #00233C">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2023. All Rights Reserved
#         </div>
#     </div>
# </footer>
