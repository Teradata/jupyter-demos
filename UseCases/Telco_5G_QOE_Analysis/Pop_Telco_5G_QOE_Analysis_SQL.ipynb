# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        5G Quality of Experience using ClearScape Analytics
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Due to the exponential increase in 5G cellular network users, providing extensive coverage and ensuring maximum Quality of Experience (QoE) has become a significant challenge for global telecommunications. The demand for high-speed connectivity, low latency, and massive data transfer poses obstacles in delivering seamless 5G coverage across diverse geographical areas. Furthermore, transitioning from 4G/LTE to 5G technology introduces complexities in terms of compatibility and network integration. Addressing these challenges is essential to meet the evolving expectations of end-users and ensure optimal QoE.<br>
# To tackle these challenges, an analysis of Key Performance Indicators (KPIs) and channel level metrics is conducted to understand their impact on user's perceived QoE. Moreover, we gain valuable insights by investigating YouTube streaming QoE, KPIs, using commercial 4G and 5G cellular networks under different mobility and static scenarios. The demo shows the power of Vantage by utilizing its In-DB analytics capabilities to address a critical challenge in telecommunication industry: <br>Predicting quality of experience (QoE) in 5G networks.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage and explore the dataset</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>After executing this cell you will be prompted to provide the password. Enter your password, press the Enter key, then <b>use down arrow</b> to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %%
Set query_band='DEMO=Telco_5G_QOE_Analysis_SQL.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Getting Data for This Demo</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
# We have provided data for this demo on cloud storage. You have the option of either running the demo using foreign tables to access the data without using any storage on your environment or downloading the data to local storage which may yield somewhat faster execution, but will consume some of your available storage.
# <br> There are two statements in the following cell -- one is commented out. You may switch the location of your data's storage by changing the comment string.</p>

# %%
call get_data('DEMO_5G_cloud');    -- takes about 20 seconds, estimated space: 0 MB
--call get_data('DEMO_5G_local');     -- takes about 40 seconds, estimated space: 1MB
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory293255"><style>
#       table.tdhistory293255 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory293255 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory293255:last-child { text-align: left !important; }
#       tbody.tdhistory293255 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory293255 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory293255 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory293255"></th><th class="tdhistory293255">Message</th></tr></thead><tbody class="tdhistory293255 resultset-body"><tr><th class="tdhistory293255" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory293255">That ran for   0:00:10.84 with 9 statements and 0 errors. </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Next is an optional step – if you want to see status of databases/tables created and space used.</p>

# %%
call space_report();  -- optional, takes about 10 seconds
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory176868"><style>
#       table.tdhistory176868 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory176868 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory176868:last-child { text-align: left !important; }
#       tbody.tdhistory176868 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory176868 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory176868 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory176868"></th><th class="tdhistory176868">Space_Report</th></tr></thead><tbody class="tdhistory176868 resultset-body"><tr><th class="tdhistory176868" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory176868">You have:  #databases=1 #tables=1 #views=21  You have used 1.1 MB of 30,678.9 MB available - 0.0%  ... Space Usage OK</td></tr><tr><th class="tdhistory176868" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory176868"> </td></tr><tr><th class="tdhistory176868" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory176868">   Database Name                  #tables  #views     Avail MB      Used MB</td></tr><tr><th class="tdhistory176868" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory176868">   demo_user                            1      18  30,678.9 MB       1.1 MB </td></tr><tr><th class="tdhistory176868" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory176868">   DEMO_5G                              0       3       0.0 MB       0.0 MB </td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. Exploring source data</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b>5G Quality of Experience Data <br><br>CLM</b>: Refers to measurements and indicators that provide information about the quality and characteristics of the wireless communication channel between a base station (eNodeB/gNB) and a user equipment (UE) device. These metrics help in assessing the channel conditions and performance of the wireless link. Channel level metrics with 1-second granularity collected using Gnetrack Pro under different scenarios includes CQI, SNR, RSRP, RSRQ, Download & Upload bitrate, Cellid, etc. <br><b>QoE</b>: YouTube Quality of Experience information collected after every 1-second, i.e., Current quality, Video bytes downloaded, Loaded percentage. <br><b>Events</b>: YouTube player events, i.e., Stall, Quality Shift, Paused, Played, Ended<br></p>

# %% [markdown]
# ![Dataset%20Desc%20Vr2.png](attachment:Dataset%20Desc%20Vr2.png)

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Data Collection</b>The KPIs (CQI, SNR, RSRP, RSRQ) etc on 4G and 5G cell networks were collected for different scenarios. The channel level metrics were captured using G Network Pro which is a wireless network monitor. Using both android and iphone the youtube video was played, paused and queued. The buffering information and download bit rate was also captured. Four experiments that were conducted were mobility, pedestrian user that was walking outdoor and indoor sitting.</p>

# %%
select top 10 * from Demo_5G.YouTube_QoE;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory226474"><style>
#       table.tdhistory226474 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory226474 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory226474:last-child { text-align: left !important; }
#       tbody.tdhistory226474 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory226474 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory226474 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory226474"></th><th class="tdhistory226474">Video</th><th class="tdhistory226474">Quality</th><th class="tdhistory226474">Video_Bytes_Downloaded</th><th class="tdhistory226474">Loaded_Percentage</th><th class="tdhistory226474">Eid</th><th class="tdhistory226474">Dates</th><th class="tdhistory226474">Times</th></tr></thead><tbody class="tdhistory226474 resultset-body"><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory226474">9jrP7460a4o</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.101660925</td><td class="tdhistory226474">10.2</td><td class="tdhistory226474">14augs</td><td class="tdhistory226474">14/08/2022</td><td class="tdhistory226474">17:25:54</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory226474">9jrP7460a4o</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.101660925</td><td class="tdhistory226474">10.2</td><td class="tdhistory226474">14augs</td><td class="tdhistory226474">14/08/2022</td><td class="tdhistory226474">17:25:56</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory226474">9jrP7460a4o</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.101660925</td><td class="tdhistory226474">10.2</td><td class="tdhistory226474">14augs</td><td class="tdhistory226474">14/08/2022</td><td class="tdhistory226474">17:25:57</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory226474">9jrP7460a4o</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.101660925</td><td class="tdhistory226474">10.2</td><td class="tdhistory226474">14augs</td><td class="tdhistory226474">14/08/2022</td><td class="tdhistory226474">17:25:58</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory226474">9jrP7460a4o</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.112118234</td><td class="tdhistory226474">11.2</td><td class="tdhistory226474">14augs</td><td class="tdhistory226474">14/08/2022</td><td class="tdhistory226474">17:26:00</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory226474">9jrP7460a4o</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.079290227</td><td class="tdhistory226474">7.9</td><td class="tdhistory226474">14augs</td><td class="tdhistory226474">14/08/2022</td><td class="tdhistory226474">17:25:52</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory226474">JMbBjKnUoC4</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.115204518</td><td class="tdhistory226474">11.5</td><td class="tdhistory226474">m12aug</td><td class="tdhistory226474">08/12/2022</td><td class="tdhistory226474">14:40:01</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory226474">JMbBjKnUoC4</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.115204518</td><td class="tdhistory226474">11.5</td><td class="tdhistory226474">m12aug</td><td class="tdhistory226474">08/12/2022</td><td class="tdhistory226474">14:40:02</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory226474">JMbBjKnUoC4</td><td class="tdhistory226474">hd2160</td><td class="tdhistory226474">0.115204518</td><td class="tdhistory226474">11.5</td><td class="tdhistory226474">m12aug</td><td class="tdhistory226474">08/12/2022</td><td class="tdhistory226474">14:40:03</td></tr><tr><th class="tdhistory226474" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory226474">JMbBjKnUoC4</td><td class="tdhistory2 ...

# %%
select top 10 * from Demo_5G.YouTube_Player_Events;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory587951"><style>
#       table.tdhistory587951 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory587951 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory587951:last-child { text-align: left !important; }
#       tbody.tdhistory587951 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory587951 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory587951 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory587951"></th><th class="tdhistory587951">Video</th><th class="tdhistory587951">Quality</th><th class="tdhistory587951">Status</th><th class="tdhistory587951">TimeStall</th><th class="tdhistory587951">Eid</th><th class="tdhistory587951">Dates</th><th class="tdhistory587951">Times</th><th class="tdhistory587951">Category</th></tr></thead><tbody class="tdhistory587951 resultset-body"><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory587951">9jrP7460a4o</td><td class="tdhistory587951">hd2160,</td><td class="tdhistory587951">1</td><td class="tdhistory587951">0.060263095</td><td class="tdhistory587951">14augs</td><td class="tdhistory587951">14/08/2022</td><td class="tdhistory587951">17:25:41</td><td class="tdhistory587951">playing</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory587951">jAa58N4Jlos</td><td class="tdhistory587951">unknown,</td><td class="tdhistory587951">3</td><td class="tdhistory587951">0</td><td class="tdhistory587951">28airport5g</td><td class="tdhistory587951">28/09/2022</td><td class="tdhistory587951">12:05:39</td><td class="tdhistory587951">buffering</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory587951">jAa58N4Jlos</td><td class="tdhistory587951">hd2160,</td><td class="tdhistory587951">1</td><td class="tdhistory587951">0.062922093</td><td class="tdhistory587951">28airport5g</td><td class="tdhistory587951">28/09/2022</td><td class="tdhistory587951">12:05:40</td><td class="tdhistory587951">playing</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory587951">9jrP7460a4o</td><td class="tdhistory587951">unknown,</td><td class="tdhistory587951">-1</td><td class="tdhistory587951">0</td><td class="tdhistory587951">2a19aug</td><td class="tdhistory587951">19/08/2022</td><td class="tdhistory587951">16:03:52</td><td class="tdhistory587951">unstarted</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory587951">9jrP7460a4o</td><td class="tdhistory587951">hd2160,</td><td class="tdhistory587951">1</td><td class="tdhistory587951">0.044575773</td><td class="tdhistory587951">2a19aug</td><td class="tdhistory587951">19/08/2022</td><td class="tdhistory587951">16:03:54</td><td class="tdhistory587951">playing</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory587951">9jrP7460a4o</td><td class="tdhistory587951">hd2160,</td><td class="tdhistory587951">0</td><td class="tdhistory587951">302.181</td><td class="tdhistory587951">2a19aug</td><td class="tdhistory587951">19/08/2022</td><td class="tdhistory587951">16:08:56</td><td class="tdhistory587951">ended</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory587951">9jrP7460a4o</td><td class="tdhistory587951">unknown,</td><td class="tdhistory587951">3</td><td class="tdhistory587951">0</td><td class="tdhistory587951">2a19aug</td><td class="tdhistory587951">19/08/2022</td><td class="tdhistory587951">16:03:52</td><td class="tdhistory587951">buffering</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory587951">jAa58N4Jlos</td><td class="tdhistory587951">unknown,</td><td class="tdhistory587951">-1</td><td class="tdhistory587951">0</td><td class="tdhistory587951">28airport5g</td><td class="tdhistory587951">28/09/2022</td><td class="tdhistory587951">12:05:39</td><td class="tdhistory587951">unstarted</td></tr><tr><th class="tdhistory587951" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory587951">9jrP7460a4o</td><td class="tdhistory587951">unknown,</td><td class="tdhistory587951">-1</td><td class="tdh ...

# %%
select top 10 * from Demo_5G.Channel_Level_Metrics;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory113322"><style>
#       table.tdhistory113322 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory113322 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory113322:last-child { text-align: left !important; }
#       tbody.tdhistory113322 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory113322 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory113322 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory113322"></th><th class="tdhistory113322">Longitude</th><th class="tdhistory113322">Latitude</th><th class="tdhistory113322">NetworkTech</th><th class="tdhistory113322">NetworkMode</th><th class="tdhistory113322">Level</th><th class="tdhistory113322">Qual</th><th class="tdhistory113322">SNR</th><th class="tdhistory113322">CQI</th><th class="tdhistory113322">LTERSSI</th><th class="tdhistory113322">DL_bitrate</th><th class="tdhistory113322">UL_bitrate</th><th class="tdhistory113322">Altitude</th><th class="tdhistory113322">Height</th><th class="tdhistory113322">State</th><th class="tdhistory113322">EVENT</th><th class="tdhistory113322">SecondCell_RSRP</th><th class="tdhistory113322">SecondCell_RSRQ</th><th class="tdhistory113322">SecondCell_SNR</th><th class="tdhistory113322">Eid</th><th class="tdhistory113322">Experiment_Type</th><th class="tdhistory113322">Dates</th><th class="tdhistory113322">Times</th></tr></thead><tbody class="tdhistory113322 resultset-body"><tr><th class="tdhistory113322" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory113322">7.042226</td><td class="tdhistory113322">43.625951</td><td class="tdhistory113322">5G</td><td class="tdhistory113322">5G</td><td class="tdhistory113322">-118</td><td class="tdhistory113322">-6</td><td class="tdhistory113322">7</td><td class="tdhistory113322">7</td><td class="tdhistory113322">0</td><td class="tdhistory113322">5</td><td class="tdhistory113322">8</td><td class="tdhistory113322">223</td><td class="tdhistory113322">223</td><td class="tdhistory113322">D </td><td class="tdhistory113322"></td><td class="tdhistory113322">-101</td><td class="tdhistory113322">-14</td><td class="tdhistory113322">4</td><td class="tdhistory113322">4m27o</td><td class="tdhistory113322">Mobility</td><td class="tdhistory113322">27/10/2022</td><td class="tdhistory113322">10:22:18</td></tr><tr><th class="tdhistory113322" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory113322">7.068953</td><td class="tdhistory113322">43.615278</td><td class="tdhistory113322">5G</td><td class="tdhistory113322">5G</td><td class="tdhistory113322">-121</td><td class="tdhistory113322">-9</td><td class="tdhistory113322">-2</td><td class="tdhistory113322">10</td><td class="tdhistory113322">0</td><td class="tdhistory113322">0</td><td class="tdhistory113322">0</td><td class="tdhistory113322">180</td><td class="tdhistory113322">180</td><td class="tdhistory113322">I </td><td class="tdhistory113322"></td><td class="tdhistory113322">-114</td><td class="tdhistory113322">-13</td><td class="tdhistory113322">3</td><td class="tdhistory113322">5i24o</td><td class="tdhistory113322">Indoor</td><td class="tdhistory113322">24/10/2022</td><td class="tdhistory113322">17:25:27</td></tr><tr><th class="tdhistory113322" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory113322">7.068953</td><td class="tdhistory113322">43.615278</td><td class="tdhistory113322">5G</td><td class="tdhistory113322">5G</td><td class="tdhistory113322">-121</td><td class="tdhistory113322">-9</td><td class="tdhistory113322">-2</td><td class="tdhistory113322">10</td><td class="tdhistory113322">0</td><td class="tdhistory113322">0</td><td class="tdhistory113322">0</td><td class="tdhistory113322">180</td><td class="tdhistory113322">180</td><td class="tdhistory113322">I </td><td class="tdhistory113322">PERIODIC</td><td class="tdhistory113322">-114</td><td class="tdhistory113322">-13</td><td class="tdhistory113322">3</td><td class="tdhistory113322">5i24o</td><td class="tdhistory113322">Indoor</td><td class="tdhistory113322">24/10/2022</td><td class="tdhistory113322">17:25:27</td></tr><tr><th class="tdhistory113322" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory113322">7.06891</td><td class="tdhistory113322">43.615242</td><td class="tdhistory113322">4G</td><td class="tdhistory113322">LTE</td><td  ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Data Preparation</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let us first create a combined table of Youtube QoE and Channel level metrics.</p>

# %%
CREATE TABLE CLM_QOE AS (
    SELECT 
        QoE."Times" AS QoE_Time, 
        QoE."Dates" AS QoE_Date, 
        QoE."Eid" AS  Eid, 
        QoE."Video_Bytes_Downloaded",
        QoE."Video",
        QoE."Quality",
        QoE."Loaded_Percentage",
        CLM."Longitude",
        CLM."Latitude",
        CLM."NetworkTech",
        CLM."NetworkMode",
        CLM."Level",
        CLM."Qual",
        CLM."SNR",
        CLM."CQI",
        CLM."LTERSSI",
        CLM."DL_bitrate",
        CLM."UL_bitrate",
        CLM."Altitude",
        CLM."Height",
        CLM."State",
        CLM."Event",
        CLM."SecondCell_RSRP",
        CLM."SecondCell_RSRQ",
        CLM."SecondCell_SNR",
        CLM."Experiment_Type",    
        QoE."Dates" || ' ' ||QoE."Times" AS DateTime
    FROM Demo_5G.YouTube_QoE QoE
    INNER JOIN Demo_5G.Channel_Level_Metrics CLM
        ON QoE."Times" = CLM."Times"
        AND QoE."Dates" = CLM."Dates"
        AND QoE."Eid" = CLM."Eid"
) WITH DATA NO PRIMARY INDEX;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_QOE;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory266778"><style>
#       table.tdhistory266778 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory266778 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory266778:last-child { text-align: left !important; }
#       tbody.tdhistory266778 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory266778 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory266778 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory266778"></th><th class="tdhistory266778">QoE_Time</th><th class="tdhistory266778">QoE_Date</th><th class="tdhistory266778">Eid</th><th class="tdhistory266778">Video_Bytes_Downloaded</th><th class="tdhistory266778">Video</th><th class="tdhistory266778">Quality</th><th class="tdhistory266778">Loaded_Percentage</th><th class="tdhistory266778">Longitude</th><th class="tdhistory266778">Latitude</th><th class="tdhistory266778">NetworkTech</th><th class="tdhistory266778">NetworkMode</th><th class="tdhistory266778">Level</th><th class="tdhistory266778">Qual</th><th class="tdhistory266778">SNR</th><th class="tdhistory266778">CQI</th><th class="tdhistory266778">LTERSSI</th><th class="tdhistory266778">DL_bitrate</th><th class="tdhistory266778">UL_bitrate</th><th class="tdhistory266778">Altitude</th><th class="tdhistory266778">Height</th><th class="tdhistory266778">State</th><th class="tdhistory266778">EVENT</th><th class="tdhistory266778">SecondCell_RSRP</th><th class="tdhistory266778">SecondCell_RSRQ</th><th class="tdhistory266778">SecondCell_SNR</th><th class="tdhistory266778">Experiment_Type</th><th class="tdhistory266778">DateTime</th></tr></thead><tbody class="tdhistory266778 resultset-body"><tr><th class="tdhistory266778" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory266778">13:21:14</td><td class="tdhistory266778">08/10/2022</td><td class="tdhistory266778">c10aug</td><td class="tdhistory266778">0.036956978</td><td class="tdhistory266778">Baur2Ypgd60</td><td class="tdhistory266778">hd2160</td><td class="tdhistory266778">3.7</td><td class="tdhistory266778">7.068467</td><td class="tdhistory266778">43.615603</td><td class="tdhistory266778">4G</td><td class="tdhistory266778">LTE</td><td class="tdhistory266778">-102</td><td class="tdhistory266778">-11</td><td class="tdhistory266778">0</td><td class="tdhistory266778">13</td><td class="tdhistory266778">-101</td><td class="tdhistory266778">38762</td><td class="tdhistory266778">644</td><td class="tdhistory266778">184</td><td class="tdhistory266778">184</td><td class="tdhistory266778">D </td><td class="tdhistory266778">PERIODIC</td><td class="tdhistory266778">0</td><td class="tdhistory266778">0</td><td class="tdhistory266778">0</td><td class="tdhistory266778">Indoor</td><td class="tdhistory266778">08/10/2022 13:21:14</td></tr><tr><th class="tdhistory266778" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory266778">13:56:52</td><td class="tdhistory266778">09/12/2022</td><td class="tdhistory266778">4iu12</td><td class="tdhistory266778">0.774849614</td><td class="tdhistory266778">pSnB7Uh8dvQ</td><td class="tdhistory266778">hd1440</td><td class="tdhistory266778">77.5</td><td class="tdhistory266778">7.069155</td><td class="tdhistory266778">43.615262</td><td class="tdhistory266778">4G</td><td class="tdhistory266778">LTE</td><td class="tdhistory266778">-110</td><td class="tdhistory266778">-13</td><td class="tdhistory266778">7</td><td class="tdhistory266778">9</td><td class="tdhistory266778">-89</td><td class="tdhistory266778">5266</td><td class="tdhistory266778">58</td><td class="tdhistory266778">182</td><td class="tdhistory266778">182</td><td class="tdhistory266778">D </td><td class="tdhistory266778">PERIODIC</td><td class="tdhistory266778">0</td><td class="tdhistory266778">0</td><td class="tdhistory266778">0</td><td class="tdhistory266778">Indoor</td><td class="tdhistory266778">09/12/2022 13:56:52</td></tr><tr><th class="tdhistory266778" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory266778">13:57:01</td><td class="tdhistory266778">09/12/2022</td><td class="tdhistory266778">4iu12</td><td class="tdhistory266778">0.810384541</td><td class="tdhistory266778">pSnB7Uh8dvQ</td><td class="tdhistory266778">hd1440</td><td class="tdhistory266778">81</td><td class="tdhistory266778">7.069155</td><td class="tdhistory266778">43.615262</td><td class ...

# %%
SELECT COUNT(*) AS total_rows FROM CLM_QOE;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory654030"><style>
#       table.tdhistory654030 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory654030 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory654030:last-child { text-align: left !important; }
#       tbody.tdhistory654030 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory654030 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory654030 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory654030"></th><th class="tdhistory654030">total_rows</th></tr></thead><tbody class="tdhistory654030 resultset-body"><tr><th class="tdhistory654030" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory654030">91748</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. Data Exploration</b></p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>TD_CategoricalSummary</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_CATEGORICALSUMMARY </b>function   displays the distinct values and their counts for each specified input table column</p>

# %%
SELECT * FROM TD_CategoricalSummary (
ON CLM_QOE AS InputTable
USING
    TargetColumns ('Experiment_Type','NetworkTech','NetworkMode','Event','State','Eid') 
) AS dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory389234"><style>
#       table.tdhistory389234 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory389234 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory389234:last-child { text-align: left !important; }
#       tbody.tdhistory389234 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory389234 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory389234 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory389234"></th><th class="tdhistory389234">ColumnName</th><th class="tdhistory389234">DistinctValue</th><th class="tdhistory389234">DistinctValueCount</th></tr></thead><tbody class="tdhistory389234 resultset-body"><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2m11aug</td><td class="tdhistory389234">876</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">28airport5g</td><td class="tdhistory389234">218</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">14augs</td><td class="tdhistory389234">51</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2i25auglte</td><td class="tdhistory389234">398</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2m16aug</td><td class="tdhistory389234">345</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2a19aug</td><td class="tdhistory389234">310</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2p9aug</td><td class="tdhistory389234">293</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2p23aug</td><td class="tdhistory389234">280</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2m20aug</td><td class="tdhistory389234">412</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2paug8</td><td class="tdhistory389234">492</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">3a25auglte</td><td class="tdhistory389234">91</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">4a26</td><td class="tdhistory389234">216</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2m23auglte</td><td class="tdhistory389234">482</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">3m16aug</td><td class="tdhistory389234">554</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">4a31</td><td class="tdhistory389234">224</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">16</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">4a30</td><td class="tdhistory389234">212</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">17</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">2m25auglte</td><td class="tdhistory389234">245</td></tr><tr><th class="tdhistory389234" style= "background: rgba(243, 243, 243, 0.75)">18</th><td class="tdhistory389234">Eid</td><td class="tdhistory389234">3m25auglte</td><td class="tdhistory389234">395</td></tr><tr><th class="tdhistory389234" style= "backgrou ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>TD_ColumnSummary</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_ColumnSummary </b>function  displays Column name, datatype and other demographics like count of NULLs etc for each specified input table column</p>

# %%
SELECT * FROM TD_ColumnSummary (
  ON CLM_QOE AS InputTable
  USING
  TargetColumns ('Longitude','Latitude','LTERSSI','Level')
) AS dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory964368"><style>
#       table.tdhistory964368 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory964368 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory964368:last-child { text-align: left !important; }
#       tbody.tdhistory964368 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory964368 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory964368 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory964368"></th><th class="tdhistory964368">ColumnName</th><th class="tdhistory964368">Datatype</th><th class="tdhistory964368">NonNullCount</th><th class="tdhistory964368">NullCount</th><th class="tdhistory964368">BlankCount</th><th class="tdhistory964368">ZeroCount</th><th class="tdhistory964368">PositiveCount</th><th class="tdhistory964368">NegativeCount</th><th class="tdhistory964368">NullPercentage</th><th class="tdhistory964368">NonNullPercentage</th></tr></thead><tbody class="tdhistory964368 resultset-body"><tr><th class="tdhistory964368" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory964368">Latitude</td><td class="tdhistory964368">FLOAT</td><td class="tdhistory964368">91748</td><td class="tdhistory964368">0</td><td class="tdhistory964368"></td><td class="tdhistory964368">1298</td><td class="tdhistory964368">90450</td><td class="tdhistory964368">0</td><td class="tdhistory964368">0</td><td class="tdhistory964368">100</td></tr><tr><th class="tdhistory964368" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory964368">Longitude</td><td class="tdhistory964368">FLOAT</td><td class="tdhistory964368">91748</td><td class="tdhistory964368">0</td><td class="tdhistory964368"></td><td class="tdhistory964368">1298</td><td class="tdhistory964368">90045</td><td class="tdhistory964368">405</td><td class="tdhistory964368">0</td><td class="tdhistory964368">100</td></tr><tr><th class="tdhistory964368" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory964368">Level</td><td class="tdhistory964368">INTEGER</td><td class="tdhistory964368">91748</td><td class="tdhistory964368">0</td><td class="tdhistory964368"></td><td class="tdhistory964368">0</td><td class="tdhistory964368">0</td><td class="tdhistory964368">91748</td><td class="tdhistory964368">0</td><td class="tdhistory964368">100</td></tr><tr><th class="tdhistory964368" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory964368">LTERSSI</td><td class="tdhistory964368">INTEGER</td><td class="tdhistory964368">91748</td><td class="tdhistory964368">0</td><td class="tdhistory964368"></td><td class="tdhistory964368">42680</td><td class="tdhistory964368">0</td><td class="tdhistory964368">49068</td><td class="tdhistory964368">0</td><td class="tdhistory964368">100</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>4.1 Exploratory Data Analysis using TD_Plot</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_Plot</b> provides the ability to generate charts. The generated charts can be in the JPG, PNG, or SVG formats.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     Bar Chart - Video Quality Distribution</b></p>

# %%
CREATE MULTISET VOLATILE TABLE BAR_Graph_Videos_4G AS (
    SELECT Video, Quality,Video_Bytes_Downloaded,
        AVG(Loaded_Percentage) OVER (PARTITION BY Quality) AS Average_Loaded_Percentage, 
        Eid, DateTime,
        CASE 
            WHEN Quality = 'hd2160' THEN 1
            WHEN Quality = 'hd1440' THEN 2
            WHEN Quality = 'hd1080' THEN 3
            WHEN Quality = 'hd720' THEN 4
            WHEN Quality IN ('unknown', 'medium', 'large') THEN 5
        END AS Quality_Code,
        1 AS series
    FROM CLM_QOE
    WHERE Eid LIKE '4%'
    GROUP BY Video, Quality, Video_Bytes_Downloaded, Loaded_Percentage, Eid, DateTime
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In table BAR_Graph_Videos_4G we have the metrics for 4G videos</p>

# %%
CREATE MULTISET VOLATILE TABLE BAR_Graph_Videos_5G AS (
    SELECT Video, Quality,Video_Bytes_Downloaded, 
        AVG(Loaded_Percentage) OVER (PARTITION BY Quality) AS Average_Loaded_Percentage, 
        Eid, DateTime,
        CASE 
            WHEN Quality = 'hd2160' THEN 1
            WHEN Quality = 'hd1440' THEN 2
            WHEN Quality = 'hd1080' THEN 3
            WHEN Quality = 'hd720' THEN 4
            WHEN Quality IN ('unknown', 'medium', 'large') THEN 5
        END AS Quality_Code,
        1 AS series
    FROM CLM_QOE
    WHERE Eid LIKE '5%'
    GROUP BY Video, Quality, Video_Bytes_Downloaded,Loaded_Percentage, Eid, DateTime
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>In table BAR_Graph_Videos_5G we have the metrics for 5G videos</p>

# %%
EXECUTE FUNCTION INTO VOLATILE ART(barGraph)
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(BAR_Graph_Videos_4G),
        ROW_AXIS(SEQUENCE(Quality_Code)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS("Average_Loaded_Percentage"),
           CONTENT(REAL)
        )
    ) where Quality_Code IN (1,2,3,4),
    
    
    SERIES_SPEC
    (
        TABLE_NAME(BAR_Graph_Videos_5G),
        ROW_AXIS(SEQUENCE(Quality_Code)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS("Average_Loaded_Percentage"),
           CONTENT(REAL)
        )
    ) where Quality_Code IN (1,2,3,4),
    
    
    
    FUNC_PARAMS
    (
        LAYOUT(2,1),
        WIDTH(900),
        HEIGHT(600),
        TITLE('Video Quality Distribution'),
        PLOTS[
            (
                ID(1),
                CELL(1,1),
                TITLE ('Video Quality Distribution on 4G Smartphone'),
                TYPE('bar'),
                LEGEND('best'),
                XLABEL('Quality Threshold'),
                YLABEL('Average_Loaded_Percentage')
            ),
            
             (
                ID(2),
                CELL(2,1),
                TITLE ('Video Quality Distribution on 5G Smartphone'),
                TYPE('bar'),
                LEGEND('best'),
                XLABEL('Quality Threshold'),
                YLABEL('Average_Loaded_Percentage')
            )
        ]
    )
);
# Out:
# Success: 1 rows affected

# %%
Select * from barGraph;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory40122"><style>
#       table.tdhistory40122 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory40122 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory40122:last-child { text-align: left !important; }
#       tbody.tdhistory40122 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory40122 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory40122 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory40122"></th><th class="tdhistory40122">Quality</th><th class="tdhistory40122">ROW_I</th><th class="tdhistory40122">IMAGE</th></tr></thead><tbody class="tdhistory40122 resultset-body"><tr><th class="tdhistory40122" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory40122"></td><td class="tdhistory40122">0</td><td class="tdhistory40122">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Click on the cell in the IMAGE column to select it, then right click on the cell and select View Image.</b></i> <br>The image should look like below.</p>

# %% [markdown]
# <center><img src="images/bargraph.png"/></center>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>From the above Bar Chart we can infer that</p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li> hd1440 consistently shows higher average loaded percentages on both 4G and 5G smartphones. </li>
# <li> hd1440 provides a better user experience in terms of loading time compared to other quality categories on both networks.</li>
# <li> These findings also suggest that network performance can vary for different video quality categories on different networks.</li>
#     <li> Optimal quality choices may depend on the smartphone's network capabilities.</li></ul>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Scatter Plot - 5G Vs 4G Mobility and Indoor Stalling Events</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Let us create subsets of 4G & 5G data for our analysis</p>

# %%
CREATE MULTISET VOLATILE TABLE "5g_time_stall_Mobility" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '5'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'M'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "4g_time_stall_Mobility" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '4'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'M'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA               
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "4g_time_stall_Indoor" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '4'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'I'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE "5g_time_stall_Indoor" AS (
    SELECT Video, Quality, Status, TimeStall, Eid, Dates,
           CAST(TO_TIMESTAMP(Dates || ' ' || Times, 'DD/MM/YYYY HH24:MI:SS') AS TIMESTAMP(6)) AS Date_Time, Category
    FROM Demo_5G.YouTube_Player_Events
    WHERE SUBSTRING(Eid FROM 1 FOR 1) = '5'
    AND SUBSTRING(Eid FROM 2 FOR 1) = 'I'
    AND Quality IN ('hd2160,', 'hd1080,', 'hd1440,', 'hd720,')
) WITH DATA
On Commit Preserve Rows;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let us check if our timeseries is regular or irregular series.<br>Irregular time series are data sequences where the observations or data points are not uniformly spaced in time. This may happen due to missing data or uneven data collection.

# %%
WITH time_diffs AS (
  SELECT
    Eid,
    MIN(Times) AS Min_Times,
    MAX(Times) AS Max_Times,
    Max_Times - LAG(Max_Times) OVER (ORDER BY Max_Times) AS Time_Diff
  FROM Demo_5G.YouTube_Player_Events
  GROUP BY Eid
)
SELECT
  CASE
    WHEN COUNT(DISTINCT Time_Diff) > 1 THEN 'Irregular'
    ELSE 'Regular' 
  END AS Time_Series_Type
FROM time_diffs;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory986516"><style>
#       table.tdhistory986516 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory986516 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory986516:last-child { text-align: left !important; }
#       tbody.tdhistory986516 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory986516 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory986516 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory986516"></th><th class="tdhistory986516">Time_Series_Type</th></tr></thead><tbody class="tdhistory986516 resultset-body"><tr><th class="tdhistory986516" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory986516">Irregular</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Our series is irregular, first let us make the series regular by resampling our data.

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>TD_Resample</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
#     <b>TD_Resample</b> function Transforms converts irregular time series into a regular time series and performs linear interpolation.TD_Resample can also be used to alter the sampling interval for a time series.<br>Finding the minimum date, so that we can re-sample the dates from this date onwards which will convert irregular time series into a regular time series.

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "5g_time_stall_Mobility";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory720519"><style>
#       table.tdhistory720519 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory720519 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory720519:last-child { text-align: left !important; }
#       tbody.tdhistory720519 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory720519 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory720519 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory720519"></th><th class="tdhistory720519">Min_Date</th><th class="tdhistory720519">Max_Date</th><th class="tdhistory720519">Total_Count</th><th class="tdhistory720519">Unique_Count</th><th class="tdhistory720519">Repetitions_Status</th></tr></thead><tbody class="tdhistory720519 resultset-body"><tr><th class="tdhistory720519" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory720519">2022-07-09 03:58:12.000000</td><td class="tdhistory720519">2022-10-09 17:13:48.000000</td><td class="tdhistory720519">96</td><td class="tdhistory720519">94</td><td class="tdhistory720519">Repetitions Detected</td></tr></tbody></table></div>

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "4g_time_stall_Mobility";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory553334"><style>
#       table.tdhistory553334 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory553334 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory553334:last-child { text-align: left !important; }
#       tbody.tdhistory553334 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory553334 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory553334 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory553334"></th><th class="tdhistory553334">Min_Date</th><th class="tdhistory553334">Max_Date</th><th class="tdhistory553334">Total_Count</th><th class="tdhistory553334">Unique_Count</th><th class="tdhistory553334">Repetitions_Status</th></tr></thead><tbody class="tdhistory553334 resultset-body"><tr><th class="tdhistory553334" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory553334">2022-07-09 04:01:34.000000</td><td class="tdhistory553334">2022-10-28 12:23:24.000000</td><td class="tdhistory553334">264</td><td class="tdhistory553334">247</td><td class="tdhistory553334">Repetitions Detected</td></tr></tbody></table></div>

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "5g_time_stall_Indoor";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory384995"><style>
#       table.tdhistory384995 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory384995 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory384995:last-child { text-align: left !important; }
#       tbody.tdhistory384995 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory384995 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory384995 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory384995"></th><th class="tdhistory384995">Min_Date</th><th class="tdhistory384995">Max_Date</th><th class="tdhistory384995">Total_Count</th><th class="tdhistory384995">Unique_Count</th><th class="tdhistory384995">Repetitions_Status</th></tr></thead><tbody class="tdhistory384995 resultset-body"><tr><th class="tdhistory384995" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory384995">2022-08-09 15:24:44.000000</td><td class="tdhistory384995">2022-12-09 13:58:35.000000</td><td class="tdhistory384995">23</td><td class="tdhistory384995">23</td><td class="tdhistory384995">No Repetitions Found</td></tr></tbody></table></div>

# %%
SELECT MIN(Date_Time) AS Min_Date,
       MAX(Date_Time) AS Max_Date,
       COUNT(*) AS Total_Count,
       COUNT(DISTINCT Date_Time) AS Unique_Count,
       CASE
           WHEN COUNT(*) <> COUNT(DISTINCT Date_Time) THEN 'Repetitions Detected'
           ELSE 'No Repetitions Found'
       END AS Repetitions_Status
FROM "4g_time_stall_Indoor";
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory193226"><style>
#       table.tdhistory193226 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory193226 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory193226:last-child { text-align: left !important; }
#       tbody.tdhistory193226 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory193226 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory193226 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory193226"></th><th class="tdhistory193226">Min_Date</th><th class="tdhistory193226">Max_Date</th><th class="tdhistory193226">Total_Count</th><th class="tdhistory193226">Unique_Count</th><th class="tdhistory193226">Repetitions_Status</th></tr></thead><tbody class="tdhistory193226 resultset-body"><tr><th class="tdhistory193226" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory193226">2022-08-09 15:31:35.000000</td><td class="tdhistory193226">2022-12-09 13:58:33.000000</td><td class="tdhistory193226">331</td><td class="tdhistory193226">310</td><td class="tdhistory193226">Repetitions Detected</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Using the resample function to convert irregular time series into a regular time series

# %%
EXECUTE FUNCTION INTO VOLATILE ART("4g_resampled_time_stall_Mobility")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("4g_time_stall_Mobility"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-07-09 04:01:34'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 379539 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART("5g_resampled_time_stall_Mobility")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("5g_time_stall_Mobility"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-07-09 03:58:12'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 280704 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART("5g_resampled_time_stall_Indoor")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("5g_time_stall_Indoor"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-08-09 15:24:44'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 408815 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART("4g_resampled_time_stall_Indoor")

TD_RESAMPLE(
    SERIES_SPEC(
        TABLE_NAME("4g_time_stall_Indoor"),
        ROW_AXIS(timecode(date_time)),
        SERIES_ID(Quality),
        PAYLOAD(FIELDS(TimeStall), CONTENT(REAL)
     )
    ),
    FUNC_PARAMS(
        TIMECODE(
            START_VALUE(TIMESTAMP '2022-08-09 15:31:35'), 
            DURATION(minutes(1))
        ),
        INTERPOLATE(LINEAR)
    )
);
# Out:
# Success: 367069 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART(scatter_graph_timestall)
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME("4g_resampled_time_stall_Mobility"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME("5g_resampled_time_stall_Mobility"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    

     SERIES_SPEC
    (
        TABLE_NAME("4g_resampled_time_stall_Indoor"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME("5g_resampled_time_stall_Indoor"),
        ROW_AXIS(TIMECODE(ROW_I)),
        SERIES_ID(Quality),
        PAYLOAD
        (
           FIELDS(TimeStall),
           CONTENT(REAL)
        )
    ),
    
    FUNC_PARAMS
    (
        LAYOUT(4, 1),
        WIDTH(1500),
        HEIGHT(600),
        TITLE('SCATTER GRAPH'),
        PLOTS[
            (
                ID(1),
                CELL(1, 1),
                TITLE ('4G Stalling on Video Resolutions Mobility'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            ),
            
            (
                ID(2),
                CELL(2, 1),
                TITLE ('5G Stalling on Video Resolutions Mobility'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            ),
            
            (
                ID(3),
                CELL(3, 1),
                TITLE ('4G Stalling on Video Resolutions Indoor'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            ),
            
            (
                ID(4),
                CELL(4, 1),
                TITLE ('5G Stalling on Video Resolutions Indoor'),
                TYPE('scatter'),
                LEGEND('best'),
                XLABEL('TIME SERIES'),
                YLABEL('Stalling Time in minutes')
            )
        ]
    )
);
# Out:
# Success: 1 rows affected

# %%
select * from scatter_graph_timestall;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory774039"><style>
#       table.tdhistory774039 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory774039 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory774039:last-child { text-align: left !important; }
#       tbody.tdhistory774039 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory774039 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory774039 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory774039"></th><th class="tdhistory774039">Quality</th><th class="tdhistory774039">ROW_I</th><th class="tdhistory774039">IMAGE</th></tr></thead><tbody class="tdhistory774039 resultset-body"><tr><th class="tdhistory774039" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory774039"></td><td class="tdhistory774039">0</td><td class="tdhistory774039">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Click on the cell in the IMAGE column to select it, then right click on the cell and select View Image.</b></i> <br>The image should look like below.

# %% [markdown]
# <center><img src="images/scatter.png"/></center>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>From the above Scatter Plot we can infer that</p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li> 4G on mobility, hd1440 exhibited the highest stalling duration over time, while hd720 experienced the least stalling. On 5G in mobility, hd2160 had brief but high stalling, while hd1440 showed less stalling but played for longer durations. </li>
# <li>Shifting to indoor settings on 4G, hd2160 initially had the highest stalling and hd1440 had minimal stalling.</li>
# <li>Indoor scenario on 5G, hd2160 had persistent stalling, hd1440 had the least stalling, and both hd1080 and hd720 showed minimal interruptions.</li>
#  <li> This indicates that higher video qualities tend to experience more stalling, especially in challenging network conditions, while lower qualities offer smoother playback</li></ul>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Line Graph - 5G vs 4G ( CQI, RSRP, RSRQ, SNR)</b></p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_5G_CQI AS (
  SELECT
    CQI,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      CQI,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY CQI)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY CQI), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        CQI,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '5G'
      GROUP BY CQI, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
CREATE  MULTISET VOLATILE TABLE CLM_4G_CQI AS (
  SELECT
    CQI,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY CQI) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY CQI), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      CQI,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY CQI)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY CQI), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        CQI,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '4G'
      GROUP BY CQI, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_5G_Level AS (
  SELECT
    Level,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      Level,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY Level)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY Level), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        Level,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '5G'
      GROUP BY Level, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_4G_Level AS (
  SELECT
    Level,
    Experiment_Type,
    Experiment_Count,
    CASE
      WHEN MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) = MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level) THEN 0 -- Handle division by zero
      ELSE (Experiment_Count_Standardized - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level)) / NULLIF(MAX(Experiment_Count_Standardized) OVER (PARTITION BY Level) - MIN(Experiment_Count_Standardized) OVER (PARTITION BY Level), 0)
    END AS Experiment_Count_Standardized_Range
  FROM (
    SELECT
      Level,
      Experiment_Type,
      Experiment_Count,
      COALESCE((Experiment_Count - AVG(Experiment_Count) OVER (PARTITION BY Level)) / NULLIF(STDDEV_POP(Experiment_Count) OVER (PARTITION BY Level), 0), 0) AS Experiment_Count_Standardized
    FROM (
      SELECT
        Level,
        Experiment_Type,
        COUNT(*) AS Experiment_Count
      FROM CLM_QOE
      WHERE NetworkTech = '4G'
      GROUP BY Level, Experiment_Type
    ) t
  ) t2
) WITH DATA
on commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
EXECUTE FUNCTION INTO VOLATILE ART(Benchamrking_CLM)
TD_Plot
(
    SERIES_SPEC
    (
        TABLE_NAME(CLM_5G_CQI),
        ROW_AXIS(SEQUENCE(CQI)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL)
        )
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME(CLM_4G_CQI ),
        ROW_AXIS(SEQUENCE(CQI)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL))
    
    ),
    
    SERIES_SPEC
    (
        TABLE_NAME(CLM_5G_Level ),
        ROW_AXIS(SEQUENCE(Level)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL))
    
    ),
    SERIES_SPEC
    (
        TABLE_NAME(CLM_4G_Level ),
        ROW_AXIS(SEQUENCE(Level)),
        SERIES_ID(Experiment_Type),
        PAYLOAD
        (
           FIELDS(Experiment_Count_Standardized_Range),
           CONTENT(REAL))
    
    ),
    
    
    FUNC_PARAMS
    (
        LAYOUT(2,2),
        WIDTH(1000),
        HEIGHT(800),
        TITLE('4G Vs 5G Channel Level Metric Performance '),
        PLOTS[
            (
                ID(1),
                CELL(1,1),
                TYPE('line'),
                Title('5G CQI'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('CQI'),
                YLABEL('Frequecny')
            ),(
                ID(2),
                CELL(1,2),
                TYPE('line'),
                Title('4G CQI'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('CQI'),
                YLABEL('Frequecny')
            ),
            
            (
                ID(3),
                CELL(2,1),
                TYPE('line'),
                Title('5G RSRP'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('RSRP'),
                YLABEL('Frequecny')
            ),
            (
                ID(4),
                CELL(2,2),
                TYPE('line'),
                Title('4G RSRP'),
                MARKER('o'),
                LEGEND('best'),
                XLABEL('RSRP'),
                YLABEL('Frequecny')
            )

        ]
    )
);
# Out:
# Success: 1 rows affected

# %%
select * from Benchamrking_CLM;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory833043"><style>
#       table.tdhistory833043 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory833043 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory833043:last-child { text-align: left !important; }
#       tbody.tdhistory833043 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory833043 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory833043 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory833043"></th><th class="tdhistory833043">Experiment_Type</th><th class="tdhistory833043">ROW_I</th><th class="tdhistory833043">IMAGE</th></tr></thead><tbody class="tdhistory833043 resultset-body"><tr><th class="tdhistory833043" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory833043"></td><td class="tdhistory833043">0</td><td class="tdhistory833043">...</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Click on the cell in the IMAGE column to select it, then right click on the cell and select View Image.</b></i> <br>The image should look like below.

# %% [markdown]
# <center><img src="images/line.png"/></center>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>From the above line chart we can infer that
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li> The spread-out distribution in the 5G and 4G CQI graphs indicates that the CQI values vary across different experiments, higher values indicating better signal quality.</li>
# <li>In the case of RSRP, the presence of frequent spikes in both the 5G and 4G RSRP graphs suggests significant fluctuations in signal strength. The spikes indicate instances where the RSRP values deviate from the average or expected levels. Negative values of RSRP indicating relatively weaker signal power.</li>
# <li>Overall, these observations provide insights into the performance of CQI and RSRP metrics across different experiments and network technologies. The variations and patterns in CQI and RSRP values reflect the changing channel conditions, signal quality, and signal power, which can impact the overall network performance and user experience.</li>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. Feature Engineering and Selection</b></p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     Target Variable</b></p>

# %% [markdown]
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
# <li>To identify a user's quality of experience using youtube video statistics we derive "load rate", a metric can be used to represent how smooth the video is playing. </li>
#     <li>If the load rate will is low there will be more buffering time and in turn will impact user's overall viewing  experience and vice versa</li>
#     </ul>
#  <ul style = 'font-size:16px;font-family:Arial;color:#00233C'> Derive Features Include
#     <li><b>Load_rate</b>  = loaded percentage/ (current time)-(start time of the experiment) i.e Duration of Experiment</li>
#     <li><b>Rate_category</b> = (Less Then 0.3 = Low),  (Between  0.3 and 0.5 = Medium), (Above 0.5 - High)</li>
#     <li><b>Distance</b> = Total Haversine Distance for EIDs </li></ul>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS AS (
  SELECT dt.*,  
    CASE
      WHEN dt.load_rate >= 0 AND dt.load_rate <= 0.30 THEN 'low'
      WHEN dt.load_rate >= 0.30 AND dt.load_rate < 0.50 THEN 'med'
      ELSE 'high'
    END AS rate_category
    
  FROM (
    select CLM_QOE.*,  
     TO_TIMESTAMP(CLM_QOE."DateTime",'DD/MM/YYYY HH24:MI:SS') AS OTHER_TIME,
     MIN(TO_TIMESTAMP(CLM_QOE."DateTime",'DD/MM/YYYY HH24:MI:SS')) 
     OVER (PARTITION BY CLM_QOE."Eid") AS MIN_TIME,
     (OTHER_TIME - MIN_TIME) HOUR(2) TO SECOND AS TIME_DIFF,
     CAST(EXTRACT(HOUR  FROM TIME_DIFF) * 3600
     + EXTRACT(MINUTE FROM TIME_DIFF) * 60
      + EXTRACT(SECOND FROM TIME_DIFF) AS INT) AS TIME_DIFF_SECS,
      CLM_QOE.Loaded_Percentage / NULLIFZERO (TIME_DIFF_SECS) AS LOAD_RATE
      FROM CLM_QOE
  ) AS dt
) WITH DATA
On commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_ADS;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory538566"><style>
#       table.tdhistory538566 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory538566 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory538566:last-child { text-align: left !important; }
#       tbody.tdhistory538566 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory538566 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory538566 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory538566"></th><th class="tdhistory538566">QoE_Time</th><th class="tdhistory538566">QoE_Date</th><th class="tdhistory538566">Eid</th><th class="tdhistory538566">Video_Bytes_Downloaded</th><th class="tdhistory538566">Video</th><th class="tdhistory538566">Quality</th><th class="tdhistory538566">Loaded_Percentage</th><th class="tdhistory538566">Longitude</th><th class="tdhistory538566">Latitude</th><th class="tdhistory538566">NetworkTech</th><th class="tdhistory538566">NetworkMode</th><th class="tdhistory538566">Level</th><th class="tdhistory538566">Qual</th><th class="tdhistory538566">SNR</th><th class="tdhistory538566">CQI</th><th class="tdhistory538566">LTERSSI</th><th class="tdhistory538566">DL_bitrate</th><th class="tdhistory538566">UL_bitrate</th><th class="tdhistory538566">Altitude</th><th class="tdhistory538566">Height</th><th class="tdhistory538566">State</th><th class="tdhistory538566">EVENT</th><th class="tdhistory538566">SecondCell_RSRP</th><th class="tdhistory538566">SecondCell_RSRQ</th><th class="tdhistory538566">SecondCell_SNR</th><th class="tdhistory538566">Experiment_Type</th><th class="tdhistory538566">DateTime</th><th class="tdhistory538566">OTHER_TIME</th><th class="tdhistory538566">MIN_TIME</th><th class="tdhistory538566">TIME_DIFF</th><th class="tdhistory538566">TIME_DIFF_SECS</th><th class="tdhistory538566">LOAD_RATE</th><th class="tdhistory538566">rate_category</th></tr></thead><tbody class="tdhistory538566 resultset-body"><tr><th class="tdhistory538566" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory538566">19:06:11</td><td class="tdhistory538566">23/08/2022</td><td class="tdhistory538566">2m23auglte</td><td class="tdhistory538566">0.293883016</td><td class="tdhistory538566">JMbBjKnUoC4</td><td class="tdhistory538566">hd2160</td><td class="tdhistory538566">29.4</td><td class="tdhistory538566">7.070095</td><td class="tdhistory538566">43.617203</td><td class="tdhistory538566">4G</td><td class="tdhistory538566">LTE</td><td class="tdhistory538566">-85</td><td class="tdhistory538566">-11</td><td class="tdhistory538566">13</td><td class="tdhistory538566">12</td><td class="tdhistory538566">-91</td><td class="tdhistory538566">4</td><td class="tdhistory538566">5</td><td class="tdhistory538566">178</td><td class="tdhistory538566">178</td><td class="tdhistory538566">D </td><td class="tdhistory538566">PERIODIC</td><td class="tdhistory538566">0</td><td class="tdhistory538566">0</td><td class="tdhistory538566">0</td><td class="tdhistory538566">Mobility</td><td class="tdhistory538566">23/08/2022 19:06:11</td><td class="tdhistory538566">2022-08-23 19:06:11.000000</td><td class="tdhistory538566">2022-08-23 19:04:36.000000</td><td class="tdhistory538566">  0:01:35.000000</td><td class="tdhistory538566">95</td><td class="tdhistory538566">0.3094736842105263</td><td class="tdhistory538566">med</td></tr><tr><th class="tdhistory538566" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory538566">19:09:41</td><td class="tdhistory538566">23/08/2022</td><td class="tdhistory538566">2m23auglte</td><td class="tdhistory538566">0.831941034</td><td class="tdhistory538566">JMbBjKnUoC4</td><td class="tdhistory538566">hd2160</td><td class="tdhistory538566">83.2</td><td class="tdhistory538566">7.072831</td><td class="tdhistory538566">43.616862</td><td class="tdhistory538566">4G</td><td class="tdhistory538566">LTE</td><td class="tdhistory538566">-83</td><td class="tdhistory538566">-6</td><td class="tdhistory538566">15</td><td class="tdhistory538566">9</td><td class="tdhistory538566">-83</td><td class="tdhistory538566">3</td><td class="tdhistory538566">5</td><td class="tdhistory538566">171</td><td class="tdhistory538566">171</td><td class="tdhistory538566">D </td><td class="tdhistory538566">PERIODIC</td><td class="tdhistory538566">0</td><td class="tdhistory538566">0</td><td class="tdhistory538566">0</td><td cla ...

# %%
SELECT * FROM TD_CategoricalSummary (
ON CLM_ADS AS InputTable
USING
    TargetColumns ('rate_category') 
) AS dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory67733"><style>
#       table.tdhistory67733 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory67733 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory67733:last-child { text-align: left !important; }
#       tbody.tdhistory67733 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory67733 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory67733 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory67733"></th><th class="tdhistory67733">ColumnName</th><th class="tdhistory67733">DistinctValue</th><th class="tdhistory67733">DistinctValueCount</th></tr></thead><tbody class="tdhistory67733 resultset-body"><tr><th class="tdhistory67733" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory67733">rate_category</td><td class="tdhistory67733">low</td><td class="tdhistory67733">29338</td></tr><tr><th class="tdhistory67733" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory67733">rate_category</td><td class="tdhistory67733">high</td><td class="tdhistory67733">27452</td></tr><tr><th class="tdhistory67733" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory67733">rate_category</td><td class="tdhistory67733">med</td><td class="tdhistory67733">34958</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Rate_Category column is our target variable for the models we'll create in next steps. We will classify our test data in one of the above category(cluster).</p>

# %%
%chart x=DistinctValue,y=DistinctValueCount,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster",height= 400,width=400

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     Data Preparation</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Before we can use the data in models we will perform some data preparation steps.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Label Encoding </b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_OrdinalEncodingFit </b>function identifies distinct categorical values from an input table or a user-defined list and returns the distinct categorical values along with the ordinal value for each category.The <b>TD_OrdinalEncodingTransform</b> function maps the categorical value to a specified ordinal value using the TD_OrdinalEncodingFit output.</p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_ENCODED AS (
SELECT * FROM TD_OrdinalEncodingFit (
ON CLM_ADS AS InputTable
USING
TargetColumn('Quality','NetworkTech','NetworkMode','Experiment_Type','rate_category')
Approach ('AUTO')
StartValue (0,0,0,0,0)
DefaultValue (-1,-1,-1,-1,-1)
) AS dt
) WITH DATA
On commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_ADS_ENCODED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory55522"><style>
#       table.tdhistory55522 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory55522 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory55522:last-child { text-align: left !important; }
#       tbody.tdhistory55522 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory55522 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory55522 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory55522"></th><th class="tdhistory55522">TD_ColumnName_ORDFIT</th><th class="tdhistory55522">TD_Category_ORDFIT</th><th class="tdhistory55522">TD_Value_ORDFIT</th><th class="tdhistory55522">TD_Index_ORDFIT</th><th class="tdhistory55522">Quality</th><th class="tdhistory55522">NetworkTech</th><th class="tdhistory55522">NetworkMode</th><th class="tdhistory55522">Experiment_Type</th><th class="tdhistory55522">rate_category</th></tr></thead><tbody class="tdhistory55522 resultset-body"><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory55522">NetworkTech</td><td class="tdhistory55522">5G</td><td class="tdhistory55522">2</td><td class="tdhistory55522">1</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory55522">NetworkTech</td><td class="tdhistory55522">TD_OTHER_CATEGORY</td><td class="tdhistory55522">-1</td><td class="tdhistory55522">-2</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory55522">NetworkMode</td><td class="tdhistory55522">4G</td><td class="tdhistory55522">0</td><td class="tdhistory55522">2</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory55522">NetworkMode</td><td class="tdhistory55522">5G</td><td class="tdhistory55522">1</td><td class="tdhistory55522">2</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory55522">NetworkMode</td><td class="tdhistory55522">LTE</td><td class="tdhistory55522">3</td><td class="tdhistory55522">2</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory55522">NetworkMode</td><td class="tdhistory55522">UMTS</td><td class="tdhistory55522">4</td><td class="tdhistory55522">2</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory55522">Quality</td><td class="tdhistory55522">hd1080</td><td class="tdhistory55522">0</td><td class="tdhistory55522">0</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory55522">Quality</td><td class="tdhistory55522">hd1440</td><td class="tdhistory55522">1</td><td class="tdhistory55522">0</td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td><td class="tdhistory55522"></td></tr><tr><th class="tdhistory55522" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory55522">Quality</td><td class="tdhistory55522">hd2160</td><td class="tdhistory55522">2</td><td class="tdhistory55522">0</td><td class="tdhistory55522"></td><td class="t ...

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_TRANSFORMED AS (
SELECT * FROM TD_OrdinalEncodingTransform (
ON CLM_ADS as InputTable
ON CLM_ADS_ENCODED as FitTable Dimension
USING
ACCUMULATE('QoE_Time','QoE_Date','Eid','Video_Bytes_Downloaded','Video','Loaded_Percentage', 'Longitude','Latitude','Level','Qual','SNR','CQI', 'LTERSSI', 'DL_bitrate','UL_bitrate','Altitude','Height','State','EVENT','SecondCell_RSRP','SecondCell_RSRQ','SecondCell_SNR', 'DateTime','OTHER_TIME', 'MIN_TIME', 'TIME_DIFF','TIME_DIFF_SECS','Load_Rate')
) AS dt
) WITH DATA
On commit preserve rows;
# Out:
# Success: 0 rows affected

# %%
select top 10 * from CLM_ADS_TRANSFORMED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory772203"><style>
#       table.tdhistory772203 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory772203 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory772203:last-child { text-align: left !important; }
#       tbody.tdhistory772203 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory772203 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory772203 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory772203"></th><th class="tdhistory772203">QoE_Time</th><th class="tdhistory772203">QoE_Date</th><th class="tdhistory772203">Eid</th><th class="tdhistory772203">Video_Bytes_Downloaded</th><th class="tdhistory772203">Video</th><th class="tdhistory772203">Loaded_Percentage</th><th class="tdhistory772203">Longitude</th><th class="tdhistory772203">Latitude</th><th class="tdhistory772203">Level</th><th class="tdhistory772203">Qual</th><th class="tdhistory772203">SNR</th><th class="tdhistory772203">CQI</th><th class="tdhistory772203">LTERSSI</th><th class="tdhistory772203">DL_bitrate</th><th class="tdhistory772203">UL_bitrate</th><th class="tdhistory772203">Altitude</th><th class="tdhistory772203">Height</th><th class="tdhistory772203">State</th><th class="tdhistory772203">EVENT</th><th class="tdhistory772203">SecondCell_RSRP</th><th class="tdhistory772203">SecondCell_RSRQ</th><th class="tdhistory772203">SecondCell_SNR</th><th class="tdhistory772203">DateTime</th><th class="tdhistory772203">OTHER_TIME</th><th class="tdhistory772203">MIN_TIME</th><th class="tdhistory772203">TIME_DIFF</th><th class="tdhistory772203">TIME_DIFF_SECS</th><th class="tdhistory772203">LOAD_RATE</th><th class="tdhistory772203">Quality</th><th class="tdhistory772203">NetworkTech</th><th class="tdhistory772203">NetworkMode</th><th class="tdhistory772203">Experiment_Type</th><th class="tdhistory772203">rate_category</th></tr></thead><tbody class="tdhistory772203 resultset-body"><tr><th class="tdhistory772203" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory772203">12:09:06</td><td class="tdhistory772203">28/09/2022</td><td class="tdhistory772203">28airport5g</td><td class="tdhistory772203">1</td><td class="tdhistory772203">jAa58N4Jlos</td><td class="tdhistory772203">100</td><td class="tdhistory772203">7.213881</td><td class="tdhistory772203">43.664696</td><td class="tdhistory772203">-108</td><td class="tdhistory772203">-11</td><td class="tdhistory772203">0</td><td class="tdhistory772203">9</td><td class="tdhistory772203">0</td><td class="tdhistory772203">7</td><td class="tdhistory772203">10</td><td class="tdhistory772203">56</td><td class="tdhistory772203">56</td><td class="tdhistory772203">D </td><td class="tdhistory772203">PERIODIC</td><td class="tdhistory772203">-112</td><td class="tdhistory772203">-16</td><td class="tdhistory772203">3</td><td class="tdhistory772203">28/09/2022 12:09:06</td><td class="tdhistory772203">2022-09-28 12:09:06.000000</td><td class="tdhistory772203">2022-09-28 12:05:41.000000</td><td class="tdhistory772203">  0:03:25.000000</td><td class="tdhistory772203">205</td><td class="tdhistory772203">0.4878048780487805</td><td class="tdhistory772203">2</td><td class="tdhistory772203">2</td><td class="tdhistory772203">1</td><td class="tdhistory772203">2</td><td class="tdhistory772203">2</td></tr><tr><th class="tdhistory772203" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory772203">12:05:46</td><td class="tdhistory772203">28/09/2022</td><td class="tdhistory772203">28airport5g</td><td class="tdhistory772203">0.091167672</td><td class="tdhistory772203">jAa58N4Jlos</td><td class="tdhistory772203">9.1</td><td class="tdhistory772203">7.214106</td><td class="tdhistory772203">43.66486</td><td class="tdhistory772203">-115</td><td class="tdhistory772203">-16</td><td class="tdhistory772203">1</td><td class="tdhistory772203">7</td><td class="tdhistory772203">-113</td><td class="tdhistory772203">1653</td><td class="tdhistory772203">20</td><td class="tdhistory772203">56</td><td class="tdhistory772203">56</td><td class="tdhistory772203">D </td><td class="tdhistory772203">PERIODIC</td><td class="tdhistory772203">0</td><td class="tdhistory772203">0</td><td class="tdhistory772203">0</td><td class="tdhistory772203">28/09/2022 12:05:46</td><td class="tdhistory772203">2022-09-28 12:05:46.000000</td><td class="tdhistory772203"> ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_TrainTestSplit </b>The function randomly divides the data sets into train and test subsets to evaluate machine learning algorithms and validation processes. The first subset is used to train the model. The second subset is used to make predictions and compare the predictions to actual values. </p>

# %%
CREATE MULTISET TABLE CLM_ADS_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_TRANSFORMED AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET TABLE CLM_ADS_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_TRANSFORMED AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA;
# Out:
# Success: 0 rows affected

# %%
select rate_category, count(*) from CLM_ADS_TEST group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory964525"><style>
#       table.tdhistory964525 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory964525 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory964525:last-child { text-align: left !important; }
#       tbody.tdhistory964525 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory964525 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory964525 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory964525"></th><th class="tdhistory964525">rate_category</th><th class="tdhistory964525">Count(*)</th></tr></thead><tbody class="tdhistory964525 resultset-body"><tr><th class="tdhistory964525" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory964525">1</td><td class="tdhistory964525">8719</td></tr><tr><th class="tdhistory964525" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory964525">0</td><td class="tdhistory964525">8344</td></tr><tr><th class="tdhistory964525" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory964525">2</td><td class="tdhistory964525">10462</td></tr></tbody></table></div>

# %%
select rate_category, count(*) as counts from CLM_ADS_TEST group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory442293"><style>
#       table.tdhistory442293 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory442293 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory442293:last-child { text-align: left !important; }
#       tbody.tdhistory442293 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory442293 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory442293 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory442293"></th><th class="tdhistory442293">rate_category</th><th class="tdhistory442293">counts</th></tr></thead><tbody class="tdhistory442293 resultset-body"><tr><th class="tdhistory442293" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory442293">1</td><td class="tdhistory442293">8719</td></tr><tr><th class="tdhistory442293" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory442293">0</td><td class="tdhistory442293">8344</td></tr><tr><th class="tdhistory442293" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory442293">2</td><td class="tdhistory442293">10462</td></tr></tbody></table></div>

# %%
%chart x=rate_category,y=counts,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster in Test data",height= 400,width=400

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. Model Training and Evaluation </b> </p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     6.1 Decision Forest</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_DecisionForest</b> function is an ensemble algorithm used for classification and regression predictive modeling problems. It is an extension of bootstrap aggregation (bagging) of decision trees.
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>This function takes the training data as input, as well as the following function parameters</p>
#     <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#         <li>InputColumns; list or range of columns used as features (we used an ordinal reference of columns 2:217)</li>
#         <li>ResponseColumn; the dependent or target value (we used “class”, the first column)</li>
#         <li>TreeType; either CLASSIFICATION or REGRESSION</li>
#     <li>Other hyperparameter values detailed in the documentation</li>
#         </ul>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates model.  Due to the limited resources of this VM, processing this step may take up to 4 minutes to run.</b></i>

# %%
CREATE MULTISET TABLE CLM_ADS_MDL_DF AS (
select * from TD_DecisionForest (
ON CLM_ADS_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode','Experiment_Type')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType('classification')
) as dt
) WITH DATA
;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <hr style="height:1px;border:none;background-color:#00233C;">
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>
#     6.2 XGboost</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>
#  The <b>TD_XGBoost </b>is an implementation of the gradient boosted decision tree designed for speed and performance. In gradient boosting, each iteration fits a model to the residuals (errors) of the previous iteration to correct the errors made by existing models. The predicted residual is multiplied by this learning rate and then added to the previous prediction. Models are added sequentially until no further improvements can be made. It is called gradient boosting because it uses a gradient descent algorithm to minimize the loss when adding new models.</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 1 minute to run.</b></i>

# %%
CREATE MULTISET TABLE CLM_ADS_MDL_XGB AS (
select * from TD_XGBoost (
ON CLM_ADS_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode','Experiment_Type')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)    
   ModelType('classification')
) as dt
) WITH DATA;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>
#     7. Macro Model - Combined</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> Run predictions based on the models created above.

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>Decision Forest</b></p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_PRED_DF AS (
SELECT * FROM TD_DecisionForestPredict (
ON CLM_ADS_TEST AS InputTable PARTITION BY ANY
ON CLM_ADS_MDL_DF AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from CLM_ADS_PRED_DF;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory570028"><style>
#       table.tdhistory570028 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory570028 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory570028:last-child { text-align: left !important; }
#       tbody.tdhistory570028 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory570028 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory570028 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory570028"></th><th class="tdhistory570028">DateTime</th><th class="tdhistory570028">prediction</th><th class="tdhistory570028">confidence_lower</th><th class="tdhistory570028">confidence_upper</th><th class="tdhistory570028">rate_category</th></tr></thead><tbody class="tdhistory570028 resultset-body"><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory570028">08/11/2022 17:10:23</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.7</td><td class="tdhistory570028">0.7</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory570028">08/11/2022 17:04:45</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.47</td><td class="tdhistory570028">0.47</td><td class="tdhistory570028">2</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory570028">08/11/2022 17:05:49</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.59</td><td class="tdhistory570028">0.59</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory570028">08/11/2022 17:05:20</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.71</td><td class="tdhistory570028">0.71</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory570028">08/11/2022 17:03:51</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.43</td><td class="tdhistory570028">0.43</td><td class="tdhistory570028">2</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory570028">08/11/2022 17:12:40</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.75</td><td class="tdhistory570028">0.75</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory570028">08/11/2022 17:10:42</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.73</td><td class="tdhistory570028">0.73</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory570028">08/11/2022 17:06:05</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.69</td><td class="tdhistory570028">0.69</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory570028">08/11/2022 17:13:55</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.71</td><td class="tdhistory570028">0.71</td><td class="tdhistory570028">1</td></tr><tr><th class="tdhistory570028" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory570028">08/11/2022 17:13:55</td><td class="tdhistory570028">1</td><td class="tdhistory570028">0.71</td><td class="tdhistory570028">0.71</td><td class="tdhistory570028">1</td></tr></tbody></table></div>

# %%
select prediction as rate_category, count(*) as counts from CLM_ADS_PRED_DF group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory892074"><style>
#       table.tdhistory892074 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory892074 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory892074:last-child { text-align: left !important; }
#       tbody.tdhistory892074 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory892074 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory892074 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory892074"></th><th class="tdhistory892074">rate_category</th><th class="tdhistory892074">counts</th></tr></thead><tbody class="tdhistory892074 resultset-body"><tr><th class="tdhistory892074" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory892074">1</td><td class="tdhistory892074">8434</td></tr><tr><th class="tdhistory892074" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory892074"></td><td class="tdhistory892074">382</td></tr><tr><th class="tdhistory892074" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory892074">2</td><td class="tdhistory892074">11284</td></tr><tr><th class="tdhistory892074" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory892074">0</td><td class="tdhistory892074">7425</td></tr></tbody></table></div>

# %%
%chart x=rate_category,y=counts,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster in Test data by Decision Forest Model",height= 400,width=400

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can compare the counts categorized by DF model and the test data category counts.</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>XG-boost</b></p>

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_PRED_XGB AS (
SELECT * FROM TD_XGBoostPredict (
ON CLM_ADS_TEST AS InputTable PARTITION BY ANY
ON CLM_ADS_MDL_XGB AS ModelTable DIMENSION ORDER BY task_index, tree_num, iter, class_num, 
tree_order
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
    ModelType('Classification')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from CLM_ADS_PRED_XGB;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory99706"><style>
#       table.tdhistory99706 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99706 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory99706:last-child { text-align: left !important; }
#       tbody.tdhistory99706 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory99706 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory99706 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory99706"></th><th class="tdhistory99706">DateTime</th><th class="tdhistory99706">Prediction</th><th class="tdhistory99706">Confidence_Lower</th><th class="tdhistory99706">Confidence_upper</th><th class="tdhistory99706">rate_category</th></tr></thead><tbody class="tdhistory99706 resultset-body"><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory99706">14/08/2022 17:25:59</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.34210526315789475</td><td class="tdhistory99706">0.34210526315789475</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory99706">14/08/2022 17:25:43</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.39473684210526316</td><td class="tdhistory99706">0.39473684210526316</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory99706">14/08/2022 17:26:23</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">2</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory99706">14/08/2022 17:25:44</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.3815789473684211</td><td class="tdhistory99706">0.3815789473684211</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory99706">14/08/2022 17:25:53</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.39473684210526316</td><td class="tdhistory99706">0.39473684210526316</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory99706">14/08/2022 17:25:52</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory99706">14/08/2022 17:26:04</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.3815789473684211</td><td class="tdhistory99706">0.3815789473684211</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory99706">14/08/2022 17:25:45</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory99706">14/08/2022 17:25:52</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0.3684210526315789</td><td class="tdhistory99706">0</td></tr><tr><th class="tdhistory99706" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory99706">14/08/2022 17:26:01</td><td class="tdhistory99706">0</td><td class="tdhistory99706">0.34210526315789475</td><td class="tdhistory99706">0.34210526315789475</td><td class="tdhistory99706">0</td></tr></tbody></table></div>

# %%
select prediction as rate_category, count(*) as counts from CLM_ADS_PRED_XGB group by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory146024"><style>
#       table.tdhistory146024 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory146024 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory146024:last-child { text-align: left !important; }
#       tbody.tdhistory146024 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory146024 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory146024 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory146024"></th><th class="tdhistory146024">rate_category</th><th class="tdhistory146024">counts</th></tr></thead><tbody class="tdhistory146024 resultset-body"><tr><th class="tdhistory146024" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory146024">1</td><td class="tdhistory146024">1224</td></tr><tr><th class="tdhistory146024" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory146024"></td><td class="tdhistory146024">382</td></tr><tr><th class="tdhistory146024" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory146024">2</td><td class="tdhistory146024">10996</td></tr><tr><th class="tdhistory146024" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory146024">0</td><td class="tdhistory146024">14923</td></tr></tbody></table></div>

# %%
%chart x=rate_category,y=counts,labelx="QoE Categories", labely="count of ids",type=bar,title="Number of Ids in each QoE Cluster in Test data by XGB Model",height= 400,width=400

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can compare the counts categorized by DF model and the test data category counts.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>
#     8. Model Evaluation</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>TD_ClassificationEvaluator</b> In classification problems, a confusion matrix is used to visualize the performance of a classifier. The confusion matrix contains predicted labels represented across the row-axis and actual labels represented across the column-axis. Each cell in the confusion matrix corresponds to the count of occurrences of labels in the test data. TD_ClassificationEvaluator functions creates the confusion matrix. </p>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  CLM_ADS_PRED_DF AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory455926"><style>
#       table.tdhistory455926 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory455926 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory455926:last-child { text-align: left !important; }
#       tbody.tdhistory455926 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory455926 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory455926 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory455926"></th><th class="tdhistory455926">SeqNum</th><th class="tdhistory455926">Prediction</th><th class="tdhistory455926">Mapping</th><th class="tdhistory455926">CLASS_1</th><th class="tdhistory455926">CLASS_2</th><th class="tdhistory455926">CLASS_3</th><th class="tdhistory455926">Precision</th><th class="tdhistory455926">Recall</th><th class="tdhistory455926">F1</th><th class="tdhistory455926">Support</th></tr></thead><tbody class="tdhistory455926 resultset-body"><tr><th class="tdhistory455926" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory455926">0</td><td class="tdhistory455926">0</td><td class="tdhistory455926">CLASS_1</td><td class="tdhistory455926">3829</td><td class="tdhistory455926">1321</td><td class="tdhistory455926">2275</td><td class="tdhistory455926">0.5156902356902356</td><td class="tdhistory455926">0.4655885214007782</td><td class="tdhistory455926">0.48936034251389865</td><td class="tdhistory455926">8224</td></tr><tr><th class="tdhistory455926" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory455926">1</td><td class="tdhistory455926">1</td><td class="tdhistory455926">CLASS_2</td><td class="tdhistory455926">1692</td><td class="tdhistory455926">4593</td><td class="tdhistory455926">2149</td><td class="tdhistory455926">0.5445814560113825</td><td class="tdhistory455926">0.5351899324166861</td><td class="tdhistory455926">0.5398448519040903</td><td class="tdhistory455926">8582</td></tr><tr><th class="tdhistory455926" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory455926">2</td><td class="tdhistory455926">2</td><td class="tdhistory455926">CLASS_3</td><td class="tdhistory455926">2703</td><td class="tdhistory455926">2668</td><td class="tdhistory455926">5913</td><td class="tdhistory455926">0.5240163062743708</td><td class="tdhistory455926">0.5720228306084938</td><td class="tdhistory455926">0.5469682253364785</td><td class="tdhistory455926">10337</td></tr></tbody></table></div>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  CLM_ADS_PRED_XGB AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory680864"><style>
#       table.tdhistory680864 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory680864 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory680864:last-child { text-align: left !important; }
#       tbody.tdhistory680864 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory680864 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory680864 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory680864"></th><th class="tdhistory680864">SeqNum</th><th class="tdhistory680864">Prediction</th><th class="tdhistory680864">Mapping</th><th class="tdhistory680864">CLASS_1</th><th class="tdhistory680864">CLASS_2</th><th class="tdhistory680864">CLASS_3</th><th class="tdhistory680864">Precision</th><th class="tdhistory680864">Recall</th><th class="tdhistory680864">F1</th><th class="tdhistory680864">Support</th></tr></thead><tbody class="tdhistory680864 resultset-body"><tr><th class="tdhistory680864" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory680864">0</td><td class="tdhistory680864">0</td><td class="tdhistory680864">CLASS_1</td><td class="tdhistory680864">5573</td><td class="tdhistory680864">3623</td><td class="tdhistory680864">5727</td><td class="tdhistory680864">0.37345037861019903</td><td class="tdhistory680864">0.6776507782101168</td><td class="tdhistory680864">0.4815310839417634</td><td class="tdhistory680864">8224</td></tr><tr><th class="tdhistory680864" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory680864">1</td><td class="tdhistory680864">1</td><td class="tdhistory680864">CLASS_2</td><td class="tdhistory680864">207</td><td class="tdhistory680864">615</td><td class="tdhistory680864">402</td><td class="tdhistory680864">0.5024509803921569</td><td class="tdhistory680864">0.0716616173386157</td><td class="tdhistory680864">0.12543340811747908</td><td class="tdhistory680864">8582</td></tr><tr><th class="tdhistory680864" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory680864">2</td><td class="tdhistory680864">2</td><td class="tdhistory680864">CLASS_3</td><td class="tdhistory680864">2444</td><td class="tdhistory680864">4344</td><td class="tdhistory680864">4208</td><td class="tdhistory680864">0.3826846125863951</td><td class="tdhistory680864">0.4070813582277256</td><td class="tdhistory680864">0.394506164158815</td><td class="tdhistory680864">10337</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The above output shows recall, and F1-score values of confusion matrix.</p>
# <table style = 'font-size:16px;font-family:Arial;color:#00233C'>
#   <tr>
#     <th>Column</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>Precision</td>
#     <td>The positive predictive value. Refers to the fraction of relevant instances among
# the total retrieved instances.
#         Precision answers the following question: what proportion of predicted Positives is truly Positive?
#         Precision = (TP)/(TP+FP)</td>
#   </tr>
#   <tr>
#     <td>Recall</td>
#     <td>Refers to the fraction of relevant instances retrieved over the total amount of
# relevant instances. Recall answers a different question: what proportion of actual Positives is correctly classified?
# Recall = (TP)/(TP+FN)</td>
#   </tr>
#   <tr>
#     <td>F1</td>
#     <td>F1 score, defined as the harmonic mean of the precision and recall and is a number between 0 and 1. F1 score maintains a balance between the precision and recall for your classifier.
#                       F1 = 2*(precision*recall/precision+recall)</td>
#   </tr>
#   <tr>
#     <td>Support</td>
#     <td>The number of times a label displays in the Observation Column.</td>
#   </tr>
# </table>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>**TP:- True Positive , FP :- False Positive, TN :- True Negative , FN :- False Negative</p>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>
# Feature selection using GLM</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can use GLM for chosing the significant features

# %%
CREATE VOLATILE TABLE TD_Glm_FeatureSelection AS(
SELECT * FROM TD_GLM (
ON CLM_ADS_TRANSFORMED AS InputTable
USING
InputColumns('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode','Experiment_Type')
ResponseColumn('rate_category')
MaxIterNum(100)
RegularizationLambda(0.027)
Alpha(0)
IterNumNoChange(50)
Intercept('true')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select * from TD_Glm_FeatureSelection order by attribute;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory883040"><style>
#       table.tdhistory883040 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory883040 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory883040:last-child { text-align: left !important; }
#       tbody.tdhistory883040 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory883040 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory883040 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory883040"></th><th class="tdhistory883040">attribute</th><th class="tdhistory883040">predictor</th><th class="tdhistory883040">estimate</th><th class="tdhistory883040">value</th></tr></thead><tbody class="tdhistory883040 resultset-body"><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory883040">-13</td><td class="tdhistory883040">LocalSGD Iterations</td><td class="tdhistory883040">0</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory883040">-12</td><td class="tdhistory883040">Nesterov</td><td class="tdhistory883040"></td><td class="tdhistory883040">FALSE</td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory883040">-11</td><td class="tdhistory883040">Momentum</td><td class="tdhistory883040">0</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory883040">-10</td><td class="tdhistory883040">Learning Rate (Final)</td><td class="tdhistory883040">0.018710158230410626</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory883040">-9</td><td class="tdhistory883040">Learning Rate (Initial)</td><td class="tdhistory883040">0.05</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory883040">-8</td><td class="tdhistory883040">Number of Iterations</td><td class="tdhistory883040">51</td><td class="tdhistory883040">CONVERGED</td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory883040">-7</td><td class="tdhistory883040">Alpha</td><td class="tdhistory883040">0</td><td class="tdhistory883040">L2</td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory883040">-6</td><td class="tdhistory883040">Regularization</td><td class="tdhistory883040">0.027</td><td class="tdhistory883040">ENABLED</td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory883040">-5</td><td class="tdhistory883040">BIC</td><td class="tdhistory883040">7.840024889542312e+06</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory883040">-4</td><td class="tdhistory883040">AIC</td><td class="tdhistory883040">7.83989291432877e+06</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory883040">-3</td><td class="tdhistory883040">Number of Observations</td><td class="tdhistory883040">91748</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory883040">-2</td><td class="tdhistory883040">MSE</td><td class="tdhistory883040">1.2896014103216523e+37</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory883040">-1</td><td class="tdhistory883040">Loss Function</td><td class="tdhistory883040"></td><td class="tdhistory883040">SQUARED_ERROR</td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory883040">0</td><td class="tdhistory883040">(Intercept)</td><td class="tdhistory883040">-1.6211198477978802e+10</td><td class="tdhistory883040"></td></tr><tr><th class="tdhistory883040" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory883040">1</td><td class="tdhistory883040">Level</td><td class="tdhistory883040">1.602050807 ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We can see the estimates column to see its significance of the attribute on the model.  </p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>
#     9. Micro-models (dividing the dataset on experiment types)</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Let us divide our dataset based on experiment types.

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_INDOOR AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_MOBILITY AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_OUTDOOR AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 2
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE CLM_ADS_PEDESTRIAN AS (
select * from CLM_ADS_TRANSFORMED where Experiment_Type = 3
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Indoor</p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =0 i.e Indoor

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_INDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_INDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Indoor</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>As we have seen earlier in macro models that Decision Forest model gave better results, hence we will use Decision forest for micro models.

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 2 minutes to run.</b></i>

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_MDL AS (
select * from TD_DecisionForest (
ON INDOOR_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Prediction for Indoor</h3>

# %%
CREATE MULTISET VOLATILE TABLE INDOOR_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON INDOOR_TEST AS InputTable PARTITION BY ANY
ON INDOOR_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from INDOOR_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory30869"><style>
#       table.tdhistory30869 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory30869 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory30869:last-child { text-align: left !important; }
#       tbody.tdhistory30869 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory30869 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory30869 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory30869"></th><th class="tdhistory30869">DateTime</th><th class="tdhistory30869">prediction</th><th class="tdhistory30869">confidence_lower</th><th class="tdhistory30869">confidence_upper</th><th class="tdhistory30869">rate_category</th></tr></thead><tbody class="tdhistory30869 resultset-body"><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory30869">24/09/2022 9:34:53</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.58</td><td class="tdhistory30869">0.58</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory30869">24/09/2022 9:31:42</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.62</td><td class="tdhistory30869">0.62</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory30869">24/09/2022 9:35:14</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.62</td><td class="tdhistory30869">0.62</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory30869">24/09/2022 9:32:47</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.59</td><td class="tdhistory30869">0.59</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory30869">24/09/2022 9:35:20</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.58</td><td class="tdhistory30869">0.58</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory30869">24/09/2022 9:33:21</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.59</td><td class="tdhistory30869">0.59</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory30869">24/09/2022 9:33:06</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.59</td><td class="tdhistory30869">0.59</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory30869">24/09/2022 9:33:12</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.61</td><td class="tdhistory30869">0.61</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory30869">24/09/2022 9:34:54</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.61</td><td class="tdhistory30869">0.61</td><td class="tdhistory30869">2</td></tr><tr><th class="tdhistory30869" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory30869">24/09/2022 9:32:06</td><td class="tdhistory30869">2</td><td class="tdhistory30869">0.62</td><td class="tdhistory30869">0.62</td><td class="tdhistory30869">2</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Indoor</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  INDOOR_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory74839"><style>
#       table.tdhistory74839 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory74839 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory74839:last-child { text-align: left !important; }
#       tbody.tdhistory74839 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory74839 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory74839 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory74839"></th><th class="tdhistory74839">SeqNum</th><th class="tdhistory74839">Prediction</th><th class="tdhistory74839">Mapping</th><th class="tdhistory74839">CLASS_1</th><th class="tdhistory74839">CLASS_2</th><th class="tdhistory74839">CLASS_3</th><th class="tdhistory74839">Precision</th><th class="tdhistory74839">Recall</th><th class="tdhistory74839">F1</th><th class="tdhistory74839">Support</th></tr></thead><tbody class="tdhistory74839 resultset-body"><tr><th class="tdhistory74839" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory74839">0</td><td class="tdhistory74839">0</td><td class="tdhistory74839">CLASS_1</td><td class="tdhistory74839">652</td><td class="tdhistory74839">318</td><td class="tdhistory74839">844</td><td class="tdhistory74839">0.35942668136714445</td><td class="tdhistory74839">0.6436327739387957</td><td class="tdhistory74839">0.4612663600990449</td><td class="tdhistory74839">1013</td></tr><tr><th class="tdhistory74839" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory74839">1</td><td class="tdhistory74839">1</td><td class="tdhistory74839">CLASS_2</td><td class="tdhistory74839">65</td><td class="tdhistory74839">83</td><td class="tdhistory74839">39</td><td class="tdhistory74839">0.44385026737967914</td><td class="tdhistory74839">0.08934337997847147</td><td class="tdhistory74839">0.14874551971326164</td><td class="tdhistory74839">929</td></tr><tr><th class="tdhistory74839" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory74839">2</td><td class="tdhistory74839">2</td><td class="tdhistory74839">CLASS_3</td><td class="tdhistory74839">296</td><td class="tdhistory74839">528</td><td class="tdhistory74839">1110</td><td class="tdhistory74839">0.5739400206825233</td><td class="tdhistory74839">0.5569493226292022</td><td class="tdhistory74839">0.565317035905271</td><td class="tdhistory74839">1993</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Outdoor</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =1 i.e Outdoor

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_OUTDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_OUTDOOR AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Outdoor</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 2 minute to run.</b></i>

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_MDL AS (
select * from TD_DecisionForest (
ON OUTDOOR_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Predicition for Outdoor</h3>

# %%
CREATE MULTISET VOLATILE TABLE OUTDOOR_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON OUTDOOR_TEST AS InputTable PARTITION BY ANY
ON OUTDOOR_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from OUTDOOR_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory513282"><style>
#       table.tdhistory513282 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory513282 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory513282:last-child { text-align: left !important; }
#       tbody.tdhistory513282 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory513282 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory513282 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory513282"></th><th class="tdhistory513282">DateTime</th><th class="tdhistory513282">prediction</th><th class="tdhistory513282">confidence_lower</th><th class="tdhistory513282">confidence_upper</th><th class="tdhistory513282">rate_category</th></tr></thead><tbody class="tdhistory513282 resultset-body"><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory513282">09/12/2022 18:19:26</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.56</td><td class="tdhistory513282">0.56</td><td class="tdhistory513282">2</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory513282">09/12/2022 18:17:07</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.57</td><td class="tdhistory513282">0.57</td><td class="tdhistory513282">0</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory513282">09/12/2022 18:16:05</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.53</td><td class="tdhistory513282">0.53</td><td class="tdhistory513282">0</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory513282">09/12/2022 18:16:48</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.57</td><td class="tdhistory513282">0.57</td><td class="tdhistory513282">0</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory513282">09/12/2022 18:17:30</td><td class="tdhistory513282">2</td><td class="tdhistory513282">0.5</td><td class="tdhistory513282">0.5</td><td class="tdhistory513282">0</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory513282">09/12/2022 18:17:53</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.52</td><td class="tdhistory513282">0.52</td><td class="tdhistory513282">0</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory513282">09/12/2022 18:19:21</td><td class="tdhistory513282">2</td><td class="tdhistory513282">0.52</td><td class="tdhistory513282">0.52</td><td class="tdhistory513282">2</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory513282">09/12/2022 18:17:42</td><td class="tdhistory513282">2</td><td class="tdhistory513282">0.53</td><td class="tdhistory513282">0.53</td><td class="tdhistory513282">0</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory513282">09/12/2022 18:18:35</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.5</td><td class="tdhistory513282">0.5</td><td class="tdhistory513282">2</td></tr><tr><th class="tdhistory513282" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory513282">09/12/2022 18:15:56</td><td class="tdhistory513282">0</td><td class="tdhistory513282">0.5</td><td class="tdhistory513282">0.5</td><td class="tdhistory513282">0</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Outdoor</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  OUTDOOR_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory635026"><style>
#       table.tdhistory635026 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory635026 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory635026:last-child { text-align: left !important; }
#       tbody.tdhistory635026 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory635026 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory635026 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory635026"></th><th class="tdhistory635026">SeqNum</th><th class="tdhistory635026">Prediction</th><th class="tdhistory635026">Mapping</th><th class="tdhistory635026">CLASS_1</th><th class="tdhistory635026">CLASS_2</th><th class="tdhistory635026">CLASS_3</th><th class="tdhistory635026">Precision</th><th class="tdhistory635026">Recall</th><th class="tdhistory635026">F1</th><th class="tdhistory635026">Support</th></tr></thead><tbody class="tdhistory635026 resultset-body"><tr><th class="tdhistory635026" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory635026">0</td><td class="tdhistory635026">0</td><td class="tdhistory635026">CLASS_1</td><td class="tdhistory635026">1604</td><td class="tdhistory635026">765</td><td class="tdhistory635026">1301</td><td class="tdhistory635026">0.4370572207084469</td><td class="tdhistory635026">0.7218721872187218</td><td class="tdhistory635026">0.5444670739986422</td><td class="tdhistory635026">2222</td></tr><tr><th class="tdhistory635026" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory635026">1</td><td class="tdhistory635026">1</td><td class="tdhistory635026">CLASS_2</td><td class="tdhistory635026">50</td><td class="tdhistory635026">96</td><td class="tdhistory635026">49</td><td class="tdhistory635026">0.49230769230769234</td><td class="tdhistory635026">0.07673860911270983</td><td class="tdhistory635026">0.13278008298755187</td><td class="tdhistory635026">1251</td></tr><tr><th class="tdhistory635026" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory635026">2</td><td class="tdhistory635026">2</td><td class="tdhistory635026">CLASS_3</td><td class="tdhistory635026">568</td><td class="tdhistory635026">390</td><td class="tdhistory635026">829</td><td class="tdhistory635026">0.46390598768886404</td><td class="tdhistory635026">0.38044974759063793</td><td class="tdhistory635026">0.4180534543620777</td><td class="tdhistory635026">2179</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Mobility</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =2 i.e Mobility

# %%
CREATE MULTISET VOLATILE TABLE MOBILITY_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_MOBILITY AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE VOLATILE TABLE MOBILITY_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_MOBILITY AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Mobility</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates a model. Due to the limited resources of this VM, processing this step may take up to 12 minutes to run.</b></i>

# %%
CREATE MULTISET VOLATILE TABLE MOBILITY_MDL AS (
select * from TD_DecisionForest (
ON MOBILITY_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Predicition for Mobility</h3>

# %%
CREATE MULTISET VOLATILE TABLE MOBILITY_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON MOBILITY_TEST AS InputTable PARTITION BY ANY
ON MOBILITY_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from MOBILITY_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory568104"><style>
#       table.tdhistory568104 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory568104 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory568104:last-child { text-align: left !important; }
#       tbody.tdhistory568104 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory568104 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory568104 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory568104"></th><th class="tdhistory568104">DateTime</th><th class="tdhistory568104">prediction</th><th class="tdhistory568104">confidence_lower</th><th class="tdhistory568104">confidence_upper</th><th class="tdhistory568104">rate_category</th></tr></thead><tbody class="tdhistory568104 resultset-body"><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory568104">21/08/2022 17:44:43</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.45</td><td class="tdhistory568104">0.45</td><td class="tdhistory568104">0</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory568104">21/08/2022 17:46:31</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.41</td><td class="tdhistory568104">0.41</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory568104">21/08/2022 17:44:37</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.55</td><td class="tdhistory568104">0.55</td><td class="tdhistory568104">0</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory568104">21/08/2022 17:46:37</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.57</td><td class="tdhistory568104">0.57</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory568104">21/08/2022 17:47:01</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.61</td><td class="tdhistory568104">0.61</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory568104">21/08/2022 17:48:51</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.58</td><td class="tdhistory568104">0.58</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory568104">21/08/2022 17:48:02</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.41</td><td class="tdhistory568104">0.41</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory568104">21/08/2022 17:47:32</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.48</td><td class="tdhistory568104">0.48</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory568104">21/08/2022 17:48:43</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.42</td><td class="tdhistory568104">0.42</td><td class="tdhistory568104">2</td></tr><tr><th class="tdhistory568104" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory568104">21/08/2022 17:45:20</td><td class="tdhistory568104">1</td><td class="tdhistory568104">0.45</td><td class="tdhistory568104">0.45</td><td class="tdhistory568104">0</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Mobility</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  MOBILITY_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory844997"><style>
#       table.tdhistory844997 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory844997 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory844997:last-child { text-align: left !important; }
#       tbody.tdhistory844997 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory844997 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory844997 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory844997"></th><th class="tdhistory844997">SeqNum</th><th class="tdhistory844997">Prediction</th><th class="tdhistory844997">Mapping</th><th class="tdhistory844997">CLASS_1</th><th class="tdhistory844997">CLASS_2</th><th class="tdhistory844997">CLASS_3</th><th class="tdhistory844997">Precision</th><th class="tdhistory844997">Recall</th><th class="tdhistory844997">F1</th><th class="tdhistory844997">Support</th></tr></thead><tbody class="tdhistory844997 resultset-body"><tr><th class="tdhistory844997" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory844997">0</td><td class="tdhistory844997">0</td><td class="tdhistory844997">CLASS_1</td><td class="tdhistory844997">197</td><td class="tdhistory844997">61</td><td class="tdhistory844997">57</td><td class="tdhistory844997">0.6253968253968254</td><td class="tdhistory844997">0.07459295721317682</td><td class="tdhistory844997">0.13328822733423545</td><td class="tdhistory844997">2641</td></tr><tr><th class="tdhistory844997" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory844997">1</td><td class="tdhistory844997">1</td><td class="tdhistory844997">CLASS_2</td><td class="tdhistory844997">1902</td><td class="tdhistory844997">4197</td><td class="tdhistory844997">2183</td><td class="tdhistory844997">0.5067616517749336</td><td class="tdhistory844997">0.868944099378882</td><td class="tdhistory844997">0.6401769371568029</td><td class="tdhistory844997">4830</td></tr><tr><th class="tdhistory844997" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory844997">2</td><td class="tdhistory844997">2</td><td class="tdhistory844997">CLASS_3</td><td class="tdhistory844997">542</td><td class="tdhistory844997">572</td><td class="tdhistory844997">1200</td><td class="tdhistory844997">0.5185825410544511</td><td class="tdhistory844997">0.3488372093023256</td><td class="tdhistory844997">0.4171011470281544</td><td class="tdhistory844997">3440</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'>Pedestrian</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Now let's create train and test dataset for experiment type =3 i.e Pedestrian

# %%
CREATE MULTISET VOLATILE TABLE PEDESTRIAN_TRAIN AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_PEDESTRIAN AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 1
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
CREATE MULTISET VOLATILE TABLE PEDESTRIAN_TEST AS (
select * from TD_TrainTestSplit (
ON CLM_ADS_PEDESTRIAN AS InputTable
USING
TrainSize(0.7)
TestSize(0.3)
)as dt WHERE TD_isTrainRow = 0
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Creation for Pedestrian</h3>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> <b><i>* Below step creates model.  Due to limited resources of this VM, processing may up to 3 minutes to complete.</b></i>

# %%
CREATE VOLATILE TABLE PEDESTRIAN_MDL AS (
select * from TD_DecisionForest (
ON PEDESTRIAN_TRAIN AS InputTable PARTITION BY ANY
USING
   InputColumns ('Level','Qual','SNR','CQI','LTERSSI','DL_bitrate','UL_bitrate','Altitude','Height','Quality','NetworkTech','NetworkMode')
   ResponseColumn('rate_category')
   MaxDepth (50)
   MinNodeSize (20)
   NumTrees (100)
   ModelType ('classification')
) as dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Predicition for Pedestrian</h3>

# %%
CREATE MULTISET VOLATILE TABLE PEDESTRIAN_PRED AS (
SELECT * FROM TD_DecisionForestPredict (
ON PEDESTRIAN_TEST AS InputTable PARTITION BY ANY
ON PEDESTRIAN_MDL AS ModelTable DIMENSION
USING
  IdColumn ('DateTime')
  Accumulate('rate_category')
) AS dt
) WITH DATA
ON COMMIT PRESERVE ROWS;
# Out:
# Success: 0 rows affected

# %%
select top 10* from PEDESTRIAN_PRED;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory879548"><style>
#       table.tdhistory879548 { display: block !important; min-height: 294px !important; overflow: auto !important; height: 294px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory879548 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory879548:last-child { text-align: left !important; }
#       tbody.tdhistory879548 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory879548 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory879548 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory879548"></th><th class="tdhistory879548">DateTime</th><th class="tdhistory879548">prediction</th><th class="tdhistory879548">confidence_lower</th><th class="tdhistory879548">confidence_upper</th><th class="tdhistory879548">rate_category</th></tr></thead><tbody class="tdhistory879548 resultset-body"><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory879548">27/08/2022 14:02:19</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.37</td><td class="tdhistory879548">0.37</td><td class="tdhistory879548">0</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory879548">27/08/2022 14:02:30</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.42</td><td class="tdhistory879548">0.42</td><td class="tdhistory879548">2</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory879548">27/08/2022 14:05:47</td><td class="tdhistory879548">0</td><td class="tdhistory879548">0.4</td><td class="tdhistory879548">0.4</td><td class="tdhistory879548">2</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory879548">27/08/2022 14:02:39</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.44</td><td class="tdhistory879548">0.44</td><td class="tdhistory879548">2</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory879548">27/08/2022 14:04:57</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.43</td><td class="tdhistory879548">0.43</td><td class="tdhistory879548">2</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory879548">27/08/2022 14:04:35</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.42</td><td class="tdhistory879548">0.42</td><td class="tdhistory879548">2</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory879548">27/08/2022 14:01:34</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.4</td><td class="tdhistory879548">0.4</td><td class="tdhistory879548">0</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory879548">27/08/2022 14:02:05</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.38</td><td class="tdhistory879548">0.38</td><td class="tdhistory879548">0</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory879548">27/08/2022 14:05:02</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.43</td><td class="tdhistory879548">0.43</td><td class="tdhistory879548">2</td></tr><tr><th class="tdhistory879548" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory879548">27/08/2022 14:03:10</td><td class="tdhistory879548">1</td><td class="tdhistory879548">0.46</td><td class="tdhistory879548">0.46</td><td class="tdhistory879548">2</td></tr></tbody></table></div>

# %% [markdown]
# <h3 style = 'font-size:16px;font-family:Arial;color:#00233C'>Model Evaluation for Pedestrian</h3>

# %%
SELECT * from TD_CLASSIFICATIONEVALUATOR(
ON  PEDESTRIAN_PRED AS InputTable
USING
Labels(0,1,2)
ObservationColumn('rate_category')
PredictionColumn ('prediction')
) as dt;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory823193"><style>
#       table.tdhistory823193 { display: block !important; min-height: 147px !important; overflow: auto !important; height: 147px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory823193 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory823193:last-child { text-align: left !important; }
#       tbody.tdhistory823193 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory823193 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory823193 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory823193"></th><th class="tdhistory823193">SeqNum</th><th class="tdhistory823193">Prediction</th><th class="tdhistory823193">Mapping</th><th class="tdhistory823193">CLASS_1</th><th class="tdhistory823193">CLASS_2</th><th class="tdhistory823193">CLASS_3</th><th class="tdhistory823193">Precision</th><th class="tdhistory823193">Recall</th><th class="tdhistory823193">F1</th><th class="tdhistory823193">Support</th></tr></thead><tbody class="tdhistory823193 resultset-body"><tr><th class="tdhistory823193" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory823193">0</td><td class="tdhistory823193">0</td><td class="tdhistory823193">CLASS_1</td><td class="tdhistory823193">1344</td><td class="tdhistory823193">457</td><td class="tdhistory823193">1172</td><td class="tdhistory823193">0.4520686175580222</td><td class="tdhistory823193">0.6075949367088608</td><td class="tdhistory823193">0.5184185149469623</td><td class="tdhistory823193">2212</td></tr><tr><th class="tdhistory823193" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory823193">1</td><td class="tdhistory823193">1</td><td class="tdhistory823193">CLASS_2</td><td class="tdhistory823193">133</td><td class="tdhistory823193">442</td><td class="tdhistory823193">167</td><td class="tdhistory823193">0.5956873315363881</td><td class="tdhistory823193">0.27904040404040403</td><td class="tdhistory823193">0.38005159071367145</td><td class="tdhistory823193">1584</td></tr><tr><th class="tdhistory823193" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory823193">2</td><td class="tdhistory823193">2</td><td class="tdhistory823193">CLASS_3</td><td class="tdhistory823193">735</td><td class="tdhistory823193">685</td><td class="tdhistory823193">1512</td><td class="tdhistory823193">0.5156889495225102</td><td class="tdhistory823193">0.5303402314977201</td><td class="tdhistory823193">0.5229119833996196</td><td class="tdhistory823193">2851</td></tr></tbody></table></div>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>10. Conclusion </b> </p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'> We have seen that for macro model Decision Forest is performing better than the XGBoost model. Also pridicition of micro models is better than the macro model.

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>11. Cleanup</b> </p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Worktables</b></p>

# %%
DROP TABLE CLM_QOE;
# Out:
# Success: 40 rows affected

# %%
DROP TABLE CLM_ADS_TEST;
# Out:
# Success: 47 rows affected

# %%
DROP TABLE CLM_ADS_TRAIN;
# Out:
# Success: 47 rows affected

# %%
DROP TABLE CLM_ADS_MDL_DF;
# Out:
# Success: 17 rows affected

# %%
DROP TABLE CLM_ADS_MDL_XGB;
# Out:
# Success: 19 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'><b>Database and Tables</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The following code will clean up tables and databases created above.</p>

# %%
call remove_data('DEMO_5G');-- takes about 5 seconds, optional if you want to use the data later
# Out:
# Success: 0 rows affected
# Success: 0 rows affected
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory321983"><style>
#       table.tdhistory321983 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory321983 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory321983:last-child { text-align: left !important; }
#       tbody.tdhistory321983 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory321983 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory321983 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory321983"></th><th class="tdhistory321983">Message</th></tr></thead><tbody class="tdhistory321983 resultset-body"><tr><th class="tdhistory321983" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory321983">Removed objects related to DEMO_5G. That ran for 0:00:03.20</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Reference Links:</b></p>
# <ul style = 'font-size:16px;font-family:Arial;color:#00233C'>
#         <li>Teradata Analytic Function Reference:
#         <a href = 'https://docs.teradata.com/r/Teradata-VantageCloud-Lake/Analyzing-Your-Data/Analytics-Database-Analytic-Functions/Analytics-Database-Analytic-Functions-Overview'>
#         https://docs.teradata.com/r/Teradata-VantageCloud-Lake/Analyzing-Your-Data/Analytics-Database-Analytic-Functions/Analytics-Database-Analytic-Functions-Overview</a></li>
#      <li>TD_Plot
#         <a href = 'https://docs.teradata.com/search/all?query=TD_PLOT&content-lang=en-US'>
#        TD_Plot</a></li>
#          <li>Unbounded Array Framework
#         <a href = 'https://docs.teradata.com/search/all?query=Unbounded+Array+Framework+&content-lang=en-US'>
#        UAF</a></li>
#
# </ul>

# %% [markdown]
# <footer style="padding-bottom:35px; background:#f9f9f9; border-bottom:3px solid #00233C">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2023. All Rights Reserved
#         </div>
#     </div>
# </footer>
