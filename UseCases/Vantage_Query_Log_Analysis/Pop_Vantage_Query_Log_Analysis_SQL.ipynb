# %% [markdown]
# <header style="padding:1px;background:#f9f9f9;border-top:3px solid #00b2b1"><img id="Teradata-logo" src="https://www.teradata.com/Teradata/Images/Rebrand/Teradata_logo-two_color.png" alt="Teradata" width="220" align="right" />
#
# <b style = 'font-size:28px;font-family:Arial;color:#E37C4D'>DBQL Usage</b>
# </header>
#
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>Introduction</b></p>
#
# <p style = 'font-size:16px;font-family:Arial'>Database Query Logging (DBQL) is used to track query behaviour in Teradata Vantage. Like other system tables, the predefined DBQL logs are created as relational tables in DBC during normal Teradata Database installation. However, while most system tables are populated automatically, you control whether or not to populate the DBQL tables. If you choose not to use the feature, the tables remain empty.
# <br>
# <p style = 'font-size:16px;font-family:Arial'><b>When to Use DBQL</b>
# <p style = 'font-size:16px;font-family:Arial'>Use DBQL to:
#
# <li style = 'font-size:16px;font-family:Arial'>Capture query/statement counts and response times. You can look in the DBQL logs to see if this is the first time this query has been broken and what the historical pattern of its execution has been.</li>
# <li style = 'font-size:16px;font-family:Arial'>Validate that nonunique secondary indexes (NUSIs) are actually used. You can free up space and improve table update performance by deleting NUSIs.</li>
# <li style = 'font-size:16px;font-family:Arial'>Determine which aggregate join indexes (AJIs) are used the most. This allows you to make a cost-benefit analysis on their AJIs, comparing usage against size and time to build.</li>
# <li style = 'font-size:16px;font-family:Arial'>Analyze SQL text and process steps. View the SQL text that inadvertently wiped out the system using DBQL historical data and then attempt to rebuild the lost data.</li>
# <li style = 'font-size:16px;font-family:Arial'>Log optimizer queries as XML documents.</li>
# <li style = 'font-size:16px;font-family:Arial'>Make further refinements to workload groups and scheduling.</li>
# <li style = 'font-size:16px;font-family:Arial'>Discover potential application improvements.</li>
# <li style = 'font-size:16px;font-family:Arial'>Understand basic workload trends, such as growth patterns and workload mix, and identify outliers.</li>
# <li style = 'font-size:16px;font-family:Arial'>Determine whether the query has redrive protection and if the request was redriven after a database failure.</li>
# </p>
# <br>
# <p style = 'font-size:16px;font-family:Arial'>DBQL provides a series of predefined tables and views that can store historical records of queries and their duration, performance, and target activity based on rules you specify. DBQL is flexible enough to log information on the variety of SQL requests, from short transactions to longer-running analysis and mining queries that run on Teradata Database. You can log information for an application name, a user or group of users, or a list of accounts.</p>
#
#
# <p style = 'font-size:16px;font-family:Arial'><a href = 'https://docs.teradata.com/r/Teradata-VantageTM-Database-Administration/March-2019/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs'>Link to the DBQL documentation</a></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Apart from the DBQLogTbl there are other DBQL tables which can be used for complete analysis of the system. The DBQL tables are created in database DBC by the DIP utility during installation.</p>
# <p style = 'font-size:16px;font-family:Arial'>For details, see “Database Initialization Program (DIP)” in Teradata Vantage™ - Database Utilities. The tables are empty until you run a BEGIN QUERY LOGGING or REPLACE QUERY LOGGING request with the required option.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>Below are the major DBQL tables.
# </p>
# <table style ='font-size:14px;font-family:Arial'>
#     <tr>
#     <th>Dictionary Table</th>
#     <th>Purpose</th>
#     <th>Field Name</th>
#   </tr>
#   <tr>
#     <td>DBQLExplainTbl</td>
#     <td>Contains the explain information in an unformatted string without line breaks.</td>
#     <td>The EXPLAIN option.</td>
#   </tr>
#   <tr>
#     <td>DBQLogTbl</td>
#     <td>Is the main table containing information about queries being logged.</td>
#     <td>A BEGIN QUERY LOGGING or REPLACE QUERY LOGGING request. No option is required.</td>
#   </tr>
#   <tr>
#     <td>DBQLObjTbl</td>
#     <td>Stores information on the target objects of the query being logged. One row is logged for each object referenced by the query.</td>
#     <td>The OBJECT option.</td>
#   </tr>
#   <tr>
#     <td>DBQLSQLTbl</td>
#     <td>Stores the full SQL text of the query. One query string may require more than one row.</td>
#     <td>The WITH SQL option.</td>
#   </tr>
#   <tr>
#     <td>DBQLStepTbl</td>
#     <td>Stores information about each processing step used to satisfy the query. One row is logged for each step, including parallel steps.</td>
#     <td>The WITH STEPINFO option.</td>
#   </tr>
#   <tr>
#     <td>DBQLUtilityTbl</td>
#     <td>Each row stores information about one completed load/export or Data Stream Architecture job.</td>
#     <td>The WITH UTILITYINFO option.</td>
#   </tr>
# </table>
#
# <p style = 'font-size:16px;font-family:Arial'>Apart from the tables mentioned above, there are other tables like the DBQLParamTbl, DBQLRuleTbl, DBQLRuleCountTbl, DBQLSummaryTbl, DBQLXMLTbl and DBQLXMLLockTbl. Please find the details of the DBQL tables <a href = 'https://docs.teradata.com/r/Teradata-VantageTM-Database-Administration/March-2019/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs/DBQL-Tables'>here.</a></p>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>1. Connect to Vantage</b></p>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#E37C4D'> <b>Let's start by connecting to the Vantage system </b></p>
# <p style = 'font-size:16px;font-family:Arial'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
Set query_band='DEMO=DBQLUsage.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>2. DBQL Logging Options</b></p>
# <p style = 'font-size:18px;font-family:Arial'>When you initially set up logging, before you can use the BEGIN LOGGING statement, you must run the DIPACC script to create the DBC.ACCLogRule macro, which allows you to create logging rules in the DBC.AccLogRuleTbl using BEGIN LOGGING statements.</p>
#
# <p style = 'font-size:18px;font-family:Arial'>By default the below statement is executed on this machine by default.</p>
# # replace query logging with explain, objects, sql on all;
# <br>
# <br>
# <p style = 'font-size:18px;font-family:Arial'>In case you want to change the logging options please execute the replace logging command commented in the below cell. In this cell we have added the step table logging options also.</p>

# %%
replace query logging with explain, objects, stepinfo, sql on demo_user;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial'>After executing the above command , please use the below query to check the logging options for your user in the DBQLRules table</p>

# %%
select * from dbc.dbqlRulesV;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory864132"><style>
#       table.tdhistory864132 { display: block !important; min-height: 126px !important; overflow: auto !important; height: 126px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory864132 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory864132:last-child { text-align: left !important; }
#       tbody.tdhistory864132 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory864132 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory864132 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory864132"></th><th class="tdhistory864132">UserName</th><th class="tdhistory864132">AccountString</th><th class="tdhistory864132">ApplName</th><th class="tdhistory864132">TypeOfRule</th><th class="tdhistory864132">ExplainFlag</th><th class="tdhistory864132">ObjFlag</th><th class="tdhistory864132">SqlFlag</th><th class="tdhistory864132">StepFlag</th><th class="tdhistory864132">XMLPlanFlag</th><th class="tdhistory864132">StatsUsageFlag</th><th class="tdhistory864132">Verbose</th><th class="tdhistory864132">DetailedStats</th><th class="tdhistory864132">NoColumns</th><th class="tdhistory864132">SummaryFlag</th><th class="tdhistory864132">ThresholdFlag</th><th class="tdhistory864132">ObjectUsage</th><th class="tdhistory864132">ParamFlag</th><th class="tdhistory864132">FeatureUsage</th><th class="tdhistory864132">UtilityInfoFlag</th><th class="tdhistory864132">TextSizeLimit</th><th class="tdhistory864132">SummaryVal1</th><th class="tdhistory864132">SummaryVal2</th><th class="tdhistory864132">SummaryVal3</th><th class="tdhistory864132">LockDelay</th><th class="tdhistory864132">AlgMode</th><th class="tdhistory864132">TypeOfCriterion</th><th class="tdhistory864132">DetailDiag</th></tr></thead><tbody class="tdhistory864132 resultset-body"><tr><th class="tdhistory864132" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory864132">demo_user</td><td class="tdhistory864132"></td><td class="tdhistory864132">                                                            </td><td class="tdhistory864132">Logging enabled</td><td class="tdhistory864132">T</td><td class="tdhistory864132">T</td><td class="tdhistory864132">T</td><td class="tdhistory864132">T</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">200</td><td class="tdhistory864132"></td><td class="tdhistory864132"></td><td class="tdhistory864132"></td><td class="tdhistory864132">0</td><td class="tdhistory864132"></td><td class="tdhistory864132">NO CRITERION</td><td class="tdhistory864132"></td></tr><tr><th class="tdhistory864132" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory864132">DemoNow_Monitor</td><td class="tdhistory864132"></td><td class="tdhistory864132">                                                            </td><td class="tdhistory864132">WITH NONE (No logging)</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">F</td><td class="tdhistory864132">200</td><td class="tdhistory864132"></td><td class="tdhistory864132"></td><td class="tdhistory864132"></td><td class="tdhistory864132">0</td><td class="tdhistory864132"></td><td class="tdhistory864132">NO CRITERION</td><td class="tdhistory864132"></td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>Depending on the flag in the above output, 'F' - False or 'T' - True we can check if the DBQL logging is enabled for the user or not. </p>
# <br>
# <p style = 'font-size:16px;font-family:Arial'>Before Teradata Database writes DBQL data to Data Dictionary tables, it holds the data in cache until either:</p>
# <li style = 'font-size:16px;font-family:Arial'>The cache is full.</li>
# <li style = 'font-size:16px;font-family:Arial'>You end query logging.</li>
# <li style = 'font-size:16px;font-family:Arial'>The number of seconds has elapsed that you define in the DBS Control utility field DBQLFlushRate.</li>
# <p style = 'font-size:16px;font-family:Arial'>You can select a rate from 1 to 3,600 seconds. However, Teradata recommends a flush rate of at least 10 minutes (600 seconds), which is the default. Less than 10 minutes can impact performance.
# You flush the DBQL cache manually.</p>
# <br>
# <p style = 'font-size:16px;font-family:Arial'>If you need to flush DBQL caches more quickly than the time defined by DBQLFlushRate, take one of the following actions:</p>
#
# <li style = 'font-size:16px;font-family:Arial'>Reduce the cache size. See Changing DBQL Cache Size.</li>
# <li style = 'font-size:16px;font-family:Arial'>Issue the FLUSH QUERY LOGGING request:</li>
# </p>
# <p style = 'font-size:16px;font-family:Arial'>The example flushes the caches for all DBQL and TDWM logs.</p>

# %%
FLUSH QUERY LOGGING WITH ALL;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>the option "WITH ALL" is used to flush all logs.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>There are other flush options like ALL, ALLDBQL, ALLTDWM, DEFAULT, EXPLAIN, LOCK etc.
# There are various option that can be used in the FLUSH QUERY LOGGING option. Click <a href = 'https://docs.teradata.com/r/Teradata-VantageTM-SQL-Data-Definition-Language-Syntax-and-Examples/January-2021/Logging-Statements/FLUSH-QUERY-LOGGING/FLUSH-QUERY-LOGGING-Syntax-Elements'> here </a>to find these details.</p>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>3. Session Details</b></p>
# <p style = 'font-size:18px;font-family:Arial'>First let us get the different sessions and Demos executed</p>

# %%
SELECT sessionid,logondateTime, queryband,
getquerybandvalue(queryband, 0, 'DEMO') as DemoName, count(*) FROM 
dbc.qrylog l where  queryband like '%DEMO=%' group by 1,2, 3  order by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory889621"><style>
#       table.tdhistory889621 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory889621 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory889621:last-child { text-align: left !important; }
#       tbody.tdhistory889621 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory889621 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory889621 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory889621"></th><th class="tdhistory889621">SessionID</th><th class="tdhistory889621">LogonDateTime</th><th class="tdhistory889621">QueryBand</th><th class="tdhistory889621">DemoName</th><th class="tdhistory889621">Count(*)</th></tr></thead><tbody class="tdhistory889621 resultset-body"><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory889621">1026</td><td class="tdhistory889621">2023-07-07 02:50:09.670000</td><td class="tdhistory889621">=S> DEMO=RetailBrokenDigitalJourneysPython.ipynb;</td><td class="tdhistory889621">RetailBrokenDigitalJourneysPython.ipynb</td><td class="tdhistory889621">257</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory889621">1032</td><td class="tdhistory889621">2023-07-07 02:55:59.690000</td><td class="tdhistory889621">=S> DEMO=Car_Complaints_PY_SQL.ipynb;</td><td class="tdhistory889621">Car_Complaints_PY_SQL.ipynb</td><td class="tdhistory889621">111</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory889621">1038</td><td class="tdhistory889621">2023-07-07 03:01:50.050000</td><td class="tdhistory889621">=S> DEMO=CarbonFootprintAnalytics.ipynb;</td><td class="tdhistory889621">CarbonFootprintAnalytics.ipynb</td><td class="tdhistory889621">59</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory889621">1045</td><td class="tdhistory889621">2023-07-07 03:11:38.790000</td><td class="tdhistory889621">=S> DEMO=TimeSeriesAnalysis.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory889621">TimeSeriesAnalysis.ipynb</td><td class="tdhistory889621">5</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory889621">1045</td><td class="tdhistory889621">2023-07-07 03:11:38.790000</td><td class="tdhistory889621">=S> GET_DATA=DEMO_Financial_cloud;DEMO=TimeSeriesAnalysis.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory889621">TimeSeriesAnalysis.ipynb</td><td class="tdhistory889621">323</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory889621">1049</td><td class="tdhistory889621">2023-07-07 03:16:01.430000</td><td class="tdhistory889621">=S> GET_DATA=DEMO_CreditCard_cloud;DEMO=CreditCardFraud.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory889621">CreditCardFraud.ipynb</td><td class="tdhistory889621">76</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory889621">1049</td><td class="tdhistory889621">2023-07-07 03:16:01.430000</td><td class="tdhistory889621">=S> DEMO=CreditCardFraud.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory889621">CreditCardFraud.ipynb</td><td class="tdhistory889621">5</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory889621">1053</td><td class="tdhistory889621">2023-07-07 03:22:04.860000</td><td class="tdhistory889621">=S> DEMO=BehavioralAnalysis_PY_SQL.ipynb;</td><td class="tdhistory889621">BehavioralAnalysis_PY_SQL.ipynb</td><td class="tdhistory889621">99</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory889621">1060</td><td class="tdhistory889621">2023-07-07 03:32:43.110000</td><td class="tdhistory889621">=S> DEMO=BehavioralAnalysis_Python.ipynb;</td><td class="tdhistory889621">BehavioralAnalysis_Python.ipynb</td><td class="tdhistory889621">106</td></tr><tr><th class="tdhistory889621" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory889621">1073</td><td class="tdhistory889621">202 ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial'>From the above output please select a session for which we want to go ahead with the further analysis.</p>
# <br>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>4. DBQL Log Table</b></p>
# <p style = 'font-size:16px;font-family:Arial'><b>***From the above output please enter the SessionId for which you want to proceed with the Analysis.</b></p>

# %%
%var SessionIdParam = 1172  ----Enter session id

# %%
select sessionid, queryband,starttime, querytext, NumSteps,AmpCPUTime, TotalIOCount,
cast((firstresptime - starttime second(4)) as decimal(8,2)) as RunSecs from dbc.qrylog 
		where sessionid=${SessionIdParam} ---SessionIdParam 
    order by RunSecs DESC;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory706980"><style>
#       table.tdhistory706980 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory706980 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory706980:last-child { text-align: left !important; }
#       tbody.tdhistory706980 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory706980 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory706980 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
# WHERE InfoKey='VERSION'</td><td class="tdhistory706980">1</td><td class="tdhistory706980">0</td><td class="tdhistory706980">2</td><td class="tdhistory706980">.01</td></tr><tr><th class="tdhistory706980" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory706980">1172</td><td class="tdhistory706980"></td><td class="tdhistory706980">2023-07-13 04:41:10.590000</td><td class="tdhistory706980">select database</td><td class="tdhistory706980">0</td><td class="tdhistory706980">0</td><td class="tdhistory706980">0</td><td class="tdhistory706980">.00</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial'>The above output shows all queries executed in the Session you have selected. The first query is the query taking highest execution time and the last query is the query taking least time to execute.</p>
# <br>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>5. NOS(Native Object Store) fields in DBQL log table</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Native Object Store is used to access semi-structured or unstructured data that resides in Amazon AWS-S3 or Microsoft Azure object stores and process it inside Teradata Vantage using a rich set of built-in analytics and functions. All the parallelism of the Vantage Advanced SQL Engine can be brought to bear on processing external data, providing a benefit when analyzing huge volumes. Workload management, security and reliability all provide a solid foundation for bringing such analytic algorithms into production. Using Native Object Store, data scientist will be able to benefit from the advanced analytic capabilities provided on Teradata Vantage.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>The dbc.qrylog view has many other columns which can be used for other Analysis. Like the NOS columns as shown in the query below.</p>
# <p style = 'font-size:16px;font-family:Arial'>Replace the <b>SessionIdParam</b> in the below query with the same sessionId we used in the above query. </p>

# %%
Select SessionId,starttime,NosRecordsSkipped,NosMaxIOWaitTime,NosRecordsReturnedKB,NosPhysReadIO,NosFilesSkipped,
NosTables,NosTotalIOWaitTime,NosCPUTime,NosRecordsReturned,NosPhysReadIOKB,NosFiles from dbc.dbqlogtbl 
where sessionid=${SessionIdParam}---SessionIdParam
order by 2,1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory876363"><style>
#       table.tdhistory876363 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory876363 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory876363:last-child { text-align: left !important; }
#       tbody.tdhistory876363 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory876363 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory876363 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory876363"></th><th class="tdhistory876363">SessionID</th><th class="tdhistory876363">StartTime</th><th class="tdhistory876363">NosRecordsSkipped</th><th class="tdhistory876363">NosMaxIOWaitTime</th><th class="tdhistory876363">NosRecordsReturnedKB</th><th class="tdhistory876363">NosPhysReadIO</th><th class="tdhistory876363">NosFilesSkipped</th><th class="tdhistory876363">NosTables</th><th class="tdhistory876363">NosTotalIOWaitTime</th><th class="tdhistory876363">NosCPUTime</th><th class="tdhistory876363">NosRecordsReturned</th><th class="tdhistory876363">NosPhysReadIOKB</th><th class="tdhistory876363">NosFiles</th></tr></thead><tbody class="tdhistory876363 resultset-body"><tr><th class="tdhistory876363" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory876363">1172</td><td class="tdhistory876363">2023-07-13 04:41:10.220000</td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td></tr><tr><th class="tdhistory876363" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory876363">1172</td><td class="tdhistory876363">2023-07-13 04:41:10.570000</td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td></tr><tr><th class="tdhistory876363" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory876363">1172</td><td class="tdhistory876363">2023-07-13 04:41:10.590000</td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td></tr><tr><th class="tdhistory876363" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory876363">1172</td><td class="tdhistory876363">2023-07-13 04:41:10.600000</td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td><td class="tdhistory876363"></td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The above output shows all queries executed in the Session using the NOS functionality. Below are the details of the various fields related to NOS in the DBQLogtbl.</p>
# <table style ='font-size:14px;font-family:Arial'>
#     <tr>
#     <th>Field Name</th>
#     <th>Explanation</th>
#   </tr>
#   <tr>
#     <td>NosRecordsSkipped</td>
#     <td>Number of Native Object Store records skipped</td>
#   </tr>
#   <tr>
#     <td>NosTables</td>
#     <td>Total number of Native Object Store tables accessed.</td>
#   </tr>
#   <tr>
#     <td>NosFilesSkipped</td>
#     <td>Number of Native Object Store files that were partially or fully skipped due to errors.</td>
#   </tr>
#   <tr>
#     <td>NosFiles</td>
#     <td>Number of Native Object Store files reads attempted.</td>
#   </tr>
#   <tr>
#     <td>NosTotalIOWaitTime</td>
#     <td>Total of the Native Object Store IO wait time across all steps</td>
#   </tr>
#   <tr>
#     <td>NosPhysReadIO</td>
#     <td>Total physical read IOs for Native Object Store files</td>
#   </tr>
#   <tr>
#     <td>NosPhysReadIOKB</td>
#     <td>Total physical read IO KBs for Native Object Store files</td>
#   </tr>
#   <tr>
#     <td>NosRecordsRe-turnedKB</td>
#     <td>Number of KBs in Native Object Store records returned</td>
#   </tr>
#   <tr>
#     <td>NosMaxIOWaitTime</td>
#     <td>Max Native Object Store IO wait time for any individual IO. Float-ing point field. In seconds.</td>
#   </tr>
#   <tr>
#     <td>NosCPUTime</td>
#     <td>CPU time for reading Native Object Store files. Floating point. Units of seconds.</td>
#   </tr>
# </table>
# </p>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>6. DBQL log table Details</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The dbc.qrylog view is a view on the dbqlogtbl which has many different columns. Default rows are stored in the DBC.DBQLogTbl table, the foundation of the DBQL feature. The default is one default row per query.</p>
#
# <p style = 'font-size:16px;font-family:Arial'>The major fields of the DBQLogTbl provide general query information that is usually adequate for investigating a query that is interfering with performance. When no options are specified, the default fileds that are populated are:</p>
#
# <li style = 'font-size:16px;font-family:Arial'>User ID and user name under which the session being logged was initiated</li>
# <li style = 'font-size:16px;font-family:Arial'>Unique ID for the process, session, and host (client) connection</li>
# <li style = 'font-size:16px;font-family:Arial'>Account string, expanded as appropriate, that was current when the query completed</li>
# <li style = 'font-size:16px;font-family:Arial'>First 200 characters of the query SQL statement</li>
# <li style = 'font-size:16px;font-family:Arial'>CPU and I/O statistics</li>
# <li style = 'font-size:16px;font-family:Arial'>Default database name that was current when the query completed</li>
# </p>
# <p style = 'font-size:16px;font-family:Arial'>Please find the details of the columns in the DBQL table <a href = 'https://docs.teradata.com/r/Teradata-Database-Administration/April-2018/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs/Main-Log-Table-DBQLogTbl'>here</a>. Execute the below query to check the column details from the DBQLogTbl</a></p>

# %%
select ColumnName, ColumnFormat, ColumnType, ColumnLength from dbc.ColumnsV where tablename = 'DBQLogtbl' order by ColumnName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory342072"><style>
#       table.tdhistory342072 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory342072 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory342072:last-child { text-align: left !important; }
#       tbody.tdhistory342072 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory342072 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory342072 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory342072"></th><th class="tdhistory342072">ColumnName</th><th class="tdhistory342072">ColumnFormat</th><th class="tdhistory342072">ColumnType</th><th class="tdhistory342072">ColumnLength</th></tr></thead><tbody class="tdhistory342072 resultset-body"><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory342072">AbortFlag</td><td class="tdhistory342072">X(1)</td><td class="tdhistory342072">CF  </td><td class="tdhistory342072">1</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory342072">AcctString</td><td class="tdhistory342072">X(128)</td><td class="tdhistory342072">CV  </td><td class="tdhistory342072">256</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory342072">AcctStringDate</td><td class="tdhistory342072">YY/MM/DD</td><td class="tdhistory342072">DA  </td><td class="tdhistory342072">4</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory342072">AcctStringHour</td><td class="tdhistory342072">-(5)9</td><td class="tdhistory342072">I2  </td><td class="tdhistory342072">2</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory342072">AcctStringTime</td><td class="tdhistory342072">99:99:99</td><td class="tdhistory342072">F   </td><td class="tdhistory342072">8</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory342072">AMPCPUTime</td><td class="tdhistory342072">----,---,---,---,--9.999</td><td class="tdhistory342072">F   </td><td class="tdhistory342072">8</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory342072">AMPCPUTimeNorm</td><td class="tdhistory342072">----,---,---,---,--9.999</td><td class="tdhistory342072">F   </td><td class="tdhistory342072">8</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory342072">AppID</td><td class="tdhistory342072">X(30)</td><td class="tdhistory342072">CF  </td><td class="tdhistory342072">60</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory342072">AutoDBAData</td><td class="tdhistory342072">X(1)</td><td class="tdhistory342072">CF  </td><td class="tdhistory342072">1</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory342072">CacheFlag</td><td class="tdhistory342072">X(1)</td><td class="tdhistory342072">CF  </td><td class="tdhistory342072">1</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory342072">CalendarName</td><td class="tdhistory342072">X(128)</td><td class="tdhistory342072">CV  </td><td class="tdhistory342072">256</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory342072">CallNestingLevel</td><td class="tdhistory342072">-(3)9</td><td class="tdhistory342072">I1  </td><td class="tdhistory342072">1</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory342072">CheckpointNum</td><td class="tdhistory342072">----,---,---,---,--9</td><td class="tdhistory342072">F   </td><td class="tdhistory342072">8</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory342072">ClientAddr</td><td class="tdhistory342072">X(45)</td><td class="tdhistory342072">CF  </td><td class="tdhistory342072">45</td></tr><tr><th class="tdhistory342072" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory342072">ClientID</td><td class="tdhistory342072">X(30)</td><td class="tdhistor ...

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>7. Check Query performance using DBQL log table</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The DBQL table is used to check the performance of the queries. Let's check the queries from the session we are analyzing above.</p>

# %%
select TOP 10 queryid, cast((firstresptime - starttime second(4)) as decimal(8,2)) as RunSecs, starttime, querytext, NumSteps,AmpCPUTime, TotalIOCount
 from dbc.qrylog 
where sessionid=${SessionIdParam}---SessionIdParam
order by Runsecs desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory885126"><style>
#       table.tdhistory885126 { display: block !important; min-height: 168px !important; overflow: auto !important; height: 168px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory885126 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory885126:last-child { text-align: left !important; }
#       tbody.tdhistory885126 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory885126 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory885126 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
# WHERE InfoKey='VERSION'</td><td class="tdhistory885126">1</td><td class="tdhistory885126">0</td><td class="tdhistory885126">2</td></tr><tr><th class="tdhistory885126" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory885126">307191319199591431</td><td class="tdhistory885126">.01</td><td class="tdhistory885126">2023-07-13 04:41:10.600000</td><td class="tdhistory885126">ABORT</td><td class="tdhistory885126">0</td><td class="tdhistory885126">0</td><td class="tdhistory885126">0</td></tr><tr><th class="tdhistory885126" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory885126">307191319199591430</td><td class="tdhistory885126">.00</td><td class="tdhistory885126">2023-07-13 04:41:10.590000</td><td class="tdhistory885126">select database</td><td class="tdhistory885126">0</td><td class="tdhistory885126">0</td><td class="tdhistory885126">0</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial'>The above output shows all queries executed in the Session you have selected. The first query is the query taking highest execution time and the last query is the query taking least time to execute.</p>
# <p style = 'font-size:18px;font-family:Arial'>There are different views created on the DBQLogTbl which can be used for different purpose.</p>
# <table style ='font-size:14px;font-family:Arial'>
#     <tr>
#     <th>View Name</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>QryLog[V]</td>
#     <td>Contains default DBQL information for a query</td>
#   </tr>
#   <tr>
#     <td>QryLogTDWM[V]</td>
#     <td>Teradata Dynamic Workload Management view of the main log table, DBQLLogTbl.</td>
#   </tr>
#   <tr>
#     <td>QryLogFeatureUseJSON[V]</td>
#     <td>Provides a view into the FeatureUsage column of DBQLogTbl. This view uses the system function TD_SYSFNLIB.TD_DBQLFUL to convert the FeatureUsage bitmap column into a JSON document with a list of features used by particular requests</td>
#   </tr>
#   <tr>
#     <td>QryLogFeatureUseCountV</td>
#     <td>view is populated if the WITH FEATUREINFO option for BEGIN/REPLACE QUERY LOGGING and this view (QryLogFeatureUseCountV) is included in a request. QryLogFeatureUseCountV provides a view into the FeatureUsage column of DBQLogTbl and the QryLogFeatureListV view.</td>
#   </tr>
# </table>
# <br>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>8. DBQL Step table usage</b></p>
# <p style = 'font-size:16px;font-family:Arial'>We will further continue the analysis by checking the step details of the longest running query by replacing the parameter <b>SampleQueryId</b> with the actual QueryId from the output above.</p>
# <p style = 'font-size:16px;font-family:Arial'><b>***From the above output please enter the SampleQueryId(QueryId) for which you want to proceed with the Analysis.</b></p>

# %%
%var SampleQueryId = 307191319199591428

# %%
select
ql.queryid, qls.StepStartTime,
CAST( EXTRACT (SECOND FROM FirstRespTime) + (EXTRACT (MINUTE FROM FirstRespTime) * 60 ) + (EXTRACT (HOUR FROM FirstRespTime) *60*60 ) + (86400 * (CAST ( FirstRespTime AS DATE) - CAST ( starttime AS DATE) ) )
- (EXTRACT (SECOND FROM starttime) + (EXTRACT (MINUTE FROM starttime) * 60 ) + (EXTRACT (HOUR FROM starttime) *60*60 ) ) AS INTEGER) QryRunSecs , 
CAST(ql.AmpCpuTime AS DECIMAL(18,3)) QryCpu , 
ql.totaliocount  QryIO,
ql.spoolusage Qryspool,
qls.StepLev1Num + .1 * qls.StepLev2Num (Decimal(4,1)) as sNum,
qls.StepName as Stp,


/* run time metrics */
qls.EstProcTime,
CAST( EXTRACT (SECOND FROM StepStopTime) + (EXTRACT (MINUTE FROM StepStopTime) * 60 ) + (EXTRACT (HOUR FROM StepStopTime) *60*60 ) + (86400 * (CAST ( StepStopTime AS DATE) - CAST ( StepStartTime AS DATE) ) )
- (EXTRACT (SECOND FROM StepStartTime) + (EXTRACT (MINUTE FROM StepStartTime) * 60 ) + (EXTRACT (HOUR FROM StepStartTime) *60*60 ) ) AS INTEGER)  StepSecs,

/* cpu metrics */
 ZEROIFNULL(CAST(qls.EstCPUCost AS DECIMAL(38,1)) ) EstCpu , 
 CAST(qls.CPUTIME AS DECIMAL(38,1)) ActCpu,
CAST( (qls.maxampcputime * qls.numofactiveamps) AS DECIMAL(38,1))  StepImpCpu , 

/* IO metrics */
ZEROIFNULL(qls.EstIOCost) EstIO,
qls.IOcount
, qls.MaxAmpIO* qls.NumOfActiveAmps StepImpIO ,  

/* PJI metrics */
ZEROIFNULL(CAST ( qls.CPUTIME * 1000.0 / NULLIFZERO(qls.IOCOUNT ) AS DECIMAL(38,1) ) )StepPJI,

/* Spool metrics */
qls.SpoolUsage/1000000 StepSpool_M , 
qls.MaxAmpSpool * qls.NumOfActiveAmps / 1000000 StepImpSpoolMB , 

/* PE  metrics */
ZEROIFNULL(ActCpu/NULLIFZERO(StepImpCpu)) StepPE,

/* row estimates  */  
qls.EstRowCount,
qls.RowCount,
qls.RowCount/nullifzero(qls.EstRowCount) as RowVsEst,
qls.RowsWComprColumns/nullifzero(qls.RowCount) as CompPct,

/* Skew metrics */
(1- qls.CpuTime/ nullifzero(qls.NumOfActiveAmps*qls.maxampcputime)) * 100  as CpuSkewPct, 
(1- qls.IOCount/ nullifzero(qls.NumOfActiveAmps*qls.maxampio)) * 100  as IOSkewPct, 
(1-qls.spoolusage/nullifzero(qls.NumOfActiveAmps*qls.MaxAmpSpool)) * 100 as SpoolSkewPct,
qls.numcombinedpartitions

FROM dbc.dbqlogtbl ql
INNER JOIN dbc.dbqlsteptbl qls
ON  ql.queryid = qls.queryid
AND ql.procid = qls.procid
WHERE ql.queryid = ${SampleQueryId} ---SampleQueryId
order by qls.queryid,sNum                ;

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'>The above output shows all the steps for the query we are analyzing. The step details contain the Runsec, AmpCPUTime, IOCount, Spool along with other details, used for each step.</p>
# <br>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>9. DBQL SQL table usage</b></p>
# <p style = 'font-size:16px;font-family:Arial'>The DBQLogTbl logs only partial text of the Query which is executed. In order to get the complete text of the query we will have to check the SQL text in the DBQLSQLTbl. The below SQL will show the complete test of the query. </p>

# %%
Select QueryId, sqltextinfo from dbc.dbqlsqltbl where queryid = ${SampleQueryId} ---SampleQueryId
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory461145"><style>
#       table.tdhistory461145 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory461145 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory461145:last-child { text-align: left !important; }
#       tbody.tdhistory461145 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory461145 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory461145 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory461145"></th><th class="tdhistory461145">QueryID</th><th class="tdhistory461145">SqlTextInfo</th></tr></thead><tbody class="tdhistory461145 resultset-body"><tr><th class="tdhistory461145" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory461145">307191319199591428</td><td class="tdhistory461145">DATABASE "dbc"</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial'>Double Click on the cell showing the SQL Text to check the complete SQL text of the Query.</p>
# <p style = 'font-size:18px;font-family:Arial'>The above output shows the complete text of the Query executed. Further to check the details of each step we can check the explain plan of the query using the DBQLExplainTbl as shown in the query below .</p>
# <br>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>10. DBQL Explain table usage</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Run the below query by replacing the parameter <b>SampleQueryId</b> with the actual QueryId from the output above.</p>

# %%
Select QueryId, ExplainText from dbc.dbqlexplaintbl where queryid = ${SampleQueryId} ---SampleQueryId
;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory9603"><style>
#       table.tdhistory9603 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory9603 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory9603:last-child { text-align: left !important; }
#       tbody.tdhistory9603 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory9603 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory9603 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory9603"></th><th class="tdhistory9603">QueryID</th><th class="tdhistory9603">ExplainText</th></tr></thead><tbody class="tdhistory9603 resultset-body"><tr><th class="tdhistory9603" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory9603">307191319199591428</td><td class="tdhistory9603">  1) First, we execute the following steps in parallel.
#        1) We do a single-AMP ABORT TEST step from DBC.DBase by way of
#           the unique primary index "Field_1 = 'DBC'" with a residual
#           condition of ("'00000100'XB= DBC.DBase.Field_2").
#        2) We do a single-AMP UPDATE step from DBC.SessionTbl by way of
#           the primary index "Field_1 = 1, Field_2 = 1172" with no
#           residual conditions.
#   2) Finally, we send out an END TRANSACTION step to all AMPs involved
#      in processing the request.
#   -> No rows are returned to the user as the result of statement 1.
# </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial'>Double Click on the cell showing the Explain Text to check the complete Explain Plan of the Query.</p>
# <br>
# <p style = 'font-size:20px;font-family:Arial;color:#E37C4D'><b>11. Information on other DBQL Tables and other Documentation Links</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Apart from these main tables like the DBQL log, Step and Explain tables, other DBQL tables can also be used similarly to check the overall performance of the system. Click <a href = 'https://docs.teradata.com/r/Teradata-VantageTM-Database-Administration/March-2019/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs/DBQL-Tables'>here</a> for additional Information on different DBQL Tables,</p>
#
# <p style = 'font-size:16px;font-family:Arial'>Below are some links for the documents</p>
#
# <table style ='font-size:14px;font-family:Arial'>
#   <tr>
#     <th>Link</th>
#     <th>Description</th>
#
#   </tr>
#   <tr>
#     <td><a href = 'https://docs.teradata.com/'>TD Docs (HTML)</a></td>
#     <td>Teradata documentation (HTML).</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'http://www.info.teradata.com'>TD Docs (PDF)</a></td>
#     <td>Teradata documentation (HTML).</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'https://access.teradata.com'>TD Docs One Stop Source</a></td>
#     <td>One stop source for Teradata community, product information, and software downloads.
# Log in for customer access to:
#         Support
#         Software updates
#         Knowledge articles
#         Orange Books</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'http://www.teradata.com/products-and-services/TEN'>TEN</a></td>
#     <td>Teradata education network.</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'https://community.teradata.com'>Teradata Community</a></td>
#     <td>Link to Teradata community (also available from the customer portal).</td>
#
#   </tr>
# </table>

# %% [markdown]
# <footer style="padding:10px;background:#f9f9f9;border-bottom:3px solid #394851">©2023 Teradata. All Rights Reserved</footer>
