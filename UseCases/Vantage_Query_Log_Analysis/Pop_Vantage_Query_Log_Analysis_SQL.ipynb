# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        DBQL Usage
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>Introduction</b></p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Database Query Logging (DBQL) is used to track query behavior in Teradata Vantage. Like other system tables, the predefined DBQL logs are created as relational tables in DBC during normal Teradata Database installation. However, while most system tables are populated automatically, you control whether or not to populate the DBQL tables. If you choose not to use the feature, the tables remain empty.
# <br>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>When to Use DBQL</b>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Use DBQL to:
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Capture query/statement counts and response times. You can look in the DBQL logs to see if this is the first time this query has been broken and what the historical pattern of its execution has been.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Validate that nonunique secondary indexes (NUSIs) are actually used. You can free up space and improve table update performance by deleting NUSIs.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Determine which aggregate join indexes (AJIs) are used the most. This allows you to make a cost-benefit analysis on their AJIs, comparing usage against size and time to build.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Analyze SQL text and process steps. View the SQL text that inadvertently wiped out the system using DBQL historical data and then attempt to rebuild the lost data.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Log optimizer queries as XML documents.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Make further refinements to workload groups and scheduling.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Discover potential application improvements.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Understand basic workload trends, such as growth patterns and workload mix, and identify outliers.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Determine whether the query has redrive protection and if the request was redriven after a database failure.</li>
# </p>
# <br>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>DBQL provides a series of predefined tables and views that can store historical records of queries and their duration, performance, and target activity based on rules you specify. DBQL is flexible enough to log information on the variety of SQL requests, from short transactions to longer-running analysis and mining queries that run on Teradata Database. You can log information for an application name, a user or group of users, or a list of accounts.</p>
#
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><a href = 'https://docs.teradata.com/r/Teradata-VantageTM-Database-Administration/March-2019/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs'>Link to the DBQL documentation</a></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Apart from the DBQLogTbl there are other DBQL tables which can be used for complete analysis of the system. The DBQL tables are created in database DBC by the DIP utility during installation.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>For details, see “Database Initialization Program (DIP)” in Teradata Vantage™ - Database Utilities. The tables are empty until you run a BEGIN QUERY LOGGING or REPLACE QUERY LOGGING request with the required option.</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Below are the major DBQL tables.
# </p>
# <table style ='font-size:14px;font-family:Arial;color:#00233C'>
#     <tr>
#     <th>Dictionary Table</th>
#     <th>Purpose</th>
#     <th>Field Name</th>
#   </tr>
#   <tr>
#     <td>DBQLExplainTbl</td>
#     <td>Contains the explain information in an unformatted string without line breaks.</td>
#     <td>The EXPLAIN option.</td>
#   </tr>
#   <tr>
#     <td>DBQLogTbl</td>
#     <td>Is the main table containing information about queries being logged.</td>
#     <td>A BEGIN QUERY LOGGING or REPLACE QUERY LOGGING request. No option is required.</td>
#   </tr>
#   <tr>
#     <td>DBQLObjTbl</td>
#     <td>Stores information on the target objects of the query being logged. One row is logged for each object referenced by the query.</td>
#     <td>The OBJECT option.</td>
#   </tr>
#   <tr>
#     <td>DBQLSQLTbl</td>
#     <td>Stores the full SQL text of the query. One query string may require more than one row.</td>
#     <td>The WITH SQL option.</td>
#   </tr>
#   <tr>
#     <td>DBQLStepTbl</td>
#     <td>Stores information about each processing step used to satisfy the query. One row is logged for each step, including parallel steps.</td>
#     <td>The WITH STEPINFO option.</td>
#   </tr>
#   <tr>
#     <td>DBQLUtilityTbl</td>
#     <td>Each row stores information about one completed load/export or Data Stream Architecture job.</td>
#     <td>The WITH UTILITYINFO option.</td>
#   </tr>
# </table>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Apart from the tables mentioned above, there are other tables like the DBQLParamTbl, DBQLRuleTbl, DBQLRuleCountTbl, DBQLSummaryTbl, DBQLXMLTbl and DBQLXMLLockTbl. Please find the details of the DBQL tables <a href = 'https://docs.teradata.com/r/Teradata-VantageTM-Database-Administration/March-2019/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs/DBQL-Tables'>here.</a></p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>1. Connect to Vantage</b></p>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You will be prompted to provide the password. Enter your password, press Enter, then use down arrow to go to next cell.</p>

# %%
%connect local, hidewarnings=true
# Out:
# Password: ········
# Success: 'local' connection established and activated for user 'demo_user', with default database 'demo_user'

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Setup for execution of notebook. Begin running steps with Shift + Enter keys.</p>

# %%
Set query_band='DEMO=Vantage_Query_Log_Analysis_SQL.ipynb;' update for session;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>2. DBQL Logging Options</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>When you initially set up logging, before you can use the BEGIN LOGGING statement, you must run the DIPACC script to create the DBC.ACCLogRule macro, which allows you to create logging rules in the DBC.AccLogRuleTbl using BEGIN LOGGING statements.</p>
#
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>By default the below statement is executed on this machine by default.</p>
# # replace query logging with explain, objects, sql on all;
# <br>
# <br>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>In case you want to change the logging options please execute the replace logging command commented in the below cell. In this cell we have added the step table logging options also.</p>

# %%
replace query logging with explain, objects, stepinfo, sql on demo_user;
# Out:
# Success: 1 rows affected

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>After executing the above command , please use the below query to check the logging options for your user in the DBQLRules table</p>

# %%
select * from dbc.dbqlRulesV;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory840513"><style>
#       table.tdhistory840513 { display: block !important; min-height: 126px !important; overflow: auto !important; height: 126px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory840513 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory840513:last-child { text-align: left !important; }
#       tbody.tdhistory840513 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory840513 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory840513 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory840513"></th><th class="tdhistory840513">UserName</th><th class="tdhistory840513">AccountString</th><th class="tdhistory840513">ApplName</th><th class="tdhistory840513">TypeOfRule</th><th class="tdhistory840513">ExplainFlag</th><th class="tdhistory840513">ObjFlag</th><th class="tdhistory840513">SqlFlag</th><th class="tdhistory840513">StepFlag</th><th class="tdhistory840513">XMLPlanFlag</th><th class="tdhistory840513">StatsUsageFlag</th><th class="tdhistory840513">Verbose</th><th class="tdhistory840513">DetailedStats</th><th class="tdhistory840513">NoColumns</th><th class="tdhistory840513">SummaryFlag</th><th class="tdhistory840513">ThresholdFlag</th><th class="tdhistory840513">ObjectUsage</th><th class="tdhistory840513">ParamFlag</th><th class="tdhistory840513">FeatureUsage</th><th class="tdhistory840513">UtilityInfoFlag</th><th class="tdhistory840513">TextSizeLimit</th><th class="tdhistory840513">SummaryVal1</th><th class="tdhistory840513">SummaryVal2</th><th class="tdhistory840513">SummaryVal3</th><th class="tdhistory840513">LockDelay</th><th class="tdhistory840513">AlgMode</th><th class="tdhistory840513">TypeOfCriterion</th><th class="tdhistory840513">DetailDiag</th></tr></thead><tbody class="tdhistory840513 resultset-body"><tr><th class="tdhistory840513" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory840513">demo_user</td><td class="tdhistory840513"></td><td class="tdhistory840513">                                                            </td><td class="tdhistory840513">Logging enabled</td><td class="tdhistory840513">T</td><td class="tdhistory840513">T</td><td class="tdhistory840513">T</td><td class="tdhistory840513">T</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">200</td><td class="tdhistory840513"></td><td class="tdhistory840513"></td><td class="tdhistory840513"></td><td class="tdhistory840513">0</td><td class="tdhistory840513"></td><td class="tdhistory840513">NO CRITERION</td><td class="tdhistory840513"></td></tr><tr><th class="tdhistory840513" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory840513">DemoNow_Monitor</td><td class="tdhistory840513"></td><td class="tdhistory840513">                                                            </td><td class="tdhistory840513">WITH NONE (No logging)</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">F</td><td class="tdhistory840513">200</td><td class="tdhistory840513"></td><td class="tdhistory840513"></td><td class="tdhistory840513"></td><td class="tdhistory840513">0</td><td class="tdhistory840513"></td><td class="tdhistory840513">NO CRITERION</td><td class="tdhistory840513"></td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Depending on the flag in the above output, 'F' - False or 'T' - True we can check if the DBQL logging is enabled for the user or not. </p>
# <br>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Before Teradata Database writes DBQL data to Data Dictionary tables, it holds the data in cache until either:</p>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>The cache is full.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>You end query logging.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>The number of seconds has elapsed that you define in the DBS Control utility field DBQLFlushRate.</li>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>You can select a rate from 1 to 3,600 seconds. However, Teradata recommends a flush rate of at least 10 minutes (600 seconds), which is the default. Less than 10 minutes can impact performance.
# You flush the DBQL cache manually.</p>
# <br>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>If you need to flush DBQL caches more quickly than the time defined by DBQLFlushRate, take one of the following actions:</p>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Reduce the cache size. See Changing DBQL Cache Size.</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Issue the FLUSH QUERY LOGGING request:</li>
# </p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The example flushes the caches for all DBQL and TDWM logs.</p>

# %%
FLUSH QUERY LOGGING WITH ALL;
# Out:
# Success: 0 rows affected

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>the option "WITH ALL" is used to flush all logs.</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>There are other flush options like ALL, ALLDBQL, ALLTDWM, DEFAULT, EXPLAIN, LOCK etc.
# There are various options that can be used in the FLUSH QUERY LOGGING option. Click <a href = 'https://docs.teradata.com/r/Teradata-VantageTM-SQL-Data-Definition-Language-Syntax-and-Examples/January-2021/Logging-Statements/FLUSH-QUERY-LOGGING/FLUSH-QUERY-LOGGING-Syntax-Elements'> here </a>to find these details.</p>

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>3. Session Details</b></p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>First let us get the different sessions and Demos executed</p>

# %%
SELECT sessionid,logondateTime, queryband,
getquerybandvalue(queryband, 0, 'DEMO') as DemoName, count(*) FROM 
dbc.qrylog l where  queryband like '%DEMO=%' group by 1,2, 3  order by 1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory959694"><style>
#       table.tdhistory959694 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory959694 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory959694:last-child { text-align: left !important; }
#       tbody.tdhistory959694 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory959694 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory959694 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory959694"></th><th class="tdhistory959694">SessionID</th><th class="tdhistory959694">LogonDateTime</th><th class="tdhistory959694">QueryBand</th><th class="tdhistory959694">DemoName</th><th class="tdhistory959694">Count(*)</th></tr></thead><tbody class="tdhistory959694 resultset-body"><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> appVersion=2.2.0.0;appName=VAL;appFunc=LINEAR; =S> GET_DATA=DEMO_Financial_local;DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">2</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> appVersion=2.2.0.0;appName=VAL;appFunc=FACTORSCORE; =S> GET_DATA=DEMO_Financial_local;DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">2</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> appVersion=2.2.0.0;appName=VAL;appFunc=VARTRAN; =S> GET_DATA=DEMO_Financial_local;DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">1</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> appVersion=2.2.0.0;appName=VAL;appFunc=LINEARSCORE; =S> GET_DATA=DEMO_Financial_local;DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">2</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> appVersion=2.2.0.0;appName=VAL;appFunc=MATRIX; =S> GET_DATA=DEMO_Financial_local;DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">10</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> appVersion=2.2.0.0;appName=VAL;appFunc=REPORT; =S> GET_DATA=DEMO_Financial_local;DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">11</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=S> DEMO=VAL_Analytics_and_ML_SQL.ipynb;Version=3.3;ClientUser=demo_user;ApplicationName=JupyterExt;</td><td class="tdhistory959694">VAL_Analytics_and_ML_SQL.ipynb</td><td class="tdhistory959694">5</td></tr><tr><th class="tdhistory959694" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory959694">1024</td><td class="tdhistory959694">2023-12-20 00:56:20.980000</td><td class="tdhistory959694">=T> ap ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>From the above output please select a session for which we want to go ahead with the further analysis.</p>
# <br>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>4. DBQL Log Table</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>***From the above output please enter the SessionId for which you want to proceed with the Analysis.</b></p>

# %%
%var SessionIdParam = 1206  ----Enter session id

# %%
select sessionid, queryband,starttime, querytext, NumSteps,AmpCPUTime, TotalIOCount,
cast((firstresptime - starttime second(4)) as decimal(8,2)) as RunSecs from dbc.qrylog 
		where sessionid=${SessionIdParam} ---SessionIdParam 
    order by RunSecs DESC;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory864256"><style>
#       table.tdhistory864256 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory864256 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory864256:last-child { text-align: left !important; }
#       tbody.tdhistory864256 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory864256 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory864256 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
# 	,"xtbl"</td><td class="tdhistory864256">94</td><td class="tdhistory864256">0.728</td><td class="tdhistory864256">1384</td><td class="tdhistory864256">2.03</td></tr><tr><th class="tdhistory864256" style= "background: rgba(243, 243, 243, 0.75)">33</th><td class="tdhistory864256">1206</td><td class="tdhistory864256">=S> DEMO=VAL_teradataml_Demo_Python.ipynb;</td><td class="tdhistory864256">2023-12-21 06:16:28.310000</td><td class="tdhistory864256">SELECT SUM(_tm_w*_tm_x0*_tm_x0),SUM(_tm_w*_tm_x0*_tm_x1),SUM(_tm_w*_tm_x0*_tm_x2),SUM(_tm_w*_tm_x0*_tm_x3),SUM(_tm_w*_tm_x0*_tm_x4),SUM(_tm_w*_tm_x0*_tm_x5),SUM(_tm_w*_tm_x0*_tm_x6),SUM(_tm_w*_tm_x0*_</td><td class="tdhistory864256">9</td><td class="tdhistory864256">0.044</td><td class="tdhistory864256">275</td><td class="tdhistory864256">2.00</td></tr><tr><th class="tdhistory864256" style= "background: rgba(243, 243, 243, 0.75)">34</th><td class="tdhistory864256">1206</td><td class="tdhistory864256">=S> DEMO=VAL_teradataml_Demo_Python.ipynb;</td><td class="tdhistory864256">2023-12-21 06:16:33.020000</td><td class="tdhistory864256">SELECT SUM(_tm_w*_tm_x0*_tm_x0),SUM(_tm_w*_tm_x0*_tm_x1),SUM(_tm_w*_tm_x0*_tm_x2),SUM(_tm_w*_tm_x0*_tm_x3),SUM(_tm_w*_tm_x0*_tm_x4),SUM(_tm_w*_tm_x0*_tm_x5),SUM(_tm_w*_tm_x0*_tm_x6),SUM(_tm_w*_tm_x0*_</td><td class="tdhistory864256">9</td><td class="tdhistory864256">0.048</td><td class="tdhistory864256">275</td><td class="tdhistory864256">1.84</td></tr><tr><th class="tdhistory864256" style= "background: rgba(243, 243, 243, 0.75)">35</th><td class="tdhistory864256">1206</td><td class="tdhistory864256">=S> DEMO=VAL_teradataml_Demo_Python.ipynb;</td><td class="tdhistory864256">2023-12-21 06:15:50.020000</td><td class="tdhistory864256">SELECT SUM(_tm_w*_tm_x0*_tm_x0),SUM(_tm_w*_tm_x0*_tm_x1),SUM(_tm_w*_tm_x0*_tm_x2),SUM(_tm_w*_tm_x0*_tm_x3),SUM(_tm_w*_tm_x0*_tm_x4),SUM(_tm_w*_tm_x0*_tm_x5),SUM(_tm_w*_tm_x0*_tm_x6),SUM(_tm_w*_tm_x0*_</td><td class="tdhistory864256">9</td><td class="tdhistory864256">0.072</td><td class="tdhistory864256">275</td><td class="tdhistory864256">1.83</td></tr><tr><th class="tdhistory864256" style= "background: rgba(243, 243, 243, 0.75)">36</th><td class="tdhistory864256">1206</td><td class="tdhistory864256">=S> DEMO=VAL_teradataml_Demo_Python.ipynb;</td><td class="tdhistory864256">2023-12-21 06:16:18.780000</td><td class="tdhistory864256">SELECT SUM(_tm_w*_tm_x0*_tm_x0),SUM(_tm_w*_tm_x0*_tm_x1),SUM(_tm_w*_tm_x0*_tm_x2),SUM(_tm_w*_tm_x0*_tm_x3),SUM(_tm_w*_tm_x0*_tm_x4),SUM(_tm_w*_tm_x0*_tm_x5),SUM(_tm_w*_tm_x0*_tm_x6),SUM(_tm_w*_tm_x0*_</td><td class="tdhistory864256">9</td><td class="tdhistory864256">0.096</td><td class="tdhistory864256">275</td><td class="tdhistory864256">1.81</td></tr><tr><th class="tdhistory864256" style= "background: rgba(243, 243, 243, 0.75)">37</th><td class="tdhistory864256">1206</td><td class="tdhistory864256">=S> DEMO=VAL_teradataml_Demo_Python.ipynb;</td><td class="tdhistory864256">2023-12-21 06:15:57.000000</td><td class="tdhistory864256">SELECT SUM(_tm_w*_tm_x0*_tm_x0),SUM(_tm_w*_tm_x0*_tm_x1),SUM(_tm_w*_tm_x0*_tm_x2),SUM(_tm_w*_tm_x0*_tm_x3),SUM(_tm_w*_tm_x0*_tm_x4),SUM(_tm_w*_tm_x0*_tm_x5),SUM(_tm_w*_tm_x0*_tm_x6),SUM(_tm_w*_tm_x0*_</td><td class="tdhistory864256">9</td><td class="tdhistory864256">0.084</td><td class="tdhistory864256">275</td><td class="tdhistory864256">1.80</td></tr><tr><th class="tdhistory864256" style= "background: rgba(243, 243, 243, 0.75)">38</th><td class="tdhistory864256">1206</td><td class="tdhistory864256">=S> DEMO=VAL_teradataml_Demo_Python.ipynb;</td><td class="tdhistory864256">2023-12-21 06:15:45.520000</td><td class="tdhistory864256">SELECT SUM(_tm_w*_tm_x0*_tm_x0),SUM(_tm_w*_tm_x0*_tm_x1),SUM(_tm_w*_tm_x0*_tm_x2),SUM(_tm_w*_tm_x0*_tm_x3),SUM(_tm_w*_tm_x0*_tm_x4),SUM(_tm_w*_tm_x0*_tm_x5),SUM(_tm_w*_tm_x0*_tm_x6),SUM(_tm_w*_tm_x0*_</td><td class="tdhistory864256">9</td><td class="tdhistory864256">0.088</td><td class="tdhistory864256">275</td><td class="tdhistory864256">1.77</td> ...

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>The above output shows all queries executed in the Session you have selected. The first query is the query taking highest execution time and the last query is the query taking least time to execute.</p>
# <br>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>5. NOS(Native Object Store) fields in DBQL log table</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Native Object Store is used to access semi-structured or unstructured data that resides in Amazon AWS-S3 or Microsoft Azure object stores and process it inside Teradata Vantage using a rich set of built-in analytics and functions. All the parallelism of the Vantage Advanced SQL Engine can be brought to bear on processing external data, providing a benefit when analyzing huge volumes. Workload management, security and reliability all provide a solid foundation for bringing such analytic algorithms into production. Using Native Object Store, data scientist will be able to benefit from the advanced analytic capabilities provided on Teradata Vantage.</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The dbc.qrylog view has many other columns which can be used for other Analysis. Like the NOS columns as shown in the query below.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Replace the <b>SessionIdParam</b> in the below query with the same sessionId we used in the above query. </p>

# %%
Select SessionId,starttime,NosRecordsSkipped,NosMaxIOWaitTime,NosRecordsReturnedKB,NosPhysReadIO,NosFilesSkipped,
NosTables,NosTotalIOWaitTime,NosCPUTime,NosRecordsReturned,NosPhysReadIOKB,NosFiles from dbc.dbqlogtbl 
where sessionid=${SessionIdParam}---SessionIdParam
order by 2,1;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory239011"><style>
#       table.tdhistory239011 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory239011 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory239011:last-child { text-align: left !important; }
#       tbody.tdhistory239011 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory239011 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory239011 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory239011"></th><th class="tdhistory239011">SessionID</th><th class="tdhistory239011">StartTime</th><th class="tdhistory239011">NosRecordsSkipped</th><th class="tdhistory239011">NosMaxIOWaitTime</th><th class="tdhistory239011">NosRecordsReturnedKB</th><th class="tdhistory239011">NosPhysReadIO</th><th class="tdhistory239011">NosFilesSkipped</th><th class="tdhistory239011">NosTables</th><th class="tdhistory239011">NosTotalIOWaitTime</th><th class="tdhistory239011">NosCPUTime</th><th class="tdhistory239011">NosRecordsReturned</th><th class="tdhistory239011">NosPhysReadIOKB</th><th class="tdhistory239011">NosFiles</th></tr></thead><tbody class="tdhistory239011 resultset-body"><tr><th class="tdhistory239011" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory239011">1206</td><td class="tdhistory239011">2023-12-21 06:09:20.450000</td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td></tr><tr><th class="tdhistory239011" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory239011">1206</td><td class="tdhistory239011">2023-12-21 06:09:20.660000</td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td></tr><tr><th class="tdhistory239011" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory239011">1206</td><td class="tdhistory239011">2023-12-21 06:09:20.670000</td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td></tr><tr><th class="tdhistory239011" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory239011">1206</td><td class="tdhistory239011">2023-12-21 06:09:20.740000</td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td></tr><tr><th class="tdhistory239011" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory239011">1206</td><td class="tdhistory239011">2023-12-21 06:09:21.000000</td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td></tr><tr><th class="tdhistory239011" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory239011">1206</td><td class="tdhistory239011">2023-12-21 06:09:21.020000</td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class="tdhistory239011"></td><td class ...

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The above output shows all queries executed in the Session using the NOS functionality. Below are the details of the various fields related to NOS in the DBQLogtbl.</p>
# <table style ='font-size:14px;font-family:Arial;color:#00233C'>
#     <tr>
#     <th>Field Name</th>
#     <th>Explanation</th>
#   </tr>
#   <tr>
#     <td>NosRecordsSkipped</td>
#     <td>Number of Native Object Store records skipped</td>
#   </tr>
#   <tr>
#     <td>NosTables</td>
#     <td>Total number of Native Object Store tables accessed.</td>
#   </tr>
#   <tr>
#     <td>NosFilesSkipped</td>
#     <td>Number of Native Object Store files that were partially or fully skipped due to errors.</td>
#   </tr>
#   <tr>
#     <td>NosFiles</td>
#     <td>Number of Native Object Store files reads attempted.</td>
#   </tr>
#   <tr>
#     <td>NosTotalIOWaitTime</td>
#     <td>Total of the Native Object Store IO wait time across all steps</td>
#   </tr>
#   <tr>
#     <td>NosPhysReadIO</td>
#     <td>Total physical read IOs for Native Object Store files</td>
#   </tr>
#   <tr>
#     <td>NosPhysReadIOKB</td>
#     <td>Total physical read IO KBs for Native Object Store files</td>
#   </tr>
#   <tr>
#     <td>NosRecordsRe-turnedKB</td>
#     <td>Number of KBs in Native Object Store records returned</td>
#   </tr>
#   <tr>
#     <td>NosMaxIOWaitTime</td>
#     <td>Max Native Object Store IO wait time for any individual IO. Float-ing point field. In seconds.</td>
#   </tr>
#   <tr>
#     <td>NosCPUTime</td>
#     <td>CPU time for reading Native Object Store files. Floating point. Units of seconds.</td>
#   </tr>
# </table>
# </p>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>6. DBQL log table Details</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The dbc.qrylog view is a view on the dbqlogtbl which has many different columns. Default rows are stored in the DBC.DBQLogTbl table, the foundation of the DBQL feature. The default is one default row per query.</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The major fields of the DBQLogTbl provide general query information that is usually adequate for investigating a query that is interfering with performance. When no options are specified, the default fileds that are populated are:</p>
#
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>User ID and user name under which the session being logged was initiated</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Unique ID for the process, session, and host (client) connection</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Account string, expanded as appropriate, that was current when the query completed</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>First 200 characters of the query SQL statement</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>CPU and I/O statistics</li>
# <li style = 'font-size:16px;font-family:Arial;color:#00233C'>Default database name that was current when the query completed</li>
# </p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Please find the details of the columns in the DBQL table <a href = 'https://docs.teradata.com/r/Teradata-Database-Administration/April-2018/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs/Main-Log-Table-DBQLogTbl'>here</a>. Execute the below query to check the column details from the DBQLogTbl</a></p>

# %%
select ColumnName, ColumnFormat, ColumnType, ColumnLength from dbc.ColumnsV where tablename = 'DBQLogtbl' order by ColumnName
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory454403"><style>
#       table.tdhistory454403 { display: block !important; min-height: 588px !important; overflow: auto !important; height: 588px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory454403 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory454403:last-child { text-align: left !important; }
#       tbody.tdhistory454403 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory454403 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory454403 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory454403"></th><th class="tdhistory454403">ColumnName</th><th class="tdhistory454403">ColumnFormat</th><th class="tdhistory454403">ColumnType</th><th class="tdhistory454403">ColumnLength</th></tr></thead><tbody class="tdhistory454403 resultset-body"><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory454403">AbortFlag</td><td class="tdhistory454403">X(1)</td><td class="tdhistory454403">CF  </td><td class="tdhistory454403">1</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory454403">AcctString</td><td class="tdhistory454403">X(128)</td><td class="tdhistory454403">CV  </td><td class="tdhistory454403">256</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory454403">AcctStringDate</td><td class="tdhistory454403">YY/MM/DD</td><td class="tdhistory454403">DA  </td><td class="tdhistory454403">4</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory454403">AcctStringHour</td><td class="tdhistory454403">-(5)9</td><td class="tdhistory454403">I2  </td><td class="tdhistory454403">2</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory454403">AcctStringTime</td><td class="tdhistory454403">99:99:99</td><td class="tdhistory454403">F   </td><td class="tdhistory454403">8</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">6</th><td class="tdhistory454403">AMPCPUTime</td><td class="tdhistory454403">----,---,---,---,--9.999</td><td class="tdhistory454403">F   </td><td class="tdhistory454403">8</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">7</th><td class="tdhistory454403">AMPCPUTimeNorm</td><td class="tdhistory454403">----,---,---,---,--9.999</td><td class="tdhistory454403">F   </td><td class="tdhistory454403">8</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">8</th><td class="tdhistory454403">AppID</td><td class="tdhistory454403">X(30)</td><td class="tdhistory454403">CF  </td><td class="tdhistory454403">60</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">9</th><td class="tdhistory454403">AutoDBAData</td><td class="tdhistory454403">X(1)</td><td class="tdhistory454403">CF  </td><td class="tdhistory454403">1</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">10</th><td class="tdhistory454403">CacheFlag</td><td class="tdhistory454403">X(1)</td><td class="tdhistory454403">CF  </td><td class="tdhistory454403">1</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">11</th><td class="tdhistory454403">CalendarName</td><td class="tdhistory454403">X(128)</td><td class="tdhistory454403">CV  </td><td class="tdhistory454403">256</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">12</th><td class="tdhistory454403">CallNestingLevel</td><td class="tdhistory454403">-(3)9</td><td class="tdhistory454403">I1  </td><td class="tdhistory454403">1</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">13</th><td class="tdhistory454403">CheckpointNum</td><td class="tdhistory454403">----,---,---,---,--9</td><td class="tdhistory454403">F   </td><td class="tdhistory454403">8</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">14</th><td class="tdhistory454403">ClientAddr</td><td class="tdhistory454403">X(45)</td><td class="tdhistory454403">CF  </td><td class="tdhistory454403">45</td></tr><tr><th class="tdhistory454403" style= "background: rgba(243, 243, 243, 0.75)">15</th><td class="tdhistory454403">ClientID</td><td class="tdhistory454403">X(30)</td><td class="tdhistor ...

# %% [markdown]
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>7. Check Query performance using DBQL log table</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The DBQL table is used to check the performance of the queries. Let's check the queries from the session we are analyzing above.</p>

# %%
select TOP 5 queryid, cast((firstresptime - starttime second(4)) as decimal(8,2)) as RunSecs, starttime, querytext, NumSteps,AmpCPUTime, TotalIOCount
 from dbc.qrylog 
where sessionid=${SessionIdParam}---SessionIdParam
order by Runsecs desc;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory796032"><style>
#       table.tdhistory796032 { display: block !important; min-height: 189px !important; overflow: auto !important; height: 189px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory796032 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory796032:last-child { text-align: left !important; }
#       tbody.tdhistory796032 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory796032 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory796032 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory796032"></th><th class="tdhistory796032">QueryID</th><th class="tdhistory796032">RunSecs</th><th class="tdhistory796032">StartTime</th><th class="tdhistory796032">QueryText</th><th class="tdhistory796032">NumSteps</th><th class="tdhistory796032">AMPCPUTime</th><th class="tdhistory796032">TotalIOCount</th></tr></thead><tbody class="tdhistory796032 resultset-body"><tr><th class="tdhistory796032" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory796032">307191233927996791</td><td class="tdhistory796032">161.23</td><td class="tdhistory796032">2023-12-21 06:14:58.240000</td><td class="tdhistory796032">call val.td_analyze('LOGISTIC', 'database=DEMO_USER;tablename=ADS_Py;outputdatabase=DEMO_USER;outputtablename=ml__valib_logreg_1703166031612333;columns=all;columnstoexclude=cust_id, az_resident_ind, i</td><td class="tdhistory796032">1</td><td class="tdhistory796032">0</td><td class="tdhistory796032">0</td></tr><tr><th class="tdhistory796032" style= "background: rgba(243, 243, 243, 0.75)">2</th><td class="tdhistory796032">307191233927996626</td><td class="tdhistory796032">38.15</td><td class="tdhistory796032">2023-12-21 06:14:13.870000</td><td class="tdhistory796032">call val.td_analyze('LOGISTIC', 'database=DEMO_USER;tablename=ADS_Py;outputdatabase=DEMO_USER;outputtablename=ml__valib_logreg_1703161027712890;columns=all;columnstoexclude=cust_id, state_code, cc_avg</td><td class="tdhistory796032">1</td><td class="tdhistory796032">0</td><td class="tdhistory796032">0</td></tr><tr><th class="tdhistory796032" style= "background: rgba(243, 243, 243, 0.75)">3</th><td class="tdhistory796032">307191233927996266</td><td class="tdhistory796032">10.77</td><td class="tdhistory796032">2023-12-21 06:12:40.120000</td><td class="tdhistory796032">call val.td_analyze('STATISTICS', 'database=DEMO_Financial;tablename=Customer;outputdatabase=DEMO_USER;outputtablename=ml__valib_statistics_1703158429016151;columns=allnumericanddate;statsoptions=all;</td><td class="tdhistory796032">1</td><td class="tdhistory796032">0</td><td class="tdhistory796032">0</td></tr><tr><th class="tdhistory796032" style= "background: rgba(243, 243, 243, 0.75)">4</th><td class="tdhistory796032">307191233927996561</td><td class="tdhistory796032">5.54</td><td class="tdhistory796032">2023-12-21 06:13:46.840000</td><td class="tdhistory796032"> INSERT into "DEMO_USER"."ADS_Py" SELECT cust_id, income_bins, age_bins, tot_cust_years, tot_children, female_ind, single_ind, married_ind, separated_ind, state_code, ca_resident_ind, ny_resident_ind,</td><td class="tdhistory796032">12</td><td class="tdhistory796032">10.012</td><td class="tdhistory796032">1606</td></tr><tr><th class="tdhistory796032" style= "background: rgba(243, 243, 243, 0.75)">5</th><td class="tdhistory796032">307191233927996441</td><td class="tdhistory796032">5.26</td><td class="tdhistory796032">2023-12-21 06:13:09.200000</td><td class="tdhistory796032">call val.td_analyze('HISTOGRAM', 'database=DEMO_Financial;tablename=Customer;outputdatabase=DEMO_USER;outputtablename=ml__valib_histogram_1703158523003727;columns=income;quantiles=25;');</td><td class="tdhistory796032">1</td><td class="tdhistory796032">0</td><td class="tdhistory796032">0</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>The above output shows all queries executed in the Session you have selected. The first query is the query taking highest execution time and the last query is the query taking least time to execute.</p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>There are different views created on the DBQLogTbl which can be used for different purpose.</p>
# <table style ='font-size:14px;font-family:Arial;color:#00233C'>
#     <tr>
#     <th>View Name</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>QryLog[V]</td>
#     <td>Contains default DBQL information for a query</td>
#   </tr>
#   <tr>
#     <td>QryLogTDWM[V]</td>
#     <td>Teradata Dynamic Workload Management view of the main log table, DBQLLogTbl.</td>
#   </tr>
#   <tr>
#     <td>QryLogFeatureUseJSON[V]</td>
#     <td>Provides a view into the FeatureUsage column of DBQLogTbl. This view uses the system function TD_SYSFNLIB.TD_DBQLFUL to convert the FeatureUsage bitmap column into a JSON document with a list of features used by particular requests</td>
#   </tr>
#   <tr>
#     <td>QryLogFeatureUseCountV</td>
#     <td>view is populated if the WITH FEATUREINFO option for BEGIN/REPLACE QUERY LOGGING and this view (QryLogFeatureUseCountV) is included in a request. QryLogFeatureUseCountV provides a view into the FeatureUsage column of DBQLogTbl and the QryLogFeatureListV view.</td>
#   </tr>
# </table>
# <br>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>8. DBQL Step table usage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>We will further continue the analysis by checking the step details of the longest running query by replacing the parameter <b>SampleQueryId</b> with the actual QueryId from the output above.</p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'><b>***From the above output please enter the SampleQueryId(QueryId) for which you want to proceed with the Analysis.</b></p>

# %%
%var SampleQueryId = 307191233927996561

# %%
select
ql.queryid, qls.StepStartTime,
CAST( EXTRACT (SECOND FROM FirstRespTime) + (EXTRACT (MINUTE FROM FirstRespTime) * 60 ) + (EXTRACT (HOUR FROM FirstRespTime) *60*60 ) + (86400 * (CAST ( FirstRespTime AS DATE) - CAST ( starttime AS DATE) ) )
- (EXTRACT (SECOND FROM starttime) + (EXTRACT (MINUTE FROM starttime) * 60 ) + (EXTRACT (HOUR FROM starttime) *60*60 ) ) AS INTEGER) QryRunSecs , 
CAST(ql.AmpCpuTime AS DECIMAL(18,3)) QryCpu , 
ql.totaliocount  QryIO,
ql.spoolusage Qryspool,
qls.StepLev1Num + .1 * qls.StepLev2Num (Decimal(4,1)) as sNum,
qls.StepName as Stp,


/* run time metrics */
qls.EstProcTime,
CAST( EXTRACT (SECOND FROM StepStopTime) + (EXTRACT (MINUTE FROM StepStopTime) * 60 ) + (EXTRACT (HOUR FROM StepStopTime) *60*60 ) + (86400 * (CAST ( StepStopTime AS DATE) - CAST ( StepStartTime AS DATE) ) )
- (EXTRACT (SECOND FROM StepStartTime) + (EXTRACT (MINUTE FROM StepStartTime) * 60 ) + (EXTRACT (HOUR FROM StepStartTime) *60*60 ) ) AS INTEGER)  StepSecs,

/* cpu metrics */
 ZEROIFNULL(CAST(qls.EstCPUCost AS DECIMAL(38,1)) ) EstCpu , 
 CAST(qls.CPUTIME AS DECIMAL(38,1)) ActCpu,
CAST( (qls.maxampcputime * qls.numofactiveamps) AS DECIMAL(38,1))  StepImpCpu , 

/* IO metrics */
ZEROIFNULL(qls.EstIOCost) EstIO,
qls.IOcount
, qls.MaxAmpIO* qls.NumOfActiveAmps StepImpIO ,  

/* PJI metrics */
ZEROIFNULL(CAST ( qls.CPUTIME * 1000.0 / NULLIFZERO(qls.IOCOUNT ) AS DECIMAL(38,1) ) )StepPJI,

/* Spool metrics */
qls.SpoolUsage/1000000 StepSpool_M , 
qls.MaxAmpSpool * qls.NumOfActiveAmps / 1000000 StepImpSpoolMB , 

/* PE  metrics */
ZEROIFNULL(ActCpu/NULLIFZERO(StepImpCpu)) StepPE,

/* row estimates  */  
qls.EstRowCount,
qls.RowCount,
qls.RowCount/nullifzero(qls.EstRowCount) as RowVsEst,
qls.RowsWComprColumns/nullifzero(qls.RowCount) as CompPct,

/* Skew metrics */
(1- qls.CpuTime/ nullifzero(qls.NumOfActiveAmps*qls.maxampcputime)) * 100  as CpuSkewPct, 
(1- qls.IOCount/ nullifzero(qls.NumOfActiveAmps*qls.maxampio)) * 100  as IOSkewPct, 
(1-qls.spoolusage/nullifzero(qls.NumOfActiveAmps*qls.MaxAmpSpool)) * 100 as SpoolSkewPct,
qls.numcombinedpartitions

FROM dbc.dbqlogtbl ql
INNER JOIN dbc.dbqlsteptbl qls
ON  ql.queryid = qls.queryid
AND ql.procid = qls.procid
WHERE ql.queryid = ${SampleQueryId} ---SampleQueryId
order by qls.queryid,sNum                ;

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The above output shows all the steps for the query we are analyzing. The step details contain the Runsec, AmpCPUTime, IOCount, Spool along with other details, used for each step.</p>
# <br>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>9. DBQL SQL table usage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>The DBQLogTbl logs only partial text of the Query which is executed. In order to get the complete text of the query we will have to check the SQL text in the DBQLSQLTbl. The below SQL will show the complete test of the query. </p>

# %%
Select QueryId, sqltextinfo from dbc.dbqlsqltbl where queryid = ${SampleQueryId} ---SampleQueryId
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory248268"><style>
#       table.tdhistory248268 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory248268 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory248268:last-child { text-align: left !important; }
#       tbody.tdhistory248268 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory248268 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory248268 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory248268"></th><th class="tdhistory248268">QueryID</th><th class="tdhistory248268">SqlTextInfo</th></tr></thead><tbody class="tdhistory248268 resultset-body"><tr><th class="tdhistory248268" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory248268">307191233927996561</td><td class="tdhistory248268"> INSERT into "DEMO_USER"."ADS_Py" SELECT cust_id, income_bins, age_bins, tot_cust_years, tot_children, female_ind, single_ind, married_ind, separated_ind, state_code, ca_resident_ind, ny_resident_ind, tx_resident_ind, il_resident_ind, az_resident_ind, oh_resident_ind, ck_acct_ind, sv_acct_ind, cc_acct_ind, ck_avg_bal, sv_avg_bal, cc_avg_bal, ck_avg_tran_amt, sv_avg_tran_amt, cc_avg_tran_amt, q1_trans_cnt, q2_trans_cnt, q3_trans_cnt, q4_trans_cnt from "DEMO_USER"."ml__select__1703161876543444"</td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>Double Click on the cell showing the SQL Text to check the complete SQL text of the Query.</p>
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>The above output shows the complete text of the Query executed. Further to check the details of each step we can check the explain plan of the query using the DBQLExplainTbl as shown in the query below .</p>
# <br>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>10. DBQL Explain table usage</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Run the below query by replacing the parameter <b>SampleQueryId</b> with the actual QueryId from the output above.</p>

# %%
Select QueryId, ExplainText from dbc.dbqlexplaintbl where queryid = ${SampleQueryId} ---SampleQueryId
;
# Out:
# <div class = "td-resultset-table-div" style = "max-height: 100%; overflow-y: auto">
#       <table class="tdhistory861881"><style>
#       table.tdhistory861881 { display: block !important; min-height: 105px !important; overflow: auto !important; height: 105px !important; width: 100% !important; border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory861881 { border: 1px solid rgb(198,198,198) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: center !important; white-space: normal !important; color: var(--jp-ui-font-color1) !important; }
#       th.tdhistory861881:last-child { text-align: left !important; }
#       tbody.tdhistory861881 tr:nth-child(even) { background: rgba(243, 243, 243, 0.75) !important; }
#       tbody.tdhistory861881 tr:nth-child(odd) { background: var(--jp-ui-inverse-font-color1) !important; }
#       td.tdhistory861881 { border: 1px solid rgb(207, 207, 207) !important; border-collapse: collapse !important; ; padding: 2px 5px !important; ; font-size: 13px !important; ; text-align: left !important;          white-space: nowrap !important; overflow:hidden !important; text-overflow:ellipsis !important;; }
#     </style><thead><tr style= "background: rgba(243, 243, 243, 0.75)"><th class="tdhistory861881"></th><th class="tdhistory861881">QueryID</th><th class="tdhistory861881">ExplainText</th></tr></thead><tbody class="tdhistory861881 resultset-body"><tr><th class="tdhistory861881" style= "background: rgba(243, 243, 243, 0.75)">1</th><td class="tdhistory861881">307191233927996561</td><td class="tdhistory861881">  1) First, we lock DEMO_USER.ADS_Py in TD_MAP1 for write on a reserved
#      RowHash to prevent global deadlock.
#   2) Next, we lock DEMO_Financial_db.Transactions in view
#      DEMO_USER.ml__select__1703161876543444 in TD_MAP1 for access, we
#      lock DEMO_USER.ADS_Py in TD_MAP1 for write, we lock
#      DEMO_USER.ml__valib_transform_1703158799450161 in view
#      ml__select__1703161876543444 in TD_MAP1 for access, and we lock
#      DEMO_USER.cust in view ml__select__1703161876543444 in TD_MAP1 for
#      access.
#   3) We execute the following steps in parallel.
#        1) We do an all-AMPs RETRIEVE step in TD_MAP1 from
#           DEMO_USER.cust in view ml__select__1703161876543444 by way of
#           an all-rows scan with no residual conditions into Spool 3
#           (all_amps), which is redistributed by the hash code of (
#           DEMO_USER.cust.cust_id (FLOAT)) to all AMPs in TD_Map1.  The
#           size of Spool 3 is estimated with low confidence to be 10,356
#           rows (579,936 bytes).  The estimated time for this step is
#           0.03 seconds.
#        2) We do an all-AMPs RETRIEVE step in TD_MAP1 from
#           DEMO_USER.ml__valib_transform_1703158799450161 in view
#           ml__select__1703161876543444 by way of an all-rows scan with
#           a condition of ("NOT
#           (DEMO_USER.ml__valib_transform_1703158799450161 in view
#           ml__select__1703161876543444.cust_id IS NULL)") into Spool 4
#           (all_amps), which is redistributed by the hash code of (
#           DEMO_USER.ml__valib_transform_1703158799450161.cust_id) to
#           all AMPs in TD_Map1.  The size of Spool 4 is estimated with
#           low confidence to be 19,632 rows (1,138,656 bytes).  The
#           estimated time for this step is 0.04 seconds.
#   4) We do an all-AMPs JOIN step in TD_Map1 from Spool 3 (Last Use) by
#      way of an all-rows scan, which is joined to Spool 4 (Last Use) by
#      way of an all-rows scan.  Spool 3 and Spool 4 are left outer
#      joined using a single partition hash join, with condition(s) used
#      for non-matching on left table ("NOT (cust_id IS NULL)"), with a
#      join condition of ("(cust_id )= cust_id").  The result goes into
#      Spool 5 (all_amps) fanned out into 2 hash join partitions, which
#      is redistributed by the hash code of (
#      DEMO_USER.ml__valib_transform_1703158799450161.acct_nbr) to all
#      AMPs in TD_Map1.  The size of Spool 5 is estimated with index join
#      confidence to be 26,176 rows (2,408,192 bytes).  The estimated
#      time for this step is 0.08 seconds.
#   5) We do an all-AMPs RETRIEVE step in TD_MAP1 from
#      DEMO_Financial_db.Transactions in view
#      DEMO_USER.ml__select__1703161876543444 by way of an all-rows scan
#      with a condition of ("NOT (DEMO_Financial_db.Transactions in view
#      DEMO_USER.ml__select__1703161876543444.acct_nbr IS NULL)") into
#      Spool 6 (all_amps) fanned out into 2 hash join partitions, which
#      is redistributed by hash code to all AMPs in TD_Map1.  The size of
#      Spool 6 is estimated with low confidence to be 1,084,772 rows (
#      55,323,372 bytes).  The estimated time for this step is 1.73
#      seconds.
#   6) We do an all-AMPs JOIN step in TD_Map1 from Spool 5 (Last Use) by
#      way of an all-rows scan, which is joined to Spool 6 (Last Use) by
#      way of an all-rows scan.  Spool 5 and Spool 6 are left outer
#      joined using a hash join of 2 partitions, with condition(s) used
#      for non-matching on left table ("NOT (acct_nbr IS NULL)"), with a
#      join condition of ("acct_nbr = acct_nbr").  The result goes into
#      Spool 2 (all_amps), which is built locally on the AMPs.  The size
#      of Spool 2 is estimated with index join confidence to be 1,928,484
#      rows (223,704,144 bytes).  The estimated time for this step is
#      3.26 seconds.
#   7) We do an all-AMPs SUM step in TD_Map1 to aggregate from Spool 2
#      (Last Use) by way of an all-rows scan, and the grouping identifier
#      in field 1.  Aggregate intermediate results are computed globally,
#      then placed in Spool 8 in TD_Map1.  The size of Spool 8 is
#      estimated with low confidence to be 7,767 rows (885,438 bytes).
#      The estimated time for this step is 2.33 seconds.
#   8) We do an all-AMPs RETRIEVE step in TD_Map1 from Spool 8 (Last Use)
#      by way of an all-rows scan into Spool 1 (all_amps), which is built
#      locally on the AMPs.  The size of Spool 1 is estimated with low
#      confidence to be 7,767 rows (947,574 bytes).  The estimated time
#      for this step is 0.02 seconds.
#   9) We do an all-AMPs MERGE step in TD_MAP1 into DEMO_USER.ADS_Py from
#      Spool 1 (Last Use).  The size is estimated with low confidence to
#      be 7,767 rows.  The estimated time for this step is 3.99 seconds.
#  10) We spoil the parser's dictionary cache for the table.
#  11) Finally, we send out an END TRANSACTION step to all AMPs involved
#      in processing the request.
#   -> No rows are returned to the user as the result of statement 1.
# </td></tr></tbody></table></div>

# %% [markdown]
# <p style = 'font-size:18px;font-family:Arial;color:#00233C'>Double Click on the cell showing the Explain Text to check the complete Explain Plan of the Query.</p>
# <br>
# <hr style="height:2px;border:none;background-color:#00233C;">
# <p style = 'font-size:20px;font-family:Arial;color:#00233C'><b>11. Information on other DBQL Tables and other Documentation Links</b></p>
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Apart from these main tables like the DBQL log, Step and Explain tables, other DBQL tables can also be used similarly to check the overall performance of the system. Click <a href = 'https://docs.teradata.com/r/Teradata-VantageTM-Database-Administration/March-2019/Tracking-Query-Behavior-with-Database-Query-Logging-Operational-DBAs/DBQL-Tables'>here</a> for additional Information on different DBQL Tables,</p>
#
# <p style = 'font-size:16px;font-family:Arial;color:#00233C'>Below are some links for the documents</p>
#
# <table style ='font-size:14px;font-family:Arial;color:#00233C'>
#   <tr>
#     <th>Link</th>
#     <th>Description</th>
#
#   </tr>
#   <tr>
#     <td><a href = 'https://docs.teradata.com/'>TD Docs (HTML)</a></td>
#     <td>Teradata documentation (HTML).</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'http://www.info.teradata.com'>TD Docs (PDF)</a></td>
#     <td>Teradata documentation (HTML).</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'https://access.teradata.com'>TD Docs One Stop Source</a></td>
#     <td>One stop source for Teradata community, product information, and software downloads.
# Log in for customer access to:
#         Support
#         Software updates
#         Knowledge articles
#         Orange Books</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'http://www.teradata.com/products-and-services/TEN'>TEN</a></td>
#     <td>Teradata education network.</td>
#
#   </tr>
#   <tr>
#     <td><a href = 'https://community.teradata.com'>Teradata Community</a></td>
#     <td>Link to Teradata community (also available from the customer portal).</td>
#
#   </tr>
# </table>

# %% [markdown]
# <footer style="padding-bottom:35px; background:#f9f9f9; border-bottom:3px solid #00233C">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2023. All Rights Reserved
#         </div>
#     </div>
# </footer>
