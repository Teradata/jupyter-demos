# %%
import teradataml

# %%
tables = ['consumer_complaints', 'consumer_embeddings',
          'embeddings_models','embeddings_tokenizers','complaints_clustermodel',
         'complaint_topics','consumer_complaint_topic_similarity']

# Loop through the list of views and execute the drop view command for each view
for t in tables:
    try:
        db_drop_table(t) 
    except:
        pass
