# %% [markdown]
# <header>
#    <p  style='font-size:36px;font-family:Arial; color:#F0F0F0; background-color: #00233c; padding-left: 20pt; padding-top: 20pt;padding-bottom: 10pt; padding-right: 20pt;'>
#        Vector Store - Getting Started
#   <br>
#        <img id="teradata-logo" src="https://storage.googleapis.com/clearscape_analytics_demo_data/DEMO_Logo/teradata.svg" alt="Teradata" style="width: 125px; height: auto; margin-top: 20pt;">
#     </p>
# </header>

# %% [markdown]
# <p style="font-size:20px;font-family:Arial"><b>Introduction</b></p>
#
# <p style="font-size:16px;font-family:Arial">
# Vector stores are specialized databases designed for efficient storage, indexing, and searching of high-dimensional vector embeddings. These embeddings, generated by AI models, enable similarity search and power applications in machine learning, NLP, recommendation systems, and image/video retrieval.
# </p>
#
# <p style="font-size:16px;font-family:Arial">
# This notebook provides an in-depth exploration of vector stores in the Teradata Database, covering key concepts, vector embedding mechanisms, and efficient search techniques.
# </p>
#
# ---
#
# <p style="font-size:20px;font-family:Arial"><b>Key Concepts</b></p>
#
# <p style="font-size:18px;font-family:Arial"><b>What is a Vector Store?</b></p>
#
# <p style="font-size:16px;font-family:Arial">
# A vector store contains a vectorized representation of data, typically created using embeddings from AI models. It allows for high-speed similarity searches beyond traditional keyword matching.
# </p>
#
# <p style="font-size:16px;font-family:Arial">
# Vector embeddings are numerical representations of data (text, images, audio, etc.) mapped into a multi-dimensional space.
# </p>
#
#
# <p style="font-size:16px;font-family:Arial">
# Each embedding is a vector that captures semantic or content-based relationships. For example:
# </p>
#
# <table style="font-size:16px; font-family:Arial; border-collapse:collapse; width:100%; background-color:#1e1e1e; border:1px solid #ccc;">
#   <tr>
#     <th style="border:1px solid #ccc; padding:8px; text-align:left;">Data Type</th>
#     <th style="border:1px solid #ccc; padding:8px; text-align:left;">Example</th>
#     <th style="border:1px solid #ccc; padding:8px; text-align:left;">Vector Representation</th>
#   </tr>
#   <tr>
#     <td style="border:1px solid #ccc; padding:8px;">Text</td>
#     <td style="border:1px solid #ccc; padding:8px;">"King"</td>
#     <td style="border:1px solid #ccc; padding:8px;">[0.12, 0.45, 0.67, ...]</td>
#   </tr>
#   <tr>
#     <td style="border:1px solid #ccc; padding:8px;">Image</td>
#     <td style="border:1px solid #ccc; padding:8px;">A picture of a cat</td>
#     <td style="border:1px solid #ccc; padding:8px;">[0.23, 0.78, 0.55, ...]</td>
#   </tr>
# </table>
#
# <p style="font-size:16px;font-family:Arial">
# <b>Embedding Generation is carried out by AI_TextEmbedding Function </b>
# <ul style="font-size:16px;font-family:Arial">
#   <li>Enables text embedding generation using LLMs hosted by AzureOpenAI, AWS Bedrock. (Performs a full-table scan)</li>
#     <li> Accepts different parameters, model endpoint, key, model args etc.</li>
#
# <p style="font-size:16px;font-family:Arial">
# <b>Supported models</b>
# <ul style="font-size:15px;font-family:Arial">
# <li>Azure OpenAI</li>
# <ul style="font-size:14px;font-family:Arial">
# <li>text-embedding-ada-002</li>
#
# <li>text-embedding-3-small</li>
#
# <li>text-embedding-3-large</li>
# </ul>
#
# <li>Amazon Bedrock</li>
# <ul style="font-size:15px;font-family:Arial">
# <li>amazon.titan-embed-text-v1</li>
#
# <li>amazon.titan-embed-image-v1</li>
#
# <li>amazon.titan-embed-text-v2:0 (supported only on systems running curl v8.9.0)</li>
# </ul>
# </ul>
# </p>
#
# ---
#
# <p style="font-size:18px;font-family:Arial"><b>Vector Search</b></p>
#
# <p style="font-size:16px;font-family:Arial">
# Unlike traditional search methods, vector search understands the meaning behind a query. It provides relevant results by analyzing semantic relationships rather than exact keyword matches.
# </p>
#
# <p style="font-size:16px;font-family:Arial">
# Common types of embeddings include:
# </p>
#
# <ul style="font-size:16px;font-family:Arial">
# <li>Word Embeddings</li>
# <li>Sentence Embeddings</li>
# <li>Document Embeddings</li>
# <li>Image Embeddings</li>
# <li>Audio Embeddings</li>
# </ul>
#
# ---
#
# <p style="font-size:24px;font-family:Arial"><b>Vector Store in the Teradata Database</b></p>
#
# <p style="font-size:16px;font-family:Arial">
# A vector in Teradata is a specialized column type called <b>Vector</b>.
# </p>
#
# <p style="font-size:16px;font-family:Arial">
# The <b>vector store</b> in Teradata consists of schemas and tables that enable vector search functionality.
# </p>
#
# <hr>
#
# <p style="font-size:20px;font-family:Arial"><b>Vector Search Algorithms</b></p>
#
# <p style="font-size:16px;font-family:Arial">
# Teradata supports three main search algorithms:
# </p>
#
# <p style="font-size:18px;font-family:Arial"><b>1. VectorDistance</b></p>
# <ul style="font-size:16px;font-family:Arial">
#   <li><b>Flat index</b> (performs a full-table scan)</li>
#   <li><b>Scalable and parallel search</b></li>
#   <li><b>Exact search approach</b></li>
#   <li>Suitable for <b>smaller datasets (<10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial"><b>2. Kmeans</b></p>
# <ul style="font-size:16px;font-family:Arial">
#   <li><b>IVF (Inverted Vector File) index</b> (organizes data into clusters)</li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <p style="font-size:18px;font-family:Arial"><b>3. HNSW</b></p>
# <ul style="font-size:16px;font-family:Arial">
#   <li><b>HNSW (Hierarchical Navigable Small World) index</b></li>
#   <li><b>Graph-based Approximate Nearest Neighbors (ANN) search</b></li>
#   <li><b>Scalable and parallel training/search</b></li>
#   <li><b>Approximate search approach</b></li>
#   <li>Suitable for <b>larger datasets (>10K documents)</b></li>
# </ul>
#
# <hr>

# %% [markdown]
# <p style="font-size:20px;font-family:Arial;"><b>Types of Vector Store</b></p>
#
# <table style="font-size:15px; font-family:Arial;  width:100%; border:1px solid #ddd; border-collapse:collapse;">
#   <tr>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Type</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Description</th>
#     <th style="padding:10px; text-align:left; border:1px solid #ddd;">Use Case</th>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>1. Content-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>contents of a table</b> (or file/PDF converted to a table). Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#   <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>2. Metadata-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built on the <b>metadata</b> of tables. Queries return the <b>top matching tables</b> based on similarity. Used in <b>SQL generation</b> for data retrieval.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Helps form textual responses by retrieving data from relevant tables for more precise answers.</td>
#   </tr>
#     <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>3. File-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built from contents of PDF file. Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
#     <tr>
#     <td style="padding:10px; border:1px solid #ddd;"><b>4. Embedding-Based</b></td>
#     <td style="padding:10px; border:1px solid #ddd;">Built from the <b>user generated embeddings</b> . Queries return the <b>top relevant rows</b> based on similarity.</td>
#     <td style="padding:10px; border:1px solid #ddd;">Can be combined with <b>LLM-generated textual responses</b> for more accurate answers.</td>
#   </tr>
# </table>

# %% [markdown]
# <p style = 'font-size:20px;font-family:Arial'><b>What we will do in this Notebook</b></p>
#
# <p style = 'font-size:16px;font-family:Arial'>
# This notebook is designed to guide us through a comprehensive set of exercises focused on working with vector store management, ask and pattern managemnet API. By the end of this tutorial, we will have gained hands-on experience with creating and managing vector store objects and patterns as well as asking questions and performing similarity searches. Here's what we'll learn:
# </p>
#
# <div style = 'font-size:16px;font-family:Arial'>
# <ol>
# <li><b>Understanding Vector Store management</b></li>
# <li><b>Pattern Management for Vector Store</b></li>
# <li>
# <b>Content Based Vector Store </b>
#     <ul><li>Creating new Vector Store</li>
#         <li>Performing Similarity Search and Asking questions</li>
#         <li>Using existing Vector Store</li>
#         <li>Updating Vector Store</li>
#         <li>Destroying Vector Store</li>
#     </ul>
# </li>
# <li>
# <b>File Based Vector Store </b>
#    <ul><li>Creating a new File-based Vector Store</li>
#         <li>Performing Similarity Search and Asking questions</li>
#         <li>Updating existing Vector Store</li>
#         <li>Destroying Vector Store</li>
#     </ul>
# </li>
# <li>
# <b>Embedding Based Vector Store </b>
#    <ul><li>Creating a new Embedding-Based Vector Store</li>
#         <li>Performing Similarity Search and Asking questions</li>
#         <li>Destroying Vector Store</li>
#     </ul>
# </li>
# <li>
# <b>Metadata Based Vector Store </b>
#    <ul><li>Creating a new Metadata-Based Vector Store</li>
#         <li>Using existing Vector Store</li>
#         <li>Destroying Vector Store</li>
#     </ul>
# </li>
# <li>
# <b>Access Management in Vector Store</b>
# </li>
#
# </ol>
# </div>

# %% [markdown]
# <hr style='height:2px;border:none'>
# <b style = 'font-size:20px;font-family:Arial'>1. Configure the environment</b>

# %%
# %%capture
# !pip install teradatagenai --quiet

# %%
# %%capture
# !pip install openai --quiet

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style='font-size:16px;font-family:Arial'><i><b>Note:</b>If the above commands install the modules please restart the kernel after executing those lines to bring the installed libraries into memory. The simplest way to restart the Kernel is by typing zero zero: <b>0 0</b></i></p>
# </div>

# %%
from getpass import *
# Required imports
from teradatagenai import VSManager, VectorStore, VSPattern, VSApi, TeradataAI, TextAnalyticsAI, load_data

from teradataml import *
import os
from openai import OpenAI

import IPython.display as ipd

# Suppress warnings
import warnings
import time

warnings.filterwarnings('ignore')
display.suppress_vantage_runtime_warnings = True

display.max_rows=5

# %% [markdown]
# <hr style="height:2px;border:none">
# <p style = 'font-size:20px;font-family:Arial'><b>2. Connect to VantageCloud Lake</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Connect to VantageCloud using `create_context` from the teradataml Python library. Input your connection details, including the host, username, password and Analytic Compute Group name.</p>

# %%
print("Checking if this environment is ready to connect to VantageCloud Lake...")

if os.path.exists("/home/jovyan/JupyterLabRoot/VantageCloud_Lake/.config/.env"):
    print("Your environment parameter file exist.  Please proceed with this use case.")
    # Load all the variables from the .env file into a dictionary
    env_vars = dotenv_values("/home/jovyan/JupyterLabRoot/VantageCloud_Lake/.config/.env")
    # Create the Context
    eng = create_context(host=env_vars.get("host"), username=env_vars.get("username"), password=env_vars.get("my_variable"))
    execute_sql('''SET query_band='DEMO=VCL_GettingStarted_VectorStore.ipynb;' UPDATE FOR SESSION;''')
    print("Connected to VantageCloud Lake with:", eng)
else:
    print("Your environment has not been prepared for connecting to VantageCloud Lake.")
    print("Please contact the support team.")
# Out:
# Checking if this environment is ready to connect to VantageCloud Lake...
# Your environment parameter file exist.  Please proceed with this use case.
# Connected to VantageCloud Lake with: Engine(teradatasql://dallas47_jn6hvh5icpnu97gw:***@54.156.178.22)

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>3. Authenticate into User Environment Service (UES) </b></p>
#
# <p style="font-size:16px;font-family:Arial"><b>UES authentication</b> is required to create and manage the Python or R environments that we will be creating.  A VantageCloud Lake user can easily create the authentication objects using the Console in a VantageCloud Lake environment.  The step to create these authentication objects has already been performed for you and is available in your .env file.<br><br>To ensure that the call to the Vector Store is successful, we will create a function that we can reuse before every API call.
# </p>
# <p style="font-size:16px;font-family:Arial">
#
# <ul style="font-size:16px;font-family:Arial; margin-top:4px;">
#   <li><a href="https://docs.teradata.com/r/Teradata-VantageCloud-Lake/Analyzing-Your-Data/Teradata-Package-for-Python-on-VantageCloud-Lake/Working-with-Open-Analytics/APIs-to-Use-with-Open-Analytics-Framework/API-to-Set-Authentication-Token/set_auth_token">Click here</a> to see more details about using the Teradata APIs to set the authentication objects.</li>
#
#   <li>Check out <a href="https://medium.com/teradata/deploy-hugging-face-llms-on-teradata-vantagecloud-lake-with-nvidia-gpu-acceleration-d94d999edaa5">Step 4</a> of this tutorial to to see more details about configuring a VantageCloud Lake Environment to use our Open Analytics Framework</li>
# </ul>

# %%
# We've already loaded all the values into our environment variables and into a dictionary, env_vars.
# username=env_vars.get("username") isn't required when using base_url, pat and pem.
# We can't use the full ues-url provided which includes /open-analytics. We'll check for it and strip it if it exists.
ues_uri=env_vars.get("ues_uri")
if ues_uri.endswith("/open-analytics"):
    ues_uri = ues_uri[:-15]   # remove last 15 chars ("/open-analytics")

if set_auth_token(base_url=ues_uri,
       pat_token=env_vars.get("access_token"), 
       pem_file=env_vars.get("pem_file"),
       valid_from=int(time.time())
       ):
    print("UES Authentication successful")
else:
    print("UES Authentication failed. Check credentials.")
    sys.exit(1)
# Out:
# Authentication token is generated, authenticated and set for the session.
# UES Authentication successful

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b><i>A little something extra... </i></b></p>
#
# <p style="font-size:16px;font-family:Arial">This function will allow us to check on a task involving a vector store by executing a <code>vectorstore.status()</code> statement every 15 seconds and echoing the status.</p>

# %%
def check_vs_status(vs, poll_interval=15, timeout=600):
    """
    Waits until a vector store becomes READY, or exits immediately if deleted.

    Args:
        vs: VectorStore object with .status() method
        poll_interval (int): Seconds between status checks
        timeout (int): Max wait time (seconds)

    Returns:
        DataFrame with status row, OR None if deleted.

    Raises:
        TimeoutError: If READY not reached within timeout (and not deleted)
    """
    start_time = time.time()

    while True:
        df = vs.status()

        # If no dataframe returned OR it's empty ⇒ the vector store no longer exists
        if df is None or df.empty:
            print(f"Vector Store '{vs.name}' has been deleted. Exiting check.")
            return None

        status = df.loc[0, 'status']

        # Vector Store READY
        if status == 'READY':
            print(f"The Vector Store '{df.loc[0,'vs_name']}' is READY!")
            return df

        # Vector Store DELETED or DROPPED (some environments return these)
        if status.upper() in ("DELETED", "DROPPED", "REMOVED"):
            print(f"Vector Store '{vs.name}' reports status '{status}'. Exiting check.")
            return df

        # Otherwise still working
        print(f"Current status: {status}. Waiting {poll_interval} seconds...")

        # Timeout check
        if time.time() - start_time > timeout:
            raise TimeoutError("Vector Store did not become READY within timeout")

        time.sleep(poll_interval)

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>4. Understanding Vector Store management </b></p>
# <p style="font-size:16px;font-family:Arial">VSManager handles Vector Store Management. Below are the methods
#     <ul style="font-size:16px;font-family:Arial">
#         <li>health()</li>
#         <li>list()</li>
#         <li>list_sessions()</li>
#         <li>disconnect()</li>
#         </ul>
#             </p>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>4.1 health() - Service Health Check</b>
# <p style="font-size:16px;font-family:Arial"> <b> What It Does:</b> Ensures that the Vector Store service is up and running smoothly. It’s like a quick check-up to make sure everything is operational.<br>
#     <b> What We Get:</b> A clean report in the form of a DataFrame, indicating the health status of the service.</p>

# %%
VSManager.health()
# Out:
# Database connection established in 298.87 milliseconds.
#   status platform  version  sessions_count
# 0     up      aws  1.0.510             186

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>4.2 list() - List All Vector Stores</b>
# <p style="font-size:16px;font-family:Arial"> <b> What It Does:</b> Retrieves a list of all vector stores available in our environment. It’s like checking our inventory of vector stores.<br>
#     <b> What We Get:</b> A DataFrame with the details of each vector store.</p>

# %%
# Get the list
vslist = VSManager.list()

# 1) None check
if vslist is None:
    print("VS list is None")
else:
    # 2) Verify the username value
    username = env_vars.get("username")
    if not username:
        raise ValueError("env_vars['username'] is missing or empty.")

    # 3) Filter FIRST, then check emptiness
    filtered = vslist[vslist['database_name'] == username]

    # Approach A: shape (usually the simplest)
    if filtered.shape[0] == 0:
        print(f"There are currently no Vector Store entries for {username}.")
        no_of_vs = 0
    else:
        no_of_vs = filtered.shape[0]
        print(f"Found {filtered.shape[0]} entries for {username}.")
        ipd.display(vslist[ (vslist['database_name'] == env_vars.get("username"))])
        #ipd.display(type(vslist[ (vslist['database_name'] == env_vars.get("username"))]))
# Out:
# There are currently no Vector Store entries for dallas47_jn6hvh5icpnu97gw.

# %%
#Uncomment the vslist dataframe to see all the vector stores in the environment
# vslist

# %%
pdf = filtered.to_pandas()

# Convert vs_name column to a list safely
vs_names = pdf["vs_name"].tolist() if not pdf.empty else []

# If no entries, exit early with a message
if not vs_names:
    print("There are no Vector Store entries to destroy.")
else:
    for vs_name in vs_names:
        try:
            print(f"Destroying {vs_name}...")
            vs = VectorStore(name=vs_name, log=True)
            vs.destroy()
            check_vs_status(vs)
            print(f"Destroyed {vs_name}\n")
        except Exception as e:
            print(f"Failed to destroy {vs_name}: {e}\n")
# Out:
# There are no Vector Store entries to destroy.

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>4.3 list_sessions() - Active Sessions Overview</b>
# <p style="font-size:16px;font-family:Arial"> <b> What It Does:</b> Lists all active sessions within the Vector Data Store. Useful for managing our active interactions with the system.This is available only for admin users.<br>
#     <b> What We Get:</b>A DataFrame with details about each active session.</p>

# %%
sessions = VSManager.list_sessions()

# %%
sessions.session_details
# Out:
#                              session_id                       username                                            vs_names last_accessed
# 0  460e9d37-e045-4d41-bfbf-c9fa2afada2d       testenv_wleymashnqj4gl58                                                       22 days ago
# 1  f4c3ccd0-c18f-4114-a224-c267af92e462   test_snehal_0hhq1bwgfs5v3kjo                                                       22 days ago
# 2  394ef28a-35f8-44c1-8e0e-cf2523184b28        nktest_y39df7ughe0dhihp  nktest_y39df7ughe0dhihp_business_loyalty_discounts   22 days ago
# 3  ecbb9596-8657-4a3d-9a7e-92495103bda3  vantagecloud_yiytlbbxvmm0pjh2                       vantagecloud_yiytlbbxvmm0pjh2   25 days ago
# 4  d4327de5-dd05-47cd-97ea-ed24da741b02      aj186018_kwo9cdjd4q4rh9pn                           aj186018_kwo9cdjd4q4rh9pn   22 days ago

# %%
sessions.current_session_id
# Out:
# '721fb529-a1ab-4fd4-9445-1e7c6065a906'

# %%
sessions.total_active_sessions
# Out:
# 186

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>4.4 disconnect() - End Active Sessions</b>
# <p style="font-size:16px;font-family:Arial"> <b> What It Does:</b> Ends any active session by providing the session id (Applicable only for admin). If no session ID is provided, it terminates all active sessions created within the current python session. This is useful when we’re done working and want to disconnect from the system.<br>
#     <b> What We Get:</b>No return value, but all active sessions are closed.</p>

# %%
# VSManager.disconnect()

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>5. Pattern Management for Vector Store management </b></p>
# <p style="font-size:16px;font-family:Arial"> For metadata-based vector stores, the selection of tables/views can be huge. They can span multiple databases and it can become tedious to list them using include_objects and exclude_objects as mentioned in Ingest support. Patterns provide a way to select these tables/views and columns using simple regular expressions. A pattern string can be formed by using SQL wildcards ( % or _ ) and is specified while creating a pattern.
#     <ul style="font-size:16px;font-family:Arial">
#         <li>VSPattern() :Creates an Instance of VSPattern</li>
#         <li>create(): method to define the pattern for the vector store.</li>
#         <li>list_patterns(): lists the patterns </li>
#         <li>get() : Retrieve a list of objects that match</li>
#         <li>delete(): deletes the pattern </li>
#        </ul>
#             </p>

# %%
ptn_name = username+'_customer_include'
ptn = VSPattern(name=ptn_name)

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>5.1 create()</b>

# %%
try:
    ptn.create(pattern_string = 'DEMO%.%customer%')
     
except:
    ptn.delete()
    ptn.create(pattern_string = 'DEMO%.%customer%')
# Out:
# Pattern dallas47_jn6hvh5icpnu97gw_customer_include created.

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>5.2 list_patterns()</b>

# %%
VSManager.list_patterns()
# Out:
#                                       PatternName PatternString
# 0   sn186005_feb03_63z6fpyuh8lhkz39_employee_data    %employee%
# 1       demo_23mar_99u4m2v5sd495c4s_employee_data    %employee%
# 2         dallas47_jn6hvh5icpnu97gw_employee_data    %employee%
# 3                                    demo_exclude        %DEMO%
# 4  jupyter_demos_23309587709_1_0_3u3uycoqo6ulzfst    %employee%

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>5.3 get()</b>

# %%
ptn.get()
# Out:
#                                            Object list
# 0     "DEMO_ComplaintAnalysis".Customer_360_Complaints
# 1  "DEMO_ComplaintAnalysis_db".Customer_360_Complaints
# 2        "DEMO_ComplaintAnalysis".Customer_360_Details
# 3                   "DEMO_BankChurn_db".customer_churn
# 4                      "DEMO_BankChurn".customer_churn

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>5.4 delete()</b>

# %%
ptn.delete()
# Out:
# Pattern dallas47_jn6hvh5icpnu97gw_customer_include deleted.

# %%
#to confirm that pattern is deleted
VSManager.list_patterns()
# Out:
#                                       PatternName PatternString
# 0   sn186005_feb03_63z6fpyuh8lhkz39_employee_data    %employee%
# 1       demo_23mar_99u4m2v5sd495c4s_employee_data    %employee%
# 2         dallas47_jn6hvh5icpnu97gw_employee_data    %employee%
# 3                                    demo_exclude        %DEMO%
# 4  jupyter_demos_23309587709_1_0_3u3uycoqo6ulzfst    %employee%

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>6. Content-Based Vector Store </b></p>
# <p style="font-size:16px;font-family:Arial"> Content-based vector store uses table contents as vector store and is useful for cases where table contents contain texts of data that need to be searched to find relevant answers.</p>
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.1 Creating a new Vector Store</b>
# <p style="font-size:16px;font-family:Arial">Steps to create Vector Store
#     <ul style="font-size:16px;font-family:Arial">
#         <li>Initialize a VectorStore Instance : Create an instance of VectorStore </li>
#         <li>Create the Vector Store : Use the create() method on the vector store instance to create a new vector store. </li>
#         <li>Check the status of create() using status()</li>
# </ul>

# %%
vs_name = env_vars.get("username")+'_vs'

# %%
vs_name
# Out:
# 'dallas47_jn6hvh5icpnu97gw_vs'

# %%
# ACTION: Specify a name for a new vector store.
vs = VectorStore(name=vs_name, log=True)

# %%
# We need to specify the data source to create the embeddings for the 
# new vector store. The data source can be a string of a (fully-qualified, 
# if needed) table name, or a teradataml DataFrame.
#
# The following creates a teradataml DataFrame from this table to use as input.
# As the usecase is only for knowledge purpose we are taking subset of data
input_data = DataFrame.from_query("SELECT * FROM DEMO_Retail.Web_Comment where comment_id < 100")
input_data
# Out:
#             customer_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      comment_text               comment_summary
# comment_id
# ...

# %%
# Create vector store with the title specified earlier.
# The following specification lacks "chat_completion_model" argument.
# Per the user guide, default value is "anthropic.claude-3-haiku-20240307-v1:0"
# NOTE: If you ask to create an existing vector store, an error will be thrown.
vs.create(embeddings_model= 'amazon.titan-embed-text-v1',
          search_algorithm= 'KMEANS',
          seed=10,
          top_k=5,
          metric='EUCLIDEAN',
          object_names= input_data,
          key_columns= ['comment_id'],
          data_columns= ['comment_text'],
          vector_column= 'VectorIndex')
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs creation started.
# Use the 'status()' api to check the status of the operation.

# %% [markdown]
# <p style="font-size:18px;font-family:Arial"><b>Checking the Status of the vector store</b>
# <p style="font-size:16px;font-family:Arial">
# Though the create, update, destroy APIs are synchronous and will complete only after the operation is complete, user can ensure the same using the <b>status</b> API.  <br>
#     Check the <b>status</b>: The status function allows us to confirm whether the particular operation is successful.</p>

# %% [markdown]
# <p style="font-size:16px;font-family:Arial"><b> Wait for the status to become Ready to use the vector store.</b><br>We create the below function which will wait till the status of the Vector Store is in Ready State.
# </p>

# %%
check_vs_status(vs)
# Out:
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs' is READY!
#                         vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs  READY

# %%
vs.get_details()
# Out:
#                         vs_name     store_type description              database_name  sample_size            embeddings_model  embeddings_dims     metric search_algorithm  top_k search_threshold  search_numcluster ef_search initial_centroids_method  train_numcluster  max_iternum  stop_threshold  seed  num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects                                                  document_objects  document_columns document_indexes prompt vector_column                   chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status base_url_embeddings base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated metadata_columns base_url_content_safety base_url_t
# ...

# %% [markdown]
# <p style="font-size:16px;font-family:Arial"> Use the <b>list</b> function to retrieve all available vector stores and confirm if the vector store has been created.

# %%
VSManager.list()
# Out:
#                                                          vs_name     store_type description                                    database_name vs_status permission
# 0  finance_agent_demo_y49lltwbbea1svoq_finance_metric_policies_2  content-based        None              FINANCE_AGENT_DEMO_Y49LLTWBBEA1SVOQ     READY  NO ACCESS
# 1                             clearscapr_demo_2_sqp294bexuvf96b9     file-based        None               CLEARSCAPR_DEMO_2_SQP294BEXUVF96B9     READY  NO ACCESS
# 2                               demo_cluster_99u4m2v5sd495c4s_vs  content-based        None                    DEMO_CLUSTER_99U4M2V5SD495C4S     READY  NO ACCESS
# 3                                                table_knowledge  content-based        None                   TDVSLANG_0108_TEPBFMB23LEREW77     READY  NO ACCESS
# 4     jupyter_demos_23367616100_10_0_3u3uycoqo6ulzfst_sql_pdf_vs     file-based        None  JUPYTER_DEMOS_23367616100_10_0_3U3UYCOQO6ULZFST     READY  NO ACCESS

# %%
# NOTE: To destroy a vector store, use the destroy() function.
#vs.destroy()

# %% [markdown]
# <p style="font-size:16px;font-family:Arial">Check the type of vector store created

# %%
vs.store_type
# Out:
# 'content-based'

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.2 Performing a Similarity Search in a Vector Store</b>
# <p style="font-size:16px;font-family:Arial"> <b> similarity search</b> allows us to find the most relevant vectors based on a given input. By passing a question to an existing vector store, we can retrieve the closest matches based on the selected search algorithm.<br>
# <ol style="font-size:16px;font-family:Arial"><b>How It Works</b>
#     <li><b>Input a question</b> Pass a question or input text to question argument of similarity_search().</li>
#         <li><b>Perform the Similarity Search</b> The vector store searches for the most relevant matches using the specified search_algorithm.</li>
#         <li><b>Retrieve Top Matches</b> The result contains the top_k most relevant entries along with their similarity scores, helping us understand how closely they match the input.</li>
#         </ol>
#  <p style="font-size:16px;font-family:Arial">   This process enables efficient retrieval of information based on vector embeddings, making it useful for applications such as <b>semantic search, recommendation systems, and document retrieval</b>.

# %%
question = 'Which item has most comments'
response = vs.similarity_search(question=question)

# %%
# The "similar_objects" in the response is by default a DataFrame with top_k entries.
response.similar_objects
# Out:
#       score               DataBaseName                       TableName comment_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            comment_text  index_label
# ...

# %%
# Alternative option: Using JSON format could be speedier.
# We repeat the previous call by now specifying return_type='json'
question = 'Which item has most comments?'
response = vs.similarity_search(question=question, return_type='json')

# %%
# The "similar.objects" in the response is now a JSON object with top_k entries.
response.similar_objects
# Out:
# [{'score': 0.09974871700361178,
#   'DataBaseName': 'DALLAS47_JN6HVH5ICPNU97GW',
#   'TableName': 'ml___frmqry_v_1775599269197543',
#   'comment_id': '12',
#   'comment_text': 'More and more i find myself reliant on the reviews written by savvy shoppers before me and for the most past, they are right on in their estimation of the product. in the case of this dress-if it had not been for the reveiws-i doubt i would have even tried this. the dress is beautifully made, lined and reminiscent of the old retailer quality. it is lined in the solid periwinkle-colored fabric that matches the outer fabric print. tts and very form-fitting. falls just above the knee and does not rid'},
#  {'score': 0.0868446952896735,
#   'DataBaseName': 'DALLAS47_JN6HVH5ICPNU97GW',
#   'TableName': 'ml___frmqry_v_1775599269197543',
#   'comment_id': '28',
# ...

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.2.1 Generating a Natural Language Response</b>
# <p style="font-size:16px;font-family:Arial"> Once the <b> similarity search</b>method retrieves relevant results from the vector store, we can generate a natural language response by proving a prompt.<br>
# <ol style="font-size:16px;font-family:Arial"><b>Steps to Prepare the Response</b>
#     <li><b>Input a question</b> Pass a question or input text to question argument of prepare_response(). </li>
#     <li><b>Retrieve Similarity Results</b> The similarity_search() method returns the most relevant matches along with their similarity scores.</li>
#         <li><b>Input a prompt</b> By passing prompt, we ask the model to format the output in a particular way.</li>
#         </ol>
#  <p style="font-size:16px;font-family:Arial">   As we can see below, by passing the question and the prompt, the response is formated in a conversational manner as suggested in the prompt.</p>.

# %%
question='Did any one say the about the material of shirt?'
prompt='Format the response in a conversational way.'
response = vs.prepare_response(question=question, similarity_results=response, prompt=prompt)

# %%
# NOTE: The "response" object is a string. If we ask to display the string itself,
# the special characters like new lines will not be interpreted.
# To show the actual text with new lines, explicitly specify to print() the "response" object.

print(response)
# Out:
# Based on the provided data, there are a few comments that mention the material of the shirts:
#
# 1. "Very soft and comfortable. the shirt has an unusual, asymmetrical seam that appears along the front, right-hand side of the garment." This comment suggests the shirt is made of a soft, comfortable material.
#
# 2. "If this product was in petite, i would get the petite. the regular is a little long on me but a tailor can do a simple fix on that. fits nicely!" This comment does not directly mention the material, but implies the fit and comfort of the shirt.
#
# However, there are no specific comments that directly state the material composition of the shirts. The comments focus more on the fit, style, and overall quality of the shirts rather than the specific material used.

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.2.2 ask -Unified Similarity Search & Response Generation</b>
# <p style="font-size:16px;font-family:Arial"> To improve efficiency, we can  <b> combine similarity search and response generation</b> into a single operation. This method performs a similarity search in the vector store using the <b>input query</b> and then prepares a natural language response based on the retrieved results.<br>
# <ol style="font-size:16px;font-family:Arial"><b>How It Works</b>
#     <li><b>Input a question</b> Pass a question or input text to question argument of ask(). </li>
#     <li><b>Input a prompt</b> By passing prompt, we ask the model to format the output in a particular way.</li>
#         </ol>
#  <p style="font-size:16px;font-family:Arial"> <b>Faster Execution</b>  By combining both steps into a single function call, response time is reduced, making the system more efficient.</p>

# %%
custom_prompt = """Do not assume information. 
Only provide information that is present in the data.
Format results like this:
Comment ID: 
Comment: 
"""
question ='Are there any negative comments on shirts?'
response = vs.ask(question=question, prompt=custom_prompt)

# %%
print(response)
# Out:
# Yes, there are a few negative comments on the shirts in the data:
#
# Comment ID: 53
# Comment: Very soft and comfortable. the shirt has an unusual, asymmetrical seam that appears along the front, right-hand side of the garment. (the model is positioned so that you can't see this detail from the picture. i attached a picture that includes the front seam.) i actually like the seam - it creates more visual interest, and adds a little bit of ruching that helps hide my belly. the cowl neck is very well done - there are two layers that form the cowl, and i've found that it means wardrobe malfun
#
# This comment mentions an unusual asymmetrical seam on the shirt, which could be seen as a negative.

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.3 Initializing and Using the Existing Vector Store</b>
# <p style="font-size:16px;font-family:Arial"><b>Using an Existing Vector Store</b><br>If we have an existing vector store that we want to reuse, we can initialize it by providing the <b>name</b> of the store. This allows us to interact with and perform operations on the existing store without creating a new one.
#     <ul style="font-size:16px;font-family:Arial">Steps to Initialize existing Vector Store
#         <li>Provide the Name of the Vector Store : Specify the name of an existing vector store that  we went to access. In our case, for object_names we will pass in the teradataml DataFrame. </li>
#         <li>Initialize the Vector Store Instance :By using the provided name, we can initialize the vector store instance and begin interacting with it. </li>
# </ul>
# </p>

# %%
# ACTION: Specify an existing vector store to initialize.
updated_vs = VectorStore(vs_name)
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs is initialized.

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.4 Updating Existing Vector Store </b>
#     <p style="font-size:18px;font-family:Arial"><b>6.4.1 Updating Arguments</b>
# <p style="font-size:16px;font-family:Arial"> We can  <b> update</b> specific parameters of an existing vector store without having to recreate it. For instance, we want to modify the <b>search algorithm</b> or other configuration settings to better suit our needs. This can be done using the update() API, which allows us to change the arguments of the vector store.<br>
# <ol style="font-size:16px;font-family:Arial"><b>Steps to Update an Existing Vector Store</b>
#     <li><b>Access the Existing Vector Store</b> We first ensure that an existing vector store is already initialized. </li>
#     <li><b>Use the update() API</b> Then we call the update() method on the vector store instance and provide the new argument(s) we want to modify, such as the search_algorithm.</li>
#         </ol>
# </p>.

# %%
updated_vs.update(search_algorithm="HNSW")
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs update started.
# Use the 'status()' api to check the status of the operation.

# %%
#updated_vs.status()
check_vs_status(updated_vs)
# Out:
# Current status: UPDATING. Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs' is READY!
#                         vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs  READY

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.4.2 Updating Data</b>
# <p style="font-size:16px;font-family:Arial"> We can add or delete data in a Vector Store.<br>
# <ol style="font-size:16px;font-family:Arial"><b>Steps to Update an Existing Vector Store</b>
#     <li><b>Access the Existing Vector Store</b> We first ensure that an existing vector store is already initialized. </li>
#     <li><b>Use the update() API</b> Then we call the update() method on the vector store instance and provide the new argument(s) we want to modify, such as the search_algorithm.</li>
#         </ol>
# </p>.

# %%
update_data = DataFrame.from_query("SELECT * FROM DEMO_Retail.Web_Comment where comment_id between 101 and 150")
update_data
# Out:
#             customer_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          comment_text                         comment_summary
# comment_id
# ...

# %%
updated_vs.update(object_names=update_data,
                  alter_operation="ADD",
                  update_style="MINOR")
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs update started.
# Use the 'status()' api to check the status of the operation.

# %%
#updated_vs.status()
check_vs_status(updated_vs)
# Out:
# Current status: UPDATING. Waiting 15 seconds...
# Current status: UPDATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs' is READY!
#                         vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs  READY

# %%
op = updated_vs.get_indexes_embeddings()
op
# Out:
#                 DataBaseName                       TableName  comment_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          comment_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
op.loc[op['comment_id'] >= 100]
# Out:
#                 DataBaseName                       TableName  comment_id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                comment_text  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                      
# ...

# %% [markdown]
# <p style="font-size:16px;font-family:Arial">We can see from above that new data has beed added in Vector Store.</p>

# %% [markdown]
# <p style="font-size:18px;font-family:Arial"><b>Delete contents from Vector Store.</b>

# %%
updated_vs.update(object_names=update_data,
                  alter_operation="DELETE",
                  update_style="MINOR")
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs update started.
# Use the 'status()' api to check the status of the operation.

# %%
#updated_vs.status()
check_vs_status(updated_vs)
# Out:
# Current status: UPDATING. Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs' is READY!
#                         vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs  READY

# %%
op2 = updated_vs.get_indexes_embeddings()

# %%
op2.loc[op['comment_id'] >= 100]
# Out:
# Empty DataFrame
# Columns: [DataBaseName, TableName, comment_id, comment_text, TD_TEMP_ID, VectorIndex, VectorIndex_normalized]
# Index: []

# %% [markdown]
# <p style="font-size:16px;font-family:Arial">Data has beed deleted from Vector Store.</p>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>6.5 Destroy the Vector Store</b>
# <p style="font-size:16px;font-family:Arial">destroy() method will destroy the vector store.

# %%
vs.destroy()
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(vs)
# Out:
# Vector Store does not exist or it is has been destroyed successfully.
# Vector Store 'dallas47_jn6hvh5icpnu97gw_vs' has been deleted. Exiting check.

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>7. File-Based Vector Store </b></p>
# <p style="font-size:16px;font-family:Arial"> File-based vector store can be created by passing file(s) /directory path(s) to the document_files parameter. Path(s) can also be passed as wildcards.<br>
# Currently only pdf files are supported as input. The files are processed internally, converted to chunks and stored into a database table. In case of file-based vector store, only one object_names should be specified that indicates the file content splits. key_columns is not supported for file-based vector stores.
#  <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>7.1 Creating a file based Vector Store </b></p>

# %% [markdown]
# <p style="font-size:16px;font-family:Arial">To create a vector store from a PDF document, follow these steps:
#            <br>1. Create an Instance of Vector Store : First, instantiate a new vector store where the PDF content will be stored. </li>
#         </ul>
# </p>

# %%
pdf_vs_name = env_vars.get("username")+'_sql_pdf_vs'
pdf_vs_name
# Out:
# 'dallas47_jn6hvh5icpnu97gw_sql_pdf_vs'

# %%
# ACTION: Specify a name for a new vector store.
pdf_vs = VectorStore(pdf_vs_name)

# %%
import os
files = [os.path.join(os.getcwd(), "SQL_Fundamentals.pdf")]

# %% [markdown]
# <p style="font-size:16px;font-family:Arial"> 2. Call the <b>create</b> Method <br>
# Using the vector store instance, call the create() method and pass the PDF document file(s) as the document_files argument to upload and vectorize the content.

# %%
pdf_vs.create(embeddings_model= 'amazon.titan-embed-text-v1',
              search_algorithm= 'VECTORDISTANCE',
              top_k= 10,
              object_names= ['sql_fundamentals'],
              data_columns= ['chunks'],
              vector_column= 'VectorIndex',
              chunk_size= 500,
              optimized_chunking=False,
              overwrite_object=True,
              document_files=files)
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_sql_pdf_vs creation started.
# Use the 'status()' api to check the status of the operation.

# %%
#pdf_vs.status()
check_vs_status(pdf_vs)
# Out:
# Current status: CREATING (PROCESSING DOCUMENTS 0.0 %). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_sql_pdf_vs' is READY!
#                                 vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_sql_pdf_vs  READY

# %%
vslist = VSManager.list()
vslist[ (vslist['database_name'] == env_vars.get("username"))]
# Out:
#                                 vs_name  store_type description              database_name vs_status permission
# 0  dallas47_jn6hvh5icpnu97gw_sql_pdf_vs  file-based        None  DALLAS47_JN6HVH5ICPNU97GW     READY      ADMIN

# %% [markdown]
# <p style="font-size:16px;font-family:Arial">Check the type of Vector Store</p>

# %%
pdf_vs.store_type
# Out:
# 'file-based'

# %% [markdown]
# <p style="font-size:16px;font-family:Arial">Get the Index Embeddings table</p>

# %%
df = pdf_vs.get_indexes_embeddings()
df
# Out:
#                 DataBaseName         TableName  TD_ID           TD_FILENAME                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chunks  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# ...

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>7.2  Asking a Question Based on Uploaded Document to the Vector Store</b>
# <p style="font-size:16px;font-family:Arial"> Once we have uploaded our PDF content into the vector store, we can ask specific questions based on the content stored in the vector store. The vector store will use its similarity search to find the most relevant information and provide a detailed response.<br>
# Steps to Ask a Question from the Vector Store
# <ol style="font-size:16px;font-family:Arial">
#     <li><b>Define the Question and Prompt</b> : Formulate the question we would like to ask and provide a prompt for context. In our case, the question is about searching for NULL and NOT NULL values in Teradata.</li>
#     <li><b>Use the ask Method</b> : Call the ask() method on the vector store instance, passing both the question and prompt. The vector store will then return a response based on the content of the uploaded document.</li></ol></p>

# %%
question= 'How to search for Nulls and Not Nulls together in Teradata with an example?'
prompt= 'Briefly explain, provide a syntax in educational tone.'
try:
    response = pdf_vs.ask(question=question, prompt=prompt)
except:
    setAuthToken()
    check_vs_status(pdf_vs)
    pdf_vs.get_details()
    response = pdf_vs.ask(question=question, prompt=prompt)

# %%
print(response)
# Out:
# To search for nulls and values that are not null together in the same SQL statement in Teradata, you need to use separate search conditions for nulls and non-null values. Here's the syntax and an example:
#
# Syntax:
# SELECT column1, column2, ...
# FROM table_name
# WHERE column1 IS NULL OR column1 <> NULL
#    OR column2 IS NOT NULL
#    AND other_conditions;
#
# Example:
# Suppose you have an "employee" table with columns "name", "department", and "job_title". To select the names of all employees who have a job title of 'Manager', 'Vice Pres', or null, you can use the following SQL statement:
#
# SELECT name
# FROM employee
# WHERE job_title IN ('Manager', 'Vice Pres')
#    OR job_title IS NULL;
#
# In this example, the search condition is divided into two parts:
#
# 1. `job_title IN ('Manager', 'Vice Pres')` - This part searches for employees with a job title of 'Manager' or 'Vice Pres'.
# 2. `OR job_title IS NULL` - This part searches for employees with a null job title.
#
# ...

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>7.3 Updating Data of an Existing Vector Store</b>
# <p style="font-size:16px;font-family:Arial"> You can <b>add</b> or <b>delete</b> data in a Vector Store.
# </p>

# %%
pdf_vs.update(document_files="LLM_handbook.pdf", alter_operation="ADD")
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_sql_pdf_vs update started.
# Use the 'status()' api to check the status of the operation.

# %%
#pdf_vs.status()
check_vs_status(pdf_vs)
# Out:
# Current status: CREATING (PROCESSING DOCUMENTS 0.0 %). Waiting 15 seconds...
# Current status: UPDATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_sql_pdf_vs' is READY!
#                                 vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_sql_pdf_vs  READY

# %%
df = pdf_vs.get_indexes_embeddings()

# %%
df.loc[df['TD_FILENAME'] == 'LLM_handbook.pdf']
# Out:
#                 DataBaseName                                                                  TableName  TD_ID       TD_FILENAME                                                                                                                                                                                                                                                                                                                                                                                                                                                                               chunks  TD_TEMP_ID                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
question= 'what are LLMs?'
prompt= 'Briefly explain, provide a syntax in educational tone.'
response = pdf_vs.ask(question=question, prompt=prompt)

# %%
print(response)
# Out:
# LLMs (Large Language Models) are large-scale, pre-trained, statistical language models based on neural networks. They are the result of decades of research and development in the field of language modeling, which can be categorized into four waves:
#
# 1. Statistical language models
# 2. Neural language models
# 3. Pre-trained language models
# 4. Large Language Models (LLMs)
#
# The key characteristics of LLMs are:
#
# Syntax:
# ```
# LLMs are large-scale, pre-trained, statistical language models based on neural networks. They are the result of decades of research and development in the field of language modeling, which can be categorized into four waves:
#
# 1. Statistical language models
# 2. Neural language models
# 3. Pre-trained language models
# 4. Large Language Models (LLMs)
# ```
#
# Explanation:
# ...

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>7.4 Destroy the Vector Store</b>
# <p style="font-size:16px;font-family:Arial">destroy() method will destroy the vector store.

# %%
pdf_vs.destroy()
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_sql_pdf_vs destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(pdf_vs)
# Out:
# Vector Store does not exist or it is has been destroyed successfully.
# Vector Store 'dallas47_jn6hvh5icpnu97gw_sql_pdf_vs' has been deleted. Exiting check.

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>8. Embedding based Vector Store </b></p>
# <p style="font-size:16px;font-family:Arial"> An embedding-based vector store can be created by supplying the user-generated embedded data to object_names. It is mandatory to set the is_embedded parameter to True if the input data is pre embedded.
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>8.1 Creating a new Embedding-Based Vector Store</b>
#     There are two ways in which users can get the embeddings :
# <ul style="font-size:16px;font-family:Arial">
#     <li> Users can use TextAnalayticsAI to generate embeddings.</li>
#     <li>Users can bring their own embedded data to vector store.</li>
#     </ul>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>8.1.1 Users can use TextAnalayticsAI to generate embeddings</b>

# %%
load_data('employee', 'employee_data')
data = DataFrame('employee_data')

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p style='font-size:16px;font-family:Arial'><i><b>Note:</b> For running the TextAnalyticsAI function we will need the AWS keys, if you dont have the keys you can skip this section.</i></p>
# </div>

# %%
user_conformation = input("Do you have AWS Access Key the embeddings? (yes/no): ")

if user_conformation.lower() == 'yes':
    # Set the environment variables related to the authorization arguments.
    os.environ['AWS_ACCESS_KEY_ID'] = getpass("Enter AWS Access Key ID: ")
    os.environ['AWS_SECRET_ACCESS_KEY'] = getpass("Enter AWS Secret Access Key: ")
    os.environ['AWS_DEFAULT_REGION'] = getpass("Enter AWS Default Region: ")
    
    print("creating embeddings using TextAnalyticsAI function ")
    llm_embedding = TeradataAI(api_type = "aws",
                  model_name = "amazon.titan-embed-text-v2:0")
    # Instantiate the TextAnalyticsAI class with the embedding model.
    obj_embeddings = TextAnalyticsAI(llm=llm_embedding)
    # Generate embeddings for the articles in the employee data.
    TAI_embeddings = obj_embeddings.embeddings(column="articles", data=data, accumulate='articles',output_format='VECTOR')
    
    print("embedding generation complete")
    #print(TAI_embeddings)
    
    print("creating vector store")
    emb_vs_name = env_vars.get("username")+'_TAI_emb'
    emb_vs_name
    
    # ACTION: Specify a name for a new vector store.
    emb_vs = VectorStore(name=emb_vs_name, log=True)
    
    emb_vs.create(object_names= TAI_embeddings,
           data_columns= ['Embedding'],
           vector_column = 'VectorIndex',
           is_embedded = True)
    
    #emb_vs.status()
    check_vs_status(emb_vs)
    print("type of vector store")
    print(emb_vs.store_type)

else:
    print("Skipping the section, please proceed further .")
# Out:
# Do you have AWS Access Key the embeddings? (yes/no):  yes
# Enter AWS Access Key ID:  ····················
# Enter AWS Secret Access Key:  ········································
# Enter AWS Default Region:  ·········
# creating embeddings using TextAnalyticsAI function
# embedding generation complete
# creating vector store
# Vector store dallas47_jn6hvh5icpnu97gw_TAI_emb creation started.
# Use the 'status()' api to check the status of the operation.
# Current status: CREATING (PREPARING INPUT). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_TAI_emb' is READY!
# type of vector store
# embedding-based

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>8.1.2 Creating embeddings using OpenAi</b>

# %%
#values are provided in the .env file
litellm_key = env_vars.get("litellm_key")
litellm_base_url = env_vars.get("litellm_base_url")

# %%
data = DataFrame('employee_data')
input_df = data.to_pandas().reset_index()

# %%
client = OpenAI(
    api_key=litellm_key,           # Your proxy API key
    base_url=litellm_base_url  # Your LiteLLM proxy URL
)

response = client.embeddings.create(
    #model="titan-embed-text-v2",
    model="openai/text-embedding-3-small",
    input=input_df.articles
)

# Extract embeddings
input_df["embedding"] = [item.embedding for item in response.data]

# converting raw embeddings to str for inserting in table
input_df["embedding_str"] = input_df["embedding"].astype(str)
input_df['embedding_str'] = input_df['embedding_str'].str.replace(r'[\[\]]', '', regex=True)

input_df = input_df.drop('embedding', axis=1)

# %%
input_df
# Out:
#   employee_id  employee_name  \
# 0           4  Michael Brown
# 1           5   Linda Taylor
# 2           2     Alex Smith
# 3           3  Emily Johnson
# 4           1     Parker Doe
#
#                                        employee_data  \
# 0  Michael Brown an Australian has a loan due on ...
# 1  Linda Taylor a German cleared all their loans ...
# 2  Alex Smith a Canadian has an outstanding loan ...
# 3  Emily Johnson from the UK cleared all their lo...
# 4  Parker Doe originally from Brazil has successf...
#
#                                             articles  \
# 0  The recent 2020 United States elections have s...
# 1  The 2019 Amazon rainforest wildfires were a se...
# 2  The 2020 Tokyo Olympics was postponed to 2021 ...
# 3  Renewable energy sources such as solar wind an...
# 4  Climate change poses significant challenges gl...
#
#                                              reviews  \
# 0  Both the food and the delivery service were to...
# ...

# %% [markdown]
# <p style='font-size:16px;font-family:Arial;'>Loading the embeddings in the database table.</p>

# %%
qry = ('''
CREATE MULTISET TABLE openai_emb 
     (
      employee_id VARCHAR(20) CHARACTER SET LATIN NOT CASESPECIFIC,
      employee_name VARCHAR(100) CHARACTER SET LATIN NOT CASESPECIFIC,
      employee_data VARCHAR(100) CHARACTER SET LATIN NOT CASESPECIFIC,
      articles VARCHAR(100) CHARACTER SET LATIN NOT CASESPECIFIC,
      reviews VARCHAR(100) CHARACTER SET LATIN NOT CASESPECIFIC,
      quotes VARCHAR(100) CHARACTER SET LATIN NOT CASESPECIFIC,
      embedding_str VARCHAR(10000) CHARACTER SET LATIN NOT CASESPECIFIC)
PRIMARY INDEX(employee_id) ;''')

try:
    execute_sql(qry)
     
except:
    db_drop_table('openai_emb')
    execute_sql(qry)

#copying embeddings into teradata table
copy_to_sql(df = input_df, table_name = 'openai_emb',if_exists = 'append')

# %%
openai_emb = DataFrame('openai_emb')

# %%
emb_openai_vs = env_vars.get("username")+'_openai_vs'
emb_openai_vs
# Out:
# 'dallas47_jn6hvh5icpnu97gw_openai_vs'

# %%
# ACTION: Specify a name for a new vector store.
emb_openai_vs = VectorStore(name=emb_openai_vs, log=True)

# %%
emb_openai_vs.create(object_names= openai_emb,
           key_columns= ['employee_id'],
           data_columns= ['embedding_str'],
           metadata_columns = ['employee_name', 'employee_data','quotes'],
           embedding_data_columns = 'articles',
           vector_column = 'VectorIndex',
           is_embedded = True)
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_openai_vs creation started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(emb_openai_vs)
# Out:
# Current status: CREATING (PREPARING INPUT). Waiting 15 seconds...
# ---------------------------------------------------------------------------
# TeradataMlException                       Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 check_vs_status(emb_openai_vs)
#
# Cell In[4], line 19, in check_vs_status(vs, poll_interval, timeout)
#      16 start_time = time.time()
#      18 while True:
# ---> 19     df = vs.status()
#      21     # If no dataframe returned OR it's empty ⇒ the vector store no longer exists
#      22     if df is None or df.empty:
#
# File ~/.local/lib/python3.11/site-packages/teradatagenai/telemetry_utils/queryband.py:58, in collect_queryband.<locals>.outer_wrapper.<locals>.inner_wrapper(*func_args, **func_kwargs)
#      53 @wraps(func)
#      54 def inner_wrapper(*func_args, **func_kwargs):
#      55     # Pass the required argument 'session_queryband' along with other
# ...

# %%
emb_openai_vs.store_type
# Out:
# 'embedding-based'

# %%
emb_openai_vs.get_details()
# Out:
#                                vs_name       store_type description              database_name sample_size embeddings_model  embeddings_dims metric search_algorithm top_k search_threshold search_numcluster ef_search initial_centroids_method train_numcluster max_iternum stop_threshold  seed num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects document_objects   document_columns document_indexes prompt vector_column chat_completion_model rerank_weight relevance_search_threshold relevance_top_k chat_completion_max_tokens      vs_status base_url_embeddings base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names                                                                                                              vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings last_updated                                         
# ...

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>8.1.3 Users can bring their own embedded data to vector store</b>

# %%
load_data('amazon', 'amazon_reviews_embedded')
amazon_reviews_embedded = DataFrame('amazon_reviews_embedded')
amazon_reviews_embedded
# Out:
#                               aid  rating                                         prodsummary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
emb_data_vs = env_vars.get("username")+'_vs_emb'
emb_data_vs
# Out:
# 'dallas47_jn6hvh5icpnu97gw_vs_emb'

# %%
# ACTION: Specify a name for a new vector store.
emb_data_vs = VectorStore(name=emb_data_vs, log=True)

# %%
emb_data_vs.create(object_names= amazon_reviews_embedded,
           key_columns= ['rev_id', 'aid'],
           data_columns= ['embedding'],
           metadata_columns = ['prodsummary', 'rating'],
           embedding_data_columns = 'rev_text',
           vector_column = 'VectorIndex',
           is_embedded = True)
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs_emb creation started.
# Use the 'status()' api to check the status of the operation.

# %%
# Check the status of the vector store.
#emb_data_vs.status()
check_vs_status(emb_data_vs)
# Out:
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs_emb' is READY!
#                             vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs_emb  READY

# %%
emb_data_vs.get_details()
# Out:
#                             vs_name       store_type description              database_name  sample_size              embeddings_model  embeddings_dims  metric search_algorithm  top_k search_threshold search_numcluster ef_search initial_centroids_method train_numcluster max_iternum stop_threshold  seed num_init num_layer ef_construction num_connPerNode maxNum_connPerNode apply_heuristics include_patterns exclude_patterns include_objects exclude_objects                                           document_objects document_columns   document_indexes prompt vector_column                   chat_completion_model  rerank_weight relevance_search_threshold  relevance_top_k  chat_completion_max_tokens vs_status base_url_embeddings base_url_completions doc_ingest_host base_url_ranking ranking_model doc_ingest_port file_names vs_error_message optimized_chunking nv_ingestor is_normalized file_names_mappings                      last_updated                                                          
# ...

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>8.2 Similarity search when vector is supplied in input</b>

# %%
op = emb_data_vs.similarity_search_by_vector(question='-0.06944,0.080352,0.045963,0.006985,-0.000496,-0.025461,0.045302,-0.028107,0.031248,0.00077,-0.028107,0.016781,-0.023147,-0.068779,-0.07936,-0.030091,0.027611,-0.047616,-0.025461,0.029595,0.024635,-0.025461,-0.029926,0.046294,-0.065142,-0.019013,0.037366,-0.008019,0.065472,-0.054891,-0.009507,0.022816,0.009341,-0.041995,0.022651,0.028603,0.059851,0.047286,0.014467,0.002118,0.016616,-0.009383,-0.001643,0.015624,0.002831,0.005539,0.0248,0.018517,-0.007109,-0.013723,0.029926,0.006903,-0.011325,0.075723,0.009259,0.043648,0.035382,-0.02943,0.023147,-0.036208,-0.017856,-0.032736,0.019013,-0.037035,0.022155,-0.036704,-0.003596,-0.012069,0.021824,0.013805,-0.062827,0.016616,0.008928,-0.04431,-0.019592,-0.002397,0.048608,-0.00341,-0.024139,0.006985,-0.005001,0.002542,0.001777,0.002025,0.026123,0.055883,0.015707,0.014963,0.024304,0.001157,0.042326,-0.004753,-0.044971,0.005373,0.074731,0.002728,-0.028934,0.032736,0.011573,-0.012483,-0.040507,0.040507,0.001736,-0.036539,0.028438,0.053568,0.048278,0.082006,0.011739,0.064811,0.034059,0.062496,-0.013309,-0.065803,0.05456,-0.046624,0.009837,0.005539,-0.015376,0.016947,-0.065472,0.015128,-0.018352,0.062496,0.005539,-0.036208,0.001715,-0.023643,-0.000646,-0.047616,0.035712,0.011325,0.013723,0.07936,-0.010375,-0.021989,0.030091,0.013475,0.038358,-0.034059,-0.068118,0.013475,0.036043,-0.017029,-0.028107,-0.002687,0.00992,-0.001963,-0.04431,-0.009052,-0.088619,-0.016699,-0.027611,0.006861,-0.046624,-0.047286,-0.00744,0.00187,0.004133,-0.008225,-0.018352,0.001405,-0.033067,-0.000858,-0.001705,-0.028107,-0.01984,-0.010251,-0.013888,0.002005,0.046294,0.025461,-0.021163,-0.044971,-0.034886,-0.010747,-0.024304,0.006035,-0.019344,0.001126,-0.018352,0.015045,0.02728,-0.020749,0.000527,0.007523,-0.019427,-0.010499,0.038027,-0.027445,-0.018931,0.021659,0.037035,-0.054891,0.005539,-0.051254,-0.003968,0.011739,-0.041003,0.017029,0.011408,-0.007564,0.051584,0.010499,-0.001788,0.001075,0.032902,0.020997,-0.015624,0.020749,0.038027,0.020749,-0.046955,-0.012069,0.050262,-0.048608,0.028934,-0.074731,0.025461,-0.056875,0.013971,-0.018104,-0.054891,-0.001343,0.013888,0.019427,0.038688,0.057536,-0.011077,0.082006,0.024139,0.033894,0.037366,0.02943,-0.026619,-0.032075,-0.040672,-0.021493,0.001891,-0.013805,-0.005415,0.016451,-0.001963,0.003617,0.003286,0.016533,-0.071424,-0.042987,0.023808,-0.071424,0.008101,0.018683,-0.037862,-0.036208,0.037366,0.006531,0.016203,0.031083,-0.006448,0.008349,-0.045963,0.012648,0.032571,-0.007688,-0.043318,0.025792,0.000889,0.015211,-0.018765,-0.013061,0.040176,-0.035712,0.02232,-0.011243,-0.030091,-0.04431,-0.059851,0.011904,-0.013888,0.060182,0.04431,-0.017691,-0.008721,-0.000509,-0.010375,-0.033563,-0.03968,-0.018104,0.010044,0.020005,-0.024304,0.046955,0.001447,0.017029,-0.011739,-0.042326,0.014219,0.036539,0.028768,-0.008597,-0.005745,0.00868,-0.040011,-0.036704,0.007192,-0.042326,0.061504,0.015789,-0.023147,-0.005373,-0.039184,0.014053,-0.000713,0.003038,-0.009135,0.012483,-0.028107,-0.014549,-0.060512,0.048939,-0.069771,0.000607,0.012648,0.017195,0.018683,0.008804,0.030918,-0.038027,-0.00279,0.027611,0.007068,0.031579,0.029099,-0.004898,0.04431,-0.056875,-0.034886,-0.008267,-0.005911,-0.018517,0.009837,0.0248,0.023147,0.04464,-0.017029,0.016285,-0.0124,0.030091,0.012069,-0.013392,-0.000163,0.038027,0.008721,0.005621,-0.015707,-0.062827,-0.060182,0.026453,0.028107,0.015293,0.014219,-0.047616,0.006076,0.032571,-0.047616,-0.027115,0.046294,-0.006985,-0.027445,0.005167,-0.03191,-0.009383,-0.022981,0.025957,0.001974,0.010127,-0.038854,-0.020253,-0.046955,0.011408,-0.047616,0.006985,-0.058198,0.021989,-0.001674,0.011987,-0.006861,0.043979,0.011408,-0.007853,-0.03439,0.025957,0.013557,0.02976,0.008721,-0.012731,-0.054891,-0.058859,-0.004857,-0.005291,-0.008349,0.007895,-0.020997,0.038854,-0.008349,0.016616,-0.060843,0.040507,0.021824,0.002253,-0.012565,0.006324,0.040011,0.073078,-0.02943,0.014384,-0.031083,0.010995,-0.025131,0.009011,0.015707,0.060182,0.05919,0.017443,0.033563,-0.039184,0.051915,0.040011,-0.021493,0.036208,-0.030091,0.022981,0.056214,0.070432,-0.004071,-0.019013,-0.000377,0.014549,-0.044971,-0.019592,0.013392,0.008308,-0.002563,-0.032902,0.001405,0.013061,0.013061,-0.018269,0.022155,-0.038358,0.048608,0.078699,-0.023477,-0.031744,-0.008308,-0.042326,0.015045,0.072086,0.010333,-0.058859,0.001467,0.040011,-0.011243,0.045302,-0.028107,-0.012731,0.056875,-0.003265,-0.015541,0.007771,0.030091,-0.057206,-0.014632,0.020667,-0.041995,0.030752,0.014053,-0.038027,0.013061,0.012565,0.002366,0.049931,-0.02976,0.015045,0.007564,-0.015459,0.04464,0.005745,-0.029099,-0.013557,-0.005869,0.024304,-0.026784,0.007688,-0.073078,-0.046624,-0.00155,0.000107,0.009259,-0.022155,0.015376,0.003885,-0.080352,0.011408,-0.020749,-0.01612,0.011573,0.055222,0.013557,0.00155,0.000961,0.012069,0.002955,-0.014797,-0.041499,-0.018683,-0.035216,-0.043648,0.103169,-0.007688,-0.024965,-0.005911,-0.012483,-0.024635,0.033398,-0.014053,0.015872,0.013723,0.000314,0.033728,-0.020088,0.016947,-0.061504,-0.046624,0.07407,-0.009383,0.001602,-0.040507,-0.071424,0.000899,-0.010127,-0.024635,-0.005828,0.03968,0.021989,-0.001684,-0.028272,0.035216,-0.046294,-0.002614,-0.027941,-0.020667,0.016368,0.001157,0.005952,0.007523,0.017195,0.038027,0.004402,-0.004505,0.057536,0.042987,-0.028438,-0.033728,0.010747,-0.004629,0.026123,0.014219,-0.003245,-0.028107,0.060182,0.03439,0.016947,-3.8e-05,-0.005229,0.013144,0.042987,0.007275,-0.028768,-0.000734,-0.002687,0.030091,-0.01488,-0.027611,-0.012813,-0.015707,-0.023477,0.001509,0.028934,-0.015376,0.000372,0.005456,-0.041334,0.032571,-0.030422,0.009837,-0.054891,-0.016368,0.005497,0.03224,-0.012648,-0.038027,0.002056,-0.035216,-0.017029,-0.046955,0.035712,0.019013,-0.023477,-0.033894,0.005787,0.021493,0.011491,0.0248,0.026288,0.035712,-0.031248,0.012896,0.025627,0.046955,-0.047947,-0.076054,0.054891,-0.045632,5.1e-05,0.006613,-0.003761,-0.021659,-0.038854,0.031414,-0.028438,-0.013061,-0.05952,-0.01612,-0.018021,0.002997,0.003038,-0.047286,-0.015376,-0.021163,-0.016285,-0.002893,-0.011656,0.021659,0.024469,0.01612,0.09391,0.030918,0.009672,-0.021659,0.056214,-0.04431,0.021824,-0.011325,0.014384,-0.0248,0.043318,0.005249,-0.010664,0.030422,0.060182,-0.006903,-0.038854,-0.000153,0.007936,-0.032075,0.008473,-0.008473,0.021989,0.020749,0.020667,-0.016037,-0.016781,-0.004898,0.00744,0.020088,0.026784,0.020088,0.005022,-0.036208,-0.00186,-0.006861,0.005663,-0.014797,0.052907,-0.013723,0.04431,-0.001963,0.043318,-0.006365,0.002501,-0.011987,0.024304,0.010375,-0.017608,-0.033728,0.018517,0.00092,0.002687,-0.004629,-0.002015,0.041499,0.010664,0.048278,0.011573,-0.065142,0.029926,0.018352,0.007812,-0.03439,0.019592,0.026784,0.0496,-0.007688,0.006531,-0.001457,0.0124,0.016285,0.004505,-0.014963,-0.030091,-0.07936,0.001602,0.013144,-0.026288,-0.00062,0.000297,-0.001225,-0.011408,-0.0124,0.007027,-0.004009,-0.003968,0.029926,0.007895,0.033563,0.013061,0.006696,0.009507,-0.009796,0.05456,-0.048608,0.006076,0.032902,-0.020667,-0.002914,0.000925,0.05423,0.011077,-0.036208,0.008845,-0.030752,-0.05919,0.04431,0.037035,-0.009011,-0.020749,0.007647,0.033894,-0.052246,0.037862,0.041334,0.019344,-0.075723,-0.004795,-0.000889,-0.011325,-0.006944,0.036539,0.021163,0.015211,0.075723,-0.02976,-0.022816,-0.027445,-0.014797,0.068779,0.03472,0.107137,-0.03439,-0.001059,-0.013723,-0.023973,0.046955,-0.000853,-0.05456,-0.025957,-0.044971,-0.0496,0.048608,-0.014219,0.010499,-0.015376,-0.026784,-0.023477,0.042326,0.018104,0.018517,0.046955,0.018269,-0.02976,0.028934,-0.031579,-0.009713,0.010747,-0.023477,0.062496,0.046624,-0.042987,0.070763,0.004898,-1.1e-05,-0.03439,0.001953,0.001788,0.016781,-0.02232,0.028768,0.044971,0.028768,-0.00868,-0.037035,0.001498,-0.02728,-0.006985,0.011656,-0.013557,0.010664,-0.052576,-0.026619,0.002645,0.021328,-0.009383,0.007688,-0.026619,0.045963,-0.037862,-0.024139,0.06448,-0.060843,0.045302,0.070432,-0.013805,0.023973,-0.066795,0.095233,0.006159,0.009011,0.04183,-0.065142,0.026123,-0.007068,-0.02232,0.016947,0.038027,0.014384,0.015211,-0.050262,0.038358,-0.008804,0.021659,0.03439,0.023973,0.00248,0.023477,0.002366,-0.003451,0.002459,0.095894,0.004898,-0.001059,0.034886,0.006944,0.005993,0.05952,-0.021328,0.005373,-0.037035,-0.001297,0.051584,-0.0496,0.028934,0.018021,0.042987,0.003989,-0.03191,0.043318,0.036043,0.017029,0.009383,-0.001405,-0.084651,-0.003079,-0.011325,0.004175,0.01488,-0.012483,0.041995,-0.018765,-0.011243,-0.001591,0.024635,0.01984,0.006241,0.009383,0.003761,0.04927,0.011325,0.020667,-0.022816,-0.0496,-0.014715,0.028107,0.001225,0.012152,-0.013888,-0.058198,0.03935,0.024635,0.072416,-0.048939,0.020336,0.015128,0.004237,-0.008597,0.031414,-0.040507,-0.018765,-0.011325,0.056544,0.029595,0.001044,-0.015789,0.05423,0.032902,-0.0031,-0.010333,-0.022816,-0.025461,0.006241,-0.000273,-0.011987,-0.038027,-0.061174,0.003865,-0.02943,0.012731,0.06448,-0.040507,0.011408,0.047947,0.015128,-0.011739,0.021659,0.012069,0.020997,-0.011325,0.003637,0.014549,-0.015045,0.011077,-0.008184,0.005869,-0.037862,-0.000806,0.018517,0.028603,0.00992,-0.000245,0.005249,-0.005084,-0.000692,-0.00094,-0.019179,-0.000625,-0.009135,-0.002811,-0.018104,-0.060182,-0.0248,0.000605,0.017856,0.005022,-0.017443,0.014384,-0.010127,-0.007523,0.041003,0.033563,-0.037366,0.003927,0.00806,-0.048278,0.016533,-0.021989,-0.009176,0.019013,0.022485,-0.005332,-0.026123,-0.014632,0.023973,-0.022155,0.016947,-0.020088,0.008184,-0.021493,0.027941,0.073408,0.03224,0.018104,-0.01736,-0.007275,0.031414,-0.007357,-0.04464,0.045302,-0.010664,-0.016203,0.010375,0.004567,0.0124,-0.009011,-0.010457')

# %%
op.similar_objects
# Out:
#       score               DataBaseName                TableName          rev_id         aid                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 rev_text                                              prodsummary rating                                                                                                                                                                                                                                                                                                                                                                  
# ...

# %%
op.similar_objects_count
# Out:
# 10

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>8.3 Destroy the Vector Store</b>
# <p style="font-size:16px;font-family:Arial">destroy() method will destroy the vector store.

# %%
emb_data_vs.destroy()
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs_emb destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(emb_data_vs)
# Out:
# Vector Store does not exist or it is has been destroyed successfully.
# Vector Store 'dallas47_jn6hvh5icpnu97gw_vs_emb' has been deleted. Exiting check.

# %%
emb_openai_vs.destroy()
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_openai_vs destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(emb_openai_vs)
# Out:
# Current status: DESTROYING. Waiting 15 seconds...
# Vector Store does not exist or it is has been destroyed successfully.
# Vector Store 'dallas47_jn6hvh5icpnu97gw_openai_vs' has been deleted. Exiting check.

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>9. Metadata based Vector Store </b></p>
# <p style="font-size:16px;font-family:Arial">Metadata-based vector store contains metadata information about tables such as the table and column description. The description is populated using an LLM via prompt and optionally samples from table contents and other tables in the vector store are used to generate it.
# </p>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>9.1  Creating Metadata based Vector Store </b>
# <p style="font-size:16px;font-family:Arial">Metadata-based vector store can be formed in two ways:<br>
#     <ol style="font-size:16px;font-family:Arial">
#         <li>Specify the table names in include_objects parameter which the user wants to include to create Vector Store and if the user wants to exclude specific set of tables they can specify the same in exclude_objects parameter.</li>
#         <li>Specify the patterns in include_patterns and exclude_patterns parameter.</li>
# </ol>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>9.1.1  Creating Metadata based Vector Store using tablenames</b>

# %%
vs_meta_name = env_vars.get("username")+'_vs_meta'
vs_meta_name
# Out:
# 'dallas47_jn6hvh5icpnu97gw_vs_meta'

# %%
vs_meta = VectorStore(name=vs_meta_name)

# %%
db = env_vars.get("username")

# %%
vs_meta.create(embeddings_model= 'amazon.titan-embed-text-v1',
               search_algorithm= 'VECTORDISTANCE',
               top_k= 10,
               target_database = db,
               include_objects = ['employee_data'])
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs_meta creation started.
# Use the 'status()' api to check the status of the operation.

# %%
#vs_meta.status()
check_vs_status(vs_meta)
# Out:
# Current status: CREATING (GENERATING OBJECT DESCRIPTIONS). Waiting 15 seconds...
# Current status: CREATING (GENERATING COLUMN DESCRIPTIONS). Waiting 15 seconds...
# Current status: CREATING (GENERATING EMBEDDINGS). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs_meta' is READY!
#                              vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs_meta  READY

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>9.1.2  Creating Metadata based Vector Store using patterns</b>

# %%
# This pattern will fetch all tables/views
ptn_name = username+'_employee_data'

try:
    ptn2 = VSPattern(name=ptn_name)
    ptn2.create(pattern_string = '%employee%')
except:
    print(f"{ptn_name} already exists!")
# Out:
# dallas47_jn6hvh5icpnu97gw_employee_data already exists!

# %%
vs_meta_name2 = env_vars.get("username")+'_vs_meta2'
vs_meta_name2
# Out:
# 'dallas47_jn6hvh5icpnu97gw_vs_meta2'

# %%
vs_meta2 = VectorStore(name=vs_meta_name2)

# %%
# Metabased vector consumes patterns
vs_meta2.create(embeddings_model= 'amazon.titan-embed-text-v1',
               search_algorithm= 'VECTORDISTANCE',
               top_k= 10,
               include_patterns = [ptn2])
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs_meta2 creation started.
# Use the 'status()' api to check the status of the operation.

# %%
#vs_meta2.status()
check_vs_status(vs_meta2)
# Out:
# Current status: CREATING (GENERATING OBJECT DESCRIPTIONS). Waiting 15 seconds...
# Current status: CREATING (GENERATING COLUMN DESCRIPTIONS). Waiting 15 seconds...
# The Vector Store 'dallas47_jn6hvh5icpnu97gw_vs_meta2' is READY!
#                               vs_name status
# 0  dallas47_jn6hvh5icpnu97gw_vs_meta2  READY

# %%
vs_meta2.store_type
# Out:
# 'metadata-based'

# %% [markdown]
# <p style="font-size:16px;font-family:Arial"><b><i>The Metabased Vector Store does not currently support prepare_response() and ask() APIs. Only similarity_search is supported</b>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>9.2 Destroy the Vector Store</b>
# <p style="font-size:16px;font-family:Arial">destroy() method will destroy the vector store.

# %%
vs_meta.destroy()
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs_meta destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(vs_meta)
# Out:
# Current status: DESTROYING. Waiting 15 seconds...
# Vector Store does not exist or it is has been destroyed successfully.
# Vector Store 'dallas47_jn6hvh5icpnu97gw_vs_meta' has been deleted. Exiting check.

# %%
vs_meta2.destroy()
# Out:
# Vector store dallas47_jn6hvh5icpnu97gw_vs_meta2 destroy started.
# Use the 'status()' api to check the status of the operation.

# %%
check_vs_status(vs_meta2)
# Out:
# Current status: DESTROYING. Waiting 15 seconds...
# Vector Store does not exist or it is has been destroyed successfully.
# Vector Store 'dallas47_jn6hvh5icpnu97gw_vs_meta2' has been deleted. Exiting check.

# %% [markdown]
# <hr style="height:2px;border:none;">
# <p style="font-size:20px;font-family:Arial"><b>10. Access Management in Vector Store </b></p>
# <p style="font-size:16px;font-family:Arial">We can manage both <b>admin</b> and <b>user</b> permissions for users in our vector store. This section shows how to <b>grant</b> and <b>revoke</b> these permissions to control access effectively.<br>
#     <i>Note</i> Only admin user can view the permissions or grant/revoke user/admin access to Vector Store
# </p>

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>10.1  Listing User Permissions in the Vector Store </b>
# <p style="font-size:16px;font-family:Arial"> To view the permissions currently assigned to users in the vector store, we can use the <b>list_user_permissions()</b> method. This will display a list of all users and the respective access rights they have on the Vector Store.<br>
#     <i>For the below commands we'll need a separate userid.</i></p>

# %%
#vs.list_user_permissions()

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>10.2  Granting USER Permission</b>
# <p style="font-size:16px;font-family:Arial">We can grant or revoke <b>USER </b> permission for specific users to control their access level to the vector store. You'll need to know another database username to substitute before attempting to execute the next cell.</p>

# %%
#updated_vs.grant.user('<any username>')

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>10.3 Revoke USER Permission</b>
# <p style="font-size:16px;font-family:Arial">Use the revoke.user() method to remove <b>USER </b> permission for from user.  You'll need to know another database username to substitute before attempting to execute the next cell.</p>

# %%
#updated_vs.revoke.user('<any username>')

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>10.4  Granting ADMIN Permission</b>
# <p style="font-size:16px;font-family:Arial">We can grant or revoke<b>ADMIN </b> permission for specific users to control their access level to the vector store. You'll need to know another database username to substitute before attempting to execute the next cell.</p>

# %%
#updated_vs.grant.admin('<any username>')

# %% [markdown]
# <hr style="height:1px;border:none;">
# <p style="font-size:18px;font-family:Arial"><b>10.5 Revoke ADMIN Permission</b>
# <p style="font-size:16px;font-family:Arial">Use the revoke.admin() method to remove<b>ADMIN </b> permission from user. You'll need to know another database username to substitute before attempting to execute the next cells.</p>

# %%
#updated_vs.revoke.admin('<any username>')

# %%
#updated_vs.list_user_permissions()

# %% [markdown]
# <hr style='height:2px;border:none;'>
# <b style = 'font-size:20px;font-family:Arial'>11. Cleanup</b>
# <p style = 'font-size:18px;font-family:Arial'><b>11.1 Destroying the Vector Store </b></p>
# <p style = 'font-size:16px;font-family:Arial'>When a vector store is no longer needed, we can permanently delete it to free up resources. The destroy operation removes the vector store and all associated data.<br>
# <ol style = 'font-size:16px;font-family:Arial'> Important Considerations
#     <li>Irreversible Action: Once a vector store is destroyed, it cannot be recovered.</li>
#     <li>If you have granted permissions to another database user, you will need to uncomment the <code>updated_vs</code> statements and not execute the <code>vs</code> statements.
#     <li>Does Not Remove Connection: Destroying a vector store only deletes the vector store—it does not remove the underlying database connection. The instance remains active and can be used to create a new vector store.
#     </li>

# %%
# Get the list
vslist = VSManager.list()

if vslist is None:
    print("VS list is None")
else:
    filtered = vslist[vslist['database_name'] == username]
    if filtered.shape[0] == 0:
        print(f"There are currently no Vector Stores for {username} to delete.")
        no_of_vs = 0
    else:
        no_of_vs = filtered.shape[0]
        print(f"Found {filtered.shape[0]} entries for {username}.")
        ipd.display(vslist[ (vslist['database_name'] == username)])
        ipd.display(type(vslist[ (vslist['database_name'] == username)]))
        pdf = filtered.to_pandas()
        vs_names = pdf["vs_name"].tolist() if not pdf.empty else []

        for vs_name in vs_names:
            try:
                print(f"Destroying {vs_name}...")
                vs = VectorStore(name=vs_name, log=True)
                vs.destroy()
                check_vs_status(vs)
                print(f"Destroyed {vs_name}\n")
            except Exception as e:
                print(f"Failed to destroy {vs_name}: {e}\n")
        print('Finished deleting Vector Stores!')
# Out:
# Found 1 entries for dallas47_jn6hvh5icpnu97gw.
#                              vs_name       store_type description              database_name vs_status permission
# 0  dallas47_jn6hvh5icpnu97gw_TAI_emb  embedding-based        None  DALLAS47_JN6HVH5ICPNU97GW     READY      ADMIN
# teradataml.dataframe.dataframe.DataFrame
# Destroying dallas47_jn6hvh5icpnu97gw_TAI_emb...
# Vector store dallas47_jn6hvh5icpnu97gw_TAI_emb is initialized.
# Failed to destroy dallas47_jn6hvh5icpnu97gw_TAI_emb: [Teradata][teradataml](TDML_2412) Failed to execute get_details. Response Code: 400, Message:The UserId, Password or Account is invalid.
#
# Finished deleting Vector Stores!

# %%
db_drop_table(table_name='employee_data')
# Out:
# True

# %%
db_drop_table(table_name='openai_emb')
# Out:
# True

# %%
db_drop_table(table_name='amazon_reviews_embedded')
# Out:
# True

# %% [markdown]
# <p style = 'font-size:16px;font-family:Arial'><b>Deleting the pattern </b></p>

# %%
ptn_name = username+'_employee_data'

# %%
try:
    ptn_name.delete()
except:
    pass

# %% [markdown]
# <hr style='height:1px;border:none;'>
#
# <p style = 'font-size:18px;font-family:Arial'> <b>11.2 Disconnect from the session</b></p>
# <p style = 'font-size:16px;font-family:Arial'>Use the VSManager.disconnect() method to remove Disconnect from the session.</p>

# %%
VSManager.disconnect()

# %%
# --------------------------------------------------
# Get teradataml context (already created earlier)
# --------------------------------------------------
ctx = get_context()

# --------------------------------------------------
# Find Vector Store sessions for this user
# --------------------------------------------------

sql_find_sessions = f"""
    SELECT
        SessionNo
    FROM DBC.SessionInfoV
    WHERE UserName = '{username}'
      AND ClientSystemUserId = 'datainsights'
"""

cur = execute_sql(sql_find_sessions)
sessions = cur.fetchall()
cur.close()

if not sessions:
    print("✅ No lingering Vector Store sessions found.")
else:
    print(f"⚠ Found {len(sessions)} Vector Store session(s).")

# --------------------------------------------------
# Abort + log off each session
# --------------------------------------------------
sql_abort_template = """
    SELECT SYSLIB.AbortSessions(
        -1,         -- all hosts
        NULL,       -- user already filtered
        {session_no},
        'Y',        -- logoff
        'Y'         -- override
    )
"""

for (session_no,) in sessions:
    print(f"🔴 Aborting Vector Store session SessionNo={session_no}")

    sql_abort = sql_abort_template.format(
        session_no=session_no
    )

    cur = execute_sql(sql_abort)
    aborted_count = cur.fetchone()[0]
    cur.close()

    print(f"   → Sessions aborted: {aborted_count}")

print("✅ Vector Store sessions cleanup complete.")
# Out:
# ⚠ Found 17 Vector Store session(s).
# 🔴 Aborting Vector Store session SessionNo=1437375
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1436769
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437440
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437062
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437073
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437225
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1435850
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437451
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437227
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437789
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437493
#    → Sessions aborted: 1
# 🔴 Aborting Vector Store session SessionNo=1437776
#    → Sessions aborted: 1
# ...

# %%
remove_context()
# Out:
# True

# %% [markdown]
# <footer style="padding-bottom:35px; border-bottom:3px solid #91A0Ab">
#     <div style="float:left;margin-top:14px">ClearScape Analytics™</div>
#     <div style="float:right;">
#         <div style="float:left; margin-top:14px">
#             Copyright © Teradata Corporation - 2025,2026. All Rights Reserved
#         </div>
#     </div>
# </footer>
